# %% [markdown]
# Author:
#
#         KIM, JeongYoong, jeongyoong@ccnets.org
#
#     COPYRIGHT (c) 2024. CCNets. All Rights reserved.

# %% [markdown]
# <p align="center">
#   <img src="https://storage.googleapis.com/kaggle-datasets-images/4956778/8344638/a2a6aa289fce8461958dc287f1dab799/dataset-cover.jpg?t=2024-05-07-09-36-53" alt="IMG">
# </p>

# %% [markdown]
# <h1 style = 'font-family: Times New Roman'> <b>|</b><i> 1. Content</i></h1>
#
# <br>
#
# > <h4 style = 'font-family: Times New Roman'>
# This dataset explores how weather conditions impact renewable energy generation. <br><br>Spanning from January 1, 2017, to August 31, 2022, the dataset provides climate data such as temperature, pressure, wind speed, and sunlight duration at 15-minute intervals. <br><br>By incorporating variables like GHI and SunlightTime, it enables the prediction of solar energy production.
#
#
# - DataSource: https://www.kaggle.com/datasets/pythonafroz/renewable-power-generation-and-weather-conditions/data
#
# <hr>
#
# CCNet result: https://wandb.ai/ccnets/causal-learning
#
# <blockquote>
# R&sup2 score: <mark>0.90</mark>
#
# </blockquote>
#
# Benchmark: https://www.kaggle.com/datasets/pythonafroz/renewable-power-generation-and-weather-conditions/code?datasetId=4956778&sortBy=voteCount
# <blockquote>
# R&sup2 score:
#
# - RandomForest: 0.89
# - LSTM: 0.87
# - KNN: 0.80
# - XGBoost: 0.82
#
# </blockquote>
#
# <h1 style = 'font-family: Times New Roman'> <b>|</b><i> 2. About Dataset</i></h1>
#
# <br>
#
# <details>
#     <summary>More Columns Info</summary>
#     17 columns in the dataset, below is <u>description of main features</u>:
#
#     *  (1) Time: The timestamp of the recorded data in the format of YYYY-MM-DD HH:MM:SS.
#
#     *  (2) Energy delta[Wh]: The difference in energy consumption in Watt-hours (Wh) from the previous timestamp to the current timestamp.
#
#     *  (3) GHI: Global Horizontal Irradiance in Watts per square meter (W/m²) measured by a pyranometer.
#
#     *  (4) temp: The temperature in degrees Celsius (°C) measured at the same height as the pyranometer.
#
#     *  (5) pressure: The atmospheric pressure in hectopascals (hPa) measured at the same height as the pyranometer.
#
#     *  (6) humidity: The relative humidity in percentage (%) measured at the same height as the pyranometer.
#
#     *  (7) wind_speed: The wind speed in meters per second (m/s) measured at the same height as the pyranometer.
#
#     *  (8) rain_1h: The amount of precipitation in millimeters (mm) measured over the past hour.
#
#     *  (9) snow_1h: The amount of snowfall in millimeters.
#
#     *  (10) clouds_all: The cloud situation.
# </details>
#
# <h1 style = 'font-family: Times New Roman'> <b>|</b><i> 3. Goal of the Notebook</i></h1>
#
# > <h4 style = 'font-family: Times New Roman'>
# Goal is to train and test model using GPT, Pytorch. <br><br>
#     The Target Column used here is <b>Energy delta[Wh]</b>
# </h4>

# %% [markdown]
# ***

# %% [markdown]
# <a id="1"></a>
# > <h1 style = 'font-family: Times New Roman'><b> <b style = 'color: #42c2f5'>1.</b> Import Necessary Libraries and Dataset</b></h1>

# %%
import os
import sys
import warnings
warnings.filterwarnings("ignore")

path_append = "../../"
sys.path.append(path_append)  # Go up one directory from where you are.

# %%
import pandas  as pd
df = pd.read_csv(path_append + '../data/Renewable Power Generation and weather Conditions/Renewable.csv')
df.head()
# Out:
#                   Time  Energy delta[Wh]  GHI  temp  pressure  humidity
# 0  2017-01-01 00:00:00                 0  0.0   1.6      1021       100  \
# 1  2017-01-01 00:15:00                 0  0.0   1.6      1021       100
# 2  2017-01-01 00:30:00                 0  0.0   1.6      1021       100
# 3  2017-01-01 00:45:00                 0  0.0   1.6      1021       100
# 4  2017-01-01 01:00:00                 0  0.0   1.7      1020       100
#
#    wind_speed  rain_1h  snow_1h  clouds_all  isSun  sunlightTime  dayLength
# 0         4.9      0.0      0.0         100      0             0        450  \
# 1         4.9      0.0      0.0         100      0             0        450
# 2         4.9      0.0      0.0         100      0             0        450
# 3         4.9      0.0      0.0         100      0             0        450
# 4         5.2      0.0      0.0         100      0             0        450
#
#    SunlightTime/daylength  weather_type  hour  month
# 0                     0.0             4     0      1
# 1                     0.0             4     0      1
# 2                     0.0             4     0      1
# 3                     0.0             4     0      1
# 4                     0.0             4     1      1

# %% [markdown]
# <a id="2"></a>
# > <h1 style = 'font-family: Times New Roman'><b> <b style = 'color: #4290f5'>2.</b> Modeling: Preprocess </b></h1>

# %%
from preprocessing.data_frame import auto_preprocess_dataframe
target_columns = ['Energy delta[Wh]']
df, description = auto_preprocess_dataframe(df, target_columns) 

description
# Out:
# Column 'isSun' has 2 unique values.
# Column 'weather_type' has 5 unique values.
#                              Min          Max          Mean          Std
# GHI                    -0.034188     4.863248  6.623192e-01     1.114787  \
# temp                   -3.969044     3.911737  2.426539e-17     1.202485
# pressure               -5.175015     4.285020  3.446264e-15     1.295453
# humidity               -2.818182     0.727273 -1.904288e-01     0.709294
# wind_speed             -3.937746    10.362254  1.191893e-15     1.821694
# rain_1h                -0.066035     8.023965  1.141051e-17     0.278913
# snow_1h                -0.007148     2.812852 -1.306702e-18     0.069710
# clouds_all             -1.801176     0.928938 -1.850958e-16     1.000003
# sunlightTime           -0.076923     2.538462  4.659515e-01     0.702313
# dayLength              -1.723228     1.565768 -7.633489e-17     1.124434
# SunlightTime/daylength -0.265187     0.734813  1.986007e-19     0.329023
# hour                   -1.916601     1.916967 -1.285849e-16     1.153718
# time_scaled            -1.000000     0.979167 -1.050814e-02     0.577294
# day_of_year_sin        -0.999991     0.999991  4.237514e-02     0.703366
# day_of_year_cos        -0.999963     1.000000 -3.146358e-02     0.708870
# month_sin              -1.000000     1.000000  2.745637e-02     0.706813
# month_cos              -1.000000     1.000000 -4.449917e-02     0.705469
# isSun                   0.000000     1.000000  5.199618e-01     0.499603
# weather_type_1          0.000000     1.000000  1.421718e-01     0.349227
# weather_type_2          0.000000     1.000000  1.800423e-01     0.384224
# weather_type_3          0.000000     1.000000  1.608936e-01     0.367434
# weather_type_4          0.000000     1.000000  3.710005e-01     0.483074
# weather_type_5          0.000000     1.000000  1.458918e-01     0.352999
# Energy delta[Wh]        0.000000  5020.000000  5.730082e+02  1044.824047
#
#                         Null Count    Scaled          Encoded
# GHI                              0    Robust             None
# temp                             0    Minmax             None
# pressure                         0    Minmax             None
# humidity                         0    Robust             None
# wind_speed                       0      None             None
# rain_1h                          0      None             None
# snow_1h                          0      None             None
# clouds_all                       0  Standard             None
# sunlightTime                     0    Robust             None
# dayLength                        0    Minmax             None
# SunlightTime/daylength           0      None             None
# hour                             0    Minmax             None
# time_scaled                      0      None  EncodedDateTime
# day_of_year_sin                  0      None  EncodedDateTime
# day_of_year_cos                  0      None  EncodedDateTime
# month_sin                        0      None  EncodedDateTime
# month_cos                        0      None  EncodedDateTime
# isSun                            0      None          One-hot
# weather_type_1                   0      None          One_hot
# weather_type_2                   0      None          One_hot
# weather_type_3                   0      None          One_hot
# weather_type_4                   0      None          One_hot
# weather_type_5                   0      None          One_hot
# Energy delta[Wh]                 0      None             None
# {'num_features': 23,
#  'num_classes': 1,
#  'encoded_columns': Index(['day_of_year_cos', 'day_of_year_sin', 'isSun', 'month_cos', 'month_sin',
#         'time_scaled', 'weather_type'],
#        dtype='object'),
#  'one_hot_encoded_columns': Index(['isSun', 'weather_type'], dtype='object'),
#  'encoded_datatime_columns': Index(['time_scaled', 'day_of_year_sin', 'day_of_year_cos', 'month_sin',
#         'month_cos'],
#        dtype='object'),
#  'scalers': {'GHI': 'robust',
#   'SunlightTime/daylength': 'none',
#   'clouds_all': 'standard',
#   'dayLength': 'minmax',
#   'hour': 'minmax',
#   'humidity': 'robust',
#   'pressure': 'minmax',
#   'rain_1h': 'none',
#   'snow_1h': 'none',
#   'sunlightTime': 'robust',
#   'temp': 'minmax',
#   'wind_speed': 'none'}}

# %%
import torch
from sklearn.model_selection import train_test_split
from preprocessing.dataset import TemplateDataset

max_seq_len = 32
min_seq_len = 16
train_df, test_df = train_test_split(df, test_size=0.2, shuffle=False)
# predict the next value in the sequence
train_df_x = train_df.iloc[:, :-1] # all columns except the last one
train_df_y = train_df.iloc[:, -1:] # only the last column

test_df_x = test_df.iloc[:, :-1] # all columns except the last one
test_df_y = test_df.iloc[:, -1:] # only the last column

print('train df shape: ', train_df.shape)
print('test df shape: ', test_df.shape)
trainset = TemplateDataset(train_df_x, train_df_y, min_seq_len = min_seq_len, max_seq_len=max_seq_len)
testset = TemplateDataset(test_df_x, test_df_y, min_seq_len = max_seq_len, max_seq_len=max_seq_len)
# Out:
# train df shape:  (157420, 24)
# test df shape:  (39356, 24)

# %% [markdown]
# <a id="3"></a>
# > <h1 style = 'font-family: Times New Roman'><b> <b style = 'color: #427bf5'>3.</b> Modeling: Causal Learning</b></h1>

# %% [markdown]
# ### **3-1. Initialize Causal Learning Class**
#
# <blockquote>
#
# Imports the `CausalLearning` class from the causal_learning module.
#
# It then sets the computation device to GPU if available, otherwise to CPU.
#
# Finally, it initializes an instance of the `CausalLearning` class with the machine learning configuration (`ml_config`), data configuration (`data_config`), the specified device, and
#
# additional options (`use_print` and `use_wandb`) for enabling print statements and logging with *Weights & Biases*.
#
# </blockquote>

# %%
from tools.config.data_config import DataConfig
from tools.config.ml_config import MLConfig
from causal_learning import CausalLearning

num_features = description['num_features']
num_classes = description['num_classes']
data_config = DataConfig(dataset_name = 'renewable-power-gen-prediction', task_type='regression', obs_shape=[num_features], label_size=num_classes)

#  Set training configuration from the AlgorithmConfig class, returning them as a Namespace object.
ml_config = MLConfig(model_name = 'gpt')
ml_config.training.error_function = 'mae'
ml_config.training.num_epoch = 20

# Set the device to GPU if available, else CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") 

# Initialize the CausalLearning class with the training configuration, data configuration, device, and use_print and use_wandb flags
causal_learning = CausalLearning(ml_config, data_config, device, use_print=True, use_wandb= True)
# Out:
# Trainer Name: causal_trainer
#
#
# ModelConfig Parameters:
#    d_model  dropout model_name  num_layers  use_seq_input
# 0      256     0.05        gpt           5           True
# TrainConfig Parameters:
#    batch_size error_function max_seq_len min_seq_len  num_epoch
# 0          64            mae        None        None         20
# OptimConfig Parameters:
#   clip_grad_range  decay_rate_100k  learning_rate  max_grad_norm
# 0            None             0.05          0.001            1.0  \
#
#   scheduler_type
# 0    exponential
# DataConfig Parameters:
#                      dataset_name   task_type obs_shape  label_size
# 0  renewable-power-gen-prediction  regression      [23]           1  \
#
#   explain_size show_image_indices
# 0         None               None

# %% [markdown]
# ### **3-2. Train Causal Learning**
#
# <blockquote>
#
# Initiates the training process for the causal learning using the `trainset` and `testset`.
#
# During the training, the model will be trained on the `trainset` and evaluated on the `testset`.
#
# The results of the training and evaluation will include various metrics.
#
# </blockquote>

# %%
causal_learning.train(trainset, testset)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: junhopark (ccnets). Use `wandb login --relogin` to force relogin
# wandb version 0.17.3 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>c:\Users\user\Projects\causal-learning\examples\time_series\wandb\run-20240625_151233-dghtdf7i</code>
# Syncing run <strong><a href='https://wandb.ai/ccnets/causal-learning/runs/dghtdf7i' target="_blank">renewable-power-gen-prediction : 24-06-25 15:12:31</a></strong> to <a href='https://wandb.ai/ccnets/causal-learning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ccnets/causal-learning' target="_blank">https://wandb.ai/ccnets/causal-learning</a>
#  View run at <a href='https://wandb.ai/ccnets/causal-learning/runs/dghtdf7i' target="_blank">https://wandb.ai/ccnets/causal-learning/runs/dghtdf7i</a>
# wandb: Adding directory to artifact (.\..\saved\renewable-power-gen-prediction\causal-learning)... Done. 0.0s
# Epochs:   0%|          | 0/20 [00:00<?, ?it/s]
# Iterations:   0%|          | 0/2459 [00:00<?, ?it/s]
# [0/20][100/2459][Time 12.01]
# Unified LR across all optimizers: 0.000996978883189373
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.1146	Gen: 0.4488	Rec: 0.4554	E: 0.1059	R: 0.1196	P: 0.7961
#
# mse: 1151697.0000
# mae: 479.4897
# rmse: 1073.1715
# r2: -0.2379
#
# =====================Eval Metrics========================
# mse: 1354437.0000
# mae: 548.5568
# rmse: 1163.8029
# r2: -0.2741
#
# [0/20][200/2459][Time 12.18]
# Unified LR across all optimizers: 0.0009939966705585644
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0445	Gen: 0.3053	Rec: 0.3114	E: 0.0378	R: 0.0488	P: 0.5754
#
# mse: 1181797.6250
# mae: 494.7833
# rmse: 1087.1051
# r2: -0.2446
#
# =====================Eval Metrics========================
# mse: 1197094.7500
# mae: 500.2005
# rmse: 1094.1183
# r2: -0.2481
#
# [0/20][300/2459][Time 11.71]
# Unified LR across all optimizers: 0.0009910233784699313
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0364	Gen: 0.2833	Rec: 0.2874	E: 0.0317	R: 0.0390	P: 0.5355
#
# mse: 1662106.6250
# mae: 622.6227
# rmse: 1289.2272
# r2: -0.2874
#
# =====================Eval Metrics========================
# mse: 1496898.0000
# mae: 589.3663
# rmse: 1223.4778
# r2: -0.2853
#
# [0/20][400/2459][Time 12.14]
# Unified LR across all optimizers: 0.0009880589802399075
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0348	Gen: 0.2694	Rec: 0.2727	E: 0.0320	R: 0.0374	P: 0.5086
#
# mse: 1464184.6250
# mae: 564.4009
# rmse: 1210.0349
# r2: -0.2564
#
# =====================Eval Metrics========================
# mse: 1368936.3750
# mae: 564.4601
# rmse: 1170.0155
# r2: -0.2823
#
# [0/20][500/2459][Time 11.81]
# Unified LR across all optimizers: 0.000985103449264739
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0330	Gen: 0.2527	Rec: 0.2550	E: 0.0302	R: 0.0333	P: 0.4783
#
# mse: 1194040.2500
# mae: 489.9746
# rmse: 1092.7214
# r2: -0.2275
#
# =====================Eval Metrics========================
# mse: 1524262.0000
# mae: 607.3505
# rmse: 1234.6101
# r2: -0.2960
#
# [0/20][600/2459][Time 11.97]
# Unified LR across all optimizers: 0.0009821567590202554
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0326	Gen: 0.2337	Rec: 0.2364	E: 0.0296	R: 0.0334	P: 0.4416
#
# mse: 1824991.0000
# mae: 679.2139
# rmse: 1350.9222
# r2: -0.3175
#
# =====================Eval Metrics========================
# mse: 1518939.2500
# mae: 618.0965
# rmse: 1232.4525
# r2: -0.3130
#
# [0/20][700/2459][Time 12.00]
# Unified LR across all optimizers: 0.000979218883061626
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0280	Gen: 0.2266	Rec: 0.2280	E: 0.0269	R: 0.0287	P: 0.4296
#
# mse: 1110088.6250
# mae: 494.2746
# rmse: 1053.6074
# r2: -0.2547
#
# =====================Eval Metrics========================
# mse: 926782.4375
# mae: 434.7204
# rmse: 962.6954
# r2: -0.2250
#
# [0/20][800/2459][Time 12.08]
# Unified LR across all optimizers: 0.0009762897950231208
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0216	Gen: 0.2195	Rec: 0.2181	E: 0.0230	R: 0.0209	P: 0.4165
#
# mse: 1250099.8750
# mae: 476.0518
# rmse: 1118.0786
# r2: -0.1976
#
# =====================Eval Metrics========================
# mse: 1582776.1250
# mae: 658.1494
# rmse: 1258.0844
# r2: -0.3505
#
# [0/20][900/2459][Time 12.09]
# Unified LR across all optimizers: 0.0009733694686178784
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0210	Gen: 0.2182	Rec: 0.2164	E: 0.0238	R: 0.0195	P: 0.4166
#
# mse: 1218626.3750
# mae: 503.3380
# rmse: 1103.9141
# r2: -0.2352
#
# =====================Eval Metrics========================
# mse: 1347577.3750
# mae: 537.2644
# rmse: 1160.8521
# r2: -0.2464
#
# [0/20][1000/2459][Time 12.15]
# Unified LR across all optimizers: 0.0009704578776376673
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0231	Gen: 0.2095	Rec: 0.2078	E: 0.0247	R: 0.0217	P: 0.3965
#
# mse: 1496071.7500
# mae: 559.7029
# rmse: 1223.1401
# r2: -0.2362
#
# =====================Eval Metrics========================
# mse: 1166477.7500
# mae: 490.8199
# rmse: 1080.0360
# r2: -0.2281
#
# [0/20][1100/2459][Time 12.10]
# Unified LR across all optimizers: 0.0009675549959526509
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0221	Gen: 0.1933	Rec: 0.1917	E: 0.0240	R: 0.0209	P: 0.3652
#
# mse: 1285904.3750
# mae: 529.3569
# rmse: 1133.9773
# r2: -0.2439
#
# =====================Eval Metrics========================
# mse: 1241329.0000
# mae: 523.0653
# rmse: 1114.1494
# r2: -0.2479
#
# [0/20][1200/2459][Time 11.89]
# Unified LR across all optimizers: 0.0009646607975111544
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0245	Gen: 0.1803	Rec: 0.1784	E: 0.0266	R: 0.0225	P: 0.3360
#
# mse: 1177834.6250
# mae: 508.7466
# rmse: 1085.2809
# r2: -0.2406
#
# =====================Eval Metrics========================
# mse: 1114792.0000
# mae: 493.9399
# rmse: 1055.8372
# r2: -0.2364
#
# [0/20][1300/2459][Time 11.98]
# Unified LR across all optimizers: 0.0009617752563394297
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0232	Gen: 0.1586	Rec: 0.1561	E: 0.0263	R: 0.0209	P: 0.2941
#
# mse: 1385434.7500
# mae: 557.6841
# rmse: 1177.0449
# r2: -0.2532
#
# =====================Eval Metrics========================
# mse: 1385949.3750
# mae: 557.9971
# rmse: 1177.2635
# r2: -0.2545
#
# [0/20][1400/2459][Time 12.05]
# Unified LR across all optimizers: 0.0009588983465414223
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0229	Gen: 0.1523	Rec: 0.1497	E: 0.0255	R: 0.0204	P: 0.2799
#
# mse: 1608860.0000
# mae: 637.6528
# rmse: 1268.4084
# r2: -0.2883
#
# =====================Eval Metrics========================
# mse: 1287155.7500
# mae: 529.9606
# rmse: 1134.5288
# r2: -0.2334
#
# [0/20][1500/2459][Time 12.17]
# Unified LR across all optimizers: 0.0009560300422985396
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0219	Gen: 0.1422	Rec: 0.1395	E: 0.0245	R: 0.0193	P: 0.2609
#
# mse: 1596856.0000
# mae: 619.9100
# rmse: 1263.6677
# r2: -0.2693
#
# =====================Eval Metrics========================
# mse: 1399398.3750
# mae: 590.7941
# rmse: 1182.9617
# r2: -0.2760
#
# [0/20][1600/2459][Time 12.07]
# Unified LR across all optimizers: 0.0009531703178694185
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0221	Gen: 0.1348	Rec: 0.1318	E: 0.0252	R: 0.0194	P: 0.2461
#
# mse: 994194.4375
# mae: 426.8211
# rmse: 997.0930
# r2: -0.1715
#
# =====================Eval Metrics========================
# mse: 1562989.0000
# mae: 621.8474
# rmse: 1250.1956
# r2: -0.2771
#
# [0/20][1700/2459][Time 12.21]
# Unified LR across all optimizers: 0.0009503191475896951
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0208	Gen: 0.1306	Rec: 0.1278	E: 0.0243	R: 0.0182	P: 0.2384
#
# mse: 1635712.7500
# mae: 610.1337
# rmse: 1278.9498
# r2: -0.2469
#
# =====================Eval Metrics========================
# mse: 1429939.3750
# mae: 587.6049
# rmse: 1195.8008
# r2: -0.2613
#
# [0/20][1800/2459][Time 11.97]
# Unified LR across all optimizers: 0.0009474765058717739
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0216	Gen: 0.1249	Rec: 0.1225	E: 0.0240	R: 0.0194	P: 0.2287
#
# mse: 1172793.0000
# mae: 517.7305
# rmse: 1082.9557
# r2: -0.2312
#
# =====================Eval Metrics========================
# mse: 1452444.0000
# mae: 606.8705
# rmse: 1205.1738
# r2: -0.2735
#
# [0/20][1900/2459][Time 11.96]
# Unified LR across all optimizers: 0.0009446423672045985
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0201	Gen: 0.1227	Rec: 0.1210	E: 0.0218	R: 0.0184	P: 0.2256
#
# mse: 1039664.5000
# mae: 445.9323
# rmse: 1019.6394
# r2: -0.1705
#
# =====================Eval Metrics========================
# mse: 1621081.2500
# mae: 640.7401
# rmse: 1273.2169
# r2: -0.2794
#
# [0/20][2000/2459][Time 12.04]
# Unified LR across all optimizers: 0.0009418167061534219
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0224	Gen: 0.1205	Rec: 0.1191	E: 0.0247	R: 0.0221	P: 0.2198
#
# mse: 1321576.1250
# mae: 522.7396
# rmse: 1149.5983
# r2: -0.1918
#
# =====================Eval Metrics========================
# mse: 1407387.8750
# mae: 611.9092
# rmse: 1186.3337
# r2: -0.2837
#
# [0/20][2100/2459][Time 11.90]
# Unified LR across all optimizers: 0.0009389994973595789
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0228	Gen: 0.1201	Rec: 0.1188	E: 0.0249	R: 0.0220	P: 0.2174
#
# mse: 1724307.2500
# mae: 598.9338
# rmse: 1313.1288
# r2: -0.1954
#
# =====================Eval Metrics========================
# mse: 1209956.5000
# mae: 549.7497
# rmse: 1099.9802
# r2: -0.2506
#
# [0/20][2200/2459][Time 11.90]
# Unified LR across all optimizers: 0.0009361907155402595
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0226	Gen: 0.1190	Rec: 0.1186	E: 0.0229	R: 0.0213	P: 0.2174
#
# mse: 855157.0625
# mae: 394.3030
# rmse: 924.7470
# r2: -0.1358
#
# =====================Eval Metrics========================
# mse: 1818519.0000
# mae: 679.5417
# rmse: 1348.5248
# r2: -0.2624
#
# [0/20][2300/2459][Time 11.94]
# Unified LR across all optimizers: 0.0009333903354882786
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0197	Gen: 0.1161	Rec: 0.1141	E: 0.0223	R: 0.0176	P: 0.2130
#
# mse: 1264147.3750
# mae: 552.2290
# rmse: 1124.3431
# r2: -0.2222
#
# =====================Eval Metrics========================
# mse: 1283075.0000
# mae: 542.8303
# rmse: 1132.7290
# r2: -0.2011
#
# [0/20][2400/2459][Time 12.15]
# Unified LR across all optimizers: 0.0009305983320718549
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0190	Gen: 0.1122	Rec: 0.1093	E: 0.0219	R: 0.0160	P: 0.2053
#
# mse: 1476098.6250
# mae: 555.2757
# rmse: 1214.9480
# r2: -0.1700
#
# =====================Eval Metrics========================
# mse: 1213861.8750
# mae: 564.9257
# rmse: 1101.7540
# r2: -0.2445
# Iterations:   0%|          | 0/2459 [00:00<?, ?it/s]
# [1/20][41/2459][Time 12.06]
# Unified LR across all optimizers: 0.0009278146802343803
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0185	Gen: 0.1097	Rec: 0.1068	E: 0.0217	R: 0.0158	P: 0.1994
#
# mse: 1129925.2500
# mae: 501.1025
# rmse: 1062.9794
# r2: -0.1591
#
# =====================Eval Metrics========================
# mse: 1307215.6250
# mae: 558.0349
# rmse: 1143.3353
# r2: -0.1875
#
# [1/20][141/2459][Time 12.01]
# Unified LR across all optimizers: 0.0009250393549941983
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0177	Gen: 0.1033	Rec: 0.1010	E: 0.0201	R: 0.0158	P: 0.1889
#
# mse: 1493143.8750
# mae: 597.3525
# rmse: 1221.9426
# r2: -0.1780
#
# =====================Eval Metrics========================
# mse: 1138658.7500
# mae: 509.2680
# rmse: 1067.0796
# r2: -0.1428
#
# [1/20][241/2459][Time 12.04]
# Unified LR across all optimizers: 0.0009222723314443782
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0193	Gen: 0.0974	Rec: 0.0962	E: 0.0209	R: 0.0195	P: 0.1764
#
# mse: 1390056.1250
# mae: 552.3404
# rmse: 1179.0065
# r2: -0.1298
#
# =====================Eval Metrics========================
# mse: 1116670.1250
# mae: 506.2162
# rmse: 1056.7262
# r2: -0.1399
#
# [1/20][341/2459][Time 11.85]
# Unified LR across all optimizers: 0.0009195135847524926
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0199	Gen: 0.0964	Rec: 0.0953	E: 0.0216	R: 0.0199	P: 0.1735
#
# mse: 1361649.7500
# mae: 541.5975
# rmse: 1166.8975
# r2: -0.1145
#
# =====================Eval Metrics========================
# mse: 1175062.3750
# mae: 539.6684
# rmse: 1084.0029
# r2: -0.1433
#
# [1/20][441/2459][Time 12.13]
# Unified LR across all optimizers: 0.0009167630901603946
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0180	Gen: 0.0935	Rec: 0.0919	E: 0.0193	R: 0.0164	P: 0.1697
#
# mse: 995181.5000
# mae: 441.8690
# rmse: 997.5878
# r2: -0.0528
#
# =====================Eval Metrics========================
# mse: 1362872.8750
# mae: 583.9553
# rmse: 1167.4215
# r2: -0.1336
#
# [1/20][541/2459][Time 12.24]
# Unified LR across all optimizers: 0.0009140208229839937
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0185	Gen: 0.0913	Rec: 0.0901	E: 0.0199	R: 0.0173	P: 0.1644
#
# mse: 1543374.0000
# mae: 612.3773
# rmse: 1242.3260
# r2: -0.1077
#
# =====================Eval Metrics========================
# mse: 1513756.0000
# mae: 621.5680
# rmse: 1230.3479
# r2: -0.1297
#
# [1/20][641/2459][Time 12.14]
# Unified LR across all optimizers: 0.0009112867586130364
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0193	Gen: 0.0904	Rec: 0.0905	E: 0.0192	R: 0.0198	P: 0.1632
#
# mse: 1407982.2500
# mae: 572.8150
# rmse: 1186.5842
# r2: -0.0805
#
# =====================Eval Metrics========================
# mse: 1213482.0000
# mae: 505.1158
# rmse: 1101.5815
# r2: -0.0534
#
# [1/20][741/2459][Time 12.18]
# Unified LR across all optimizers: 0.0009085608725108856
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0156	Gen: 0.0888	Rec: 0.0871	E: 0.0174	R: 0.0149	P: 0.1618
#
# mse: 830646.6250
# mae: 392.2876
# rmse: 911.3982
# r2: 0.0227
#
# =====================Eval Metrics========================
# mse: 1269286.2500
# mae: 551.0901
# rmse: 1126.6261
# r2: -0.0666
#
# [1/20][841/2459][Time 12.02]
# Unified LR across all optimizers: 0.0009058431402142976
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0152	Gen: 0.0875	Rec: 0.0847	E: 0.0192	R: 0.0126	P: 0.1585
#
# mse: 1083466.5000
# mae: 477.5805
# rmse: 1040.8970
# r2: 0.0001
#
# =====================Eval Metrics========================
# mse: 1109642.5000
# mae: 497.7068
# rmse: 1053.3958
# r2: -0.0021
#
# [1/20][941/2459][Time 12.10]
# Unified LR across all optimizers: 0.0009031335373332055
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0151	Gen: 0.0858	Rec: 0.0831	E: 0.0177	R: 0.0124	P: 0.1547
#
# mse: 1167396.0000
# mae: 505.5031
# rmse: 1080.4611
# r2: 0.0138
#
# =====================Eval Metrics========================
# mse: 1125434.3750
# mae: 483.6773
# rmse: 1060.8649
# r2: 0.0162
#
# [1/20][1041/2459][Time 12.08]
# Unified LR across all optimizers: 0.0009004320395504991
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0150	Gen: 0.0844	Rec: 0.0826	E: 0.0177	R: 0.0131	P: 0.1536
#
# mse: 1175589.3750
# mae: 511.8067
# rmse: 1084.2460
# r2: 0.0332
#
# =====================Eval Metrics========================
# mse: 1194853.2500
# mae: 546.8933
# rmse: 1093.0934
# r2: 0.0223
#
# [1/20][1141/2459][Time 12.31]
# Unified LR across all optimizers: 0.000897738622621806
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0134	Gen: 0.0828	Rec: 0.0804	E: 0.0156	R: 0.0109	P: 0.1510
#
# mse: 714391.3750
# mae: 372.8896
# rmse: 845.2167
# r2: 0.1574
#
# =====================Eval Metrics========================
# mse: 1250709.5000
# mae: 551.3598
# rmse: 1118.3512
# r2: 0.0545
#
# [1/20][1241/2459][Time 12.17]
# Unified LR across all optimizers: 0.0008950532623752764
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0137	Gen: 0.0822	Rec: 0.0805	E: 0.0158	R: 0.0122	P: 0.1504
#
# mse: 931906.1875
# mae: 395.1566
# rmse: 965.3529
# r2: 0.1538
#
# =====================Eval Metrics========================
# mse: 893575.6250
# mae: 417.0372
# rmse: 945.2913
# r2: 0.1552
#
# [1/20][1341/2459][Time 12.17]
# Unified LR across all optimizers: 0.0008923759347113617
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0124	Gen: 0.0817	Rec: 0.0791	E: 0.0153	R: 0.0097	P: 0.1500
#
# mse: 843593.6875
# mae: 387.5342
# rmse: 918.4736
# r2: 0.1897
#
# =====================Eval Metrics========================
# mse: 866633.0000
# mae: 406.0058
# rmse: 930.9313
# r2: 0.1935
#
# [1/20][1441/2459][Time 12.27]
# Unified LR across all optimizers: 0.000889706615602604
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0123	Gen: 0.0798	Rec: 0.0772	E: 0.0149	R: 0.0098	P: 0.1458
#
# mse: 1023952.0000
# mae: 429.7898
# rmse: 1011.9052
# r2: 0.1930
#
# =====================Eval Metrics========================
# mse: 723302.1250
# mae: 369.4096
# rmse: 850.4717
# r2: 0.2411
#
# [1/20][1541/2459][Time 12.09]
# Unified LR across all optimizers: 0.0008870452810934158
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0119	Gen: 0.0780	Rec: 0.0751	E: 0.0152	R: 0.0092	P: 0.1432
#
# mse: 912346.8125
# mae: 403.8177
# rmse: 955.1685
# r2: 0.2256
#
# =====================Eval Metrics========================
# mse: 725938.1875
# mae: 409.7383
# rmse: 852.0201
# r2: 0.2615
#
# [1/20][1641/2459][Time 12.12]
# Unified LR across all optimizers: 0.0008843919072998678
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0117	Gen: 0.0765	Rec: 0.0735	E: 0.0148	R: 0.0088	P: 0.1400
#
# mse: 823206.1250
# mae: 387.7444
# rmse: 907.3071
# r2: 0.2585
#
# =====================Eval Metrics========================
# mse: 848155.1875
# mae: 405.3122
# rmse: 920.9534
# r2: 0.2526
#
# [1/20][1741/2459][Time 12.17]
# Unified LR across all optimizers: 0.0008817464704094733
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0110	Gen: 0.0766	Rec: 0.0741	E: 0.0137	R: 0.0086	P: 0.1417
#
# mse: 669385.7500
# mae: 357.1486
# rmse: 818.1600
# r2: 0.3187
#
# =====================Eval Metrics========================
# mse: 699714.0000
# mae: 370.6255
# rmse: 836.4891
# r2: 0.3029
#
# [1/20][1841/2459][Time 12.10]
# Unified LR across all optimizers: 0.0008791089466809735
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0109	Gen: 0.0769	Rec: 0.0742	E: 0.0140	R: 0.0082	P: 0.1420
#
# mse: 741013.5625
# mae: 363.2088
# rmse: 860.8215
# r2: 0.3217
#
# =====================Eval Metrics========================
# mse: 701957.6875
# mae: 372.1667
# rmse: 837.8292
# r2: 0.3209
#
# [1/20][1941/2459][Time 12.17]
# Unified LR across all optimizers: 0.0008764793124441268
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0108	Gen: 0.0746	Rec: 0.0717	E: 0.0145	R: 0.0083	P: 0.1368
#
# mse: 627910.0625
# mae: 350.2097
# rmse: 792.4078
# r2: 0.3577
#
# =====================Eval Metrics========================
# mse: 753915.0000
# mae: 388.9373
# rmse: 868.2828
# r2: 0.3321
#
# [1/20][2041/2459][Time 12.08]
# Unified LR across all optimizers: 0.0008738575440994944
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0103	Gen: 0.0739	Rec: 0.0712	E: 0.0131	R: 0.0074	P: 0.1365
#
# mse: 814547.5000
# mae: 374.1698
# rmse: 902.5228
# r2: 0.3346
#
# =====================Eval Metrics========================
# mse: 547914.6875
# mae: 291.1648
# rmse: 740.2126
# r2: 0.3919
#
# [1/20][2141/2459][Time 12.16]
# Unified LR across all optimizers: 0.0008712436181182304
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0101	Gen: 0.0721	Rec: 0.0696	E: 0.0124	R: 0.0076	P: 0.1332
#
# mse: 781628.0625
# mae: 358.0467
# rmse: 884.0973
# r2: 0.3420
#
# =====================Eval Metrics========================
# mse: 766567.7500
# mae: 396.5610
# rmse: 875.5386
# r2: 0.3609
#
# [1/20][2241/2459][Time 12.17]
# Unified LR across all optimizers: 0.0008686375110418687
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0103	Gen: 0.0730	Rec: 0.0703	E: 0.0140	R: 0.0078	P: 0.1350
#
# mse: 762883.2500
# mae: 394.1730
# rmse: 873.4319
# r2: 0.3801
#
# =====================Eval Metrics========================
# mse: 641701.6875
# mae: 345.5704
# rmse: 801.0629
# r2: 0.4009
#
# [1/20][2341/2459][Time 12.42]
# Unified LR across all optimizers: 0.0008660391994821131
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0097	Gen: 0.0715	Rec: 0.0690	E: 0.0121	R: 0.0074	P: 0.1326
#
# mse: 700447.7500
# mae: 356.7289
# rmse: 836.9276
# r2: 0.3906
#
# =====================Eval Metrics========================
# mse: 628864.2500
# mae: 354.2878
# rmse: 793.0096
# r2: 0.4055
#
# [1/20][2441/2459][Time 12.01]
# Unified LR across all optimizers: 0.0008634486601206292
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0092	Gen: 0.0709	Rec: 0.0685	E: 0.0117	R: 0.0069	P: 0.1320
#
# mse: 553572.6875
# mae: 305.0917
# rmse: 744.0247
# r2: 0.4435
#
# =====================Eval Metrics========================
# mse: 722344.8125
# mae: 385.2327
# rmse: 849.9087
# r2: 0.4050
# Iterations:   0%|          | 0/2459 [00:00<?, ?it/s]
# [2/20][82/2459][Time 12.15]
# Unified LR across all optimizers: 0.0008608658697088319
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0094	Gen: 0.0707	Rec: 0.0681	E: 0.0123	R: 0.0069	P: 0.1313
#
# mse: 432458.0625
# mae: 253.5985
# rmse: 657.6154
# r2: 0.4723
#
# =====================Eval Metrics========================
# mse: 577721.8750
# mae: 335.0959
# rmse: 760.0802
# r2: 0.4446
#
# [2/20][182/2459][Time 12.02]
# Unified LR across all optimizers: 0.0008582908050676784
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0092	Gen: 0.0690	Rec: 0.0663	E: 0.0123	R: 0.0065	P: 0.1280
#
# mse: 611573.6250
# mae: 300.5927
# rmse: 782.0317
# r2: 0.4422
#
# =====================Eval Metrics========================
# mse: 750828.7500
# mae: 406.8158
# rmse: 866.5037
# r2: 0.4004
#
# [2/20][282/2459][Time 11.94]
# Unified LR across all optimizers: 0.0008557234430874619
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0090	Gen: 0.0694	Rec: 0.0667	E: 0.0119	R: 0.0064	P: 0.1288
#
# mse: 561122.2500
# mae: 310.7600
# rmse: 749.0809
# r2: 0.4678
#
# =====================Eval Metrics========================
# mse: 872233.6875
# mae: 459.1500
# rmse: 933.9345
# r2: 0.3914
#
# [2/20][382/2459][Time 12.06]
# Unified LR across all optimizers: 0.0008531637607276009
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0093	Gen: 0.0690	Rec: 0.0660	E: 0.0129	R: 0.0066	P: 0.1274
#
# mse: 618792.2500
# mae: 326.1450
# rmse: 786.6335
# r2: 0.4539
#
# =====================Eval Metrics========================
# mse: 685790.1250
# mae: 373.4062
# rmse: 828.1245
# r2: 0.4332
#
# [2/20][482/2459][Time 12.24]
# Unified LR across all optimizers: 0.0008506117350164344
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0084	Gen: 0.0658	Rec: 0.0634	E: 0.0114	R: 0.0061	P: 0.1227
#
# mse: 503367.7500
# mae: 295.0839
# rmse: 709.4841
# r2: 0.4986
#
# =====================Eval Metrics========================
# mse: 504196.1875
# mae: 296.2426
# rmse: 710.0677
# r2: 0.4807
#
# [2/20][582/2459][Time 12.26]
# Unified LR across all optimizers: 0.0008480673430510153
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0085	Gen: 0.0655	Rec: 0.0630	E: 0.0111	R: 0.0060	P: 0.1216
#
# mse: 586882.9375
# mae: 328.5192
# rmse: 766.0828
# r2: 0.4880
#
# =====================Eval Metrics========================
# mse: 466696.8125
# mae: 280.2687
# rmse: 683.1521
# r2: 0.5170
#
# [2/20][682/2459][Time 12.16]
# Unified LR across all optimizers: 0.0008455305619969057
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0083	Gen: 0.0651	Rec: 0.0626	E: 0.0112	R: 0.0060	P: 0.1207
#
# mse: 604536.9375
# mae: 333.5252
# rmse: 777.5197
# r2: 0.4895
#
# =====================Eval Metrics========================
# mse: 474050.0625
# mae: 300.0544
# rmse: 688.5129
# r2: 0.5316
#
# [2/20][782/2459][Time 12.26]
# Unified LR across all optimizers: 0.0008430013690879698
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0081	Gen: 0.0631	Rec: 0.0607	E: 0.0117	R: 0.0060	P: 0.1168
#
# mse: 577261.2500
# mae: 307.8977
# rmse: 759.7771
# r2: 0.4966
#
# =====================Eval Metrics========================
# mse: 559604.6875
# mae: 316.1573
# rmse: 748.0673
# r2: 0.5047
#
# [2/20][882/2459][Time 12.10]
# Unified LR across all optimizers: 0.0008404797416261722
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0079	Gen: 0.0626	Rec: 0.0602	E: 0.0102	R: 0.0056	P: 0.1168
#
# mse: 702118.6250
# mae: 369.6491
# rmse: 837.9252
# r2: 0.4825
#
# =====================Eval Metrics========================
# mse: 623522.1250
# mae: 366.5818
# rmse: 789.6342
# r2: 0.4973
#
# [2/20][982/2459][Time 12.29]
# Unified LR across all optimizers: 0.0008379656569813726
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0080	Gen: 0.0626	Rec: 0.0602	E: 0.0108	R: 0.0056	P: 0.1161
#
# mse: 577401.4375
# mae: 325.9550
# rmse: 759.8694
# r2: 0.5147
#
# =====================Eval Metrics========================
# mse: 457652.4062
# mae: 302.0638
# rmse: 676.5001
# r2: 0.5356
#
# [2/20][1082/2459][Time 12.27]
# Unified LR across all optimizers: 0.0008354590925911228
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0083	Gen: 0.0621	Rec: 0.0593	E: 0.0132	R: 0.0058	P: 0.1142
#
# mse: 583786.2500
# mae: 339.3409
# rmse: 764.0591
# r2: 0.5143
#
# =====================Eval Metrics========================
# mse: 520413.3438
# mae: 340.5805
# rmse: 721.3968
# r2: 0.5290
#
# [2/20][1182/2459][Time 12.38]
# Unified LR across all optimizers: 0.0008329600259604655
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0077	Gen: 0.0612	Rec: 0.0590	E: 0.0103	R: 0.0055	P: 0.1136
#
# mse: 446510.6250
# mae: 293.5253
# rmse: 668.2145
# r2: 0.5728
#
# =====================Eval Metrics========================
# mse: 513927.1250
# mae: 318.1817
# rmse: 716.8871
# r2: 0.5434
#
# [2/20][1282/2459][Time 12.16]
# Unified LR across all optimizers: 0.0008304684346617307
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0064	Gen: 0.0580	Rec: 0.0568	E: 0.0077	R: 0.0053	P: 0.1095
#
# mse: 356009.3750
# mae: 259.1495
# rmse: 596.6652
# r2: 0.5815
#
# =====================Eval Metrics========================
# mse: 414645.7500
# mae: 271.9887
# rmse: 643.9299
# r2: 0.6089
#
# [2/20][1382/2459][Time 12.20]
# Unified LR across all optimizers: 0.0008279842963343345
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0059	Gen: 0.0574	Rec: 0.0565	E: 0.0068	R: 0.0049	P: 0.1093
#
# mse: 339135.8750
# mae: 245.6193
# rmse: 582.3538
# r2: 0.6296
#
# =====================Eval Metrics========================
# mse: 357499.4688
# mae: 263.8884
# rmse: 597.9126
# r2: 0.6176
#
# [2/20][1482/2459][Time 12.11]
# Unified LR across all optimizers: 0.0008255075886845802
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0057	Gen: 0.0558	Rec: 0.0549	E: 0.0070	R: 0.0049	P: 0.1065
#
# mse: 471207.3125
# mae: 299.1109
# rmse: 686.4454
# r2: 0.5943
#
# =====================Eval Metrics========================
# mse: 432342.2188
# mae: 280.8752
# rmse: 657.5273
# r2: 0.5849
#
# [2/20][1582/2459][Time 12.38]
# Unified LR across all optimizers: 0.0008230382894854561
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0055	Gen: 0.0544	Rec: 0.0535	E: 0.0065	R: 0.0047	P: 0.1040
#
# mse: 408250.5000
# mae: 252.3855
# rmse: 638.9448
# r2: 0.6005
#
# =====================Eval Metrics========================
# mse: 565256.4375
# mae: 356.5113
# rmse: 751.8354
# r2: 0.5714
#
# [2/20][1682/2459][Time 12.14]
# Unified LR across all optimizers: 0.0008205763765764379
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0054	Gen: 0.0531	Rec: 0.0523	E: 0.0063	R: 0.0047	P: 0.1010
#
# mse: 376378.4062
# mae: 264.0136
# rmse: 613.4969
# r2: 0.6379
#
# =====================Eval Metrics========================
# mse: 396879.5625
# mae: 268.0905
# rmse: 629.9838
# r2: 0.6328
#
# [2/20][1782/2459][Time 12.31]
# Unified LR across all optimizers: 0.0008181218278632888
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0051	Gen: 0.0523	Rec: 0.0516	E: 0.0059	R: 0.0044	P: 0.1004
#
# mse: 474608.0938
# mae: 294.6387
# rmse: 688.9180
# r2: 0.6132
#
# =====================Eval Metrics========================
# mse: 348048.3750
# mae: 277.5013
# rmse: 589.9562
# r2: 0.6635
#
# [2/20][1882/2459][Time 12.45]
# Unified LR across all optimizers: 0.0008156746213178617
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0054	Gen: 0.0529	Rec: 0.0521	E: 0.0066	R: 0.0047	P: 0.1012
#
# mse: 303718.3438
# mae: 213.3250
# rmse: 551.1064
# r2: 0.6733
#
# =====================Eval Metrics========================
# mse: 450131.8125
# mae: 309.2032
# rmse: 670.9186
# r2: 0.6442
#
# [2/20][1982/2459][Time 12.25]
# Unified LR across all optimizers: 0.0008132347349779003
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0052	Gen: 0.0518	Rec: 0.0511	E: 0.0062	R: 0.0045	P: 0.0991
#
# mse: 352933.7812
# mae: 254.1976
# rmse: 594.0823
# r2: 0.6780
#
# =====================Eval Metrics========================
# mse: 497761.9375
# mae: 335.7487
# rmse: 705.5225
# r2: 0.6462
#
# [2/20][2082/2459][Time 12.28]
# Unified LR across all optimizers: 0.0008108021469468434
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0051	Gen: 0.0518	Rec: 0.0512	E: 0.0059	R: 0.0045	P: 0.0993
#
# mse: 421659.5938
# mae: 270.7916
# rmse: 649.3532
# r2: 0.6641
#
# =====================Eval Metrics========================
# mse: 343798.4688
# mae: 256.0869
# rmse: 586.3433
# r2: 0.6933
#
# [2/20][2182/2459][Time 12.30]
# Unified LR across all optimizers: 0.0008083768353936277
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0053	Gen: 0.0512	Rec: 0.0503	E: 0.0065	R: 0.0045	P: 0.0972
#
# mse: 391216.9375
# mae: 268.6537
# rmse: 625.4734
# r2: 0.6603
#
# =====================Eval Metrics========================
# mse: 293524.6875
# mae: 229.7078
# rmse: 541.7792
# r2: 0.6641
#
# [2/20][2282/2459][Time 12.30]
# Unified LR across all optimizers: 0.0008059587785524923
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0050	Gen: 0.0502	Rec: 0.0495	E: 0.0060	R: 0.0044	P: 0.0967
#
# mse: 409796.8125
# mae: 283.5873
# rmse: 640.1537
# r2: 0.6721
#
# =====================Eval Metrics========================
# mse: 315366.1250
# mae: 232.8508
# rmse: 561.5747
# r2: 0.7219
#
# [2/20][2382/2459][Time 12.45]
# Unified LR across all optimizers: 0.0008035479547227831
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0049	Gen: 0.0503	Rec: 0.0497	E: 0.0057	R: 0.0043	P: 0.0967
#
# mse: 380742.3750
# mae: 274.7136
# rmse: 617.0433
# r2: 0.7137
#
# =====================Eval Metrics========================
# mse: 242918.2656
# mae: 219.2939
# rmse: 492.8674
# r2: 0.7659
# Iterations:   0%|          | 0/2459 [00:00<?, ?it/s]
# [3/20][23/2459][Time 12.35]
# Unified LR across all optimizers: 0.0008011443422687582
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0051	Gen: 0.0494	Rec: 0.0486	E: 0.0060	R: 0.0044	P: 0.0945
#
# mse: 443555.5625
# mae: 288.8464
# rmse: 665.9997
# r2: 0.6801
#
# =====================Eval Metrics========================
# mse: 201464.5000
# mae: 205.4699
# rmse: 448.8480
# r2: 0.7749
#
# [3/20][123/2459][Time 12.28]
# Unified LR across all optimizers: 0.0007987479196193923
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0050	Gen: 0.0497	Rec: 0.0490	E: 0.0058	R: 0.0043	P: 0.0949
#
# mse: 320729.2500
# mae: 223.9363
# rmse: 566.3297
# r2: 0.7170
#
# =====================Eval Metrics========================
# mse: 414771.9688
# mae: 305.3589
# rmse: 644.0280
# r2: 0.6822
#
# [3/20][223/2459][Time 12.34]
# Unified LR across all optimizers: 0.0007963586652681868
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0049	Gen: 0.0494	Rec: 0.0488	E: 0.0056	R: 0.0043	P: 0.0950
#
# mse: 290988.1875
# mae: 225.3537
# rmse: 539.4332
# r2: 0.7315
#
# =====================Eval Metrics========================
# mse: 209812.4531
# mae: 189.9310
# rmse: 458.0529
# r2: 0.7738
#
# [3/20][323/2459][Time 12.17]
# Unified LR across all optimizers: 0.0007939765577729723
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0047	Gen: 0.0490	Rec: 0.0484	E: 0.0054	R: 0.0041	P: 0.0942
#
# mse: 323481.2812
# mae: 235.8338
# rmse: 568.7542
# r2: 0.7327
#
# =====================Eval Metrics========================
# mse: 164672.7812
# mae: 175.7286
# rmse: 405.7990
# r2: 0.7929
#
# [3/20][423/2459][Time 12.15]
# Unified LR across all optimizers: 0.0007916015757557189
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0046	Gen: 0.0488	Rec: 0.0483	E: 0.0051	R: 0.0041	P: 0.0939
#
# mse: 255474.2500
# mae: 204.4087
# rmse: 505.4446
# r2: 0.7320
#
# =====================Eval Metrics========================
# mse: 305306.1562
# mae: 240.4044
# rmse: 552.5452
# r2: 0.7420
#
# [3/20][523/2459][Time 12.43]
# Unified LR across all optimizers: 0.0007892336979023447
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0048	Gen: 0.0492	Rec: 0.0487	E: 0.0054	R: 0.0044	P: 0.0950
#
# mse: 296301.8750
# mae: 234.0650
# rmse: 544.3362
# r2: 0.7589
#
# =====================Eval Metrics========================
# mse: 223080.7812
# mae: 213.5867
# rmse: 472.3143
# r2: 0.7715
#
# [3/20][623/2459][Time 12.01]
# Unified LR across all optimizers: 0.0007868729029625218
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0046	Gen: 0.0476	Rec: 0.0471	E: 0.0052	R: 0.0043	P: 0.0918
#
# mse: 353176.8750
# mae: 258.6655
# rmse: 594.2869
# r2: 0.7479
#
# =====================Eval Metrics========================
# mse: 214116.3750
# mae: 204.0370
# rmse: 462.7271
# r2: 0.7662
#
# [3/20][723/2459][Time 12.26]
# Unified LR across all optimizers: 0.0007845191697494887
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0044	Gen: 0.0480	Rec: 0.0475	E: 0.0050	R: 0.0040	P: 0.0923
#
# mse: 216566.3750
# mae: 190.1735
# rmse: 465.3669
# r2: 0.7802
#
# =====================Eval Metrics========================
# mse: 270005.0000
# mae: 236.5101
# rmse: 519.6201
# r2: 0.7715
#
# [3/20][823/2459][Time 12.24]
# Unified LR across all optimizers: 0.0007821724771398585
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0049	Gen: 0.0485	Rec: 0.0477	E: 0.0059	R: 0.0041	P: 0.0931
#
# mse: 143586.2500
# mae: 165.8392
# rmse: 378.9278
# r2: 0.8328
#
# =====================Eval Metrics========================
# mse: 253470.2188
# mae: 225.8463
# rmse: 503.4583
# r2: 0.7664
#
# [3/20][923/2459][Time 12.37]
# Unified LR across all optimizers: 0.0007798328040734291
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0045	Gen: 0.0470	Rec: 0.0465	E: 0.0051	R: 0.0040	P: 0.0904
#
# mse: 306026.8438
# mae: 234.5965
# rmse: 553.1970
# r2: 0.7402
#
# =====================Eval Metrics========================
# mse: 216753.5156
# mae: 214.2594
# rmse: 465.5680
# r2: 0.8018
#
# [3/20][1023/2459][Time 12.18]
# Unified LR across all optimizers: 0.0007775001295529957
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0047	Gen: 0.0475	Rec: 0.0468	E: 0.0054	R: 0.0040	P: 0.0909
#
# mse: 189993.2656
# mae: 179.3795
# rmse: 435.8822
# r2: 0.7991
#
# =====================Eval Metrics========================
# mse: 181768.6094
# mae: 192.0682
# rmse: 426.3433
# r2: 0.8411
#
# [3/20][1123/2459][Time 12.40]
# Unified LR across all optimizers: 0.00077517443264416
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0046	Gen: 0.0469	Rec: 0.0463	E: 0.0054	R: 0.0042	P: 0.0905
#
# mse: 220076.0469
# mae: 219.1484
# rmse: 469.1227
# r2: 0.8040
#
# =====================Eval Metrics========================
# mse: 190621.9375
# mae: 192.7505
# rmse: 436.6027
# r2: 0.8386
#
# [3/20][1223/2459][Time 12.23]
# Unified LR across all optimizers: 0.000772855692475145
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0045	Gen: 0.0471	Rec: 0.0465	E: 0.0053	R: 0.0039	P: 0.0907
#
# mse: 280604.3750
# mae: 219.7118
# rmse: 529.7210
# r2: 0.7684
#
# =====================Eval Metrics========================
# mse: 202093.8750
# mae: 185.0598
# rmse: 449.5485
# r2: 0.8161
#
# [3/20][1323/2459][Time 12.21]
# Unified LR across all optimizers: 0.0007705438882366049
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0045	Gen: 0.0469	Rec: 0.0463	E: 0.0050	R: 0.0039	P: 0.0901
#
# mse: 196126.3125
# mae: 177.3937
# rmse: 442.8615
# r2: 0.8159
#
# =====================Eval Metrics========================
# mse: 181665.5469
# mae: 175.1589
# rmse: 426.2224
# r2: 0.8257
#
# [3/20][1423/2459][Time 12.20]
# Unified LR across all optimizers: 0.0007682389991814431
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0046	Gen: 0.0468	Rec: 0.0461	E: 0.0055	R: 0.0040	P: 0.0901
#
# mse: 178099.2188
# mae: 194.9529
# rmse: 422.0180
# r2: 0.8299
#
# =====================Eval Metrics========================
# mse: 198040.9375
# mae: 206.4040
# rmse: 445.0179
# r2: 0.8073
#
# [3/20][1523/2459][Time 12.11]
# Unified LR across all optimizers: 0.0007659410046246184
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0044	Gen: 0.0456	Rec: 0.0453	E: 0.0049	R: 0.0040	P: 0.0879
#
# mse: 166714.4062
# mae: 173.0195
# rmse: 408.3068
# r2: 0.8177
#
# =====================Eval Metrics========================
# mse: 257268.2031
# mae: 232.3783
# rmse: 507.2161
# r2: 0.7900
#
# [3/20][1623/2459][Time 12.25]
# Unified LR across all optimizers: 0.0007636498839429665
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0045	Gen: 0.0457	Rec: 0.0452	E: 0.0050	R: 0.0039	P: 0.0877
#
# mse: 98821.2812
# mae: 122.9141
# rmse: 314.3585
# r2: 0.8644
#
# =====================Eval Metrics========================
# mse: 206844.5312
# mae: 192.9657
# rmse: 454.8016
# r2: 0.7767
#
# [3/20][1723/2459][Time 12.30]
# Unified LR across all optimizers: 0.0007613656165750123
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0045	Gen: 0.0454	Rec: 0.0447	E: 0.0055	R: 0.0039	P: 0.0870
#
# mse: 157993.2812
# mae: 172.9138
# rmse: 397.4837
# r2: 0.8626
#
# =====================Eval Metrics========================
# mse: 136189.0938
# mae: 158.7826
# rmse: 369.0381
# r2: 0.8852
#
# [3/20][1823/2459][Time 12.25]
# Unified LR across all optimizers: 0.0007590881820207827
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0044	Gen: 0.0446	Rec: 0.0440	E: 0.0050	R: 0.0038	P: 0.0853
#
# mse: 161349.5625
# mae: 173.5498
# rmse: 401.6834
# r2: 0.8567
#
# =====================Eval Metrics========================
# mse: 182890.9375
# mae: 197.5286
# rmse: 427.6575
# r2: 0.8381
#
# [3/20][1923/2459][Time 12.16]
# Unified LR across all optimizers: 0.0007568175598416272
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0041	Gen: 0.0443	Rec: 0.0439	E: 0.0046	R: 0.0038	P: 0.0853
#
# mse: 136398.3906
# mae: 162.2819
# rmse: 369.3215
# r2: 0.8803
#
# =====================Eval Metrics========================
# mse: 139021.5625
# mae: 154.9204
# rmse: 372.8560
# r2: 0.8624
#
# [3/20][2023/2459][Time 12.17]
# Unified LR across all optimizers: 0.0007545537296600323
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0044	Gen: 0.0449	Rec: 0.0444	E: 0.0052	R: 0.0041	P: 0.0862
#
# mse: 156943.4844
# mae: 161.0333
# rmse: 396.1609
# r2: 0.8603
#
# =====================Eval Metrics========================
# mse: 92414.3203
# mae: 123.5165
# rmse: 303.9972
# r2: 0.8921
#
# [3/20][2123/2459][Time 12.24]
# Unified LR across all optimizers: 0.0007522966711594383
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0043	Gen: 0.0448	Rec: 0.0443	E: 0.0049	R: 0.0038	P: 0.0860
#
# mse: 137806.6875
# mae: 159.1641
# rmse: 371.2232
# r2: 0.8672
#
# =====================Eval Metrics========================
# mse: 131330.2812
# mae: 169.8955
# rmse: 362.3952
# r2: 0.8723
#
# [3/20][2223/2459][Time 12.12]
# Unified LR across all optimizers: 0.0007500463640840577
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0040	Gen: 0.0436	Rec: 0.0432	E: 0.0045	R: 0.0036	P: 0.0842
#
# mse: 177199.7812
# mae: 205.5476
# rmse: 420.9510
# r2: 0.8654
#
# =====================Eval Metrics========================
# mse: 111574.8906
# mae: 140.3349
# rmse: 334.0283
# r2: 0.8692
#
# [3/20][2323/2459][Time 12.33]
# Unified LR across all optimizers: 0.0007478027882386922
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0046	Gen: 0.0446	Rec: 0.0437	E: 0.0054	R: 0.0036	P: 0.0848
#
# mse: 249948.9062
# mae: 236.2614
# rmse: 499.9489
# r2: 0.8345
#
# =====================Eval Metrics========================
# mse: 190817.2188
# mae: 200.8224
# rmse: 436.8263
# r2: 0.8237
#
# [3/20][2423/2459][Time 12.34]
# Unified LR across all optimizers: 0.0007455659234885542
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0048	Gen: 0.0454	Rec: 0.0445	E: 0.0061	R: 0.0040	P: 0.0865
#
# mse: 117031.6172
# mae: 142.6338
# rmse: 342.0988
# r2: 0.8753
#
# =====================Eval Metrics========================
# mse: 87101.3438
# mae: 136.4776
# rmse: 295.1294
# r2: 0.9016
# Iterations:   0%|          | 0/2459 [00:00<?, ?it/s]
# [4/20][64/2459][Time 12.22]
# Unified LR across all optimizers: 0.0007433357497590818
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0045	Gen: 0.0444	Rec: 0.0438	E: 0.0053	R: 0.0039	P: 0.0850
#
# mse: 169235.9844
# mae: 167.9964
# rmse: 411.3830
# r2: 0.8447
#
# =====================Eval Metrics========================
# mse: 162822.5312
# mae: 177.4315
# rmse: 403.5127
# r2: 0.8556
#
# [4/20][164/2459][Time 12.09]
# Unified LR across all optimizers: 0.0007411122470357627
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0045	Gen: 0.0438	Rec: 0.0431	E: 0.0053	R: 0.0038	P: 0.0840
#
# mse: 182032.1406
# mae: 169.2712
# rmse: 426.6523
# r2: 0.8314
#
# =====================Eval Metrics========================
# mse: 174567.0938
# mae: 194.5031
# rmse: 417.8123
# r2: 0.8648
#
# [4/20][264/2459][Time 12.17]
# Unified LR across all optimizers: 0.0007388953953639536
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0045	Gen: 0.0443	Rec: 0.0437	E: 0.0053	R: 0.0039	P: 0.0847
#
# mse: 134207.9062
# mae: 166.8429
# rmse: 366.3440
# r2: 0.9014
#
# =====================Eval Metrics========================
# mse: 107022.6719
# mae: 147.0144
# rmse: 327.1432
# r2: 0.9122
#
# [4/20][364/2459][Time 12.24]
# Unified LR across all optimizers: 0.0007366851748486997
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0045	Gen: 0.0438	Rec: 0.0432	E: 0.0052	R: 0.0039	P: 0.0841
#
# mse: 104234.6562
# mae: 128.7500
# rmse: 322.8539
# r2: 0.8885
#
# =====================Eval Metrics========================
# mse: 131271.6875
# mae: 172.6975
# rmse: 362.3144
# r2: 0.8693
#
# [4/20][464/2459][Time 12.31]
# Unified LR across all optimizers: 0.0007344815656545561
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0044	Gen: 0.0436	Rec: 0.0430	E: 0.0052	R: 0.0039	P: 0.0833
#
# mse: 101306.3672
# mae: 139.3716
# rmse: 318.2866
# r2: 0.8832
#
# =====================Eval Metrics========================
# mse: 159484.4219
# mae: 185.3438
# rmse: 399.3550
# r2: 0.8724
#
# [4/20][564/2459][Time 12.58]
# Unified LR across all optimizers: 0.0007322845480054125
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0046	Gen: 0.0427	Rec: 0.0419	E: 0.0054	R: 0.0038	P: 0.0810
#
# mse: 79848.2656
# mae: 119.7108
# rmse: 282.5743
# r2: 0.9170
#
# =====================Eval Metrics========================
# mse: 66576.9297
# mae: 115.0605
# rmse: 258.0251
# r2: 0.9322
#
# [4/20][664/2459][Time 12.28]
# Unified LR across all optimizers: 0.0007300941021843118
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0044	Gen: 0.0428	Rec: 0.0422	E: 0.0053	R: 0.0039	P: 0.0823
#
# mse: 190832.7188
# mae: 179.6574
# rmse: 436.8441
# r2: 0.8616
#
# =====================Eval Metrics========================
# mse: 159775.7031
# mae: 162.5045
# rmse: 399.7195
# r2: 0.8274
#
# [4/20][764/2459][Time 12.28]
# Unified LR across all optimizers: 0.0007279102085332781
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0043	Gen: 0.0432	Rec: 0.0426	E: 0.0050	R: 0.0037	P: 0.0824
#
# mse: 135598.9219
# mae: 153.6936
# rmse: 368.2376
# r2: 0.8869
#
# =====================Eval Metrics========================
# mse: 152565.8906
# mae: 160.2178
# rmse: 390.5968
# r2: 0.8461
#
# [4/20][864/2459][Time 12.29]
# Unified LR across all optimizers: 0.0007257328474531336
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0046	Gen: 0.0428	Rec: 0.0420	E: 0.0056	R: 0.0039	P: 0.0817
#
# mse: 123893.9609
# mae: 164.7612
# rmse: 351.9857
# r2: 0.9093
#
# =====================Eval Metrics========================
# mse: 64027.6289
# mae: 123.1393
# rmse: 253.0368
# r2: 0.9328
#
# [4/20][964/2459][Time 12.34]
# Unified LR across all optimizers: 0.0007235619994033299
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0044	Gen: 0.0427	Rec: 0.0421	E: 0.0051	R: 0.0038	P: 0.0817
#
# mse: 109213.0859
# mae: 140.3719
# rmse: 330.4740
# r2: 0.8726
#
# =====================Eval Metrics========================
# mse: 48644.1406
# mae: 104.8756
# rmse: 220.5542
# r2: 0.9370
#
# [4/20][1064/2459][Time 11.94]
# Unified LR across all optimizers: 0.0007213976449017682
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0046	Gen: 0.0424	Rec: 0.0417	E: 0.0058	R: 0.0040	P: 0.0812
#
# mse: 124536.6875
# mae: 149.3489
# rmse: 352.8976
# r2: 0.8651
#
# =====================Eval Metrics========================
# mse: 85019.9531
# mae: 142.8888
# rmse: 291.5818
# r2: 0.9240
#
# [4/20][1164/2459][Time 12.17]
# Unified LR across all optimizers: 0.0007192397645246242
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0042	Gen: 0.0419	Rec: 0.0414	E: 0.0049	R: 0.0038	P: 0.0808
#
# mse: 86399.9531
# mae: 117.5627
# rmse: 293.9387
# r2: 0.9193
#
# =====================Eval Metrics========================
# mse: 141068.9688
# mae: 164.4093
# rmse: 375.5915
# r2: 0.8781
#
# [4/20][1264/2459][Time 12.37]
# Unified LR across all optimizers: 0.0007170883389061767
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0043	Gen: 0.0417	Rec: 0.0411	E: 0.0051	R: 0.0037	P: 0.0800
#
# mse: 77832.5703
# mae: 121.8280
# rmse: 278.9849
# r2: 0.9283
#
# =====================Eval Metrics========================
# mse: 167821.5938
# mae: 206.7549
# rmse: 409.6603
# r2: 0.8902
#
# [4/20][1364/2459][Time 12.09]
# Unified LR across all optimizers: 0.0007149433487386315
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0042	Gen: 0.0410	Rec: 0.0404	E: 0.0048	R: 0.0036	P: 0.0784
#
# mse: 146520.7812
# mae: 122.6013
# rmse: 382.7803
# r2: 0.8343
#
# =====================Eval Metrics========================
# mse: 163429.1406
# mae: 165.1471
# rmse: 404.2637
# r2: 0.8585
#
# [4/20][1464/2459][Time 12.24]
# Unified LR across all optimizers: 0.0007128047747719494
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0046	Gen: 0.0418	Rec: 0.0410	E: 0.0055	R: 0.0037	P: 0.0796
#
# mse: 78837.9766
# mae: 115.2832
# rmse: 280.7810
# r2: 0.9241
#
# =====================Eval Metrics========================
# mse: 93315.4922
# mae: 156.5250
# rmse: 305.4759
# r2: 0.9263
#
# [4/20][1564/2459][Time 12.34]
# Unified LR across all optimizers: 0.0007106725978136725
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0043	Gen: 0.0417	Rec: 0.0411	E: 0.0050	R: 0.0038	P: 0.0799
#
# mse: 73491.5938
# mae: 118.2047
# rmse: 271.0933
# r2: 0.9219
#
# =====================Eval Metrics========================
# mse: 102848.9609
# mae: 158.6384
# rmse: 320.7007
# r2: 0.8989
#
# [4/20][1664/2459][Time 12.16]
# Unified LR across all optimizers: 0.0007085467987287521
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0043	Gen: 0.0416	Rec: 0.0409	E: 0.0050	R: 0.0036	P: 0.0797
#
# mse: 142751.5781
# mae: 158.4221
# rmse: 377.8248
# r2: 0.8787
#
# =====================Eval Metrics========================
# mse: 124182.2266
# mae: 146.4147
# rmse: 352.3950
# r2: 0.8978
#
# ...
# r2: 0.9311
#
# [5/20][2305/2459][Time 12.45]
# Unified LR across all optimizers: 0.0006457086589521159
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0032	Gen: 0.0375	Rec: 0.0371	E: 0.0038	R: 0.0027	P: 0.0726
#
# mse: 81453.2422
# mae: 129.8622
# rmse: 285.4001
# r2: 0.9330
#
# =====================Eval Metrics========================
# mse: 71015.4062
# mae: 121.4790
# rmse: 266.4872
# r2: 0.9346
#
# [5/20][2405/2459][Time 12.43]
# Unified LR across all optimizers: 0.0006437771832197627
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0030	Gen: 0.0372	Rec: 0.0368	E: 0.0035	R: 0.0026	P: 0.0720
#
# mse: 101409.0625
# mae: 135.6937
# rmse: 318.4479
# r2: 0.8940
#
# =====================Eval Metrics========================
# mse: 120933.9688
# mae: 129.1583
# rmse: 347.7556
# r2: 0.8620
# Iterations:   0%|          | 0/2459 [00:00<?, ?it/s]
# [6/20][46/2459][Time 12.21]
# Unified LR across all optimizers: 0.0006418514850133148
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0031	Gen: 0.0376	Rec: 0.0372	E: 0.0041	R: 0.0028	P: 0.0730
#
# mse: 82484.6719
# mae: 115.6245
# rmse: 287.2014
# r2: 0.9179
#
# =====================Eval Metrics========================
# mse: 115796.7656
# mae: 151.3258
# rmse: 340.2892
# r2: 0.9139
#
# [6/20][146/2459][Time 12.25]
# Unified LR across all optimizers: 0.0006399315470507513
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0028	Gen: 0.0361	Rec: 0.0358	E: 0.0032	R: 0.0025	P: 0.0701
#
# mse: 63194.0664
# mae: 106.3186
# rmse: 251.3843
# r2: 0.9477
#
# =====================Eval Metrics========================
# mse: 151203.9062
# mae: 161.8332
# rmse: 388.8495
# r2: 0.8738
#
# [6/20][246/2459][Time 12.24]
# Unified LR across all optimizers: 0.0006380173521017453
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0033	Gen: 0.0365	Rec: 0.0361	E: 0.0040	R: 0.0028	P: 0.0708
#
# mse: 53629.8125
# mae: 93.8208
# rmse: 231.5811
# r2: 0.9414
#
# =====================Eval Metrics========================
# mse: 77843.9531
# mae: 122.5627
# rmse: 279.0053
# r2: 0.9322
#
# [6/20][346/2459][Time 12.35]
# Unified LR across all optimizers: 0.0006361088829875093
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0034	Gen: 0.0365	Rec: 0.0360	E: 0.0040	R: 0.0029	P: 0.0708
#
# mse: 54105.1641
# mae: 109.4824
# rmse: 232.6052
# r2: 0.9510
#
# =====================Eval Metrics========================
# mse: 103080.5781
# mae: 134.4375
# rmse: 321.0616
# r2: 0.8945
#
# [6/20][446/2459][Time 12.37]
# Unified LR across all optimizers: 0.0006342061225806431
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0033	Gen: 0.0370	Rec: 0.0365	E: 0.0045	R: 0.0028	P: 0.0715
#
# mse: 63366.9844
# mae: 83.5132
# rmse: 251.7280
# r2: 0.9398
#
# =====================Eval Metrics========================
# mse: 105581.9609
# mae: 137.0486
# rmse: 324.9338
# r2: 0.8995
#
# [6/20][546/2459][Time 12.40]
# Unified LR across all optimizers: 0.0006323090538049785
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0032	Gen: 0.0370	Rec: 0.0365	E: 0.0039	R: 0.0027	P: 0.0718
#
# mse: 78098.4453
# mae: 113.6021
# rmse: 279.4610
# r2: 0.9389
#
# =====================Eval Metrics========================
# mse: 99221.0000
# mae: 117.1378
# rmse: 314.9937
# r2: 0.9094
#
# [6/20][646/2459][Time 12.40]
# Unified LR across all optimizers: 0.0006304176596354259
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0032	Gen: 0.0362	Rec: 0.0357	E: 0.0042	R: 0.0027	P: 0.0700
#
# mse: 107777.2969
# mae: 141.4851
# rmse: 328.2945
# r2: 0.9231
#
# =====================Eval Metrics========================
# mse: 102999.0625
# mae: 151.1522
# rmse: 320.9347
# r2: 0.9039
#
# [6/20][746/2459][Time 12.38]
# Unified LR across all optimizers: 0.0006285319230978225
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0029	Gen: 0.0363	Rec: 0.0359	E: 0.0036	R: 0.0025	P: 0.0706
#
# mse: 94259.4375
# mae: 124.3686
# rmse: 307.0170
# r2: 0.9013
#
# =====================Eval Metrics========================
# mse: 150237.5156
# mae: 148.5356
# rmse: 387.6049
# r2: 0.8491
#
# [6/20][846/2459][Time 12.34]
# Unified LR across all optimizers: 0.000626651827268779
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0032	Gen: 0.0364	Rec: 0.0359	E: 0.0038	R: 0.0027	P: 0.0704
#
# mse: 103911.2891
# mae: 144.5770
# rmse: 322.3528
# r2: 0.9061
#
# =====================Eval Metrics========================
# mse: 93674.6875
# mae: 135.4087
# rmse: 306.0632
# r2: 0.9306
#
# [6/20][946/2459][Time 12.41]
# Unified LR across all optimizers: 0.000624777355275529
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0034	Gen: 0.0367	Rec: 0.0360	E: 0.0040	R: 0.0027	P: 0.0703
#
# mse: 64635.0938
# mae: 105.7515
# rmse: 254.2343
# r2: 0.9415
#
# =====================Eval Metrics========================
# mse: 152447.6406
# mae: 157.2021
# rmse: 390.4454
# r2: 0.8460
#
# [6/20][1046/2459][Time 12.31]
# Unified LR across all optimizers: 0.0006229084902957762
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0031	Gen: 0.0353	Rec: 0.0348	E: 0.0037	R: 0.0026	P: 0.0680
#
# mse: 95496.6250
# mae: 132.3213
# rmse: 309.0253
# r2: 0.9086
#
# =====================Eval Metrics========================
# mse: 122027.9219
# mae: 134.6983
# rmse: 349.3250
# r2: 0.8934
#
# [6/20][1146/2459][Time 12.34]
# Unified LR across all optimizers: 0.0006210452155575442
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0029	Gen: 0.0353	Rec: 0.0350	E: 0.0034	R: 0.0025	P: 0.0687
#
# mse: 105085.2188
# mae: 129.9514
# rmse: 324.1685
# r2: 0.8809
#
# =====================Eval Metrics========================
# mse: 82824.2734
# mae: 127.1685
# rmse: 287.7921
# r2: 0.9252
#
# [6/20][1246/2459][Time 12.23]
# Unified LR across all optimizers: 0.0006191875143390252
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0028	Gen: 0.0352	Rec: 0.0348	E: 0.0035	R: 0.0025	P: 0.0682
#
# mse: 83529.4688
# mae: 127.9107
# rmse: 289.0146
# r2: 0.9318
#
# =====================Eval Metrics========================
# mse: 133727.0000
# mae: 158.7727
# rmse: 365.6870
# r2: 0.8689
#
# [6/20][1346/2459][Time 12.27]
# Unified LR across all optimizers: 0.0006173353699684315
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0028	Gen: 0.0347	Rec: 0.0343	E: 0.0032	R: 0.0025	P: 0.0673
#
# mse: 64254.4531
# mae: 110.1378
# rmse: 253.4846
# r2: 0.9292
#
# =====================Eval Metrics========================
# mse: 117297.8594
# mae: 143.9901
# rmse: 342.4878
# r2: 0.8915
#
# [6/20][1446/2459][Time 12.09]
# Unified LR across all optimizers: 0.0006154887658238438
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0029	Gen: 0.0353	Rec: 0.0349	E: 0.0035	R: 0.0025	P: 0.0684
#
# mse: 109982.8984
# mae: 131.3934
# rmse: 331.6367
# r2: 0.9129
#
# =====================Eval Metrics========================
# mse: 74600.7031
# mae: 112.0457
# rmse: 273.1313
# r2: 0.9237
#
# [6/20][1546/2459][Time 12.13]
# Unified LR across all optimizers: 0.0006136476853330627
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0032	Gen: 0.0355	Rec: 0.0348	E: 0.0039	R: 0.0026	P: 0.0686
#
# mse: 115459.2578
# mae: 138.1504
# rmse: 339.7930
# r2: 0.8837
#
# =====================Eval Metrics========================
# mse: 163260.6719
# mae: 164.1990
# rmse: 404.0553
# r2: 0.8721
#
# [6/20][1646/2459][Time 12.16]
# Unified LR across all optimizers: 0.0006118121119734627
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0031	Gen: 0.0352	Rec: 0.0347	E: 0.0038	R: 0.0027	P: 0.0678
#
# mse: 63468.4375
# mae: 104.9698
# rmse: 251.9294
# r2: 0.9404
#
# =====================Eval Metrics========================
# mse: 50385.0078
# mae: 102.7304
# rmse: 224.4660
# r2: 0.9550
#
# [6/20][1746/2459][Time 12.43]
# Unified LR across all optimizers: 0.0006099820292718395
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0029	Gen: 0.0346	Rec: 0.0342	E: 0.0034	R: 0.0025	P: 0.0672
#
# mse: 68665.3594
# mae: 114.3067
# rmse: 262.0408
# r2: 0.9266
#
# =====================Eval Metrics========================
# mse: 111787.3438
# mae: 129.2161
# rmse: 334.3461
# r2: 0.8847
#
# [6/20][1846/2459][Time 12.10]
# Unified LR across all optimizers: 0.0006081574208042645
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0029	Gen: 0.0350	Rec: 0.0346	E: 0.0036	R: 0.0025	P: 0.0680
#
# mse: 85795.6953
# mae: 124.1370
# rmse: 292.9090
# r2: 0.9159
#
# =====================Eval Metrics========================
# mse: 83587.4141
# mae: 127.2418
# rmse: 289.1149
# r2: 0.9178
#
# [6/20][1946/2459][Time 12.20]
# Unified LR across all optimizers: 0.0006063382701959386
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0029	Gen: 0.0353	Rec: 0.0350	E: 0.0034	R: 0.0025	P: 0.0686
#
# mse: 127798.9375
# mae: 135.1693
# rmse: 357.4898
# r2: 0.8680
#
# =====================Eval Metrics========================
# mse: 88367.9922
# mae: 136.3040
# rmse: 297.2675
# r2: 0.9287
#
# [6/20][2046/2459][Time 12.71]
# Unified LR across all optimizers: 0.0006045245611210422
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0030	Gen: 0.0350	Rec: 0.0346	E: 0.0037	R: 0.0027	P: 0.0679
#
# mse: 71648.7812
# mae: 104.1050
# rmse: 267.6729
# r2: 0.9137
#
# =====================Eval Metrics========================
# mse: 93026.8516
# mae: 125.1249
# rmse: 305.0030
# r2: 0.9315
#
# [6/20][2146/2459][Time 12.51]
# Unified LR across all optimizers: 0.000602716277302591
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0027	Gen: 0.0347	Rec: 0.0343	E: 0.0032	R: 0.0024	P: 0.0678
#
# mse: 72320.5000
# mae: 112.3566
# rmse: 268.9247
# r2: 0.9352
#
# =====================Eval Metrics========================
# mse: 95552.3047
# mae: 143.0536
# rmse: 309.1154
# r2: 0.9265
#
# [6/20][2246/2459][Time 12.38]
# Unified LR across all optimizers: 0.000600913402512289
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0029	Gen: 0.0345	Rec: 0.0342	E: 0.0034	R: 0.0025	P: 0.0669
#
# mse: 67022.9922
# mae: 117.7100
# rmse: 258.8880
# r2: 0.9369
#
# =====================Eval Metrics========================
# mse: 133640.9375
# mae: 142.4992
# rmse: 365.5693
# r2: 0.8489
#
# [6/20][2346/2459][Time 12.39]
# Unified LR across all optimizers: 0.000599115920570383
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0029	Gen: 0.0341	Rec: 0.0336	E: 0.0033	R: 0.0024	P: 0.0661
#
# mse: 69772.7891
# mae: 117.0997
# rmse: 264.1454
# r2: 0.9259
#
# =====================Eval Metrics========================
# mse: 241735.0938
# mae: 184.3439
# rmse: 491.6656
# r2: 0.7634
#
# [6/20][2446/2459][Time 12.43]
# Unified LR across all optimizers: 0.0005973238153455189
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0027	Gen: 0.0339	Rec: 0.0335	E: 0.0032	R: 0.0024	P: 0.0660
#
# mse: 58111.8984
# mae: 110.6199
# rmse: 241.0641
# r2: 0.9454
#
# =====================Eval Metrics========================
# mse: 144657.0156
# mae: 153.6487
# rmse: 380.3380
# r2: 0.8445
# Iterations:   0%|          | 0/2459 [00:00<?, ?it/s]
# [7/20][87/2459][Time 12.36]
# Unified LR across all optimizers: 0.0005955370707545932
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0027	Gen: 0.0342	Rec: 0.0338	E: 0.0032	R: 0.0024	P: 0.0664
#
# mse: 97017.0234
# mae: 124.1423
# rmse: 311.4756
# r2: 0.9101
#
# =====================Eval Metrics========================
# mse: 204099.3438
# mae: 156.5592
# rmse: 451.7736
# r2: 0.8187
#
# [7/20][187/2459][Time 12.59]
# Unified LR across all optimizers: 0.0005937556707626122
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0029	Gen: 0.0341	Rec: 0.0336	E: 0.0038	R: 0.0024	P: 0.0658
#
# mse: 84936.7734
# mae: 122.3980
# rmse: 291.4391
# r2: 0.9276
#
# =====================Eval Metrics========================
# mse: 87281.6016
# mae: 126.1232
# rmse: 295.4346
# r2: 0.9217
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 causal_learning.train(trainset, testset)
#
# File c:\Users\user\Projects\causal-learning\examples\time_series\../..\causal_learning.py:80, in CausalLearning.train(self, trainset, testset)
#      77 dataloader = get_data_loader(trainset, min(len(trainset), self.batch_size))
#      79 for iters, (source_batch, target_batch) in enumerate(tqdm_notebook(dataloader, desc='Iterations', leave=False)):
# ---> 80     ccnet_metric = self.train_iteration(source_batch, target_batch)
#      82     train_results = self.evaluate(trainset)
#      84     test_results = self.evaluate(testset)
#
# File c:\Users\user\Projects\causal-learning\examples\time_series\../..\causal_learning.py:69, in CausalLearning.train_iteration(self, source_batch, target_batch)
#      66 source_batch, target_batch, padding_mask = prepare_batches(source_batch, target_batch, self.label_size, self.task_type, self.device)
#      68 source_batch, target_batch, padding_mask = manage_batch_dimensions(self.use_seq_input, source_batch, target_batch, padding_mask)
# ---> 69 ccnet_metric = self.trainer.train_models(source_batch, target_batch, padding_mask)
#      71 return ccnet_metric
#
# File c:\Users\user\Projects\causal-learning\examples\time_series\../..\ccnet\causal_trainer.py:53, in CausalTrainer.train_models(self, observation, label, padding_mask)
#      49 producer_error = self.error_fn(generation_loss + reconstruction_loss, inference_loss, padding_mask)
#      51 ################################  Backward Pass  ###############################################
#      52 # Perform the backward pass and update the models.
# ---> 53 self.backwards(
#      54     [self.explainer, self.reasoner, self.producer],
#      55     [explainer_error, reasoner_error, producer_error]
#      56     )
#      57 ################################  Model Update  ###############################################
#      58 # Update optimizers and schedulers, and reset the random seed.
#      59 self.update_step()
#
# File c:\Users\user\Projects\causal-learning\examples\time_series\../..\ccnet\trainer_base.py:93, in TrainerBase.backwards(self, networks, network_errors)
#      91 retain_graph = (net_idx < num_network - 1)
#      92 # Apply the discounted gradients in the backward pass
# ---> 93 error.backward(torch.ones_like(error), retain_graph=retain_graph)
#      94 # Prevent gradient updates for the current network after its errors have been processed
#      95 network.requires_grad_(False)
#
# File c:\Users\user\.conda\envs\torch\lib\site-packages\torch\_tensor.py:525, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     515 if has_torch_function_unary(self):
#     516     return handle_torch_function(
#     517         Tensor.backward,
#     518         (self,),
#    (...)
#     523         inputs=inputs,
#     524     )
# --> 525 torch.autograd.backward(
#     526     self, gradient, retain_graph, create_graph, inputs=inputs
#     527 )
#
# File c:\Users\user\.conda\envs\torch\lib\site-packages\torch\autograd\__init__.py:267, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     262     retain_graph = create_graph
#     264 # The reason we repeat the same comment below is that
#     265 # some Python versions print out the first line of a multi-line function
#     266 # calls in the traceback and some print out the last line
# --> 267 _engine_run_backward(
#     268     tensors,
#     269     grad_tensors_,
#     270     retain_graph,
#     271     create_graph,
#     272     inputs,
#     273     allow_unreachable=True,
#     274     accumulate_grad=True,
#     275 )
#
# File c:\Users\user\.conda\envs\torch\lib\site-packages\torch\autograd\graph.py:744, in _engine_run_backward(t_outputs, *args, **kwargs)
#     742     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     743 try:
# --> 744     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     745         t_outputs, *args, **kwargs
#     746     )  # Calls into the C++ engine to run the backward pass
#     747 finally:
#     748     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# ### **3-3. Test Causal Learning**
#
# <blockquote>
#
# This function `test` evaluates the performance of the causal_learning on a given dataset.
#
# It validates the performance, logs the test metrics using *Weights and Biases* (wandb) if `use_wandb` is True, and returns the *test metrics*.
#
# </blockquote>

# %%
causal_learning.test(testset)
# Out:
# {'mse': 120771.546875,
#  'mae': 138.86721801757812,
#  'rmse': 347.5220031738281,
#  'r2': 0.8896623849868774}
