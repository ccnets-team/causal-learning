# %% [markdown]
# Author:
#
#         KIM, JeongYoong, jeongyoong@ccnets.org
#
#     COPYRIGHT (c) 2024. CCNets. All Rights reserved.

# %% [markdown]
# <p align="center">
#   <img src="https://storage.googleapis.com/kaggle-datasets-images/4956778/8344638/a2a6aa289fce8461958dc287f1dab799/dataset-cover.jpg?t=2024-05-07-09-36-53" alt="IMG">
# </p>

# %% [markdown]
# <h1 style = 'font-family: Times New Roman'> <b>|</b><i> 1. Content</i></h1>
#
# <br>
#
# > <h4 style = 'font-family: Times New Roman'>
# This dataset explores how weather conditions impact renewable energy generation. <br><br>Spanning from January 1, 2017, to August 31, 2022, the dataset provides climate data such as temperature, pressure, wind speed, and sunlight duration at 15-minute intervals. <br><br>By incorporating variables like GHI and SunlightTime, it enables the prediction of solar energy production.
#
#
# - DataSource: https://www.kaggle.com/datasets/pythonafroz/renewable-power-generation-and-weather-conditions/data
#
# <hr>
#
# CCNet result: https://wandb.ai/ccnets/causal-learning
#
# <blockquote>
# R&sup2 score: <mark>0.90</mark>
#
# </blockquote>
#
# Benchmark: https://www.kaggle.com/datasets/pythonafroz/renewable-power-generation-and-weather-conditions/code?datasetId=4956778&sortBy=voteCount
# <blockquote>
# R&sup2 score:
#
# - RandomForest: 0.89
# - LSTM: 0.87
# - KNN: 0.80
# - XGBoost: 0.82
#
# </blockquote>
#
# <h1 style = 'font-family: Times New Roman'> <b>|</b><i> 2. About Dataset</i></h1>
#
# <br>
#
# <details>
#     <summary>More Columns Info</summary>
#     17 columns in the dataset, below is <u>description of main features</u>:
#
#     *  (1) Time: The timestamp of the recorded data in the format of YYYY-MM-DD HH:MM:SS.
#
#     *  (2) Energy delta[Wh]: The difference in energy consumption in Watt-hours (Wh) from the previous timestamp to the current timestamp.
#
#     *  (3) GHI: Global Horizontal Irradiance in Watts per square meter (W/m²) measured by a pyranometer.
#
#     *  (4) temp: The temperature in degrees Celsius (°C) measured at the same height as the pyranometer.
#
#     *  (5) pressure: The atmospheric pressure in hectopascals (hPa) measured at the same height as the pyranometer.
#
#     *  (6) humidity: The relative humidity in percentage (%) measured at the same height as the pyranometer.
#
#     *  (7) wind_speed: The wind speed in meters per second (m/s) measured at the same height as the pyranometer.
#
#     *  (8) rain_1h: The amount of precipitation in millimeters (mm) measured over the past hour.
#
#     *  (9) snow_1h: The amount of snowfall in millimeters.
#
#     *  (10) clouds_all: The cloud situation.
# </details>
#
# <h1 style = 'font-family: Times New Roman'> <b>|</b><i> 3. Goal of the Notebook</i></h1>
#
# > <h4 style = 'font-family: Times New Roman'>
# Goal is to train and test model using GPT, Pytorch. <br><br>
#     The Target Column used here is <b>Energy delta[Wh]</b>
# </h4>

# %% [markdown]
# ***

# %% [markdown]
# <a id="1"></a>
# > <h1 style = 'font-family: Times New Roman'><b> <b style = 'color: #42c2f5'>1.</b> Import Necessary Libraries and Dataset</b></h1>

# %%
import os
import sys
import warnings
warnings.filterwarnings("ignore")

path_append = "../../"
sys.path.append(path_append)  # Go up one directory from where you are.

# %%
import pandas  as pd
df = pd.read_csv(path_append + '../data/Renewable Power Generation and weather Conditions/Renewable.csv')
df.head()
# Out:
#                   Time  Energy delta[Wh]  GHI  temp  pressure  humidity  \
# 0  2017-01-01 00:00:00                 0  0.0   1.6      1021       100
# 1  2017-01-01 00:15:00                 0  0.0   1.6      1021       100
# 2  2017-01-01 00:30:00                 0  0.0   1.6      1021       100
# 3  2017-01-01 00:45:00                 0  0.0   1.6      1021       100
# 4  2017-01-01 01:00:00                 0  0.0   1.7      1020       100
#
#    wind_speed  rain_1h  snow_1h  clouds_all  isSun  sunlightTime  dayLength  \
# 0         4.9      0.0      0.0         100      0             0        450
# 1         4.9      0.0      0.0         100      0             0        450
# 2         4.9      0.0      0.0         100      0             0        450
# 3         4.9      0.0      0.0         100      0             0        450
# 4         5.2      0.0      0.0         100      0             0        450
#
#    SunlightTime/daylength  weather_type  hour  month
# 0                     0.0             4     0      1
# 1                     0.0             4     0      1
# 2                     0.0             4     0      1
# 3                     0.0             4     0      1
# 4                     0.0             4     1      1

# %% [markdown]
# <a id="2"></a>
# > <h1 style = 'font-family: Times New Roman'><b> <b style = 'color: #4290f5'>2.</b> Modeling: Preprocess </b></h1>

# %%
from preprocessing.data_frame import auto_preprocess_dataframe
target_columns = ['Energy delta[Wh]']
df, description = auto_preprocess_dataframe(df, target_columns) 

description
# Out:
# Column 'isSun' has 2 unique values.
# Column 'weather_type' has 5 unique values.
#                              Min          Max          Mean          Std  \
# GHI                    -0.034188     4.863248  6.623192e-01     1.114787
# temp                   -3.969044     3.911737  2.426539e-17     1.202485
# pressure               -5.175015     4.285020  3.446264e-15     1.295453
# humidity               -2.818182     0.727273 -1.904288e-01     0.709294
# wind_speed             -3.937746    10.362254  1.191893e-15     1.821694
# rain_1h                -0.066035     8.023965  1.141051e-17     0.278913
# snow_1h                -0.007148     2.812852 -1.306702e-18     0.069710
# clouds_all             -1.801176     0.928938 -1.850958e-16     1.000003
# sunlightTime           -0.076923     2.538462  4.659515e-01     0.702313
# dayLength              -1.723228     1.565768 -7.633489e-17     1.124434
# SunlightTime/daylength -0.265187     0.734813  1.986007e-19     0.329023
# hour                   -1.916601     1.916967 -1.285849e-16     1.153718
# time_scaled            -1.000000     0.979167 -1.050814e-02     0.577294
# day_of_year_sin        -0.999991     0.999991  4.237514e-02     0.703366
# day_of_year_cos        -0.999963     1.000000 -3.146358e-02     0.708870
# month_sin              -1.000000     1.000000  2.745637e-02     0.706813
# month_cos              -1.000000     1.000000 -4.449917e-02     0.705469
# isSun                   0.000000     1.000000  5.199618e-01     0.499603
# weather_type_1          0.000000     1.000000  1.421718e-01     0.349227
# weather_type_2          0.000000     1.000000  1.800423e-01     0.384224
# weather_type_3          0.000000     1.000000  1.608936e-01     0.367434
# weather_type_4          0.000000     1.000000  3.710005e-01     0.483074
# weather_type_5          0.000000     1.000000  1.458918e-01     0.352999
# Energy delta[Wh]        0.000000  5020.000000  5.730082e+02  1044.824047
#
#                         Null Count    Scaled          Encoded
# GHI                              0    Robust             None
# temp                             0    Minmax             None
# pressure                         0    Minmax             None
# humidity                         0    Robust             None
# wind_speed                       0      None             None
# rain_1h                          0      None             None
# snow_1h                          0      None             None
# clouds_all                       0  Standard             None
# sunlightTime                     0    Robust             None
# dayLength                        0    Minmax             None
# SunlightTime/daylength           0      None             None
# hour                             0    Minmax             None
# time_scaled                      0      None  EncodedDateTime
# day_of_year_sin                  0      None  EncodedDateTime
# day_of_year_cos                  0      None  EncodedDateTime
# month_sin                        0      None  EncodedDateTime
# month_cos                        0      None  EncodedDateTime
# isSun                            0      None          One-hot
# weather_type_1                   0      None          One_hot
# weather_type_2                   0      None          One_hot
# weather_type_3                   0      None          One_hot
# weather_type_4                   0      None          One_hot
# weather_type_5                   0      None          One_hot
# Energy delta[Wh]                 0      None             None
# {'num_features': 23,
#  'num_classes': 1,
#  'encoded_columns': Index(['day_of_year_cos', 'day_of_year_sin', 'isSun', 'month_cos', 'month_sin',
#         'time_scaled', 'weather_type'],
#        dtype='object'),
#  'one_hot_encoded_columns': Index(['isSun', 'weather_type'], dtype='object'),
#  'encoded_datatime_columns': Index(['time_scaled', 'day_of_year_sin', 'day_of_year_cos', 'month_sin',
#         'month_cos'],
#        dtype='object'),
#  'scalers': {'GHI': 'robust',
#   'SunlightTime/daylength': 'none',
#   'clouds_all': 'standard',
#   'dayLength': 'minmax',
#   'hour': 'minmax',
#   'humidity': 'robust',
#   'pressure': 'minmax',
#   'rain_1h': 'none',
#   'snow_1h': 'none',
#   'sunlightTime': 'robust',
#   'temp': 'minmax',
#   'wind_speed': 'none'}}

# %%
import torch
from sklearn.model_selection import train_test_split
from preprocessing.dataset import TemplateDataset

max_seq_len = 32
min_seq_len = 16
train_df, test_df = train_test_split(df, test_size=0.2, shuffle=False)
# predict the next value in the sequence
train_df_x = train_df.iloc[:, :-1] # all columns except the last one
train_df_y = train_df.iloc[:, -1:] # only the last column

test_df_x = test_df.iloc[:, :-1] # all columns except the last one
test_df_y = test_df.iloc[:, -1:] # only the last column

print('train df shape: ', train_df.shape)
print('test df shape: ', test_df.shape)
trainset = TemplateDataset(train_df_x, train_df_y, min_seq_len = min_seq_len, max_seq_len=max_seq_len)
testset = TemplateDataset(test_df_x, test_df_y, min_seq_len = max_seq_len, max_seq_len=max_seq_len)
# Out:
# train df shape:  (157420, 24)
# test df shape:  (39356, 24)

# %% [markdown]
# <a id="3"></a>
# > <h1 style = 'font-family: Times New Roman'><b> <b style = 'color: #427bf5'>3.</b> Modeling: Causal Learning</b></h1>

# %% [markdown]
# ### **3-1. Initialize Causal Learning Class**
#
# <blockquote>
#
# Imports the `CausalLearning` class from the causal_learning module.
#
# It then sets the computation device to GPU if available, otherwise to CPU.
#
# Finally, it initializes an instance of the `CausalLearning` class with the machine learning configuration (`ml_config`), data configuration (`data_config`), the specified device, and
#
# additional options (`use_print` and `use_wandb`) for enabling print statements and logging with *Weights & Biases*.
#
# </blockquote>

# %%
from tools.config.data_config import DataConfig
from tools.config.ml_config import MLConfig
from causal_learning import CausalLearning

num_features = description['num_features']
num_classes = description['num_classes']
data_config = DataConfig(dataset_name = 'renewable-power-gen-prediction', task_type='regression', obs_shape=[num_features], label_size=num_classes)

#  Set training configuration from the AlgorithmConfig class, returning them as a Namespace object.
ml_config = MLConfig(model_name = 'gpt')
ml_config.training.error_function = 'mae'
ml_config.training.num_epoch = 20

# Set the device to GPU if available, else CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") 

# Initialize the CausalLearning class with the training configuration, data configuration, device, and use_print and use_wandb flags
causal_learning = CausalLearning(ml_config, data_config, device, use_print=True, use_wandb= False)

# %% [markdown]
# ### **3-2. Train Causal Learning**
#
# <blockquote>
#
# Initiates the training process for the causal learning using the `trainset` and `testset`.
#
# During the training, the model will be trained on the `trainset` and evaluated on the `testset`.
#
# The results of the training and evaluation will include various metrics.
#
# </blockquote>

# %%
causal_learning.train(trainset, testset)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: junhopark (ccnets). Use `wandb login --relogin` to force relogin
# wandb version 0.17.3 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.1
# Run data is saved locally in <code>c:\Users\CCNets-team\Projects\causal-learning\examples\time_series\wandb\run-20240627_232622-35gkqtyp</code>
# Syncing run <strong><a href='https://wandb.ai/ccnets/causal-learning/runs/35gkqtyp' target="_blank">renewable-power-gen-prediction : 24-06-27 23:26:19</a></strong> to <a href='https://wandb.ai/ccnets/causal-learning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ccnets/causal-learning' target="_blank">https://wandb.ai/ccnets/causal-learning</a>
#  View run at <a href='https://wandb.ai/ccnets/causal-learning/runs/35gkqtyp' target="_blank">https://wandb.ai/ccnets/causal-learning/runs/35gkqtyp</a>
# wandb: Adding directory to artifact (.\..\saved\renewable-power-gen-prediction\causal-learning)... Done. 0.0s
# Trainer Name: causal_trainer
#
#
# ModelConfig Parameters:
#    d_model  dropout model_name  num_layers  use_seq_input
# 0      256     0.05        gpt           5           True
# TrainConfig Parameters:
#    batch_size error_function  max_seq_len  min_seq_len  num_epoch
# 0          64            mae           32           16         20
# OptimConfig Parameters:
#   clip_grad_range  decay_rate_100k  learning_rate  max_grad_norm  \
# 0            None             0.05          0.001            1.0
#
#   scheduler_type
# 0    exponential
# DataConfig Parameters:
#                      dataset_name   task_type obs_shape  label_size  \
# 0  renewable-power-gen-prediction  regression      [23]           1
#
#   explain_size show_image_indices
# 0         None               None
# Epochs:   0%|          | 0/20 [00:00<?, ?it/s]
# Iterations:   0%|          | 0/2459 [00:00<?, ?it/s]
# [0/20][100/2459][Time 11.41]
# Unified LR across all optimizers: 0.000996978883189373
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.1093	Gen: 0.4210	Rec: 0.4286	E: 0.1010	R: 0.1142	P: 0.7476
#
# mse: 1146772.2500
# mae: 476.9363
# rmse: 1070.8745
# r2: -0.2326
#
# =====================Eval Metrics========================
# mse: 1348859.5000
# mae: 546.5742
# rmse: 1161.4041
# r2: -0.2689
#
# [0/20][200/2459][Time 10.72]
# Unified LR across all optimizers: 0.0009939966705585644
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0396	Gen: 0.3092	Rec: 0.3081	E: 0.0402	R: 0.0389	P: 0.5866
#
# mse: 1174910.5000
# mae: 490.8178
# rmse: 1083.9329
# r2: -0.2373
#
# =====================Eval Metrics========================
# mse: 1189924.7500
# mae: 496.6674
# rmse: 1090.8367
# r2: -0.2406
#
# [0/20][300/2459][Time 10.87]
# Unified LR across all optimizers: 0.0009910233784699313
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0339	Gen: 0.2870	Rec: 0.2843	E: 0.0357	R: 0.0306	P: 0.5480
#
# mse: 1652514.8750
# mae: 618.8815
# rmse: 1285.5018
# r2: -0.2799
#
# =====================Eval Metrics========================
# mse: 1487683.7500
# mae: 585.6297
# rmse: 1219.7064
# r2: -0.2773
#
# [0/20][400/2459][Time 10.81]
# Unified LR across all optimizers: 0.0009880589802399075
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0309	Gen: 0.2594	Rec: 0.2575	E: 0.0326	R: 0.0291	P: 0.4900
#
# mse: 1454761.7500
# mae: 560.7587
# rmse: 1206.1350
# r2: -0.2483
#
# =====================Eval Metrics========================
# mse: 1359512.1250
# mae: 560.9090
# rmse: 1165.9812
# r2: -0.2735
#
# [0/20][500/2459][Time 10.84]
# Unified LR across all optimizers: 0.000985103449264739
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0261	Gen: 0.2343	Rec: 0.2325	E: 0.0286	R: 0.0243	P: 0.4411
#
# mse: 1183821.0000
# mae: 484.8791
# rmse: 1088.0354
# r2: -0.2170
#
# =====================Eval Metrics========================
# mse: 1511502.2500
# mae: 602.7501
# rmse: 1229.4316
# r2: -0.2852
#
# [0/20][600/2459][Time 10.72]
# Unified LR across all optimizers: 0.0009821567590202554
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0252	Gen: 0.2280	Rec: 0.2254	E: 0.0282	R: 0.0227	P: 0.4300
#
# mse: 1807631.5000
# mae: 672.6368
# rmse: 1344.4818
# r2: -0.3050
#
# =====================Eval Metrics========================
# mse: 1503166.7500
# mae: 612.0321
# rmse: 1226.0370
# r2: -0.2994
#
# [0/20][700/2459][Time 10.74]
# Unified LR across all optimizers: 0.000979218883061626
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0222	Gen: 0.2248	Rec: 0.2221	E: 0.0252	R: 0.0196	P: 0.4266
#
# mse: 1095215.0000
# mae: 487.1768
# rmse: 1046.5251
# r2: -0.2379
#
# =====================Eval Metrics========================
# mse: 913846.0625
# mae: 427.3826
# rmse: 955.9529
# r2: -0.2079
#
# [0/20][800/2459][Time 10.66]
# Unified LR across all optimizers: 0.0009762897950231208
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0218	Gen: 0.2195	Rec: 0.2164	E: 0.0253	R: 0.0191	P: 0.4151
#
# mse: 1232103.7500
# mae: 468.6088
# rmse: 1110.0017
# r2: -0.1804
#
# =====================Eval Metrics========================
# mse: 1557861.8750
# mae: 649.0557
# rmse: 1248.1433
# r2: -0.3293
#
# [0/20][900/2459][Time 10.67]
# Unified LR across all optimizers: 0.0009733694686178784
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0202	Gen: 0.2146	Rec: 0.2116	E: 0.0232	R: 0.0171	P: 0.4078
#
# mse: 1193930.6250
# mae: 494.9088
# rmse: 1092.6713
# r2: -0.2102
#
# =====================Eval Metrics========================
# mse: 1321091.2500
# mae: 528.4614
# rmse: 1149.3873
# r2: -0.2219
#
# [0/20][1000/2459][Time 10.68]
# Unified LR across all optimizers: 0.0009704578776376673
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0203	Gen: 0.2136	Rec: 0.2108	E: 0.0236	R: 0.0178	P: 0.4061
#
# mse: 1463149.7500
# mae: 549.9448
# rmse: 1209.6073
# r2: -0.2090
#
# =====================Eval Metrics========================
# mse: 1137874.1250
# mae: 482.2557
# rmse: 1066.7118
# r2: -0.1980
#
# [0/20][1100/2459][Time 10.74]
# Unified LR across all optimizers: 0.0009675549959526509
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0206	Gen: 0.1959	Rec: 0.1923	E: 0.0247	R: 0.0171	P: 0.3689
#
# mse: 1250937.6250
# mae: 516.0073
# rmse: 1118.4532
# r2: -0.2101
#
# =====================Eval Metrics========================
# mse: 1206739.7500
# mae: 509.4271
# rmse: 1098.5171
# r2: -0.2131
#
# [0/20][1200/2459][Time 10.72]
# Unified LR across all optimizers: 0.0009646607975111544
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0203	Gen: 0.1763	Rec: 0.1726	E: 0.0246	R: 0.0168	P: 0.3293
#
# mse: 1142004.2500
# mae: 495.8697
# rmse: 1068.6460
# r2: -0.2029
#
# =====================Eval Metrics========================
# mse: 1080093.8750
# mae: 481.8925
# rmse: 1039.2756
# r2: -0.1979
#
# [0/20][1300/2459][Time 10.63]
# Unified LR across all optimizers: 0.0009617752563394297
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0191	Gen: 0.1660	Rec: 0.1624	E: 0.0232	R: 0.0155	P: 0.3113
#
# mse: 1343359.0000
# mae: 542.7187
# rmse: 1159.0337
# r2: -0.2152
#
# =====================Eval Metrics========================
# mse: 1343833.0000
# mae: 542.0226
# rmse: 1159.2382
# r2: -0.2164
#
# [0/20][1400/2459][Time 10.70]
# Unified LR across all optimizers: 0.0009588983465414223
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0189	Gen: 0.1589	Rec: 0.1554	E: 0.0231	R: 0.0156	P: 0.2974
#
# mse: 1556732.6250
# mae: 623.0415
# rmse: 1247.6909
# r2: -0.2465
#
# =====================Eval Metrics========================
# mse: 1244109.7500
# mae: 515.4204
# rmse: 1115.3967
# r2: -0.1922
#
# [0/20][1500/2459][Time 10.71]
# Unified LR across all optimizers: 0.0009560300422985396
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0178	Gen: 0.1559	Rec: 0.1529	E: 0.0209	R: 0.0148	P: 0.2932
#
# mse: 1539802.2500
# mae: 602.0186
# rmse: 1240.8877
# r2: -0.2240
#
# =====================Eval Metrics========================
# mse: 1345317.1250
# mae: 575.0476
# rmse: 1159.8781
# r2: -0.2267
#
# [0/20][1600/2459][Time 10.69]
# Unified LR across all optimizers: 0.0009531703178694185
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0180	Gen: 0.1527	Rec: 0.1493	E: 0.0213	R: 0.0145	P: 0.2853
#
# mse: 950843.8125
# mae: 411.6671
# rmse: 975.1122
# r2: -0.1204
#
# =====================Eval Metrics========================
# mse: 1498867.7500
# mae: 604.7795
# rmse: 1224.2826
# r2: -0.2247
#
# [0/20][1700/2459][Time 10.82]
# Unified LR across all optimizers: 0.0009503191475896951
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0180	Gen: 0.1462	Rec: 0.1430	E: 0.0220	R: 0.0150	P: 0.2729
#
# mse: 1568022.3750
# mae: 588.1022
# rmse: 1252.2070
# r2: -0.1953
#
# =====================Eval Metrics========================
# mse: 1364909.1250
# mae: 568.1454
# rmse: 1168.2932
# r2: -0.2039
#
# [0/20][1800/2459][Time 10.84]
# Unified LR across all optimizers: 0.0009474765058717739
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0182	Gen: 0.1411	Rec: 0.1379	E: 0.0215	R: 0.0151	P: 0.2628
#
# mse: 1114709.5000
# mae: 498.5009
# rmse: 1055.7981
# r2: -0.1702
#
# =====================Eval Metrics========================
# mse: 1383871.7500
# mae: 587.4283
# rmse: 1176.3807
# r2: -0.2134
#
# [0/20][1900/2459][Time 10.91]
# Unified LR across all optimizers: 0.0009446423672045985
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0200	Gen: 0.1277	Rec: 0.1241	E: 0.0239	R: 0.0165	P: 0.2334
#
# mse: 987456.3750
# mae: 428.9051
# rmse: 993.7084
# r2: -0.1117
#
# =====================Eval Metrics========================
# mse: 1545453.5000
# mae: 618.8280
# rmse: 1243.1627
# r2: -0.2197
#
# [0/20][2000/2459][Time 10.80]
# Unified LR across all optimizers: 0.0009418167061534219
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0191	Gen: 0.1197	Rec: 0.1163	E: 0.0223	R: 0.0155	P: 0.2179
#
# mse: 1256433.0000
# mae: 503.5834
# rmse: 1120.9072
# r2: -0.1331
#
# =====================Eval Metrics========================
# mse: 1330655.5000
# mae: 586.7349
# rmse: 1153.5404
# r2: -0.2137
#
# [0/20][2100/2459][Time 10.70]
# Unified LR across all optimizers: 0.0009389994973595789
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0177	Gen: 0.1143	Rec: 0.1107	E: 0.0221	R: 0.0142	P: 0.2088
#
# mse: 1642942.2500
# mae: 580.2173
# rmse: 1281.7731
# r2: -0.1390
#
# =====================Eval Metrics========================
# mse: 1136507.1250
# mae: 526.9311
# rmse: 1066.0709
# r2: -0.1747
#
# [0/20][2200/2459][Time 10.72]
# Unified LR across all optimizers: 0.0009361907155402595
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0176	Gen: 0.1074	Rec: 0.1039	E: 0.0213	R: 0.0141	P: 0.1945
#
# mse: 804317.5000
# mae: 375.9557
# rmse: 896.8375
# r2: -0.0682
#
# =====================Eval Metrics========================
# mse: 1728777.0000
# mae: 660.0430
# rmse: 1314.8296
# r2: -0.2001
#
# [0/20][2300/2459][Time 10.83]
# Unified LR across all optimizers: 0.0009333903354882786
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0167	Gen: 0.0984	Rec: 0.0951	E: 0.0206	R: 0.0136	P: 0.1772
#
# mse: 1198077.0000
# mae: 535.9364
# rmse: 1094.5670
# r2: -0.1584
#
# =====================Eval Metrics========================
# mse: 1217389.0000
# mae: 525.7008
# rmse: 1103.3535
# r2: -0.1396
#
# [0/20][2400/2459][Time 10.85]
# Unified LR across all optimizers: 0.0009305983320718549
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0170	Gen: 0.0929	Rec: 0.0891	E: 0.0217	R: 0.0133	P: 0.1656
#
# mse: 1413972.5000
# mae: 541.6040
# rmse: 1189.1057
# r2: -0.1208
#
# =====================Eval Metrics========================
# mse: 1151069.5000
# mae: 548.8190
# rmse: 1072.8790
# r2: -0.1801
# Iterations:   0%|          | 0/2459 [00:00<?, ?it/s]
# [1/20][41/2459][Time 10.77]
# Unified LR across all optimizers: 0.0009278146802343803
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0160	Gen: 0.0902	Rec: 0.0867	E: 0.0198	R: 0.0124	P: 0.1617
#
# mse: 1092314.3750
# mae: 493.7185
# rmse: 1045.1384
# r2: -0.1205
#
# =====================Eval Metrics========================
# mse: 1261237.1250
# mae: 544.5151
# rmse: 1123.0481
# r2: -0.1457
#
# [1/20][141/2459][Time 10.65]
# Unified LR across all optimizers: 0.0009250393549941983
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0156	Gen: 0.0885	Rec: 0.0856	E: 0.0187	R: 0.0128	P: 0.1601
#
# mse: 1462527.5000
# mae: 587.6287
# rmse: 1209.3500
# r2: -0.1538
#
# =====================Eval Metrics========================
# mse: 1112373.0000
# mae: 497.9049
# rmse: 1054.6909
# r2: -0.1165
#
# [1/20][241/2459][Time 10.72]
# Unified LR across all optimizers: 0.0009222723314443782
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0152	Gen: 0.0858	Rec: 0.0830	E: 0.0184	R: 0.0126	P: 0.1554
#
# mse: 1371221.6250
# mae: 540.1681
# rmse: 1170.9917
# r2: -0.1144
#
# =====================Eval Metrics========================
# mse: 1090298.5000
# mae: 491.9818
# rmse: 1044.1736
# r2: -0.1129
#
# [1/20][341/2459][Time 10.84]
# Unified LR across all optimizers: 0.0009195135847524926
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0150	Gen: 0.0854	Rec: 0.0820	E: 0.0190	R: 0.0117	P: 0.1535
#
# mse: 1353196.3750
# mae: 532.1146
# rmse: 1163.2697
# r2: -0.1076
#
# =====================Eval Metrics========================
# mse: 1164925.0000
# mae: 533.2285
# rmse: 1079.3169
# r2: -0.1335
#
# [1/20][441/2459][Time 10.64]
# Unified LR across all optimizers: 0.0009167630901603946
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0142	Gen: 0.0826	Rec: 0.0792	E: 0.0176	R: 0.0108	P: 0.1491
#
# mse: 993896.5000
# mae: 434.8206
# rmse: 996.9436
# r2: -0.0514
#
# =====================Eval Metrics========================
# mse: 1365838.7500
# mae: 580.5576
# rmse: 1168.6910
# r2: -0.1360
#
# [1/20][541/2459][Time 10.79]
# Unified LR across all optimizers: 0.0009140208229839937
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0143	Gen: 0.0824	Rec: 0.0788	E: 0.0182	R: 0.0107	P: 0.1483
#
# mse: 1564259.6250
# mae: 611.3767
# rmse: 1250.7036
# r2: -0.1227
#
# =====================Eval Metrics========================
# mse: 1531690.8750
# mae: 617.4194
# rmse: 1237.6150
# r2: -0.1431
#
# [1/20][641/2459][Time 10.66]
# Unified LR across all optimizers: 0.0009112867586130364
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0133	Gen: 0.0803	Rec: 0.0772	E: 0.0167	R: 0.0102	P: 0.1459
#
# mse: 1439632.5000
# mae: 571.5236
# rmse: 1199.8469
# r2: -0.1048
#
# =====================Eval Metrics========================
# mse: 1240075.8750
# mae: 506.4855
# rmse: 1113.5869
# r2: -0.0765
#
# [1/20][741/2459][Time 10.82]
# Unified LR across all optimizers: 0.0009085608725108856
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0134	Gen: 0.0785	Rec: 0.0755	E: 0.0163	R: 0.0105	P: 0.1416
#
# mse: 860781.3750
# mae: 396.5544
# rmse: 927.7830
# r2: -0.0128
#
# =====================Eval Metrics========================
# mse: 1315216.6250
# mae: 563.5830
# rmse: 1146.8290
# r2: -0.1052
#
# [1/20][841/2459][Time 10.70]
# Unified LR across all optimizers: 0.0009058431402142976
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0141	Gen: 0.0782	Rec: 0.0746	E: 0.0188	R: 0.0106	P: 0.1403
#
# mse: 1142435.8750
# mae: 494.9907
# rmse: 1068.8479
# r2: -0.0543
#
# =====================Eval Metrics========================
# mse: 1168051.2500
# mae: 506.3445
# rmse: 1080.7642
# r2: -0.0548
#
# [1/20][941/2459][Time 10.79]
# Unified LR across all optimizers: 0.0009031335373332055
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0137	Gen: 0.0796	Rec: 0.0763	E: 0.0170	R: 0.0102	P: 0.1435
#
# mse: 1250542.1250
# mae: 521.7087
# rmse: 1118.2764
# r2: -0.0564
#
# =====================Eval Metrics========================
# mse: 1206864.0000
# mae: 506.3254
# rmse: 1098.5736
# r2: -0.0549
#
# [1/20][1041/2459][Time 10.80]
# Unified LR across all optimizers: 0.0009004320395504991
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0138	Gen: 0.0768	Rec: 0.0736	E: 0.0179	R: 0.0105	P: 0.1378
#
# mse: 1296877.6250
# mae: 552.4495
# rmse: 1138.8053
# r2: -0.0665
#
# =====================Eval Metrics========================
# mse: 1321376.0000
# mae: 583.8079
# rmse: 1149.5112
# r2: -0.0813
#
# [1/20][1141/2459][Time 10.72]
# Unified LR across all optimizers: 0.000897738622621806
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0128	Gen: 0.0751	Rec: 0.0723	E: 0.0154	R: 0.0100	P: 0.1355
#
# mse: 827964.8750
# mae: 398.6083
# rmse: 909.9258
# r2: 0.0234
#
# =====================Eval Metrics========================
# mse: 1419842.8750
# mae: 588.5181
# rmse: 1191.5717
# r2: -0.0733
#
# [1/20][1241/2459][Time 10.77]
# Unified LR across all optimizers: 0.0008950532623752764
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0121	Gen: 0.0745	Rec: 0.0719	E: 0.0151	R: 0.0093	P: 0.1359
#
# mse: 1071873.0000
# mae: 431.1474
# rmse: 1035.3130
# r2: 0.0267
#
# =====================Eval Metrics========================
# mse: 1037035.8125
# mae: 443.3945
# rmse: 1018.3495
# r2: 0.0196
#
# [1/20][1341/2459][Time 10.70]
# Unified LR across all optimizers: 0.0008923759347113617
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0115	Gen: 0.0750	Rec: 0.0718	E: 0.0149	R: 0.0083	P: 0.1366
#
# mse: 996698.1250
# mae: 419.2978
# rmse: 998.3477
# r2: 0.0426
#
# =====================Eval Metrics========================
# mse: 1030463.0000
# mae: 446.7907
# rmse: 1015.1172
# r2: 0.0411
#
# [1/20][1441/2459][Time 10.88]
# Unified LR across all optimizers: 0.000889706615602604
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0111	Gen: 0.0723	Rec: 0.0693	E: 0.0140	R: 0.0081	P: 0.1316
#
# mse: 1223800.6250
# mae: 476.6942
# rmse: 1106.2552
# r2: 0.0355
#
# =====================Eval Metrics========================
# mse: 886507.6250
# mae: 414.8755
# rmse: 941.5453
# r2: 0.0699
#
# [1/20][1541/2459][Time 10.71]
# Unified LR across all optimizers: 0.0008870452810934158
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0110	Gen: 0.0728	Rec: 0.0700	E: 0.0142	R: 0.0086	P: 0.1330
#
# mse: 1120470.5000
# mae: 458.2902
# rmse: 1058.5228
# r2: 0.0490
#
# =====================Eval Metrics========================
# mse: 927494.6250
# mae: 468.5174
# rmse: 963.0652
# r2: 0.0564
#
# [1/20][1641/2459][Time 10.76]
# Unified LR across all optimizers: 0.0008843919072998678
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0109	Gen: 0.0711	Rec: 0.0680	E: 0.0142	R: 0.0078	P: 0.1299
#
# mse: 1030181.7500
# mae: 442.8852
# rmse: 1014.9787
# r2: 0.0721
#
# =====================Eval Metrics========================
# mse: 1060246.2500
# mae: 464.3084
# rmse: 1029.6826
# r2: 0.0657
#
# [1/20][1741/2459][Time 10.66]
# Unified LR across all optimizers: 0.0008817464704094733
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0103	Gen: 0.0717	Rec: 0.0691	E: 0.0130	R: 0.0076	P: 0.1326
#
# mse: 869540.2500
# mae: 406.5834
# rmse: 932.4914
# r2: 0.1149
#
# =====================Eval Metrics========================
# mse: 904401.7500
# mae: 426.6136
# rmse: 951.0004
# r2: 0.0990
#
# [1/20][1841/2459][Time 10.77]
# Unified LR across all optimizers: 0.0008791089466809735
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0103	Gen: 0.0703	Rec: 0.0675	E: 0.0138	R: 0.0075	P: 0.1288
#
# mse: 961345.8125
# mae: 418.4412
# rmse: 980.4824
# r2: 0.1200
#
# =====================Eval Metrics========================
# mse: 918403.2500
# mae: 435.6794
# rmse: 958.3336
# r2: 0.1115
#
# [1/20][1941/2459][Time 10.69]
# Unified LR across all optimizers: 0.0008764793124441268
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0107	Gen: 0.0704	Rec: 0.0674	E: 0.0143	R: 0.0077	P: 0.1288
#
# mse: 833695.5000
# mae: 405.5945
# rmse: 913.0693
# r2: 0.1472
#
# =====================Eval Metrics========================
# mse: 992096.1875
# mae: 450.5170
# rmse: 996.0403
# r2: 0.1211
#
# [1/20][2041/2459][Time 10.67]
# Unified LR across all optimizers: 0.0008738575440994944
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0100	Gen: 0.0679	Rec: 0.0650	E: 0.0129	R: 0.0070	P: 0.1240
#
# mse: 1056406.2500
# mae: 435.2721
# rmse: 1027.8163
# r2: 0.1371
#
# =====================Eval Metrics========================
# mse: 734670.6875
# mae: 348.8453
# rmse: 857.1293
# r2: 0.1846
#
# [1/20][2141/2459][Time 10.61]
# Unified LR across all optimizers: 0.0008712436181182304
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0097	Gen: 0.0663	Rec: 0.0634	E: 0.0125	R: 0.0067	P: 0.1215
#
# mse: 1006893.2500
# mae: 414.6392
# rmse: 1003.4407
# r2: 0.1523
#
# =====================Eval Metrics========================
# mse: 1033338.1875
# mae: 467.0641
# rmse: 1016.5324
# r2: 0.1385
#
# [1/20][2241/2459][Time 10.58]
# Unified LR across all optimizers: 0.0008686375110418687
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0102	Gen: 0.0670	Rec: 0.0641	E: 0.0140	R: 0.0074	P: 0.1228
#
# mse: 1033274.1250
# mae: 463.2850
# rmse: 1016.5009
# r2: 0.1603
#
# =====================Eval Metrics========================
# mse: 879686.5000
# mae: 418.3940
# rmse: 937.9160
# r2: 0.1787
#
# [1/20][2341/2459][Time 10.75]
# Unified LR across all optimizers: 0.0008660391994821131
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0096	Gen: 0.0670	Rec: 0.0641	E: 0.0124	R: 0.0067	P: 0.1230
#
# mse: 938175.6250
# mae: 417.9410
# rmse: 968.5947
# r2: 0.1838
#
# =====================Eval Metrics========================
# mse: 846933.5000
# mae: 407.8173
# rmse: 920.2899
# r2: 0.1993
#
# [1/20][2441/2459][Time 10.91]
# Unified LR across all optimizers: 0.0008634486601206292
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0090	Gen: 0.0672	Rec: 0.0646	E: 0.0115	R: 0.0065	P: 0.1244
#
# mse: 757996.9375
# mae: 369.7033
# rmse: 870.6302
# r2: 0.2381
#
# =====================Eval Metrics========================
# mse: 980903.2500
# mae: 457.8763
# rmse: 990.4056
# r2: 0.1920
# Iterations:   0%|          | 0/2459 [00:00<?, ?it/s]
# [2/20][82/2459][Time 10.93]
# Unified LR across all optimizers: 0.0008608658697088319
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0093	Gen: 0.0665	Rec: 0.0636	E: 0.0125	R: 0.0065	P: 0.1220
#
# mse: 597022.4375
# mae: 315.2848
# rmse: 772.6722
# r2: 0.2714
#
# =====================Eval Metrics========================
# mse: 800741.5625
# mae: 410.9911
# rmse: 894.8416
# r2: 0.2302
#
# [2/20][182/2459][Time 10.92]
# Unified LR across all optimizers: 0.0008582908050676784
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0095	Gen: 0.0650	Rec: 0.0621	E: 0.0130	R: 0.0066	P: 0.1188
#
# mse: 812791.1250
# mae: 352.5320
# rmse: 901.5493
# r2: 0.2587
#
# =====================Eval Metrics========================
# mse: 1010760.7500
# mae: 473.7979
# rmse: 1005.3660
# r2: 0.1928
#
# [2/20][282/2459][Time 10.77]
# Unified LR across all optimizers: 0.0008557234430874619
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0092	Gen: 0.0647	Rec: 0.0619	E: 0.0123	R: 0.0064	P: 0.1189
#
# mse: 763625.0000
# mae: 368.7975
# rmse: 873.8564
# r2: 0.2757
#
# =====================Eval Metrics========================
# mse: 1162816.0000
# mae: 535.8054
# rmse: 1078.3395
# r2: 0.1887
#
# [2/20][382/2459][Time 10.82]
# Unified LR across all optimizers: 0.0008531637607276009
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0097	Gen: 0.0646	Rec: 0.0615	E: 0.0136	R: 0.0068	P: 0.1178
#
# mse: 823757.6875
# mae: 382.7923
# rmse: 907.6110
# r2: 0.2730
#
# =====================Eval Metrics========================
# mse: 908071.0000
# mae: 428.5962
# rmse: 952.9276
# r2: 0.2495
#
# [2/20][482/2459][Time 10.77]
# Unified LR across all optimizers: 0.0008506117350164344
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0088	Gen: 0.0627	Rec: 0.0604	E: 0.0116	R: 0.0066	P: 0.1160
#
# mse: 682179.2500
# mae: 349.2250
# rmse: 825.9414
# r2: 0.3205
#
# =====================Eval Metrics========================
# mse: 668646.0000
# mae: 339.7921
# rmse: 817.7078
# r2: 0.3113
#
# [2/20][582/2459][Time 10.81]
# Unified LR across all optimizers: 0.0008480673430510153
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0091	Gen: 0.0641	Rec: 0.0616	E: 0.0116	R: 0.0065	P: 0.1183
#
# mse: 790819.1250
# mae: 387.6646
# rmse: 889.2801
# r2: 0.3100
#
# =====================Eval Metrics========================
# mse: 625382.5000
# mae: 324.4762
# rmse: 790.8113
# r2: 0.3528
#
# [2/20][682/2459][Time 10.88]
# Unified LR across all optimizers: 0.0008455305619969057
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0089	Gen: 0.0638	Rec: 0.0611	E: 0.0119	R: 0.0063	P: 0.1174
#
# mse: 802230.1250
# mae: 386.4857
# rmse: 895.6730
# r2: 0.3226
#
# =====================Eval Metrics========================
# mse: 642398.1250
# mae: 347.7144
# rmse: 801.4974
# r2: 0.3652
#
# [2/20][782/2459][Time 10.77]
# Unified LR across all optimizers: 0.0008430013690879698
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0092	Gen: 0.0622	Rec: 0.0593	E: 0.0130	R: 0.0064	P: 0.1134
#
# mse: 757946.7500
# mae: 348.0838
# rmse: 870.6014
# r2: 0.3391
#
# =====================Eval Metrics========================
# mse: 734204.6875
# mae: 365.8658
# rmse: 856.8574
# r2: 0.3502
#
# [2/20][882/2459][Time 10.70]
# Unified LR across all optimizers: 0.0008404797416261722
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0089	Gen: 0.0617	Rec: 0.0592	E: 0.0113	R: 0.0063	P: 0.1135
#
# mse: 907777.6250
# mae: 425.1815
# rmse: 952.7736
# r2: 0.3309
#
# =====================Eval Metrics========================
# mse: 805076.0625
# mae: 404.4780
# rmse: 897.2603
# r2: 0.3509
#
# [2/20][982/2459][Time 10.83]
# Unified LR across all optimizers: 0.0008379656569813726
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0086	Gen: 0.0617	Rec: 0.0591	E: 0.0115	R: 0.0060	P: 0.1138
#
# mse: 745105.8125
# mae: 371.4659
# rmse: 863.1951
# r2: 0.3738
#
# =====================Eval Metrics========================
# mse: 576024.1875
# mae: 326.9135
# rmse: 758.9626
# r2: 0.4155
#
# [2/20][1082/2459][Time 10.85]
# Unified LR across all optimizers: 0.0008354590925911228
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0094	Gen: 0.0626	Rec: 0.0595	E: 0.0147	R: 0.0066	P: 0.1136
#
# mse: 743110.5000
# mae: 372.4095
# rmse: 862.0386
# r2: 0.3817
#
# =====================Eval Metrics========================
# mse: 657838.9375
# mae: 362.3700
# rmse: 811.0727
# r2: 0.4046
#
# [2/20][1182/2459][Time 10.65]
# Unified LR across all optimizers: 0.0008329600259604655
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0090	Gen: 0.0616	Rec: 0.0589	E: 0.0121	R: 0.0063	P: 0.1125
#
# mse: 581969.7500
# mae: 335.3188
# rmse: 762.8694
# r2: 0.4432
#
# =====================Eval Metrics========================
# mse: 651667.7500
# mae: 339.6509
# rmse: 807.2594
# r2: 0.4210
#
# [2/20][1282/2459][Time 10.70]
# Unified LR across all optimizers: 0.0008304684346617307
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0089	Gen: 0.0608	Rec: 0.0582	E: 0.0110	R: 0.0062	P: 0.1112
#
# mse: 467556.1562
# mae: 301.1713
# rmse: 683.7808
# r2: 0.4504
#
# =====================Eval Metrics========================
# mse: 556068.8750
# mae: 316.6231
# rmse: 745.7003
# r2: 0.4755
#
# [2/20][1382/2459][Time 10.69]
# Unified LR across all optimizers: 0.0008279842963343345
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0093	Gen: 0.0596	Rec: 0.0566	E: 0.0124	R: 0.0061	P: 0.1082
#
# mse: 447923.8750
# mae: 275.7454
# rmse: 669.2712
# r2: 0.5107
#
# =====================Eval Metrics========================
# mse: 470243.7500
# mae: 294.8622
# rmse: 685.7432
# r2: 0.4970
#
# [2/20][1482/2459][Time 10.75]
# Unified LR across all optimizers: 0.0008255075886845802
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0088	Gen: 0.0600	Rec: 0.0576	E: 0.0122	R: 0.0066	P: 0.1098
#
# mse: 603063.5000
# mae: 335.4573
# rmse: 776.5717
# r2: 0.4808
#
# =====================Eval Metrics========================
# mse: 547847.0000
# mae: 307.4966
# rmse: 740.1669
# r2: 0.4740
#
# [2/20][1582/2459][Time 10.76]
# Unified LR across all optimizers: 0.0008230382894854561
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0086	Gen: 0.0589	Rec: 0.0564	E: 0.0113	R: 0.0060	P: 0.1082
#
# mse: 510235.9375
# mae: 275.6066
# rmse: 714.3080
# r2: 0.5007
#
# =====================Eval Metrics========================
# mse: 710825.9375
# mae: 394.9317
# rmse: 843.1049
# r2: 0.4610
#
# [2/20][1682/2459][Time 10.89]
# Unified LR across all optimizers: 0.0008205763765764379
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0086	Gen: 0.0583	Rec: 0.0555	E: 0.0116	R: 0.0059	P: 0.1065
#
# mse: 476894.0312
# mae: 294.5287
# rmse: 690.5751
# r2: 0.5412
#
# =====================Eval Metrics========================
# mse: 507541.8125
# mae: 289.7358
# rmse: 712.4197
# r2: 0.5304
#
# [2/20][1782/2459][Time 10.79]
# Unified LR across all optimizers: 0.0008181218278632888
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0086	Gen: 0.0584	Rec: 0.0557	E: 0.0111	R: 0.0057	P: 0.1072
#
# mse: 596239.8125
# mae: 331.8425
# rmse: 772.1656
# r2: 0.5141
#
# =====================Eval Metrics========================
# mse: 443448.8438
# mae: 307.1830
# rmse: 665.9196
# r2: 0.5713
#
# [2/20][1882/2459][Time 10.88]
# Unified LR across all optimizers: 0.0008156746213178617
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0087	Gen: 0.0584	Rec: 0.0560	E: 0.0110	R: 0.0064	P: 0.1075
#
# mse: 385273.9688
# mae: 243.1127
# rmse: 620.7044
# r2: 0.5856
#
# =====================Eval Metrics========================
# mse: 581015.3750
# mae: 349.9295
# rmse: 762.2437
# r2: 0.5408
#
# [2/20][1982/2459][Time 10.80]
# Unified LR across all optimizers: 0.0008132347349779003
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0088	Gen: 0.0580	Rec: 0.0554	E: 0.0116	R: 0.0063	P: 0.1059
#
# mse: 458781.0000
# mae: 287.6292
# rmse: 677.3337
# r2: 0.5815
#
# =====================Eval Metrics========================
# mse: 652774.1875
# mae: 385.5874
# rmse: 807.9444
# r2: 0.5360
#
# [2/20][2082/2459][Time 10.72]
# Unified LR across all optimizers: 0.0008108021469468434
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0091	Gen: 0.0576	Rec: 0.0549	E: 0.0118	R: 0.0064	P: 0.1047
#
# mse: 539830.7500
# mae: 304.4546
# rmse: 734.7318
# r2: 0.5699
#
# =====================Eval Metrics========================
# mse: 457236.2500
# mae: 297.5197
# rmse: 676.1924
# r2: 0.5922
#
# [2/20][2182/2459][Time 10.72]
# Unified LR across all optimizers: 0.0008083768353936277
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0089	Gen: 0.0576	Rec: 0.0550	E: 0.0117	R: 0.0062	P: 0.1051
#
# mse: 490376.9375
# mae: 300.0801
# rmse: 700.2692
# r2: 0.5742
#
# =====================Eval Metrics========================
# mse: 346140.8125
# mae: 241.6685
# rmse: 588.3373
# r2: 0.6039
#
# [2/20][2282/2459][Time 10.78]
# Unified LR across all optimizers: 0.0008059587785524923
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0079	Gen: 0.0572	Rec: 0.0549	E: 0.0107	R: 0.0058	P: 0.1061
#
# mse: 520250.9062
# mae: 306.7514
# rmse: 721.2842
# r2: 0.5837
#
# =====================Eval Metrics========================
# mse: 423584.5938
# mae: 273.6694
# rmse: 650.8337
# r2: 0.6264
#
# [2/20][2382/2459][Time 10.79]
# Unified LR across all optimizers: 0.0008035479547227831
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0082	Gen: 0.0554	Rec: 0.0529	E: 0.0108	R: 0.0058	P: 0.1016
#
# mse: 513458.0312
# mae: 318.0415
# rmse: 716.5599
# r2: 0.6139
#
# =====================Eval Metrics========================
# mse: 334756.8125
# mae: 252.8729
# rmse: 578.5817
# r2: 0.6775
# Iterations:   0%|          | 0/2459 [00:00<?, ?it/s]
# [3/20][23/2459][Time 10.91]
# Unified LR across all optimizers: 0.0008011443422687582
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0086	Gen: 0.0551	Rec: 0.0524	E: 0.0118	R: 0.0061	P: 0.1005
#
# mse: 557618.0000
# mae: 319.7169
# rmse: 746.7382
# r2: 0.5978
#
# =====================Eval Metrics========================
# mse: 258545.9688
# mae: 220.9539
# rmse: 508.4742
# r2: 0.7111
#
# [3/20][123/2459][Time 10.78]
# Unified LR across all optimizers: 0.0007987479196193923
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0087	Gen: 0.0555	Rec: 0.0528	E: 0.0116	R: 0.0058	P: 0.1008
#
# mse: 408359.1562
# mae: 256.8654
# rmse: 639.0298
# r2: 0.6397
#
# =====================Eval Metrics========================
# mse: 518665.9688
# mae: 339.2183
# rmse: 720.1847
# r2: 0.6026
#
# [3/20][223/2459][Time 10.84]
# Unified LR across all optimizers: 0.0007963586652681868
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0083	Gen: 0.0545	Rec: 0.0521	E: 0.0111	R: 0.0060	P: 0.1001
#
# mse: 383746.3438
# mae: 253.3730
# rmse: 619.4727
# r2: 0.6459
#
# =====================Eval Metrics========================
# mse: 297975.5312
# mae: 223.6830
# rmse: 545.8713
# r2: 0.6787
#
# [3/20][323/2459][Time 10.82]
# Unified LR across all optimizers: 0.0007939765577729723
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0087	Gen: 0.0545	Rec: 0.0517	E: 0.0116	R: 0.0060	P: 0.0992
#
# mse: 424269.2188
# mae: 267.6004
# rmse: 651.3595
# r2: 0.6494
#
# =====================Eval Metrics========================
# mse: 218720.2031
# mae: 196.4522
# rmse: 467.6753
# r2: 0.7249
#
# [3/20][423/2459][Time 10.65]
# Unified LR across all optimizers: 0.0007916015757557189
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0082	Gen: 0.0541	Rec: 0.0516	E: 0.0106	R: 0.0056	P: 0.0987
#
# mse: 318115.8750
# mae: 220.7120
# rmse: 564.0176
# r2: 0.6663
#
# =====================Eval Metrics========================
# mse: 392033.4062
# mae: 260.3780
# rmse: 626.1257
# r2: 0.6687
#
# [3/20][523/2459][Time 10.76]
# Unified LR across all optimizers: 0.0007892336979023447
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0083	Gen: 0.0533	Rec: 0.0508	E: 0.0110	R: 0.0058	P: 0.0981
#
# mse: 394513.0000
# mae: 265.7590
# rmse: 628.1027
# r2: 0.6790
#
# =====================Eval Metrics========================
# mse: 278523.0625
# mae: 224.0108
# rmse: 527.7529
# r2: 0.7147
#
# [3/20][623/2459][Time 10.67]
# Unified LR across all optimizers: 0.0007868729029625218
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0085	Gen: 0.0513	Rec: 0.0484	E: 0.0117	R: 0.0058	P: 0.0923
#
# mse: 465957.2500
# mae: 292.6860
# rmse: 682.6106
# r2: 0.6674
#
# =====================Eval Metrics========================
# mse: 256645.3594
# mae: 210.4368
# rmse: 506.6018
# r2: 0.7197
#
# [3/20][723/2459][Time 10.78]
# Unified LR across all optimizers: 0.0007845191697494887
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0083	Gen: 0.0517	Rec: 0.0491	E: 0.0107	R: 0.0056	P: 0.0941
#
# mse: 293543.0000
# mae: 217.1133
# rmse: 541.7961
# r2: 0.7021
#
# =====================Eval Metrics========================
# mse: 330808.0312
# mae: 254.0874
# rmse: 575.1591
# r2: 0.7200
#
# [3/20][823/2459][Time 10.72]
# Unified LR across all optimizers: 0.0007821724771398585
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0089	Gen: 0.0516	Rec: 0.0486	E: 0.0119	R: 0.0059	P: 0.0929
#
# mse: 201711.2656
# mae: 186.7368
# rmse: 449.1228
# r2: 0.7651
#
# =====================Eval Metrics========================
# mse: 322799.5625
# mae: 242.0148
# rmse: 568.1545
# r2: 0.7026
#
# [3/20][923/2459][Time 10.97]
# Unified LR across all optimizers: 0.0007798328040734291
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0086	Gen: 0.0502	Rec: 0.0474	E: 0.0116	R: 0.0058	P: 0.0902
#
# mse: 364086.0312
# mae: 242.2107
# rmse: 603.3954
# r2: 0.6909
#
# =====================Eval Metrics========================
# mse: 296841.0000
# mae: 248.6063
# rmse: 544.8312
# r2: 0.7286
#
# [3/20][1023/2459][Time 10.85]
# Unified LR across all optimizers: 0.0007775001295529957
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0090	Gen: 0.0508	Rec: 0.0479	E: 0.0116	R: 0.0060	P: 0.0912
#
# mse: 246341.1250
# mae: 195.2990
# rmse: 496.3276
# r2: 0.7396
#
# =====================Eval Metrics========================
# mse: 264872.5000
# mae: 229.1360
# rmse: 514.6577
# r2: 0.7684
#
# [3/20][1123/2459][Time 10.97]
# Unified LR across all optimizers: 0.00077517443264416
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0091	Gen: 0.0504	Rec: 0.0475	E: 0.0121	R: 0.0061	P: 0.0908
#
# mse: 294207.6875
# mae: 251.2456
# rmse: 542.4092
# r2: 0.7380
#
# =====================Eval Metrics========================
# mse: 279305.8125
# mae: 231.1333
# rmse: 528.4939
# r2: 0.7635
#
# [3/20][1223/2459][Time 10.87]
# Unified LR across all optimizers: 0.000772855692475145
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0093	Gen: 0.0519	Rec: 0.0488	E: 0.0126	R: 0.0061	P: 0.0932
#
# mse: 361983.2812
# mae: 255.2526
# rmse: 601.6505
# r2: 0.7012
#
# =====================Eval Metrics========================
# mse: 265050.4062
# mae: 210.6892
# rmse: 514.8304
# r2: 0.7588
#
# [3/20][1323/2459][Time 10.95]
# Unified LR across all optimizers: 0.0007705438882366049
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0096	Gen: 0.0513	Rec: 0.0479	E: 0.0131	R: 0.0062	P: 0.0910
#
# mse: 265441.3125
# mae: 198.2428
# rmse: 515.2100
# r2: 0.7508
#
# =====================Eval Metrics========================
# mse: 246645.0000
# mae: 208.7025
# rmse: 496.6337
# r2: 0.7634
#
# [3/20][1423/2459][Time 10.84]
# Unified LR across all optimizers: 0.0007682389991814431
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0093	Gen: 0.0498	Rec: 0.0466	E: 0.0131	R: 0.0061	P: 0.0887
#
# mse: 216078.5938
# mae: 198.2969
# rmse: 464.8426
# r2: 0.7937
#
# =====================Eval Metrics========================
# mse: 249349.3750
# mae: 226.4768
# rmse: 499.3489
# r2: 0.7573
#
# [3/20][1523/2459][Time 10.87]
# Unified LR across all optimizers: 0.0007659410046246184
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0094	Gen: 0.0495	Rec: 0.0461	E: 0.0123	R: 0.0059	P: 0.0876
#
# mse: 218200.8750
# mae: 190.2160
# rmse: 467.1198
# r2: 0.7614
#
# =====================Eval Metrics========================
# mse: 325750.2812
# mae: 258.4385
# rmse: 570.7454
# r2: 0.7341
#
# [3/20][1623/2459][Time 10.76]
# Unified LR across all optimizers: 0.0007636498839429665
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0097	Gen: 0.0499	Rec: 0.0465	E: 0.0134	R: 0.0062	P: 0.0881
#
# mse: 136529.6562
# mae: 142.7610
# rmse: 369.4992
# r2: 0.8127
#
# =====================Eval Metrics========================
# mse: 235400.2188
# mae: 188.2109
# rmse: 485.1806
# r2: 0.7459
#
# [3/20][1723/2459][Time 10.74]
# Unified LR across all optimizers: 0.0007613656165750123
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0095	Gen: 0.0496	Rec: 0.0463	E: 0.0131	R: 0.0061	P: 0.0881
#
# mse: 219720.0469
# mae: 201.9376
# rmse: 468.7430
# r2: 0.8090
#
# =====================Eval Metrics========================
# mse: 200530.5000
# mae: 191.0553
# rmse: 447.8063
# r2: 0.8310
#
# [3/20][1823/2459][Time 10.76]
# Unified LR across all optimizers: 0.0007590881820207827
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0095	Gen: 0.0492	Rec: 0.0457	E: 0.0130	R: 0.0060	P: 0.0866
#
# mse: 212062.8125
# mae: 181.3851
# rmse: 460.5028
# r2: 0.8116
#
# =====================Eval Metrics========================
# mse: 236397.1250
# mae: 211.8328
# rmse: 486.2069
# r2: 0.7907
#
# [3/20][1923/2459][Time 10.75]
# Unified LR across all optimizers: 0.0007568175598416272
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0091	Gen: 0.0484	Rec: 0.0452	E: 0.0126	R: 0.0059	P: 0.0858
#
# mse: 169689.3750
# mae: 175.1759
# rmse: 411.9337
# r2: 0.8511
#
# =====================Eval Metrics========================
# mse: 166923.5781
# mae: 166.1185
# rmse: 408.5628
# r2: 0.8348
#
# [3/20][2023/2459][Time 10.78]
# Unified LR across all optimizers: 0.0007545537296600323
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0099	Gen: 0.0485	Rec: 0.0449	E: 0.0143	R: 0.0063	P: 0.0849
#
# mse: 199169.2031
# mae: 183.7694
# rmse: 446.2838
# r2: 0.8227
#
# =====================Eval Metrics========================
# mse: 127980.5312
# mae: 141.7588
# rmse: 357.7437
# r2: 0.8505
#
# [3/20][2123/2459][Time 10.72]
# Unified LR across all optimizers: 0.0007522966711594383
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0092	Gen: 0.0486	Rec: 0.0455	E: 0.0128	R: 0.0061	P: 0.0860
#
# mse: 142144.2031
# mae: 159.3880
# rmse: 377.0202
# r2: 0.8630
#
# =====================Eval Metrics========================
# mse: 169627.5312
# mae: 180.9452
# rmse: 411.8586
# r2: 0.8351
#
# [3/20][2223/2459][Time 10.76]
# Unified LR across all optimizers: 0.0007500463640840577
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0088	Gen: 0.0468	Rec: 0.0439	E: 0.0119	R: 0.0058	P: 0.0832
#
# mse: 206247.5312
# mae: 215.6702
# rmse: 454.1448
# r2: 0.8433
#
# =====================Eval Metrics========================
# mse: 129725.3281
# mae: 150.1096
# rmse: 360.1740
# r2: 0.8479
#
# [3/20][2323/2459][Time 10.82]
# Unified LR across all optimizers: 0.0007478027882386922
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0093	Gen: 0.0482	Rec: 0.0448	E: 0.0130	R: 0.0057	P: 0.0845
#
# mse: 313332.8125
# mae: 258.1455
# rmse: 559.7614
# r2: 0.7926
#
# =====================Eval Metrics========================
# mse: 230105.2969
# mae: 216.1537
# rmse: 479.6929
# r2: 0.7874
#
# [3/20][2423/2459][Time 10.76]
# Unified LR across all optimizers: 0.0007455659234885542
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0122	Gen: 0.0489	Rec: 0.0468	E: 0.0156	R: 0.0101	P: 0.0848
#
# mse: 147323.7969
# mae: 153.3506
# rmse: 383.8278
# r2: 0.8430
#
# =====================Eval Metrics========================
# mse: 108980.7812
# mae: 151.6886
# rmse: 330.1224
# r2: 0.8768
# Iterations:   0%|          | 0/2459 [00:00<?, ?it/s]
# [4/20][64/2459][Time 10.93]
# Unified LR across all optimizers: 0.0007433357497590818
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0101	Gen: 0.0479	Rec: 0.0442	E: 0.0140	R: 0.0064	P: 0.0832
#
# mse: 209319.9531
# mae: 194.8704
# rmse: 457.5150
# r2: 0.8080
#
# =====================Eval Metrics========================
# mse: 153541.0156
# mae: 169.9945
# rmse: 391.8431
# r2: 0.8638
#
# [4/20][164/2459][Time 10.84]
# Unified LR across all optimizers: 0.0007411122470357627
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0099	Gen: 0.0473	Rec: 0.0436	E: 0.0136	R: 0.0062	P: 0.0826
#
# mse: 202392.8125
# mae: 181.8739
# rmse: 449.8809
# r2: 0.8125
#
# =====================Eval Metrics========================
# mse: 211131.7969
# mae: 206.4523
# rmse: 459.4908
# r2: 0.8364
#
# [4/20][264/2459][Time 10.86]
# Unified LR across all optimizers: 0.0007388953953639536
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0094	Gen: 0.0470	Rec: 0.0438	E: 0.0130	R: 0.0062	P: 0.0828
#
# mse: 168966.1406
# mae: 185.6433
# rmse: 411.0549
# r2: 0.8759
#
# =====================Eval Metrics========================
# mse: 142405.1875
# mae: 174.6948
# rmse: 377.3661
# r2: 0.8832
#
# [4/20][364/2459][Time 10.87]
# Unified LR across all optimizers: 0.0007366851748486997
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0099	Gen: 0.0466	Rec: 0.0431	E: 0.0131	R: 0.0063	P: 0.0815
#
# mse: 107613.5156
# mae: 133.7160
# rmse: 328.0450
# r2: 0.8849
#
# =====================Eval Metrics========================
# mse: 130068.9531
# mae: 169.5708
# rmse: 360.6507
# r2: 0.8705
#
# [4/20][464/2459][Time 10.74]
# Unified LR across all optimizers: 0.0007344815656545561
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0097	Gen: 0.0476	Rec: 0.0441	E: 0.0136	R: 0.0061	P: 0.0834
#
# mse: 102646.3203
# mae: 130.5429
# rmse: 320.3846
# r2: 0.8816
#
# =====================Eval Metrics========================
# mse: 166078.3281
# mae: 183.6850
# rmse: 407.5271
# r2: 0.8671
#
# [4/20][564/2459][Time 10.85]
# Unified LR across all optimizers: 0.0007322845480054125
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0097	Gen: 0.0460	Rec: 0.0425	E: 0.0130	R: 0.0061	P: 0.0800
#
# mse: 97390.7969
# mae: 128.0592
# rmse: 312.0750
# r2: 0.8988
#
# =====================Eval Metrics========================
# mse: 82615.7812
# mae: 129.5886
# rmse: 287.4296
# r2: 0.9159
#
# [4/20][664/2459][Time 10.86]
# Unified LR across all optimizers: 0.0007300941021843118
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0095	Gen: 0.0468	Rec: 0.0434	E: 0.0132	R: 0.0061	P: 0.0822
#
# mse: 188437.4062
# mae: 179.6095
# rmse: 434.0938
# r2: 0.8633
#
# =====================Eval Metrics========================
# mse: 160437.2969
# mae: 164.2955
# rmse: 400.5462
# r2: 0.8267
#
# [4/20][764/2459][Time 10.88]
# Unified LR across all optimizers: 0.0007279102085332781
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0094	Gen: 0.0465	Rec: 0.0431	E: 0.0129	R: 0.0060	P: 0.0812
#
# mse: 152314.1094
# mae: 168.9645
# rmse: 390.2744
# r2: 0.8729
#
# =====================Eval Metrics========================
# mse: 144621.2812
# mae: 162.4858
# rmse: 380.2910
# r2: 0.8541
#
# [4/20][864/2459][Time 10.81]
# Unified LR across all optimizers: 0.0007257328474531336
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0097	Gen: 0.0460	Rec: 0.0427	E: 0.0129	R: 0.0064	P: 0.0805
#
# mse: 160178.9531
# mae: 185.2340
# rmse: 400.2236
# r2: 0.8827
#
# =====================Eval Metrics========================
# mse: 67242.9844
# mae: 121.0135
# rmse: 259.3125
# r2: 0.9294
#
# [4/20][964/2459][Time 10.80]
# Unified LR across all optimizers: 0.0007235619994033299
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0088	Gen: 0.0452	Rec: 0.0423	E: 0.0125	R: 0.0060	P: 0.0798
#
# mse: 113663.5938
# mae: 135.8960
# rmse: 337.1403
# r2: 0.8674
#
# =====================Eval Metrics========================
# mse: 37581.9297
# mae: 87.9998
# rmse: 193.8606
# r2: 0.9513
#
# [4/20][1064/2459][Time 10.68]
# Unified LR across all optimizers: 0.0007213976449017682
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0095	Gen: 0.0459	Rec: 0.0425	E: 0.0147	R: 0.0063	P: 0.0809
#
# mse: 123116.3281
# mae: 145.0967
# rmse: 350.8794
# r2: 0.8666
#
# =====================Eval Metrics========================
# mse: 92030.8359
# mae: 143.2094
# rmse: 303.3658
# r2: 0.9178
#
# [4/20][1164/2459][Time 10.74]
# Unified LR across all optimizers: 0.0007192397645246242
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0085	Gen: 0.0439	Rec: 0.0410	E: 0.0118	R: 0.0057	P: 0.0779
#
# mse: 94060.5938
# mae: 126.4934
# rmse: 306.6930
# r2: 0.9121
#
# =====================Eval Metrics========================
# mse: 134897.3750
# mae: 160.6059
# rmse: 367.2838
# r2: 0.8835
#
# [4/20][1264/2459][Time 10.77]
# Unified LR across all optimizers: 0.0007170883389061767
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0094	Gen: 0.0451	Rec: 0.0415	E: 0.0132	R: 0.0058	P: 0.0787
#
# mse: 87729.3984
# mae: 122.6828
# rmse: 296.1915
# r2: 0.9192
#
# =====================Eval Metrics========================
# mse: 199703.6250
# mae: 213.9033
# rmse: 446.8821
# r2: 0.8693
#
# [4/20][1364/2459][Time 10.87]
# Unified LR across all optimizers: 0.0007149433487386315
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0088	Gen: 0.0447	Rec: 0.0417	E: 0.0120	R: 0.0058	P: 0.0790
#
# mse: 129311.0312
# mae: 124.4786
# rmse: 359.5984
# r2: 0.8538
#
# =====================Eval Metrics========================
# mse: 135618.7188
# mae: 148.3794
# rmse: 368.2645
# r2: 0.8826
#
# [4/20][1464/2459][Time 10.69]
# Unified LR across all optimizers: 0.0007128047747719494
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0093	Gen: 0.0453	Rec: 0.0416	E: 0.0133	R: 0.0055	P: 0.0792
#
# mse: 87439.5547
# mae: 124.3789
# rmse: 295.7018
# r2: 0.9158
#
# =====================Eval Metrics========================
# mse: 107413.8125
# mae: 157.4333
# rmse: 327.7405
# r2: 0.9152
#
# ...
# Inf: 0.0019	Gen: 0.0218	Rec: 0.0217	E: 0.0021	R: 0.0017	P: 0.0429
#
# mse: 114816.4375
# mae: 126.0571
# rmse: 338.8457
# r2: 0.9028
#
# =====================Eval Metrics========================
# mse: 68136.9297
# mae: 117.7047
# rmse: 261.0305
# r2: 0.9335
#
# [18/20][1038/2459][Time 11.05]
# Unified LR across all optimizers: 0.00025740702880920776
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0019	Gen: 0.0215	Rec: 0.0213	E: 0.0021	R: 0.0017	P: 0.0421
#
# mse: 67970.6641
# mae: 97.5277
# rmse: 260.7119
# r2: 0.9475
#
# =====================Eval Metrics========================
# mse: 144128.5000
# mae: 136.2566
# rmse: 379.6426
# r2: 0.8657
#
# [18/20][1138/2459][Time 10.80]
# Unified LR across all optimizers: 0.0002566370601513783
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0019	Gen: 0.0219	Rec: 0.0217	E: 0.0021	R: 0.0017	P: 0.0431
#
# mse: 64643.0312
# mae: 102.4407
# rmse: 254.2499
# r2: 0.9480
#
# =====================Eval Metrics========================
# mse: 59087.4727
# mae: 103.0408
# rmse: 243.0791
# r2: 0.9425
#
# [18/20][1238/2459][Time 10.71]
# Unified LR across all optimizers: 0.00025586939466194623
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0019	Gen: 0.0219	Rec: 0.0217	E: 0.0021	R: 0.0017	P: 0.0432
#
# mse: 72619.8125
# mae: 115.0584
# rmse: 269.4806
# r2: 0.9470
#
# =====================Eval Metrics========================
# mse: 86192.1016
# mae: 130.3892
# rmse: 293.5849
# r2: 0.9258
#
# [18/20][1338/2459][Time 10.93]
# Unified LR across all optimizers: 0.0002551040254515604
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0019	Gen: 0.0216	Rec: 0.0214	E: 0.0021	R: 0.0017	P: 0.0423
#
# mse: 73760.5000
# mae: 109.6560
# rmse: 271.5888
# r2: 0.9091
#
# =====================Eval Metrics========================
# mse: 151451.2344
# mae: 149.2240
# rmse: 389.1674
# r2: 0.8639
#
# [18/20][1438/2459][Time 10.87]
# Unified LR across all optimizers: 0.00025434094565147686
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0020	Gen: 0.0219	Rec: 0.0217	E: 0.0022	R: 0.0018	P: 0.0429
#
# mse: 47732.5703
# mae: 84.7541
# rmse: 218.4778
# r2: 0.9437
#
# =====================Eval Metrics========================
# mse: 137952.1094
# mae: 139.5058
# rmse: 371.4190
# r2: 0.8716
#
# [18/20][1538/2459][Time 10.88]
# Unified LR across all optimizers: 0.00025358014841349796
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0020	Gen: 0.0217	Rec: 0.0214	E: 0.0027	R: 0.0018	P: 0.0425
#
# mse: 36709.5703
# mae: 78.5601
# rmse: 191.5974
# r2: 0.9608
#
# =====================Eval Metrics========================
# mse: 98586.1094
# mae: 131.9573
# rmse: 313.9843
# r2: 0.9250
#
# [18/20][1638/2459][Time 10.86]
# Unified LR across all optimizers: 0.0002528216269099114
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0018	Gen: 0.0215	Rec: 0.0213	E: 0.0020	R: 0.0016	P: 0.0424
#
# mse: 62166.9727
# mae: 97.7893
# rmse: 249.3331
# r2: 0.9503
#
# =====================Eval Metrics========================
# mse: 131689.7812
# mae: 128.8934
# rmse: 362.8909
# r2: 0.8427
#
# [18/20][1738/2459][Time 10.91]
# Unified LR across all optimizers: 0.0002520653743334272
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0018	Gen: 0.0217	Rec: 0.0215	E: 0.0020	R: 0.0016	P: 0.0428
#
# mse: 49337.5312
# mae: 90.7836
# rmse: 222.1205
# r2: 0.9526
#
# =====================Eval Metrics========================
# mse: 56039.9570
# mae: 107.3333
# rmse: 236.7276
# r2: 0.9485
#
# [18/20][1838/2459][Time 10.88]
# Unified LR across all optimizers: 0.00025131138389711857
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0019	Gen: 0.0214	Rec: 0.0211	E: 0.0022	R: 0.0017	P: 0.0419
#
# mse: 39831.2852
# mae: 82.5469
# rmse: 199.5778
# r2: 0.9668
#
# =====================Eval Metrics========================
# mse: 100159.3516
# mae: 133.5432
# rmse: 316.4796
# r2: 0.9101
#
# [18/20][1938/2459][Time 10.85]
# Unified LR across all optimizers: 0.0002505596488343595
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0020	Gen: 0.0218	Rec: 0.0216	E: 0.0023	R: 0.0017	P: 0.0430
#
# mse: 62798.5625
# mae: 93.5594
# rmse: 250.5964
# r2: 0.9208
#
# =====================Eval Metrics========================
# mse: 138549.7188
# mae: 138.9961
# rmse: 372.2227
# r2: 0.8733
#
# [18/20][2038/2459][Time 10.85]
# Unified LR across all optimizers: 0.00024981016239876484
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0019	Gen: 0.0218	Rec: 0.0216	E: 0.0022	R: 0.0017	P: 0.0429
#
# mse: 101269.2266
# mae: 134.9015
# rmse: 318.2283
# r2: 0.9151
#
# =====================Eval Metrics========================
# mse: 83318.5625
# mae: 126.3177
# rmse: 288.6495
# r2: 0.9251
#
# [18/20][2138/2459][Time 10.87]
# Unified LR across all optimizers: 0.00024906291786412973
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0019	Gen: 0.0215	Rec: 0.0213	E: 0.0022	R: 0.0016	P: 0.0423
#
# mse: 113629.9922
# mae: 129.2044
# rmse: 337.0905
# r2: 0.9284
#
# =====================Eval Metrics========================
# mse: 158256.4688
# mae: 140.6752
# rmse: 397.8146
# r2: 0.8170
#
# [18/20][2238/2459][Time 10.84]
# Unified LR across all optimizers: 0.0002483179085243687
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0019	Gen: 0.0218	Rec: 0.0216	E: 0.0021	R: 0.0017	P: 0.0431
#
# mse: 49352.5547
# mae: 94.0361
# rmse: 222.1543
# r2: 0.9584
#
# =====================Eval Metrics========================
# mse: 78139.6094
# mae: 125.7671
# rmse: 279.5346
# r2: 0.9263
#
# [18/20][2338/2459][Time 10.87]
# Unified LR across all optimizers: 0.0002475751276934567
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0020	Gen: 0.0216	Rec: 0.0213	E: 0.0025	R: 0.0017	P: 0.0424
#
# mse: 60319.4570
# mae: 96.9450
# rmse: 245.6002
# r2: 0.9167
#
# =====================Eval Metrics========================
# mse: 138974.0625
# mae: 137.3640
# rmse: 372.7922
# r2: 0.8608
#
# [18/20][2438/2459][Time 10.86]
# Unified LR across all optimizers: 0.00024683456870536733
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0019	Gen: 0.0216	Rec: 0.0214	E: 0.0022	R: 0.0017	P: 0.0427
#
# mse: 82958.7969
# mae: 100.3224
# rmse: 288.0257
# r2: 0.9231
#
# =====================Eval Metrics========================
# mse: 93768.3984
# mae: 115.6085
# rmse: 306.2162
# r2: 0.9121
# Iterations:   0%|          | 0/2459 [00:00<?, ?it/s]
# [19/20][79/2459][Time 10.91]
# Unified LR across all optimizers: 0.0002460962249140141
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0020	Gen: 0.0216	Rec: 0.0214	E: 0.0022	R: 0.0017	P: 0.0428
#
# mse: 53803.6523
# mae: 86.6854
# rmse: 231.9561
# r2: 0.9523
#
# =====================Eval Metrics========================
# mse: 106540.7109
# mae: 115.7546
# rmse: 326.4057
# r2: 0.9091
#
# [19/20][179/2459][Time 10.84]
# Unified LR across all optimizers: 0.000245360089693191
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0020	Gen: 0.0220	Rec: 0.0218	E: 0.0023	R: 0.0018	P: 0.0433
#
# mse: 80351.9375
# mae: 96.6415
# rmse: 283.4642
# r2: 0.9309
#
# =====================Eval Metrics========================
# mse: 64277.5117
# mae: 115.9688
# rmse: 253.5301
# r2: 0.9517
#
# [19/20][279/2459][Time 10.88]
# Unified LR across all optimizers: 0.0002446261564365121
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0020	Gen: 0.0217	Rec: 0.0215	E: 0.0022	R: 0.0017	P: 0.0424
#
# mse: 57467.3516
# mae: 110.2602
# rmse: 239.7235
# r2: 0.9523
#
# =====================Eval Metrics========================
# mse: 107607.4375
# mae: 127.2525
# rmse: 328.0357
# r2: 0.9054
#
# [19/20][379/2459][Time 10.90]
# Unified LR across all optimizers: 0.00024389441855735358
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0019	Gen: 0.0214	Rec: 0.0212	E: 0.0020	R: 0.0016	P: 0.0421
#
# mse: 94504.5078
# mae: 110.6436
# rmse: 307.4159
# r2: 0.9150
#
# =====================Eval Metrics========================
# mse: 123528.5000
# mae: 127.4954
# rmse: 351.4662
# r2: 0.8804
#
# [19/20][479/2459][Time 10.98]
# Unified LR across all optimizers: 0.00024316486948879314
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0019	Gen: 0.0215	Rec: 0.0213	E: 0.0022	R: 0.0017	P: 0.0424
#
# mse: 99159.0312
# mae: 125.5510
# rmse: 314.8953
# r2: 0.9175
#
# =====================Eval Metrics========================
# mse: 128511.4062
# mae: 129.0100
# rmse: 358.4849
# r2: 0.9086
#
# [19/20][579/2459][Time 11.03]
# Unified LR across all optimizers: 0.00024243750268355212
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0019	Gen: 0.0215	Rec: 0.0213	E: 0.0022	R: 0.0017	P: 0.0422
#
# mse: 71145.0781
# mae: 99.9573
# rmse: 266.7303
# r2: 0.9285
#
# =====================Eval Metrics========================
# mse: 98656.8906
# mae: 133.1091
# rmse: 314.0970
# r2: 0.9175
#
# [19/20][679/2459][Time 11.02]
# Unified LR across all optimizers: 0.00024171231161393636
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0019	Gen: 0.0215	Rec: 0.0213	E: 0.0020	R: 0.0017	P: 0.0422
#
# mse: 46838.0547
# mae: 90.4323
# rmse: 216.4210
# r2: 0.9610
#
# =====================Eval Metrics========================
# mse: 123227.3203
# mae: 139.1102
# rmse: 351.0375
# r2: 0.8930
#
# [19/20][779/2459][Time 10.86]
# Unified LR across all optimizers: 0.00024098928977177777
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0019	Gen: 0.0214	Rec: 0.0212	E: 0.0021	R: 0.0017	P: 0.0420
#
# mse: 48565.7812
# mae: 94.3920
# rmse: 220.3764
# r2: 0.9594
#
# =====================Eval Metrics========================
# mse: 92199.5312
# mae: 125.2972
# rmse: 303.6438
# r2: 0.9331
#
# [19/20][879/2459][Time 10.85]
# Unified LR across all optimizers: 0.0002402684306683755
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0019	Gen: 0.0211	Rec: 0.0209	E: 0.0022	R: 0.0017	P: 0.0415
#
# mse: 42303.1875
# mae: 77.0577
# rmse: 205.6774
# r2: 0.9494
#
# =====================Eval Metrics========================
# mse: 108096.3672
# mae: 127.5199
# rmse: 328.7801
# r2: 0.8915
#
# [19/20][979/2459][Time 10.74]
# Unified LR across all optimizers: 0.0002395497278344384
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0018	Gen: 0.0214	Rec: 0.0212	E: 0.0020	R: 0.0016	P: 0.0420
#
# mse: 89854.6328
# mae: 121.2286
# rmse: 299.7576
# r2: 0.9322
#
# =====================Eval Metrics========================
# mse: 136704.3125
# mae: 140.3555
# rmse: 369.7355
# r2: 0.8823
#
# [19/20][1079/2459][Time 10.79]
# Unified LR across all optimizers: 0.00023883317482002638
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0019	Gen: 0.0215	Rec: 0.0212	E: 0.0021	R: 0.0017	P: 0.0422
#
# mse: 42190.3906
# mae: 89.2091
# rmse: 205.4030
# r2: 0.9567
#
# =====================Eval Metrics========================
# mse: 63634.3672
# mae: 105.1019
# rmse: 252.2585
# r2: 0.9428
#
# [19/20][1179/2459][Time 10.81]
# Unified LR across all optimizers: 0.00023811876519449265
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0019	Gen: 0.0213	Rec: 0.0210	E: 0.0021	R: 0.0017	P: 0.0419
#
# mse: 113219.3281
# mae: 120.1323
# rmse: 336.4808
# r2: 0.8694
#
# =====================Eval Metrics========================
# mse: 86224.9375
# mae: 127.2794
# rmse: 293.6408
# r2: 0.9170
#
# [19/20][1279/2459][Time 10.78]
# Unified LR across all optimizers: 0.0002374064925464261
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0020	Gen: 0.0214	Rec: 0.0211	E: 0.0024	R: 0.0018	P: 0.0421
#
# mse: 100693.9844
# mae: 128.9941
# rmse: 317.3232
# r2: 0.9276
#
# =====================Eval Metrics========================
# mse: 63612.8438
# mae: 105.9705
# rmse: 252.2159
# r2: 0.9194
#
# [19/20][1379/2459][Time 10.96]
# Unified LR across all optimizers: 0.0002366963504835944
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0019	Gen: 0.0213	Rec: 0.0211	E: 0.0021	R: 0.0017	P: 0.0419
#
# mse: 50395.2344
# mae: 103.8322
# rmse: 224.4888
# r2: 0.9611
#
# =====================Eval Metrics========================
# mse: 129050.3984
# mae: 123.8636
# rmse: 359.2358
# r2: 0.8867
#
# [19/20][1479/2459][Time 10.87]
# Unified LR across all optimizers: 0.00023598833263288493
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0019	Gen: 0.0213	Rec: 0.0212	E: 0.0022	R: 0.0017	P: 0.0419
#
# mse: 89209.7109
# mae: 130.1825
# rmse: 298.6800
# r2: 0.9332
#
# =====================Eval Metrics========================
# mse: 151002.9531
# mae: 142.6076
# rmse: 388.5910
# r2: 0.8791
#
# [19/20][1579/2459][Time 10.76]
# Unified LR across all optimizers: 0.00023528243264024943
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0021	Gen: 0.0214	Rec: 0.0211	E: 0.0023	R: 0.0018	P: 0.0418
#
# mse: 60058.7070
# mae: 100.3489
# rmse: 245.0688
# r2: 0.9546
#
# =====================Eval Metrics========================
# mse: 80836.0391
# mae: 126.9506
# rmse: 284.3168
# r2: 0.9357
#
# [19/20][1679/2459][Time 10.81]
# Unified LR across all optimizers: 0.0002345786441706458
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0018	Gen: 0.0212	Rec: 0.0211	E: 0.0019	R: 0.0016	P: 0.0418
#
# mse: 132481.8125
# mae: 123.3668
# rmse: 363.9805
# r2: 0.8789
#
# =====================Eval Metrics========================
# mse: 121358.0078
# mae: 128.1873
# rmse: 348.3648
# r2: 0.8883
#
# [19/20][1779/2459][Time 10.88]
# Unified LR across all optimizers: 0.00023387696090798168
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0019	Gen: 0.0213	Rec: 0.0211	E: 0.0021	R: 0.0017	P: 0.0421
#
# mse: 66450.4375
# mae: 108.3048
# rmse: 257.7798
# r2: 0.9494
#
# =====================Eval Metrics========================
# mse: 105654.3828
# mae: 135.0075
# rmse: 325.0452
# r2: 0.9021
#
# [19/20][1879/2459][Time 10.77]
# Unified LR across all optimizers: 0.00023317737655505783
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0018	Gen: 0.0213	Rec: 0.0211	E: 0.0022	R: 0.0016	P: 0.0422
#
# mse: 62848.8438
# mae: 96.5385
# rmse: 250.6967
# r2: 0.9386
#
# =====================Eval Metrics========================
# mse: 136191.3750
# mae: 157.9239
# rmse: 369.0412
# r2: 0.9154
#
# [19/20][1979/2459][Time 10.75]
# Unified LR across all optimizers: 0.0002324798848335114
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0018	Gen: 0.0211	Rec: 0.0209	E: 0.0021	R: 0.0016	P: 0.0417
#
# mse: 190006.7344
# mae: 133.2201
# rmse: 435.8976
# r2: 0.8072
#
# =====================Eval Metrics========================
# mse: 70570.0781
# mae: 106.3600
# rmse: 265.6503
# r2: 0.9243
#
# [19/20][2079/2459][Time 10.93]
# Unified LR across all optimizers: 0.00023178447948375973
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0019	Gen: 0.0214	Rec: 0.0212	E: 0.0020	R: 0.0016	P: 0.0421
#
# mse: 96621.1406
# mae: 120.5019
# rmse: 310.8394
# r2: 0.9183
#
# =====================Eval Metrics========================
# mse: 216152.9219
# mae: 189.4994
# rmse: 464.9225
# r2: 0.8168
#
# [19/20][2179/2459][Time 10.98]
# Unified LR across all optimizers: 0.0002310911542649442
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0019	Gen: 0.0212	Rec: 0.0210	E: 0.0020	R: 0.0016	P: 0.0418
#
# mse: 48851.8828
# mae: 76.1565
# rmse: 221.0246
# r2: 0.9543
#
# =====================Eval Metrics========================
# mse: 106970.7500
# mae: 124.8368
# rmse: 327.0638
# r2: 0.8991
#
# [19/20][2279/2459][Time 11.04]
# Unified LR across all optimizers: 0.00023039990295487404
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0018	Gen: 0.0209	Rec: 0.0207	E: 0.0021	R: 0.0016	P: 0.0413
#
# mse: 40102.6328
# mae: 77.7339
# rmse: 200.2564
# r2: 0.9578
#
# =====================Eval Metrics========================
# mse: 141015.5469
# mae: 160.6086
# rmse: 375.5204
# r2: 0.8773
#
# [19/20][2379/2459][Time 10.85]
# Unified LR across all optimizers: 0.00022971071934997078
# =====================Train Metrics=======================
# CCNet:  Three Gpt
# Inf: 0.0019	Gen: 0.0211	Rec: 0.0209	E: 0.0020	R: 0.0016	P: 0.0416
#
# mse: 82134.5547
# mae: 108.6082
# rmse: 286.5913
# r2: 0.9260
#
# =====================Eval Metrics========================
# mse: 87716.7188
# mae: 134.2612
# rmse: 296.1701
# r2: 0.9238

# %% [markdown]
# ### **3-3. Test Causal Learning**
#
# <blockquote>
#
# This function `test` evaluates the performance of the causal_learning on a given dataset.
#
# It validates the performance, logs the test metrics using *Weights and Biases* (wandb) if `use_wandb` is True, and returns the *test metrics*.
#
# </blockquote>

# %%
causal_learning.test(testset)
# Out:
# {'mse': 106473.484375,
#  'mae': 125.13711547851562,
#  'rmse': 326.302734375,
#  'r2': 0.9023904800415039}
