# %% [markdown]
# # ***Causal Learning Tutorial - Airline Passenger Satisfaction Classification***
#
#
# '''
# Author:
#
#         KIM, JoengYoong, jeongyoong@ccnets.org
#
#     COPYRIGHT (c) 2024. CCNets. All Rights reserved.
# '''

# %% [markdown]
# <p align="center">
#     <img src="https://www.travelandleisure.com/thmb/h97kSvljd2QYH2nUy3Y9ZNgO_pw=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/plane-data-BUSYROUTES1217-f4f84b08d47f4951b11c148cee2c3dea.jpg" width=600>
# </p>
#
# <br>
#
# Data Source: https://www.kaggle.com/datasets/teejmahal20/airline-passenger-satisfaction/data
#
# <hr>
#
# CCNet result: https://wandb.ai/ccnets/causal-learning
#
# <blockquote>
# R&sup2 score: <mark>0.95</mark>
#
# </blockquote>
#
# Benchmark: https://www.kaggle.com/datasets/teejmahal20/airline-passenger-satisfaction/code?datasetId=522275&sortBy=voteCount
# <blockquote>
# R&sup2 score:
#
# - Random Forest: 0.96
# - LightGBM: 0.96
# - Catboost: 0.96
# - XGBoost: 0.94
#
# </blockquote>

# %% [markdown]
# ## 1. Load Libraries

# %%
import os
import sys
import warnings
warnings.filterwarnings("ignore")

path_append = "../../"
sys.path.append(path_append)  # Go up one directory from where you are.

# %%
import torch
import pandas as pd

# %% [markdown]
# ## 2. Load  Dataset

# %%
df_train = pd.read_csv(path_append + '../data/Airline Customer Satisfaction/train.csv')
df_test = pd.read_csv(path_append + '../data/Airline Customer Satisfaction/test.csv')
df_train.head()
df_test.head()
# Out:
#    Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel
# 0           0  19556  Female     Loyal Customer   52  Business travel  \
# 1           1  90035  Female     Loyal Customer   36  Business travel
# 2           2  12360    Male  disloyal Customer   20  Business travel
# 3           3  77959    Male     Loyal Customer   44  Business travel
# 4           4  36875  Female     Loyal Customer   49  Business travel
#
#       Class  Flight Distance  Inflight wifi service
# 0       Eco              160                      5  \
# 1  Business             2863                      1
# 2       Eco              192                      2
# 3  Business             3377                      0
# 4       Eco             1182                      2
#
#    Departure/Arrival time convenient  ...  Inflight entertainment
# 0                                  4  ...                       5  \
# 1                                  1  ...                       4
# 2                                  0  ...                       2
# 3                                  0  ...                       1
# 4                                  3  ...                       2
#
#    On-board service  Leg room service  Baggage handling  Checkin service
# 0                 5                 5                 5                2  \
# 1                 4                 4                 4                3
# 2                 4                 1                 3                2
# 3                 1                 1                 1                3
# 4                 2                 2                 2                4
#
#    Inflight service  Cleanliness  Departure Delay in Minutes
# 0                 5            5                          50  \
# 1                 4            5                           0
# 2                 2            2                           0
# 3                 1            4                           0
# 4                 2            4                           0
#
#    Arrival Delay in Minutes             satisfaction
# 0                      44.0                satisfied
# 1                       0.0                satisfied
# 2                       0.0  neutral or dissatisfied
# 3                       6.0                satisfied
# 4                      20.0                satisfied
#
# [5 rows x 25 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
#  11  Gate location                      103904 non-null  int64
#  12  Food and drink                     103904 non-null  int64
#  13  Online boarding                    103904 non-null  int64
#  14  Seat comfort                       103904 non-null  int64
#  15  Inflight entertainment             103904 non-null  int64
#  16  On-board service                   103904 non-null  int64
#  17  Leg room service                   103904 non-null  int64
#  18  Baggage handling                   103904 non-null  int64
#  19  Checkin service                    103904 non-null  int64
#  20  Inflight service                   103904 non-null  int64
#  21  Cleanliness                        103904 non-null  int64
#  22  Departure Delay in Minutes         103904 non-null  int64
#  23  Arrival Delay in Minutes           103594 non-null  float64
#  24  satisfaction                       103904 non-null  object
# dtypes: float64(1), int64(19), object(5)
# memory usage: 19.8+ MB

# %%
# Check labels count
df_train[['satisfaction']].value_counts()
# Out:
# satisfaction
# neutral or dissatisfied    58879
# satisfied                  45025
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Preprocessing

# %%
from preprocessing.data_frame import auto_preprocess_dataframe

target_columns = ['satisfaction']
drop_columns = ['Unnamed: 0','id']

# Assuming df_train and df_test are your initial dataframes
df_train_length = len(df_train)
df_test_length = len(df_test)

# Concatenate the dataframes
df = pd.concat([df_train, df_test], axis=0)

# Process the combined dataframe
df, description_train = auto_preprocess_dataframe(df, target_columns, drop_columns=drop_columns)

# Split the dataframe back into training and test sets
df_train = df.iloc[:df_train_length]
df_test = df.iloc[df_train_length:]

num_features = description_train['num_features']
num_classes = description_train['num_classes']

print(f"Number of features after scaling: {num_features}")
print(f"Number of classes after scaling: {num_classes}")
description_train
# Out:
# Dropped columns: Unnamed: 0, id
# Filled NaN values in column 'Arrival Delay in Minutes' with random values.
# Column 'Class' has 3 unique values.
# Column 'Customer Type' has 2 unique values.
# Column 'Gender' has 2 unique values.
# Column 'Type of Travel' has 2 unique values.
# Column 'satisfaction' has 2 unique values.
#                                         Min         Max          Mean
# Age                               -2.577411    3.622118 -1.066252e-16  \
# Flight Distance                   -0.611278    3.112030  2.603883e-01
# Inflight wifi service             -2.728696    2.271304  7.297998e-17
# Departure/Arrival time convenient -3.057599    1.942401 -3.632587e-17
# Ease of Online booking            -2.756876    2.243124 -3.015485e-16
# Gate location                     -2.976925    2.023075 -1.912579e-16
# Food and drink                    -3.204774    1.795226  8.643806e-18
# Online boarding                   -3.252633    1.747367  7.730189e-17
# Seat comfort                      -3.441361    1.558639 -4.814272e-17
# Inflight entertainment            -3.358077    1.641923  5.886541e-17
# On-board service                  -3.383023    1.616977  1.133542e-16
# Leg room service                  -3.350878    1.649122  3.966303e-17
# Baggage handling                  -2.632114    1.367886 -1.581871e-16
# Checkin service                   -3.306267    1.693733 -8.840753e-17
# Inflight service                  -3.642193    1.357807  1.703596e-16
# Cleanliness                       -3.286326    1.713674  3.140218e-17
# Departure Delay in Minutes         0.000000  132.666667  1.226143e+00
# Arrival Delay in Minutes           0.000000  121.846154  1.216964e+00
# Customer Type                      0.000000    1.000000  1.830921e-01
# Gender                             0.000000    1.000000  4.926163e-01
# Type of Travel                     0.000000    1.000000  3.094164e-01
# Class_Business                     0.000000    1.000000  4.785956e-01
# Class_Eco                          0.000000    1.000000  4.489452e-01
# Class_Eco Plus                     0.000000    1.000000  7.245919e-02
# satisfaction                       0.000000    1.000000  4.344626e-01
#
#                                         Std  Null Count  Scaled  Encoded
# Age                                1.201704           0  Minmax     None
# Flight Distance                    0.749964           0  Robust     None
# Inflight wifi service              1.329340           0    None     None
# Departure/Arrival time convenient  1.526741           0    None     None
# Ease of Online booking             1.401740           0    None     None
# Gate location                      1.278520           0    None     None
# Food and drink                     1.329933           0    None     None
# Online boarding                    1.350719           0    None     None
# Seat comfort                       1.319289           0    None     None
# Inflight entertainment             1.334049           0    None     None
# On-board service                   1.287099           0    None     None
# Leg room service                   1.316252           0    None     None
# Baggage handling                   1.180025           0    None     None
# Checkin service                    1.266185           0    None     None
# Inflight service                   1.176669           0    None     None
# Cleanliness                        1.313682           0    None     None
# Departure Delay in Minutes         3.172594           0  Robust     None
# Arrival Delay in Minutes           3.223835           0  Robust     None
# Customer Type                      0.386743           0    None  One-hot
# Gender                             0.499947           0    None  One-hot
# Type of Travel                     0.462255           0    None  One-hot
# Class_Business                     0.499544           0    None     None
# Class_Eco                          0.497388           0    None     None
# Class_Eco Plus                     0.259248           0    None     None
# satisfaction                       0.495688           0    None     None
# Number of features after scaling: 24
# Number of classes after scaling: 2
# {'num_features': 24,
#  'num_classes': 2,
#  'encoded_columns': Index(['Class', 'Customer Type', 'Gender', 'Type of Travel',
#         'ccnets_processed_satisfaction'],
#        dtype='object'),
#  'one_hot_encoded_columns': Index(['Customer Type', 'Gender', 'Type of Travel', 'Class'], dtype='object'),
#  'encoded_datatime_columns': Index([], dtype='object'),
#  'scalers': {'Age': 'minmax',
#   'Arrival Delay in Minutes': 'robust',
#   'Baggage handling': 'none',
#   'Checkin service': 'none',
#   'Cleanliness': 'none',
#   'Departure Delay in Minutes': 'robust',
#   'Departure/Arrival time convenient': 'none',
#   'Ease of Online booking': 'none',
#   'Flight Distance': 'robust',
#   'Food and drink': 'none',
#   'Gate location': 'none',
#   'Inflight entertainment': 'none',
#   'Inflight service': 'none',
#   'Inflight wifi service': 'none',
#   'Leg room service': 'none',
#   'On-board service': 'none',
#   'Online boarding': 'none',
#   'Seat comfort': 'none'}}

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Age                                103904 non-null  float64
#  1   Flight Distance                    103904 non-null  float64
#  2   Inflight wifi service              103904 non-null  float64
#  3   Departure/Arrival time convenient  103904 non-null  float64
#  4   Ease of Online booking             103904 non-null  float64
#  5   Gate location                      103904 non-null  float64
#  6   Food and drink                     103904 non-null  float64
#  7   Online boarding                    103904 non-null  float64
#  8   Seat comfort                       103904 non-null  float64
#  9   Inflight entertainment             103904 non-null  float64
#  10  On-board service                   103904 non-null  float64
#  11  Leg room service                   103904 non-null  float64
#  12  Baggage handling                   103904 non-null  float64
#  13  Checkin service                    103904 non-null  float64
#  14  Inflight service                   103904 non-null  float64
#  15  Cleanliness                        103904 non-null  float64
#  16  Departure Delay in Minutes         103904 non-null  float64
#  17  Arrival Delay in Minutes           103904 non-null  float64
#  18  Customer Type                      103904 non-null  float64
#  19  Gender                             103904 non-null  float64
#  20  Type of Travel                     103904 non-null  float64
#  21  Class_Business                     103904 non-null  float64
#  22  Class_Eco                          103904 non-null  float64
#  23  Class_Eco Plus                     103904 non-null  float64
#  24  satisfaction                       103904 non-null  int32
# dtypes: float64(24), int32(1)
# memory usage: 20.2 MB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25976 entries, 0 to 25975
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                25976 non-null  float64
#  1   Flight Distance                    25976 non-null  float64
#  2   Inflight wifi service              25976 non-null  float64
#  3   Departure/Arrival time convenient  25976 non-null  float64
#  4   Ease of Online booking             25976 non-null  float64
#  5   Gate location                      25976 non-null  float64
#  6   Food and drink                     25976 non-null  float64
#  7   Online boarding                    25976 non-null  float64
#  8   Seat comfort                       25976 non-null  float64
#  9   Inflight entertainment             25976 non-null  float64
#  10  On-board service                   25976 non-null  float64
#  11  Leg room service                   25976 non-null  float64
#  12  Baggage handling                   25976 non-null  float64
#  13  Checkin service                    25976 non-null  float64
#  14  Inflight service                   25976 non-null  float64
#  15  Cleanliness                        25976 non-null  float64
#  16  Departure Delay in Minutes         25976 non-null  float64
#  17  Arrival Delay in Minutes           25976 non-null  float64
#  18  Customer Type                      25976 non-null  float64
#  19  Gender                             25976 non-null  float64
#  20  Type of Travel                     25976 non-null  float64
#  21  Class_Business                     25976 non-null  float64
#  22  Class_Eco                          25976 non-null  float64
#  23  Class_Eco Plus                     25976 non-null  float64
#  24  satisfaction                       25976 non-null  int32
# dtypes: float64(24), int32(1)
# memory usage: 5.1 MB

# %%
# Custom Dataset Class
class AirlineDataset(torch.utils.data.Dataset):
    def __init__(self, x, y):
        self.x = x
        self.y = y
        
    def __len__(self):
        return len(self.x)

    def __getitem__(self, index):
        vals = torch.tensor(self.x[index], dtype = torch.float32)
        label = torch.tensor(self.y[index], dtype= torch.long)
        return vals, label

# %%
from sklearn.model_selection import train_test_split

# Assuming df_train is already defined
X_train, y_train = df_train.iloc[:, :-1].values, df_train.iloc[:, -1:].values
X_test, y_test = df_test.iloc[:, :-1].values, df_test.iloc[:,-1:].values

# Split the training data into train and eval sets with 80:20 ratio
X_train_split, X_eval, y_train_split, y_eval = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Create datasets
trainset = AirlineDataset(X_train_split, y_train_split)
evalset = AirlineDataset(X_eval, y_eval)
testset = AirlineDataset(X_test, y_test)

print(f"Labeled Trainset Shape: {len(trainset)}, {trainset.x.shape[1]}")
print(f"Labeled Evalset Shape: {len(evalset)}, {evalset.x.shape[1]}")
print(f"Labeled Testset Shape: {len(testset)}, {testset.x.shape[1]}")
# Out:
# Labeled Trainset Shape: 83123, 24
# Labeled Evalset Shape: 20781, 24
# Labeled Testset Shape: 25976, 24

# %%
num_features =  trainset.x.shape[1]
num_classes =  trainset.y.shape[1]

num_features, num_classes
# Out:
# (24, 1)

# %% [markdown]
# # Training

# %%
from tools.config.data_config import DataConfig
from tools.config.ml_config import MLConfig
from causal_learning import CausalLearning

# Set the data configuration
data_config = DataConfig(dataset_name = 'airline_satisfaction', task_type='binary_classification', obs_shape=[num_features], label_size=num_classes)

#  Set the ML parameters
ml_config = MLConfig(model_name = 'tabnet')
ml_config.training.error_function = 'mae'
ml_config.training.num_epoch = 5
ml_config.model.num_layers = 4

# Set the device to GPU if available, else CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") 

# Initialize the CausalLearning class with the training configuration, data configuration, device, and use_print and use_wandb flags
causal_learning = CausalLearning(ml_config, data_config, device, use_print=True, use_wandb=False)

# %%
causal_learning.train(trainset, evalset)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: junhopark (ccnets). Use `wandb login --relogin` to force relogin
# wandb version 0.17.3 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>c:\Users\user\Projects\causal-learning\examples\tabular\wandb\run-20240625_232104-i0skhvut</code>
# Syncing run <strong><a href='https://wandb.ai/ccnets/causal-learning/runs/i0skhvut' target="_blank">airline_satisfaction : 24-06-25 23:21:02</a></strong> to <a href='https://wandb.ai/ccnets/causal-learning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ccnets/causal-learning' target="_blank">https://wandb.ai/ccnets/causal-learning</a>
#  View run at <a href='https://wandb.ai/ccnets/causal-learning/runs/i0skhvut' target="_blank">https://wandb.ai/ccnets/causal-learning/runs/i0skhvut</a>
# wandb: Adding directory to artifact (.\..\saved\airline_satisfaction\causal-learning)... Done. 0.0s
# Trainer Name: causal_trainer
#
#
# ModelConfig Parameters:
#    d_model  dropout model_name  num_layers  use_seq_input
# 0      256     0.05     tabnet           4          False
# TrainConfig Parameters:
#    batch_size error_function max_seq_len min_seq_len  num_epoch
# 0          64            mae        None        None          5
# OptimConfig Parameters:
#   clip_grad_range  decay_rate_100k  learning_rate  max_grad_norm
# 0            None             0.05          0.001            1.0  \
#
#   scheduler_type
# 0    exponential
# DataConfig Parameters:
#            dataset_name              task_type obs_shape  label_size
# 0  airline_satisfaction  binary_classification      [24]           1  \
#
#   explain_size show_image_indices
# 0         None               None
# Epochs:   0%|          | 0/5 [00:00<?, ?it/s]
# Iterations:   0%|          | 0/1298 [00:00<?, ?it/s]
# [0/5][100/1298][Time 7.94]
# Unified LR across all optimizers: 0.000996978883189373
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.1314	Gen: 0.8262	Rec: 0.8147	E: 0.1429	R: 0.1200	P: 1.5094
#
# accuracy: 0.6016
# precision: 0.3008
# recall: 0.5000
# f1_score: 0.3756
# roc_auc: 0.5000
#
# =====================Eval Metrics========================
# accuracy: 0.5898
# precision: 0.2949
# recall: 0.5000
# f1_score: 0.3710
# roc_auc: 0.5000
#
# [0/5][200/1298][Time 7.54]
# Unified LR across all optimizers: 0.0009939966705585644
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0724	Gen: 0.7284	Rec: 0.7200	E: 0.0808	R: 0.0641	P: 1.3760
#
# accuracy: 0.5625
# precision: 0.2812
# recall: 0.5000
# f1_score: 0.3600
# roc_auc: 0.5000
#
# =====================Eval Metrics========================
# accuracy: 0.5742
# precision: 0.2871
# recall: 0.5000
# f1_score: 0.3648
# roc_auc: 0.5000
#
# [0/5][300/1298][Time 7.54]
# Unified LR across all optimizers: 0.0009910233784699313
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0665	Gen: 0.6558	Rec: 0.6477	E: 0.0746	R: 0.0585	P: 1.2369
#
# accuracy: 0.5586
# precision: 0.2793
# recall: 0.5000
# f1_score: 0.3584
# roc_auc: 0.5000
#
# =====================Eval Metrics========================
# accuracy: 0.5586
# precision: 0.2793
# recall: 0.5000
# f1_score: 0.3584
# roc_auc: 0.5000
#
# [0/5][400/1298][Time 7.97]
# Unified LR across all optimizers: 0.0009880589802399075
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0483	Gen: 0.5946	Rec: 0.5900	E: 0.0529	R: 0.0438	P: 1.1363
#
# accuracy: 0.6445
# precision: 0.8022
# recall: 0.6111
# f1_score: 0.5585
# roc_auc: 0.6111
#
# =====================Eval Metrics========================
# accuracy: 0.6836
# precision: 0.8224
# recall: 0.6284
# f1_score: 0.5964
# roc_auc: 0.6284
#
# [0/5][500/1298][Time 7.64]
# Unified LR across all optimizers: 0.000985103449264739
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0442	Gen: 0.5493	Rec: 0.5457	E: 0.0478	R: 0.0406	P: 1.0507
#
# accuracy: 0.8164
# precision: 0.8719
# recall: 0.7875
# f1_score: 0.7960
# roc_auc: 0.7875
#
# =====================Eval Metrics========================
# accuracy: 0.8242
# precision: 0.8643
# recall: 0.8037
# f1_score: 0.8104
# roc_auc: 0.8037
#
# [0/5][600/1298][Time 7.69]
# Unified LR across all optimizers: 0.0009821567590202554
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0362	Gen: 0.5057	Rec: 0.5021	E: 0.0399	R: 0.0326	P: 0.9716
#
# accuracy: 0.8516
# precision: 0.8868
# recall: 0.8295
# f1_score: 0.8396
# roc_auc: 0.8295
#
# =====================Eval Metrics========================
# accuracy: 0.8789
# precision: 0.9032
# recall: 0.8448
# f1_score: 0.8623
# roc_auc: 0.8448
#
# [0/5][700/1298][Time 7.67]
# Unified LR across all optimizers: 0.000979218883061626
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0324	Gen: 0.4809	Rec: 0.4780	E: 0.0354	R: 0.0295	P: 0.9265
#
# accuracy: 0.8984
# precision: 0.9092
# recall: 0.8799
# f1_score: 0.8902
# roc_auc: 0.8799
#
# =====================Eval Metrics========================
# accuracy: 0.9023
# precision: 0.9015
# recall: 0.8945
# f1_score: 0.8976
# roc_auc: 0.8945
#
# [0/5][800/1298][Time 7.67]
# Unified LR across all optimizers: 0.0009762897950231208
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0333	Gen: 0.4683	Rec: 0.4653	E: 0.0364	R: 0.0303	P: 0.9003
#
# accuracy: 0.9141
# precision: 0.9146
# recall: 0.9116
# f1_score: 0.9129
# roc_auc: 0.9116
#
# =====================Eval Metrics========================
# accuracy: 0.9453
# precision: 0.9460
# recall: 0.9449
# f1_score: 0.9452
# roc_auc: 0.9449
#
# [0/5][900/1298][Time 7.57]
# Unified LR across all optimizers: 0.0009733694686178784
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0293	Gen: 0.4488	Rec: 0.4461	E: 0.0320	R: 0.0266	P: 0.8656
#
# accuracy: 0.9492
# precision: 0.9460
# recall: 0.9440
# f1_score: 0.9450
# roc_auc: 0.9440
#
# =====================Eval Metrics========================
# accuracy: 0.9414
# precision: 0.9406
# recall: 0.9354
# f1_score: 0.9379
# roc_auc: 0.9354
#
# [0/5][1000/1298][Time 7.76]
# Unified LR across all optimizers: 0.0009704578776376673
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0279	Gen: 0.4435	Rec: 0.4407	E: 0.0307	R: 0.0251	P: 0.8563
#
# accuracy: 0.9453
# precision: 0.9453
# recall: 0.9435
# f1_score: 0.9443
# roc_auc: 0.9435
#
# =====================Eval Metrics========================
# accuracy: 0.9141
# precision: 0.9125
# recall: 0.9062
# f1_score: 0.9091
# roc_auc: 0.9062
#
# [0/5][1100/1298][Time 7.73]
# Unified LR across all optimizers: 0.0009675549959526509
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0261	Gen: 0.4277	Rec: 0.4254	E: 0.0284	R: 0.0238	P: 0.8270
#
# accuracy: 0.9258
# precision: 0.9184
# recall: 0.9262
# f1_score: 0.9219
# roc_auc: 0.9262
#
# =====================Eval Metrics========================
# accuracy: 0.9336
# precision: 0.9309
# recall: 0.9321
# f1_score: 0.9315
# roc_auc: 0.9321
#
# [0/5][1200/1298][Time 7.76]
# Unified LR across all optimizers: 0.0009646607975111544
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0272	Gen: 0.4254	Rec: 0.4226	E: 0.0300	R: 0.0243	P: 0.8208
#
# accuracy: 0.9375
# precision: 0.9353
# recall: 0.9373
# f1_score: 0.9362
# roc_auc: 0.9373
#
# =====================Eval Metrics========================
# accuracy: 0.9258
# precision: 0.9218
# recall: 0.9270
# f1_score: 0.9240
# roc_auc: 0.9270
# Iterations:   0%|          | 0/1298 [00:00<?, ?it/s]
# [1/5][2/1298][Time 7.72]
# Unified LR across all optimizers: 0.0009617752563394297
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0253	Gen: 0.4134	Rec: 0.4106	E: 0.0281	R: 0.0226	P: 0.7987
#
# accuracy: 0.9297
# precision: 0.9317
# recall: 0.9265
# f1_score: 0.9286
# roc_auc: 0.9265
#
# =====================Eval Metrics========================
# accuracy: 0.9258
# precision: 0.9214
# recall: 0.9252
# f1_score: 0.9232
# roc_auc: 0.9252
#
# [1/5][102/1298][Time 7.65]
# Unified LR across all optimizers: 0.0009588983465414223
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0235	Gen: 0.4049	Rec: 0.4021	E: 0.0263	R: 0.0208	P: 0.7835
#
# accuracy: 0.9531
# precision: 0.9495
# recall: 0.9526
# f1_score: 0.9509
# roc_auc: 0.9526
#
# =====================Eval Metrics========================
# accuracy: 0.9336
# precision: 0.9324
# recall: 0.9331
# f1_score: 0.9327
# roc_auc: 0.9331
#
# [1/5][202/1298][Time 7.65]
# Unified LR across all optimizers: 0.0009560300422985396
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0230	Gen: 0.3897	Rec: 0.3872	E: 0.0256	R: 0.0205	P: 0.7538
#
# accuracy: 0.9492
# precision: 0.9531
# recall: 0.9417
# f1_score: 0.9466
# roc_auc: 0.9417
#
# =====================Eval Metrics========================
# accuracy: 0.9219
# precision: 0.9246
# recall: 0.9196
# f1_score: 0.9212
# roc_auc: 0.9196
#
# [1/5][302/1298][Time 7.42]
# Unified LR across all optimizers: 0.0009531703178694185
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0238	Gen: 0.3848	Rec: 0.3824	E: 0.0262	R: 0.0214	P: 0.7433
#
# accuracy: 0.9492
# precision: 0.9475
# recall: 0.9499
# f1_score: 0.9486
# roc_auc: 0.9499
#
# =====================Eval Metrics========================
# accuracy: 0.9414
# precision: 0.9415
# recall: 0.9375
# f1_score: 0.9394
# roc_auc: 0.9375
#
# [1/5][402/1298][Time 7.68]
# Unified LR across all optimizers: 0.0009503191475896951
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0223	Gen: 0.3738	Rec: 0.3715	E: 0.0246	R: 0.0199	P: 0.7230
#
# accuracy: 0.9258
# precision: 0.9260
# recall: 0.9236
# f1_score: 0.9247
# roc_auc: 0.9236
#
# =====================Eval Metrics========================
# accuracy: 0.9258
# precision: 0.9270
# recall: 0.9221
# f1_score: 0.9242
# roc_auc: 0.9221
#
# [1/5][502/1298][Time 7.76]
# Unified LR across all optimizers: 0.0009474765058717739
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0202	Gen: 0.3637	Rec: 0.3624	E: 0.0214	R: 0.0189	P: 0.7060
#
# accuracy: 0.9141
# precision: 0.9141
# recall: 0.9098
# f1_score: 0.9117
# roc_auc: 0.9098
#
# =====================Eval Metrics========================
# accuracy: 0.9414
# precision: 0.9419
# recall: 0.9390
# f1_score: 0.9403
# roc_auc: 0.9390
#
# [1/5][602/1298][Time 7.98]
# Unified LR across all optimizers: 0.0009446423672045985
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0187	Gen: 0.3550	Rec: 0.3535	E: 0.0202	R: 0.0172	P: 0.6898
#
# accuracy: 0.9609
# precision: 0.9624
# recall: 0.9545
# f1_score: 0.9582
# roc_auc: 0.9545
#
# =====================Eval Metrics========================
# accuracy: 0.9375
# precision: 0.9374
# recall: 0.9357
# f1_score: 0.9365
# roc_auc: 0.9357
#
# [1/5][702/1298][Time 7.96]
# Unified LR across all optimizers: 0.0009418167061534219
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0173	Gen: 0.3453	Rec: 0.3436	E: 0.0189	R: 0.0156	P: 0.6717
#
# accuracy: 0.9414
# precision: 0.9412
# recall: 0.9405
# f1_score: 0.9408
# roc_auc: 0.9405
#
# =====================Eval Metrics========================
# accuracy: 0.9414
# precision: 0.9398
# recall: 0.9408
# f1_score: 0.9403
# roc_auc: 0.9408
#
# [1/5][802/1298][Time 7.93]
# Unified LR across all optimizers: 0.0009389994973595789
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0170	Gen: 0.3448	Rec: 0.3436	E: 0.0182	R: 0.0157	P: 0.6714
#
# accuracy: 0.9414
# precision: 0.9429
# recall: 0.9358
# f1_score: 0.9390
# roc_auc: 0.9358
#
# =====================Eval Metrics========================
# accuracy: 0.9492
# precision: 0.9512
# recall: 0.9439
# f1_score: 0.9471
# roc_auc: 0.9439
#
# [1/5][902/1298][Time 7.65]
# Unified LR across all optimizers: 0.0009361907155402595
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0168	Gen: 0.3319	Rec: 0.3306	E: 0.0181	R: 0.0155	P: 0.6458
#
# accuracy: 0.9375
# precision: 0.9382
# recall: 0.9370
# f1_score: 0.9374
# roc_auc: 0.9370
#
# =====================Eval Metrics========================
# accuracy: 0.9414
# precision: 0.9412
# recall: 0.9415
# f1_score: 0.9413
# roc_auc: 0.9415
#
# [1/5][1002/1298][Time 7.69]
# Unified LR across all optimizers: 0.0009333903354882786
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0172	Gen: 0.3245	Rec: 0.3232	E: 0.0184	R: 0.0159	P: 0.6306
#
# accuracy: 0.9531
# precision: 0.9526
# recall: 0.9526
# f1_score: 0.9526
# roc_auc: 0.9526
#
# =====================Eval Metrics========================
# accuracy: 0.9375
# precision: 0.9368
# recall: 0.9383
# f1_score: 0.9373
# roc_auc: 0.9383
#
# [1/5][1102/1298][Time 7.67]
# Unified LR across all optimizers: 0.0009305983320718549
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0161	Gen: 0.3176	Rec: 0.3163	E: 0.0174	R: 0.0147	P: 0.6179
#
# accuracy: 0.9609
# precision: 0.9608
# recall: 0.9578
# f1_score: 0.9593
# roc_auc: 0.9578
#
# =====================Eval Metrics========================
# accuracy: 0.9336
# precision: 0.9340
# recall: 0.9333
# f1_score: 0.9335
# roc_auc: 0.9333
#
# [1/5][1202/1298][Time 7.68]
# Unified LR across all optimizers: 0.0009278146802343803
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0158	Gen: 0.3147	Rec: 0.3137	E: 0.0167	R: 0.0148	P: 0.6126
#
# accuracy: 0.9258
# precision: 0.9317
# recall: 0.9196
# f1_score: 0.9238
# roc_auc: 0.9196
#
# =====================Eval Metrics========================
# accuracy: 0.9492
# precision: 0.9497
# recall: 0.9461
# f1_score: 0.9477
# roc_auc: 0.9461
# Iterations:   0%|          | 0/1298 [00:00<?, ?it/s]
# [2/5][4/1298][Time 7.73]
# Unified LR across all optimizers: 0.0009250393549941983
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0138	Gen: 0.3059	Rec: 0.3051	E: 0.0146	R: 0.0129	P: 0.5973
#
# accuracy: 0.9297
# precision: 0.9271
# recall: 0.9237
# f1_score: 0.9253
# roc_auc: 0.9237
#
# =====================Eval Metrics========================
# accuracy: 0.9453
# precision: 0.9462
# recall: 0.9403
# f1_score: 0.9430
# roc_auc: 0.9403
#
# [2/5][104/1298][Time 7.66]
# Unified LR across all optimizers: 0.0009222723314443782
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0133	Gen: 0.3009	Rec: 0.2999	E: 0.0142	R: 0.0124	P: 0.5875
#
# accuracy: 0.9609
# precision: 0.9606
# recall: 0.9606
# f1_score: 0.9606
# roc_auc: 0.9606
#
# =====================Eval Metrics========================
# accuracy: 0.9570
# precision: 0.9593
# recall: 0.9497
# f1_score: 0.9541
# roc_auc: 0.9497
#
# [2/5][204/1298][Time 7.51]
# Unified LR across all optimizers: 0.0009195135847524926
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0128	Gen: 0.2947	Rec: 0.2939	E: 0.0136	R: 0.0120	P: 0.5758
#
# accuracy: 0.9492
# precision: 0.9480
# recall: 0.9489
# f1_score: 0.9485
# roc_auc: 0.9489
#
# =====================Eval Metrics========================
# accuracy: 0.9180
# precision: 0.9183
# recall: 0.9163
# f1_score: 0.9172
# roc_auc: 0.9163
#
# [2/5][304/1298][Time 7.47]
# Unified LR across all optimizers: 0.0009167630901603946
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0124	Gen: 0.2887	Rec: 0.2878	E: 0.0133	R: 0.0116	P: 0.5641
#
# accuracy: 0.9414
# precision: 0.9458
# recall: 0.9372
# f1_score: 0.9403
# roc_auc: 0.9372
#
# =====================Eval Metrics========================
# accuracy: 0.9414
# precision: 0.9417
# recall: 0.9383
# f1_score: 0.9399
# roc_auc: 0.9383
#
# [2/5][404/1298][Time 7.68]
# Unified LR across all optimizers: 0.0009140208229839937
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0112	Gen: 0.2868	Rec: 0.2860	E: 0.0120	R: 0.0104	P: 0.5616
#
# accuracy: 0.9453
# precision: 0.9477
# recall: 0.9421
# f1_score: 0.9443
# roc_auc: 0.9421
#
# =====================Eval Metrics========================
# accuracy: 0.9453
# precision: 0.9417
# recall: 0.9464
# f1_score: 0.9438
# roc_auc: 0.9464
#
# [2/5][504/1298][Time 7.74]
# Unified LR across all optimizers: 0.0009112867586130364
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0120	Gen: 0.2849	Rec: 0.2842	E: 0.0127	R: 0.0113	P: 0.5571
#
# accuracy: 0.9453
# precision: 0.9502
# recall: 0.9354
# f1_score: 0.9417
# roc_auc: 0.9354
#
# =====================Eval Metrics========================
# accuracy: 0.9141
# precision: 0.9147
# recall: 0.9121
# f1_score: 0.9132
# roc_auc: 0.9121
#
# [2/5][604/1298][Time 7.78]
# Unified LR across all optimizers: 0.0009085608725108856
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0110	Gen: 0.2768	Rec: 0.2761	E: 0.0117	R: 0.0103	P: 0.5420
#
# accuracy: 0.9648
# precision: 0.9629
# recall: 0.9643
# f1_score: 0.9636
# roc_auc: 0.9643
#
# =====================Eval Metrics========================
# accuracy: 0.9531
# precision: 0.9544
# recall: 0.9484
# f1_score: 0.9511
# roc_auc: 0.9484
#
# [2/5][704/1298][Time 7.79]
# Unified LR across all optimizers: 0.0009058431402142976
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0111	Gen: 0.2695	Rec: 0.2689	E: 0.0117	R: 0.0105	P: 0.5273
#
# accuracy: 0.9531
# precision: 0.9562
# recall: 0.9475
# f1_score: 0.9513
# roc_auc: 0.9475
#
# =====================Eval Metrics========================
# accuracy: 0.9609
# precision: 0.9644
# recall: 0.9553
# f1_score: 0.9593
# roc_auc: 0.9553
#
# [2/5][804/1298][Time 8.34]
# Unified LR across all optimizers: 0.0009031335373332055
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0112	Gen: 0.2668	Rec: 0.2661	E: 0.0119	R: 0.0106	P: 0.5217
#
# accuracy: 0.9453
# precision: 0.9479
# recall: 0.9402
# f1_score: 0.9435
# roc_auc: 0.9402
#
# =====================Eval Metrics========================
# accuracy: 0.9219
# precision: 0.9260
# recall: 0.9231
# f1_score: 0.9218
# roc_auc: 0.9231
#
# [2/5][904/1298][Time 7.90]
# Unified LR across all optimizers: 0.0009004320395504991
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0104	Gen: 0.2561	Rec: 0.2554	E: 0.0111	R: 0.0097	P: 0.5011
#
# accuracy: 0.9531
# precision: 0.9539
# recall: 0.9526
# f1_score: 0.9530
# roc_auc: 0.9526
#
# =====================Eval Metrics========================
# accuracy: 0.9648
# precision: 0.9676
# recall: 0.9600
# f1_score: 0.9634
# roc_auc: 0.9600
#
# [2/5][1004/1298][Time 7.88]
# Unified LR across all optimizers: 0.000897738622621806
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0106	Gen: 0.2628	Rec: 0.2622	E: 0.0112	R: 0.0100	P: 0.5144
#
# accuracy: 0.9453
# precision: 0.9476
# recall: 0.9423
# f1_score: 0.9444
# roc_auc: 0.9423
#
# =====================Eval Metrics========================
# accuracy: 0.9258
# precision: 0.9249
# recall: 0.9208
# f1_score: 0.9227
# roc_auc: 0.9208
#
# [2/5][1104/1298][Time 8.02]
# Unified LR across all optimizers: 0.0008950532623752764
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0098	Gen: 0.2561	Rec: 0.2552	E: 0.0106	R: 0.0089	P: 0.5015
#
# accuracy: 0.9492
# precision: 0.9523
# recall: 0.9459
# f1_score: 0.9484
# roc_auc: 0.9459
#
# =====================Eval Metrics========================
# accuracy: 0.9453
# precision: 0.9450
# recall: 0.9450
# f1_score: 0.9450
# roc_auc: 0.9450
#
# [2/5][1204/1298][Time 7.72]
# Unified LR across all optimizers: 0.0008923759347113617
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0101	Gen: 0.2562	Rec: 0.2554	E: 0.0109	R: 0.0092	P: 0.5016
#
# accuracy: 0.9375
# precision: 0.9406
# recall: 0.9350
# f1_score: 0.9368
# roc_auc: 0.9350
#
# =====================Eval Metrics========================
# accuracy: 0.9414
# precision: 0.9374
# recall: 0.9431
# f1_score: 0.9399
# roc_auc: 0.9431
# Iterations:   0%|          | 0/1298 [00:00<?, ?it/s]
# [3/5][6/1298][Time 7.71]
# Unified LR across all optimizers: 0.000889706615602604
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0102	Gen: 0.2525	Rec: 0.2518	E: 0.0109	R: 0.0095	P: 0.4940
#
# accuracy: 0.9570
# precision: 0.9584
# recall: 0.9560
# f1_score: 0.9568
# roc_auc: 0.9560
#
# =====================Eval Metrics========================
# accuracy: 0.9492
# precision: 0.9511
# recall: 0.9459
# f1_score: 0.9481
# roc_auc: 0.9459
#
# [3/5][106/1298][Time 7.46]
# Unified LR across all optimizers: 0.0008870452810934158
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0094	Gen: 0.2503	Rec: 0.2497	E: 0.0101	R: 0.0088	P: 0.4905
#
# accuracy: 0.9492
# precision: 0.9496
# recall: 0.9502
# f1_score: 0.9492
# roc_auc: 0.9502
#
# =====================Eval Metrics========================
# accuracy: 0.9453
# precision: 0.9453
# recall: 0.9435
# f1_score: 0.9443
# roc_auc: 0.9435
#
# [3/5][206/1298][Time 7.53]
# Unified LR across all optimizers: 0.0008843919072998678
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0092	Gen: 0.2448	Rec: 0.2440	E: 0.0100	R: 0.0085	P: 0.4795
#
# accuracy: 0.9531
# precision: 0.9521
# recall: 0.9521
# f1_score: 0.9521
# roc_auc: 0.9521
#
# =====================Eval Metrics========================
# accuracy: 0.9492
# precision: 0.9478
# recall: 0.9488
# f1_score: 0.9483
# roc_auc: 0.9488
#
# [3/5][306/1298][Time 7.55]
# Unified LR across all optimizers: 0.0008817464704094733
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0089	Gen: 0.2423	Rec: 0.2416	E: 0.0096	R: 0.0082	P: 0.4751
#
# accuracy: 0.9492
# precision: 0.9503
# recall: 0.9486
# f1_score: 0.9491
# roc_auc: 0.9486
#
# =====================Eval Metrics========================
# accuracy: 0.9648
# precision: 0.9679
# recall: 0.9625
# f1_score: 0.9644
# roc_auc: 0.9625
#
# [3/5][406/1298][Time 7.66]
# Unified LR across all optimizers: 0.0008791089466809735
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0084	Gen: 0.2386	Rec: 0.2380	E: 0.0090	R: 0.0078	P: 0.4681
#
# accuracy: 0.9258
# precision: 0.9241
# recall: 0.9250
# f1_score: 0.9245
# roc_auc: 0.9250
#
# =====================Eval Metrics========================
# accuracy: 0.9570
# precision: 0.9568
# recall: 0.9560
# f1_score: 0.9564
# roc_auc: 0.9560
#
# [3/5][506/1298][Time 7.57]
# Unified LR across all optimizers: 0.0008764793124441268
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0087	Gen: 0.2370	Rec: 0.2362	E: 0.0094	R: 0.0080	P: 0.4645
#
# accuracy: 0.9180
# precision: 0.9190
# recall: 0.9142
# f1_score: 0.9162
# roc_auc: 0.9142
#
# =====================Eval Metrics========================
# accuracy: 0.9297
# precision: 0.9335
# recall: 0.9277
# f1_score: 0.9292
# roc_auc: 0.9277
#
# [3/5][606/1298][Time 7.71]
# Unified LR across all optimizers: 0.0008738575440994944
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0086	Gen: 0.2355	Rec: 0.2349	E: 0.0093	R: 0.0080	P: 0.4618
#
# accuracy: 0.9609
# precision: 0.9621
# recall: 0.9608
# f1_score: 0.9609
# roc_auc: 0.9608
#
# =====================Eval Metrics========================
# accuracy: 0.9688
# precision: 0.9707
# recall: 0.9648
# f1_score: 0.9675
# roc_auc: 0.9648
#
# [3/5][706/1298][Time 7.64]
# Unified LR across all optimizers: 0.0008712436181182304
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0087	Gen: 0.2386	Rec: 0.2380	E: 0.0093	R: 0.0081	P: 0.4678
#
# accuracy: 0.9492
# precision: 0.9480
# recall: 0.9466
# f1_score: 0.9473
# roc_auc: 0.9466
#
# =====================Eval Metrics========================
# accuracy: 0.9492
# precision: 0.9482
# recall: 0.9470
# f1_score: 0.9476
# roc_auc: 0.9470
#
# [3/5][806/1298][Time 7.63]
# Unified LR across all optimizers: 0.0008686375110418687
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0095	Gen: 0.2348	Rec: 0.2341	E: 0.0102	R: 0.0088	P: 0.4593
#
# accuracy: 0.9453
# precision: 0.9448
# recall: 0.9448
# f1_score: 0.9448
# roc_auc: 0.9448
#
# =====================Eval Metrics========================
# accuracy: 0.9570
# precision: 0.9527
# recall: 0.9575
# f1_score: 0.9550
# roc_auc: 0.9575
#
# [3/5][906/1298][Time 7.61]
# Unified LR across all optimizers: 0.0008660391994821131
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0086	Gen: 0.2389	Rec: 0.2384	E: 0.0091	R: 0.0081	P: 0.4687
#
# accuracy: 0.9570
# precision: 0.9556
# recall: 0.9540
# f1_score: 0.9548
# roc_auc: 0.9540
#
# =====================Eval Metrics========================
# accuracy: 0.9297
# precision: 0.9282
# recall: 0.9306
# f1_score: 0.9292
# roc_auc: 0.9306
#
# [3/5][1006/1298][Time 7.63]
# Unified LR across all optimizers: 0.0008634486601206292
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0084	Gen: 0.2361	Rec: 0.2353	E: 0.0092	R: 0.0077	P: 0.4630
#
# accuracy: 0.9062
# precision: 0.9068
# recall: 0.8988
# f1_score: 0.9022
# roc_auc: 0.8988
#
# =====================Eval Metrics========================
# accuracy: 0.9688
# precision: 0.9692
# recall: 0.9675
# f1_score: 0.9683
# roc_auc: 0.9675
#
# [3/5][1106/1298][Time 7.52]
# Unified LR across all optimizers: 0.0008608658697088319
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0095	Gen: 0.2354	Rec: 0.2348	E: 0.0102	R: 0.0088	P: 0.4607
#
# accuracy: 0.9414
# precision: 0.9430
# recall: 0.9393
# f1_score: 0.9407
# roc_auc: 0.9393
#
# =====================Eval Metrics========================
# accuracy: 0.9648
# precision: 0.9608
# recall: 0.9657
# f1_score: 0.9631
# roc_auc: 0.9657
#
# [3/5][1206/1298][Time 7.64]
# Unified LR across all optimizers: 0.0008582908050676784
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0082	Gen: 0.2283	Rec: 0.2277	E: 0.0088	R: 0.0076	P: 0.4479
#
# accuracy: 0.9297
# precision: 0.9339
# recall: 0.9270
# f1_score: 0.9290
# roc_auc: 0.9270
#
# =====================Eval Metrics========================
# accuracy: 0.9414
# precision: 0.9429
# recall: 0.9397
# f1_score: 0.9409
# roc_auc: 0.9397
# Iterations:   0%|          | 0/1298 [00:00<?, ?it/s]
# [4/5][8/1298][Time 7.84]
# Unified LR across all optimizers: 0.0008557234430874619
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0084	Gen: 0.2346	Rec: 0.2339	E: 0.0091	R: 0.0077	P: 0.4600
#
# accuracy: 0.9531
# precision: 0.9523
# recall: 0.9490
# f1_score: 0.9506
# roc_auc: 0.9490
#
# =====================Eval Metrics========================
# accuracy: 0.9453
# precision: 0.9517
# recall: 0.9382
# f1_score: 0.9433
# roc_auc: 0.9382
#
# [4/5][108/1298][Time 7.63]
# Unified LR across all optimizers: 0.0008531637607276009
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0078	Gen: 0.2293	Rec: 0.2286	E: 0.0085	R: 0.0071	P: 0.4500
#
# accuracy: 0.9258
# precision: 0.9270
# recall: 0.9221
# f1_score: 0.9242
# roc_auc: 0.9221
#
# =====================Eval Metrics========================
# accuracy: 0.9648
# precision: 0.9678
# recall: 0.9627
# f1_score: 0.9645
# roc_auc: 0.9627
#
# [4/5][208/1298][Time 7.64]
# Unified LR across all optimizers: 0.0008506117350164344
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0083	Gen: 0.2308	Rec: 0.2301	E: 0.0090	R: 0.0075	P: 0.4527
#
# accuracy: 0.9141
# precision: 0.9207
# recall: 0.9056
# f1_score: 0.9109
# roc_auc: 0.9056
#
# =====================Eval Metrics========================
# accuracy: 0.9453
# precision: 0.9452
# recall: 0.9431
# f1_score: 0.9441
# roc_auc: 0.9431
#
# [4/5][308/1298][Time 7.73]
# Unified LR across all optimizers: 0.0008480673430510153
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0086	Gen: 0.2286	Rec: 0.2279	E: 0.0092	R: 0.0079	P: 0.4479
#
# accuracy: 0.9688
# precision: 0.9692
# recall: 0.9670
# f1_score: 0.9680
# roc_auc: 0.9670
#
# =====================Eval Metrics========================
# accuracy: 0.9570
# precision: 0.9592
# recall: 0.9534
# f1_score: 0.9559
# roc_auc: 0.9534
#
# [4/5][408/1298][Time 7.55]
# Unified LR across all optimizers: 0.0008455305619969057
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0083	Gen: 0.2230	Rec: 0.2222	E: 0.0090	R: 0.0075	P: 0.4369
#
# accuracy: 0.9453
# precision: 0.9455
# recall: 0.9439
# f1_score: 0.9447
# roc_auc: 0.9439
#
# =====================Eval Metrics========================
# accuracy: 0.9258
# precision: 0.9316
# recall: 0.9201
# f1_score: 0.9240
# roc_auc: 0.9201
#
# [4/5][508/1298][Time 7.74]
# Unified LR across all optimizers: 0.0008430013690879698
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0085	Gen: 0.2223	Rec: 0.2217	E: 0.0091	R: 0.0078	P: 0.4355
#
# accuracy: 0.9531
# precision: 0.9446
# recall: 0.9563
# f1_score: 0.9498
# roc_auc: 0.9563
#
# =====================Eval Metrics========================
# accuracy: 0.9375
# precision: 0.9411
# recall: 0.9333
# f1_score: 0.9362
# roc_auc: 0.9333
#
# [4/5][608/1298][Time 7.66]
# Unified LR across all optimizers: 0.0008404797416261722
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0086	Gen: 0.2227	Rec: 0.2220	E: 0.0093	R: 0.0080	P: 0.4360
#
# accuracy: 0.9453
# precision: 0.9427
# recall: 0.9450
# f1_score: 0.9438
# roc_auc: 0.9450
#
# =====================Eval Metrics========================
# accuracy: 0.9414
# precision: 0.9409
# recall: 0.9414
# f1_score: 0.9411
# roc_auc: 0.9414
#
# [4/5][708/1298][Time 7.77]
# Unified LR across all optimizers: 0.0008379656569813726
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0086	Gen: 0.2266	Rec: 0.2258	E: 0.0094	R: 0.0079	P: 0.4438
#
# accuracy: 0.9688
# precision: 0.9692
# recall: 0.9681
# f1_score: 0.9686
# roc_auc: 0.9681
#
# =====================Eval Metrics========================
# accuracy: 0.9414
# precision: 0.9431
# recall: 0.9374
# f1_score: 0.9399
# roc_auc: 0.9374
#
# [4/5][808/1298][Time 7.66]
# Unified LR across all optimizers: 0.0008354590925911228
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0081	Gen: 0.2247	Rec: 0.2241	E: 0.0087	R: 0.0075	P: 0.4407
#
# accuracy: 0.9648
# precision: 0.9672
# recall: 0.9616
# f1_score: 0.9640
# roc_auc: 0.9616
#
# =====================Eval Metrics========================
# accuracy: 0.9648
# precision: 0.9640
# recall: 0.9648
# f1_score: 0.9644
# roc_auc: 0.9648
#
# [4/5][908/1298][Time 7.73]
# Unified LR across all optimizers: 0.0008329600259604655
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0074	Gen: 0.2220	Rec: 0.2215	E: 0.0080	R: 0.0068	P: 0.4361
#
# accuracy: 0.9688
# precision: 0.9708
# recall: 0.9641
# f1_score: 0.9672
# roc_auc: 0.9641
#
# =====================Eval Metrics========================
# accuracy: 0.9453
# precision: 0.9424
# recall: 0.9424
# f1_score: 0.9424
# roc_auc: 0.9424
#
# [4/5][1008/1298][Time 7.69]
# Unified LR across all optimizers: 0.0008304684346617307
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0080	Gen: 0.2191	Rec: 0.2182	E: 0.0089	R: 0.0071	P: 0.4293
#
# accuracy: 0.9688
# precision: 0.9681
# recall: 0.9692
# f1_score: 0.9686
# roc_auc: 0.9692
#
# =====================Eval Metrics========================
# accuracy: 0.9414
# precision: 0.9448
# recall: 0.9340
# f1_score: 0.9386
# roc_auc: 0.9340
#
# [4/5][1108/1298][Time 7.62]
# Unified LR across all optimizers: 0.0008279842963343345
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0079	Gen: 0.2183	Rec: 0.2174	E: 0.0088	R: 0.0070	P: 0.4278
#
# accuracy: 0.9609
# precision: 0.9624
# recall: 0.9604
# f1_score: 0.9609
# roc_auc: 0.9604
#
# =====================Eval Metrics========================
# accuracy: 0.9570
# precision: 0.9528
# recall: 0.9593
# f1_score: 0.9557
# roc_auc: 0.9593
#
# [4/5][1208/1298][Time 7.64]
# Unified LR across all optimizers: 0.0008255075886845802
# =====================Train Metrics=======================
# CCNet:  Three Tabnet
# Inf: 0.0075	Gen: 0.2191	Rec: 0.2184	E: 0.0082	R: 0.0068	P: 0.4301
#
# accuracy: 0.9375
# precision: 0.9345
# recall: 0.9384
# f1_score: 0.9362
# roc_auc: 0.9384
#
# =====================Eval Metrics========================
# accuracy: 0.9688
# precision: 0.9708
# recall: 0.9631
# f1_score: 0.9667
# roc_auc: 0.9631

# %%
causal_learning.test(testset)
# Out:
# {'accuracy': 0.9499537944793701,
#  'precision': 0.9499812144237108,
#  'recall': 0.9483292461887934,
#  'f1_score': 0.9491063278060328,
#  'roc_auc': 0.9483292461887934}
