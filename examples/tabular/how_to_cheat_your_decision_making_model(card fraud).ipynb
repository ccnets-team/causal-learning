# %% [markdown]
# Author:
#
#         PARK, JunHo, junho@ccnets.org
#
#     COPYRIGHT (c) 2024. CCNets. All Rights reserved.

# %% [markdown]
# # Cheat Your Decision-Making Model: Manipulating Credit Card Data with Causal Inference
#
# ## Introduction
#
# In this tutorial, we delve into the intricate world of causal inference to manipulate decision-making models in the domain of credit card fraud detection. Utilizing a Cooperative Network (CCNet), we explore how subtle manipulations in non-fraudulent data can expose and test the vulnerabilities of machine learning models. This demonstration not only highlights the robustness and weaknesses of current fraud detection systems but also illustrates the ethical considerations and potential risks inherent in data manipulation.

# %% [markdown]
# ## Tutorial Goals
#
# This tutorial provides a guide on using causal inference to manipulate data and evaluate its impact on machine learning models. We will cover:
#
# 1. **Training a Binary Classifier**: Train a model to distinguish between fraudulent and non-fraudulent transactions using real credit card data.
# 2. **Generating Manipulated Data with CCNet**: Use CCNet's Explainer, Reasoner, and Producer networks to create data that mimics non-fraudulent transactions but is designed to deceive the classifier by switching decision label factors.
# 3. **Evaluating Classifier Performance**: Test the classifier on both original and manipulated datasets to assess robustness. The classifier should perform well on both the original test set and the CCNet-recreated test set, indicating that CCNet has learned the data distribution that the classifier mapped for decision making.
# 4. **Comparative Dataset Analysis**:
#    - **Testset A**: Real Test Data - Authentic credit card transactions used as a baseline to evaluate the classifier's performance.
#    - **Testset B**: CCNet-generated data with random labels but maintaining the same frequency distribution as the original. The classifier's performance should be similar to Testset A, showing that CCNet understands the classifier's decision-making process.
#    - **Testset C**: CCNet-generated data with original labels. With Testset B, it is proved that CCNet creates the genuine data distribution for any case of decision label. However, as most information of the data is in the explanation vector, it is easy to manipulate by changing the decision factor of the fraud data. In short, it is easy to manipulate the decision-making process by causal inference.
# 5. **Ethical Considerations**: Discuss the ethical implications of data manipulation in machine learning, emphasizing the need for robustness in model training and the risks of misuse in applications like fraud detection.

# %%
import sys
path_append = "../../"
sys.path.append(path_append)  # Go up one directory from where you are.

# %%
# https://fraud-detection-handbook.github.io/fraud-detection-handbook/Chapter_7_DeepLearning/FeedForwardNeuralNetworks.html
import pandas as pd 

dataroot = path_append + "../data/credit_card_fraud_detection/creditcard.csv"
df = pd.read_csv(dataroot)
df
# Out:
# c:\Users\CCNets-team\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# c:\Users\CCNets-team\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
print('No Frauds', round(df['Class'].value_counts()[0] / len(df) *100,2), '%of the dataset')
print('Frauds', round(df['Class'].value_counts()[1] / len(df) *100,2), '%of the dataset')
# Out:
# No Frauds 99.83 %of the dataset
# Frauds 0.17 %of the dataset

# %%
import torch
from sklearn.preprocessing import StandardScaler, RobustScaler
from torch.utils.data import Dataset

# Initialize scalers
standard_sc = StandardScaler()
robust_sc = RobustScaler()
# Scale 'Amount' and 'Time' columns separately
df['scaled_amount'] = robust_sc.fit_transform(df['Amount'].values.reshape(-1, 1))
df['scaled_time'] = robust_sc.fit_transform(df['Time'].values.reshape(-1, 1))

# Drop original 'Time' and 'Amount' columns
df.drop(['Time', 'Amount'], axis=1, inplace=True)

# Move the 'Class' column to the end
class_column = df.pop('Class')
df = pd.concat([df, class_column], axis=1)

# Scale the rest of the features (excluding the class column)
df.iloc[:, :-1] = standard_sc.fit_transform(df.iloc[:, :-1])

# Calculate the number of features and classes
n_features = len(df.iloc[:, :-1].columns)
n_classes = len(df.iloc[:, -1:].columns)

print(n_features, n_classes)
# Out:
# 30 1

# %%
df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -0.694242 -0.044075  1.672773  0.973366 -0.245117  0.347068  0.193679
# 1  0.608496  0.161176  0.109797  0.316523  0.043483 -0.061820 -0.063700
# 2 -0.693500 -0.811578  1.169468  0.268231 -0.364572  1.351454  0.639776
# 3 -0.493325 -0.112169  1.182516 -0.609727 -0.007469  0.936150  0.192071
# 4 -0.591330  0.531541  1.021412  0.284655 -0.295015  0.071999  0.479302
#
#          V8        V9       V10  ...       V22       V23       V24       V25  \
# 0  0.082637  0.331128  0.083386  ...  0.382854 -0.176911  0.110507  0.246585
# 1  0.071253 -0.232494 -0.153350  ... -0.880077  0.162201 -0.561131  0.320694
# 2  0.207373 -1.378675  0.190700  ...  1.063358  1.456320 -1.138092 -0.628537
# 3  0.316018 -1.262503 -0.050468  ...  0.007267 -0.304777 -1.941027  1.241904
# 4 -0.226510  0.744326  0.691625  ...  1.100011 -0.220123  0.233250 -0.395202
#
#         V26       V27       V28  scaled_amount  scaled_time  Class
# 0 -0.392170  0.330892 -0.063781       0.244964    -1.996583      0
# 1  0.261069 -0.022256  0.044608      -0.342475    -1.996583      0
# 2 -0.288447 -0.137137 -0.181021       1.160686    -1.996562      0
# 3 -0.460217  0.155396  0.186189       0.140534    -1.996562      0
# 4  1.041611  0.543620  0.651816      -0.073403    -1.996541      0
#
# [5 rows x 31 columns]

# %%
# Defining the labeled and unlabeled dataset classes
class LabeledDataset(Dataset):
    def __init__(self, x, y):
        self.x = x
        self.y = y
        
    def __len__(self):
        return len(self.x)

    def __getitem__(self, index):
        vals = torch.tensor(self.x[index], dtype=torch.float32)
        label = torch.tensor(self.y[index], dtype=torch.long)
        return vals, label

# %% [markdown]
# #### Dataset Splitting for Training and Testing
#
# The original dataset is split into training and testing parts to evaluate the model's performance accurately. This step is crucial for validating the effectiveness of the training on unseen data.

# %%
from sklearn.model_selection import train_test_split

# Splitting the dataset into training and test sets for model evaluation
df_train, df_test = train_test_split(df, test_size=0.5, shuffle=True, random_state=42)
X_train, y_train = df_train.iloc[:, :-1].values, df_train.iloc[:, -1:].values
X_test, y_test = df_test.iloc[:, :-1].values, df_test.iloc[:, -1:].values

# Labeled datasets for supervised learning tasks
trainset = LabeledDataset(X_train, y_train)  # Corrected to include training data
testset = LabeledDataset(X_test, y_test)     # Test set with proper labels

# Printing the shapes of the datasets for verification
print(f"Labeled Trainset Shape: {len(trainset)}, {trainset.x.shape[1]}")
print(f"Labeled Testset Shape: {len(testset)}, {testset.x.shape[1]}")
# Out:
# Labeled Trainset Shape: 142403, 30
# Labeled Testset Shape: 142404, 30

# %% [markdown]
# #### Initial Setup and Model Configuration
#
# This section initializes the environment by setting a fixed random seed to ensure reproducibility of results. It imports necessary configurations and initializes model parameters with specific configurations. The model specified here is set to have no core model but uses a 'tabnet' encoder model for data processing, which is particularly tailored for structured or tabular data like credit card transactions.

# %%
# Set a fixed random seed for reproducibility of experiments
from nn.utils.init_layer import set_random_seed
set_random_seed(0)

# Importing configuration setups for ML parameters and data
import torch
from tools.setting.ml_params import MLParameters
from tools.setting.data_config import DataConfig
from causal_learning import CausalLearning

# Configuration for the data handling, defining dataset specifics and the task type
data_config = DataConfig(dataset_name='CreditCardFraudDetection', task_type='binary_classification', obs_shape=[n_features], label_size=n_classes, explain_size=n_features - n_classes)

# Initializing ML parameters without a core model and setting the encoder model to 'tabnet' with specific configurations
ml_params = MLParameters(model_name='tabnet', encoder_network='none')

# Setting training parameters and device configuration
ml_params.training.num_epoch = 10
ml_params.training.error_function = 'mse'
ml_params.model.num_layers = 4

device = torch.device("cuda" if torch.cuda.is_available() else "cpu") 

# Create a CausalLearning instance to manage training and data processing
causal_learning = CausalLearning(ml_params, data_config, device, use_print=True, use_wandb=False)
# Out:
# c:\Users\CCNets-team\anaconda3\lib\site-packages\transformers\utils\generic.py:311: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(

# %%
load_model = False
if load_model:
    causal_learning.load_trainer()
else:
    causal_learning.train(trainset)
# Out:
# Epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# Iterations:   0%|          | 0/2225 [00:00<?, ?it/s]
# [0/10][50/2225][Time 6.56]
# Unified LR across all optimizers: 0.0001995308238189185
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.2207	Gen: 0.6745	Rec: 0.6821	E: 0.1300	R: 0.1888	P: 1.7879
# [0/10][100/2225][Time 6.04]
# Unified LR across all optimizers: 0.00019907191565870155
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0170	Gen: 0.4445	Rec: 0.4447	E: 0.0057	R: 0.0076	P: 0.9637
# [0/10][150/2225][Time 5.87]
# Unified LR across all optimizers: 0.00019861406295796434
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0062	Gen: 0.4044	Rec: 0.4045	E: 0.0004	R: 0.0003	P: 0.9525
# [0/10][200/2225][Time 5.93]
# Unified LR across all optimizers: 0.00019815726328921765
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0114	Gen: 0.3690	Rec: 0.3690	E: 0.0088	R: 0.0080	P: 0.6998
# [0/10][250/2225][Time 5.66]
# Unified LR across all optimizers: 0.00019770151423055492
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0056	Gen: 0.3614	Rec: 0.3611	E: 0.0015	R: 0.0003	P: 0.6873
# [0/10][300/2225][Time 5.77]
# Unified LR across all optimizers: 0.00019724681336564005
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0041	Gen: 0.3417	Rec: 0.3414	E: 0.0011	R: 0.0002	P: 0.7879
# [0/10][350/2225][Time 5.87]
# Unified LR across all optimizers: 0.00019679315828369438
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0050	Gen: 0.3406	Rec: 0.3402	E: 0.0018	R: 0.0003	P: 0.7668
# [0/10][400/2225][Time 5.77]
# Unified LR across all optimizers: 0.00019634054657948372
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0065	Gen: 0.3338	Rec: 0.3328	E: 0.0067	R: 0.0006	P: 1.3910
# [0/10][450/2225][Time 5.96]
# Unified LR across all optimizers: 0.00019588897585330582
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0076	Gen: 0.3283	Rec: 0.3271	E: 0.0095	R: 0.0010	P: 0.6457
# [0/10][500/2225][Time 5.85]
# Unified LR across all optimizers: 0.00019543844371097777
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0049	Gen: 0.3123	Rec: 0.3122	E: 0.0015	R: 0.0008	P: 0.6128
# [0/10][550/2225][Time 5.87]
# Unified LR across all optimizers: 0.00019498894776382288
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0029	Gen: 0.3099	Rec: 0.3101	E: 0.0004	R: 0.0018	P: 0.5953
# [0/10][600/2225][Time 5.57]
# Unified LR across all optimizers: 0.00019454048562865856
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0031	Gen: 0.2946	Rec: 0.2940	E: 0.0063	R: 0.0004	P: 0.5341
# [0/10][650/2225][Time 5.66]
# Unified LR across all optimizers: 0.00019409305492778308
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0042	Gen: 0.2958	Rec: 0.2960	E: 0.0011	R: 0.0059	P: 0.6002
# [0/10][700/2225][Time 5.76]
# Unified LR across all optimizers: 0.00019364665328896346
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0037	Gen: 0.2867	Rec: 0.2861	E: 0.0024	R: 0.0002	P: 0.4775
# [0/10][750/2225][Time 5.91]
# Unified LR across all optimizers: 0.00019320127834542263
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0011	Gen: 0.2759	Rec: 0.2759	E: 0.0000	R: 0.0000	P: 0.4723
# [0/10][800/2225][Time 5.75]
# Unified LR across all optimizers: 0.00019275692773582703
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0024	Gen: 0.2739	Rec: 0.2735	E: 0.0033	R: 0.0001	P: 0.4757
# [0/10][850/2225][Time 5.81]
# Unified LR across all optimizers: 0.0001923135991042739
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0030	Gen: 0.2747	Rec: 0.2745	E: 0.0003	R: 0.0001	P: 0.5146
# [0/10][900/2225][Time 5.85]
# Unified LR across all optimizers: 0.0001918712901002789
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0058	Gen: 0.2742	Rec: 0.2733	E: 0.0088	R: 0.0009	P: 0.4562
# [0/10][950/2225][Time 5.75]
# Unified LR across all optimizers: 0.00019142999837876384
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0029	Gen: 0.2781	Rec: 0.2777	E: 0.0018	R: 0.0002	P: 0.4593
# [0/10][1000/2225][Time 5.90]
# Unified LR across all optimizers: 0.00019098972160004388
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0011	Gen: 0.2747	Rec: 0.2747	E: 0.0000	R: 0.0000	P: 0.5061
# [0/10][1050/2225][Time 5.81]
# Unified LR across all optimizers: 0.00019055045742981543
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0038	Gen: 0.2705	Rec: 0.2699	E: 0.0042	R: 0.0003	P: 0.4650
# [0/10][1100/2225][Time 5.66]
# Unified LR across all optimizers: 0.00019011220353914353
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0034	Gen: 0.2799	Rec: 0.2792	E: 0.0087	R: 0.0004	P: 0.6533
# [0/10][1150/2225][Time 5.93]
# Unified LR across all optimizers: 0.00018967495760444968
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0074	Gen: 0.2670	Rec: 0.2658	E: 0.0072	R: 0.0005	P: 0.4228
# [0/10][1200/2225][Time 5.70]
# Unified LR across all optimizers: 0.00018923871730749947
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0023	Gen: 0.2639	Rec: 0.2637	E: 0.0005	R: 0.0000	P: 0.4100
# [0/10][1250/2225][Time 5.65]
# Unified LR across all optimizers: 0.00018880348033539028
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0039	Gen: 0.2574	Rec: 0.2572	E: 0.0029	R: 0.0010	P: 0.3987
# [0/10][1300/2225][Time 5.90]
# Unified LR across all optimizers: 0.00018836924438053897
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0023	Gen: 0.2538	Rec: 0.2534	E: 0.0013	R: 0.0001	P: 0.3850
# [0/10][1350/2225][Time 5.73]
# Unified LR across all optimizers: 0.0001879360071406698
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0024	Gen: 0.2515	Rec: 0.2514	E: 0.0014	R: 0.0006	P: 0.3854
# [0/10][1400/2225][Time 5.80]
# Unified LR across all optimizers: 0.000187503766318802
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0064	Gen: 0.2601	Rec: 0.2592	E: 0.0037	R: 0.0006	P: 0.5293
# [0/10][1450/2225][Time 5.70]
# Unified LR across all optimizers: 0.00018707251962323787
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0021	Gen: 0.2598	Rec: 0.2597	E: 0.0003	R: 0.0001	P: 0.4960
# [0/10][1500/2225][Time 5.74]
# Unified LR across all optimizers: 0.0001866422647675502
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0041	Gen: 0.2491	Rec: 0.2490	E: 0.0020	R: 0.0008	P: 0.4535
# [0/10][1550/2225][Time 5.91]
# Unified LR across all optimizers: 0.00018621299947057073
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0028	Gen: 0.2369	Rec: 0.2368	E: 0.0010	R: 0.0004	P: 0.3340
# [0/10][1600/2225][Time 6.05]
# Unified LR across all optimizers: 0.00018578472145637737
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0039	Gen: 0.2274	Rec: 0.2276	E: 0.0008	R: 0.0009	P: 0.2743
# [0/10][1650/2225][Time 5.50]
# Unified LR across all optimizers: 0.00018535742845428288
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0032	Gen: 0.2462	Rec: 0.2454	E: 0.0039	R: 0.0001	P: 0.4525
# [0/10][1700/2225][Time 5.79]
# Unified LR across all optimizers: 0.00018493111819882223
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0035	Gen: 0.2430	Rec: 0.2425	E: 0.0014	R: 0.0002	P: 0.3673
# [0/10][1750/2225][Time 5.89]
# Unified LR across all optimizers: 0.00018450578842974107
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0043	Gen: 0.2640	Rec: 0.2635	E: 0.0036	R: 0.0005	P: 0.5724
# [0/10][1800/2225][Time 5.79]
# Unified LR across all optimizers: 0.00018408143689198318
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0051	Gen: 0.2464	Rec: 0.2461	E: 0.0022	R: 0.0006	P: 0.4396
# [0/10][1850/2225][Time 5.64]
# Unified LR across all optimizers: 0.0001836580613356789
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0030	Gen: 0.2422	Rec: 0.2421	E: 0.0013	R: 0.0011	P: 0.4338
# [0/10][1900/2225][Time 5.78]
# Unified LR across all optimizers: 0.0001832356595161332
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0009	Gen: 0.2345	Rec: 0.2345	E: 0.0000	R: 0.0000	P: 0.3246
# [0/10][1950/2225][Time 5.70]
# Unified LR across all optimizers: 0.00018281422919381367
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0008	Gen: 0.2274	Rec: 0.2274	E: 0.0000	R: 0.0000	P: 0.3049
# [0/10][2000/2225][Time 5.95]
# Unified LR across all optimizers: 0.00018239376813433867
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0025	Gen: 0.2309	Rec: 0.2308	E: 0.0006	R: 0.0004	P: 0.4167
# [0/10][2050/2225][Time 5.55]
# Unified LR across all optimizers: 0.00018197427410846564
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0023	Gen: 0.2193	Rec: 0.2190	E: 0.0010	R: 0.0002	P: 0.2823
# [0/10][2100/2225][Time 5.83]
# Unified LR across all optimizers: 0.00018155574489207887
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0027	Gen: 0.2192	Rec: 0.2187	E: 0.0015	R: 0.0001	P: 0.3189
# [0/10][2150/2225][Time 5.71]
# Unified LR across all optimizers: 0.00018113817826617823
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0018	Gen: 0.2338	Rec: 0.2335	E: 0.0018	R: 0.0002	P: 0.4111
# [0/10][2200/2225][Time 5.83]
# Unified LR across all optimizers: 0.00018072157201686696
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0026	Gen: 0.2258	Rec: 0.2258	E: 0.0011	R: 0.0014	P: 0.3251
# Iterations:   0%|          | 0/2225 [00:00<?, ?it/s]
# [1/10][25/2225][Time 5.75]
# Unified LR across all optimizers: 0.00018030592393534033
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0054	Gen: 0.2233	Rec: 0.2221	E: 0.0029	R: 0.0002	P: 0.3158
# [1/10][75/2225][Time 5.64]
# Unified LR across all optimizers: 0.0001798912318178735
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0033	Gen: 0.2349	Rec: 0.2342	E: 0.0037	R: 0.0002	P: 0.3805
# [1/10][125/2225][Time 5.52]
# Unified LR across all optimizers: 0.00017947749346581006
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0047	Gen: 0.2288	Rec: 0.2285	E: 0.0032	R: 0.0016	P: 0.4367
# [1/10][175/2225][Time 6.05]
# Unified LR across all optimizers: 0.0001790647066855505
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0030	Gen: 0.2280	Rec: 0.2279	E: 0.0023	R: 0.0007	P: 0.4066
# [1/10][225/2225][Time 5.71]
# Unified LR across all optimizers: 0.00017865286928854052
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0007	Gen: 0.2144	Rec: 0.2145	E: 0.0000	R: 0.0000	P: 0.2710
# [1/10][275/2225][Time 5.63]
# Unified LR across all optimizers: 0.00017824197909125899
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0030	Gen: 0.2243	Rec: 0.2241	E: 0.0012	R: 0.0005	P: 0.3949
# [1/10][325/2225][Time 5.64]
# Unified LR across all optimizers: 0.00017783203391520723
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0040	Gen: 0.2145	Rec: 0.2144	E: 0.0012	R: 0.0019	P: 0.2687
# [1/10][375/2225][Time 5.66]
# Unified LR across all optimizers: 0.00017742303158689668
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0050	Gen: 0.2145	Rec: 0.2146	E: 0.0011	R: 0.0015	P: 0.4516
# [1/10][425/2225][Time 5.64]
# Unified LR across all optimizers: 0.00017701496993783762
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0025	Gen: 0.2074	Rec: 0.2074	E: 0.0004	R: 0.0006	P: 0.3168
# [1/10][475/2225][Time 5.71]
# Unified LR across all optimizers: 0.00017660784680452796
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0033	Gen: 0.2042	Rec: 0.2040	E: 0.0015	R: 0.0007	P: 0.2449
# [1/10][525/2225][Time 5.49]
# Unified LR across all optimizers: 0.0001762016600284412
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0076	Gen: 0.2204	Rec: 0.2199	E: 0.0028	R: 0.0018	P: 0.3643
# [1/10][575/2225][Time 5.67]
# Unified LR across all optimizers: 0.00017579640745601563
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0071	Gen: 0.2202	Rec: 0.2199	E: 0.0030	R: 0.0023	P: 0.3105
# [1/10][625/2225][Time 5.73]
# Unified LR across all optimizers: 0.0001753920869386423
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0031	Gen: 0.2199	Rec: 0.2201	E: 0.0003	R: 0.0008	P: 0.5045
# [1/10][675/2225][Time 5.62]
# Unified LR across all optimizers: 0.0001749886963326542
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0042	Gen: 0.2043	Rec: 0.2045	E: 0.0003	R: 0.0007	P: 0.2721
# [1/10][725/2225][Time 5.86]
# Unified LR across all optimizers: 0.0001745862334993144
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0086	Gen: 0.2239	Rec: 0.2234	E: 0.0031	R: 0.0016	P: 0.3559
# [1/10][775/2225][Time 5.74]
# Unified LR across all optimizers: 0.00017418469630480507
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0033	Gen: 0.2083	Rec: 0.2081	E: 0.0008	R: 0.0007	P: 0.3643
# [1/10][825/2225][Time 5.72]
# Unified LR across all optimizers: 0.00017378408262021616
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0045	Gen: 0.2035	Rec: 0.2036	E: 0.0007	R: 0.0009	P: 0.2747
# [1/10][875/2225][Time 5.69]
# Unified LR across all optimizers: 0.00017338439032153356
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0028	Gen: 0.2052	Rec: 0.2050	E: 0.0007	R: 0.0003	P: 0.3193
# [1/10][925/2225][Time 5.55]
# Unified LR across all optimizers: 0.00017298561728962847
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0069	Gen: 0.2001	Rec: 0.1997	E: 0.0023	R: 0.0010	P: 0.2697
# [1/10][975/2225][Time 5.77]
# Unified LR across all optimizers: 0.00017258776141024598
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0064	Gen: 0.2171	Rec: 0.2165	E: 0.0023	R: 0.0010	P: 0.3147
# [1/10][1025/2225][Time 5.75]
# Unified LR across all optimizers: 0.00017219082057399394
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0030	Gen: 0.2096	Rec: 0.2094	E: 0.0011	R: 0.0004	P: 0.3103
# [1/10][1075/2225][Time 5.67]
# Unified LR across all optimizers: 0.00017179479267633146
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0041	Gen: 0.1969	Rec: 0.1959	E: 0.0032	R: 0.0002	P: 0.2494
# [1/10][1125/2225][Time 5.72]
# Unified LR across all optimizers: 0.00017139967561755819
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0040	Gen: 0.1990	Rec: 0.1996	E: 0.0005	R: 0.0033	P: 0.2659
# [1/10][1175/2225][Time 5.71]
# Unified LR across all optimizers: 0.00017100546730280274
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0007	Gen: 0.1952	Rec: 0.1951	E: 0.0002	R: 0.0001	P: 0.2479
# [1/10][1225/2225][Time 5.76]
# Unified LR across all optimizers: 0.00017061216564201177
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0030	Gen: 0.2024	Rec: 0.2025	E: 0.0005	R: 0.0010	P: 0.3327
# [1/10][1275/2225][Time 5.74]
# Unified LR across all optimizers: 0.0001702197685499392
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0041	Gen: 0.2003	Rec: 0.1999	E: 0.0032	R: 0.0020	P: 0.2599
# [1/10][1325/2225][Time 5.88]
# Unified LR across all optimizers: 0.0001698282739461345
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0029	Gen: 0.2095	Rec: 0.2094	E: 0.0013	R: 0.0012	P: 0.3407
# [1/10][1375/2225][Time 5.63]
# Unified LR across all optimizers: 0.00016943767975493242
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0035	Gen: 0.2034	Rec: 0.2039	E: 0.0015	R: 0.0028	P: 0.2850
# [1/10][1425/2225][Time 5.76]
# Unified LR across all optimizers: 0.0001690479839054414
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0048	Gen: 0.2128	Rec: 0.2138	E: 0.0028	R: 0.0081	P: 0.4707
# [1/10][1475/2225][Time 5.73]
# Unified LR across all optimizers: 0.00016865918433153277
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0010	Gen: 0.1960	Rec: 0.1960	E: 0.0009	R: 0.0011	P: 0.3394
# [1/10][1525/2225][Time 5.66]
# Unified LR across all optimizers: 0.00016827127897182985
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0061	Gen: 0.2016	Rec: 0.2011	E: 0.0084	R: 0.0070	P: 0.2591
# [1/10][1575/2225][Time 5.81]
# Unified LR across all optimizers: 0.0001678842657696972
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0064	Gen: 0.2375	Rec: 0.2376	E: 0.0061	R: 0.0073	P: 0.3884
# [1/10][1625/2225][Time 5.80]
# Unified LR across all optimizers: 0.00016749814267322938
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0026	Gen: 0.2312	Rec: 0.2307	E: 0.0027	R: 0.0004	P: 0.3887
# [1/10][1675/2225][Time 5.95]
# Unified LR across all optimizers: 0.00016711290763524007
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0054	Gen: 0.2206	Rec: 0.2215	E: 0.0008	R: 0.0063	P: 0.3265
# [1/10][1725/2225][Time 6.06]
# Unified LR across all optimizers: 0.00016672855861325146
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0074	Gen: 0.2221	Rec: 0.2234	E: 0.0039	R: 0.0186	P: 0.4237
# [1/10][1775/2225][Time 5.70]
# Unified LR across all optimizers: 0.00016634509356948314
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0035	Gen: 0.2144	Rec: 0.2144	E: 0.0013	R: 0.0020	P: 0.2830
# [1/10][1825/2225][Time 6.20]
# Unified LR across all optimizers: 0.00016596251047084197
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0066	Gen: 0.2672	Rec: 0.2651	E: 0.0200	R: 0.0021	P: 1.2173
# [1/10][1875/2225][Time 6.78]
# Unified LR across all optimizers: 0.00016558080728890993
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0075	Gen: 0.2470	Rec: 0.2481	E: 0.0070	R: 0.0172	P: 0.4039
# [1/10][1925/2225][Time 6.06]
# Unified LR across all optimizers: 0.00016519998199993532
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0031	Gen: 0.2350	Rec: 0.2355	E: 0.0005	R: 0.0045	P: 0.4318
# [1/10][1975/2225][Time 5.88]
# Unified LR across all optimizers: 0.0001648200325848201
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0094	Gen: 0.2361	Rec: 0.2355	E: 0.0180	R: 0.0147	P: 0.3618
# [1/10][2025/2225][Time 5.84]
# Unified LR across all optimizers: 0.00016444095702911038
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0077	Gen: 0.2293	Rec: 0.2312	E: 0.0028	R: 0.0244	P: 0.3530
# [1/10][2075/2225][Time 5.79]
# Unified LR across all optimizers: 0.00016406275332298505
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0095	Gen: 0.2193	Rec: 0.2203	E: 0.0077	R: 0.0178	P: 0.3414
# [1/10][2125/2225][Time 5.92]
# Unified LR across all optimizers: 0.00016368541946124596
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0038	Gen: 0.2210	Rec: 0.2211	E: 0.0035	R: 0.0046	P: 0.3097
# [1/10][2175/2225][Time 5.61]
# Unified LR across all optimizers: 0.00016330895344330638
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0018	Gen: 0.2233	Rec: 0.2235	E: 0.0002	R: 0.0010	P: 0.3915
# Iterations:   0%|          | 0/2225 [00:00<?, ?it/s]
# [2/10][0/2225][Time 5.90]
# Unified LR across all optimizers: 0.00016293335327318117
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0014	Gen: 0.2123	Rec: 0.2127	E: 0.0005	R: 0.0056	P: 0.3173
# [2/10][50/2225][Time 5.81]
# Unified LR across all optimizers: 0.00016255861695947546
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0058	Gen: 0.2277	Rec: 0.2279	E: 0.0065	R: 0.0095	P: 0.3705
# [2/10][100/2225][Time 5.73]
# Unified LR across all optimizers: 0.00016218474251537463
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0066	Gen: 0.2241	Rec: 0.2258	E: 0.0025	R: 0.0223	P: 0.3178
# [2/10][150/2225][Time 5.94]
# Unified LR across all optimizers: 0.00016181172795863357
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0043	Gen: 0.2191	Rec: 0.2185	E: 0.0036	R: 0.0017	P: 0.3126
# [2/10][200/2225][Time 5.73]
# Unified LR across all optimizers: 0.0001614395713115662
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0056	Gen: 0.2133	Rec: 0.2138	E: 0.0034	R: 0.0071	P: 0.2898
# [2/10][250/2225][Time 5.85]
# Unified LR across all optimizers: 0.00016106827060103523
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0090	Gen: 0.2328	Rec: 0.2341	E: 0.0067	R: 0.0144	P: 0.3689
# [2/10][300/2225][Time 5.79]
# Unified LR across all optimizers: 0.00016069782385844109
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0024	Gen: 0.2239	Rec: 0.2234	E: 0.0015	R: 0.0002	P: 0.3267
# [2/10][350/2225][Time 5.61]
# Unified LR across all optimizers: 0.00016032822911971208
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0036	Gen: 0.2234	Rec: 0.2228	E: 0.0020	R: 0.0005	P: 0.4018
# [2/10][400/2225][Time 5.65]
# Unified LR across all optimizers: 0.0001599594844252937
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0033	Gen: 0.2070	Rec: 0.2069	E: 0.0010	R: 0.0013	P: 0.2956
# [2/10][450/2225][Time 5.98]
# Unified LR across all optimizers: 0.00015959158782013816
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0026	Gen: 0.2094	Rec: 0.2090	E: 0.0026	R: 0.0007	P: 0.3231
# [2/10][500/2225][Time 5.88]
# Unified LR across all optimizers: 0.00015922453735369438
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0020	Gen: 0.2201	Rec: 0.2203	E: 0.0011	R: 0.0030	P: 0.9633
# [2/10][550/2225][Time 5.59]
# Unified LR across all optimizers: 0.00015885833107989733
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0044	Gen: 0.2044	Rec: 0.2048	E: 0.0018	R: 0.0053	P: 0.2843
# [2/10][600/2225][Time 5.70]
# Unified LR across all optimizers: 0.00015849296705715778
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0082	Gen: 0.2103	Rec: 0.2122	E: 0.0065	R: 0.0331	P: 0.3041
# [2/10][650/2225][Time 5.79]
# Unified LR across all optimizers: 0.0001581284433483521
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0032	Gen: 0.2142	Rec: 0.2137	E: 0.0026	R: 0.0008	P: 0.4503
# [2/10][700/2225][Time 5.77]
# Unified LR across all optimizers: 0.00015776475802081183
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0041	Gen: 0.2046	Rec: 0.2049	E: 0.0010	R: 0.0032	P: 0.2673
# [2/10][750/2225][Time 5.79]
# Unified LR across all optimizers: 0.00015740190914631356
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0077	Gen: 0.2130	Rec: 0.2160	E: 0.0026	R: 0.0510	P: 0.4607
# [2/10][800/2225][Time 5.62]
# Unified LR across all optimizers: 0.0001570398948010687
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0075	Gen: 0.2087	Rec: 0.2107	E: 0.0073	R: 0.0448	P: 0.3236
# [2/10][850/2225][Time 5.94]
# Unified LR across all optimizers: 0.00015667871306571324
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0044	Gen: 0.2033	Rec: 0.2035	E: 0.0056	R: 0.0087	P: 0.2588
# [2/10][900/2225][Time 5.64]
# Unified LR across all optimizers: 0.00015631836202529756
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0068	Gen: 0.2219	Rec: 0.2213	E: 0.0057	R: 0.0019	P: 0.4586
# [2/10][950/2225][Time 5.63]
# Unified LR across all optimizers: 0.00015595883976927632
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0014	Gen: 0.2147	Rec: 0.2143	E: 0.0048	R: 0.0007	P: 0.3206
# [2/10][1000/2225][Time 5.89]
# Unified LR across all optimizers: 0.0001556001443914984
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0032	Gen: 0.2079	Rec: 0.2084	E: 0.0010	R: 0.0102	P: 0.2729
# [2/10][1050/2225][Time 5.73]
# Unified LR across all optimizers: 0.0001552422739901963
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0059	Gen: 0.2092	Rec: 0.2089	E: 0.0078	R: 0.0034	P: 0.3426
# [2/10][1100/2225][Time 5.63]
# Unified LR across all optimizers: 0.00015488522666797712
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0078	Gen: 0.2219	Rec: 0.2211	E: 0.0268	R: 0.0061	P: 0.3887
# [2/10][1150/2225][Time 5.60]
# Unified LR across all optimizers: 0.00015452900053181137
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0100	Gen: 0.2196	Rec: 0.2225	E: 0.0034	R: 0.0373	P: 0.4380
# [2/10][1200/2225][Time 5.50]
# Unified LR across all optimizers: 0.00015417359369302347
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0070	Gen: 0.2104	Rec: 0.2115	E: 0.0085	R: 0.0317	P: 0.3693
# [2/10][1250/2225][Time 5.88]
# Unified LR across all optimizers: 0.00015381900426728195
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0065	Gen: 0.2201	Rec: 0.2208	E: 0.0078	R: 0.0130	P: 0.3940
# [2/10][1300/2225][Time 5.68]
# Unified LR across all optimizers: 0.00015346523037458877
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0056	Gen: 0.2301	Rec: 0.2294	E: 0.0078	R: 0.0066	P: 0.5272
# [2/10][1350/2225][Time 5.51]
# Unified LR across all optimizers: 0.00015311227013926996
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0035	Gen: 0.2230	Rec: 0.2223	E: 0.0027	R: 0.0004	P: 0.4018
# [2/10][1400/2225][Time 5.55]
# Unified LR across all optimizers: 0.00015276012168996563
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0028	Gen: 0.2076	Rec: 0.2075	E: 0.0018	R: 0.0013	P: 0.3345
# [2/10][1450/2225][Time 5.70]
# Unified LR across all optimizers: 0.00015240878315961963
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0096	Gen: 0.2148	Rec: 0.2151	E: 0.0095	R: 0.0253	P: 0.3479
# [2/10][1500/2225][Time 5.84]
# Unified LR across all optimizers: 0.00015205825268547007
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0012	Gen: 0.2159	Rec: 0.2155	E: 0.0023	R: 0.0001	P: 0.3282
# [2/10][1550/2225][Time 5.61]
# Unified LR across all optimizers: 0.0001517085284090394
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0055	Gen: 0.2176	Rec: 0.2181	E: 0.0035	R: 0.0090	P: 0.4231
# [2/10][1600/2225][Time 5.75]
# Unified LR across all optimizers: 0.00015135960847612417
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0038	Gen: 0.2141	Rec: 0.2151	E: 0.0004	R: 0.0065	P: 0.4177
# [2/10][1650/2225][Time 5.62]
# Unified LR across all optimizers: 0.0001510114910367858
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0098	Gen: 0.2188	Rec: 0.2170	E: 0.0219	R: 0.0071	P: 0.2848
# [2/10][1700/2225][Time 6.03]
# Unified LR across all optimizers: 0.00015066417424534014
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0058	Gen: 0.2320	Rec: 0.2322	E: 0.0032	R: 0.0076	P: 0.3484
# [2/10][1750/2225][Time 5.60]
# Unified LR across all optimizers: 0.00015031765626034814
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0044	Gen: 0.2282	Rec: 0.2282	E: 0.0033	R: 0.0048	P: 0.3717
# [2/10][1800/2225][Time 5.60]
# Unified LR across all optimizers: 0.00014997193524460595
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0084	Gen: 0.2114	Rec: 0.2130	E: 0.0042	R: 0.0226	P: 0.4322
# [2/10][1850/2225][Time 5.77]
# Unified LR across all optimizers: 0.00014962700936513516
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0080	Gen: 0.2062	Rec: 0.2057	E: 0.0072	R: 0.0043	P: 0.2895
# [2/10][1900/2225][Time 5.70]
# Unified LR across all optimizers: 0.00014928287679317315
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0065	Gen: 0.2231	Rec: 0.2247	E: 0.0019	R: 0.0163	P: 0.4725
# [2/10][1950/2225][Time 5.78]
# Unified LR across all optimizers: 0.0001489395357041632
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0066	Gen: 0.2106	Rec: 0.2111	E: 0.0060	R: 0.0118	P: 0.3273
# [2/10][2000/2225][Time 5.58]
# Unified LR across all optimizers: 0.000148596984277745
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0086	Gen: 0.2190	Rec: 0.2212	E: 0.0042	R: 0.0423	P: 0.3372
# [2/10][2050/2225][Time 5.68]
# Unified LR across all optimizers: 0.0001482552206977451
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0009	Gen: 0.2099	Rec: 0.2099	E: 0.0000	R: 0.0001	P: 0.3358
# [2/10][2100/2225][Time 5.77]
# Unified LR across all optimizers: 0.00014791424315216693
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0099	Gen: 0.2067	Rec: 0.2066	E: 0.0183	R: 0.0254	P: 0.3109
# [2/10][2150/2225][Time 5.78]
# Unified LR across all optimizers: 0.00014757404983318153
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0021	Gen: 0.2067	Rec: 0.2070	E: 0.0006	R: 0.0014	P: 0.2941
# [2/10][2200/2225][Time 5.83]
# Unified LR across all optimizers: 0.00014723463893711783
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0070	Gen: 0.2077	Rec: 0.2080	E: 0.0043	R: 0.0062	P: 0.3383
# Iterations:   0%|          | 0/2225 [00:00<?, ?it/s]
# [3/10][25/2225][Time 5.79]
# Unified LR across all optimizers: 0.00014689600866445298
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0089	Gen: 0.2069	Rec: 0.2071	E: 0.0072	R: 0.0092	P: 0.3262
# [3/10][75/2225][Time 5.73]
# Unified LR across all optimizers: 0.00014655815721980301
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0110	Gen: 0.2114	Rec: 0.2118	E: 0.0213	R: 0.0310	P: 0.2622
# [3/10][125/2225][Time 5.78]
# Unified LR across all optimizers: 0.00014622108281191326
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0052	Gen: 0.2256	Rec: 0.2256	E: 0.0031	R: 0.0086	P: 0.4636
# [3/10][175/2225][Time 5.94]
# Unified LR across all optimizers: 0.00014588478365364866
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0060	Gen: 0.2207	Rec: 0.2210	E: 0.0011	R: 0.0040	P: 0.3630
# [3/10][225/2225][Time 5.73]
# Unified LR across all optimizers: 0.0001455492579619846
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0036	Gen: 0.2005	Rec: 0.2014	E: 0.0030	R: 0.0281	P: 0.2945
# [3/10][275/2225][Time 5.72]
# Unified LR across all optimizers: 0.00014521450395799725
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0063	Gen: 0.1980	Rec: 0.1981	E: 0.0047	R: 0.0166	P: 0.2471
# [3/10][325/2225][Time 5.88]
# Unified LR across all optimizers: 0.00014488051986685427
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0028	Gen: 0.2035	Rec: 0.2033	E: 0.0019	R: 0.0011	P: 0.3539
# [3/10][375/2225][Time 5.61]
# Unified LR across all optimizers: 0.00014454730391780514
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0080	Gen: 0.2106	Rec: 0.2121	E: 0.0080	R: 0.0509	P: 0.5062
# [3/10][425/2225][Time 5.91]
# Unified LR across all optimizers: 0.0001442148543441721
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0091	Gen: 0.2108	Rec: 0.2106	E: 0.0209	R: 0.0129	P: 0.4813
# [3/10][475/2225][Time 5.70]
# Unified LR across all optimizers: 0.00014388316938334075
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0021	Gen: 0.2060	Rec: 0.2059	E: 0.0023	R: 0.0025	P: 0.3197
# [3/10][525/2225][Time 5.86]
# Unified LR across all optimizers: 0.0001435522472767503
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0062	Gen: 0.2063	Rec: 0.2054	E: 0.0078	R: 0.0037	P: 0.2865
# [3/10][575/2225][Time 5.72]
# Unified LR across all optimizers: 0.00014322208626988471
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0046	Gen: 0.2017	Rec: 0.2022	E: 0.0027	R: 0.0079	P: 0.3151
# [3/10][625/2225][Time 5.68]
# Unified LR across all optimizers: 0.00014289268461226322
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0068	Gen: 0.2025	Rec: 0.2035	E: 0.0065	R: 0.0138	P: 0.2925
# [3/10][675/2225][Time 5.65]
# Unified LR across all optimizers: 0.00014256404055743098
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0046	Gen: 0.2218	Rec: 0.2202	E: 0.0292	R: 0.0040	P: 0.3652
# [3/10][725/2225][Time 6.09]
# Unified LR across all optimizers: 0.00014223615236295
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0073	Gen: 0.2139	Rec: 0.2145	E: 0.0046	R: 0.0148	P: 0.3044
# [3/10][775/2225][Time 5.68]
# Unified LR across all optimizers: 0.0001419090182903897
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0062	Gen: 0.2070	Rec: 0.2080	E: 0.0049	R: 0.0206	P: 0.3678
# [3/10][825/2225][Time 5.65]
# Unified LR across all optimizers: 0.00014158263660531755
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0072	Gen: 0.2031	Rec: 0.2041	E: 0.0035	R: 0.0106	P: 0.2794
# [3/10][875/2225][Time 5.75]
# Unified LR across all optimizers: 0.00014125700557729063
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0034	Gen: 0.2014	Rec: 0.2014	E: 0.0033	R: 0.0061	P: 0.2942
# [3/10][925/2225][Time 5.80]
# Unified LR across all optimizers: 0.00014093212347984557
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0074	Gen: 0.2053	Rec: 0.2057	E: 0.0054	R: 0.0123	P: 0.2842
# [3/10][975/2225][Time 5.77]
# Unified LR across all optimizers: 0.00014060798859048983
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0073	Gen: 0.2104	Rec: 0.2105	E: 0.0156	R: 0.0193	P: 0.2751
# [3/10][1025/2225][Time 5.88]
# Unified LR across all optimizers: 0.00014028459919069257
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0042	Gen: 0.2198	Rec: 0.2206	E: 0.0013	R: 0.0122	P: 0.3619
# [3/10][1075/2225][Time 5.66]
# Unified LR across all optimizers: 0.00013996195356587524
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0081	Gen: 0.2155	Rec: 0.2167	E: 0.0075	R: 0.0223	P: 0.3559
# [3/10][1125/2225][Time 5.73]
# Unified LR across all optimizers: 0.0001396400500054029
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0055	Gen: 0.2140	Rec: 0.2133	E: 0.0120	R: 0.0036	P: 0.3014
# [3/10][1175/2225][Time 5.82]
# Unified LR across all optimizers: 0.00013931888680257493
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0077	Gen: 0.2216	Rec: 0.2213	E: 0.0052	R: 0.0044	P: 0.4804
# [3/10][1225/2225][Time 5.49]
# Unified LR across all optimizers: 0.000138998462254616
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0026	Gen: 0.2114	Rec: 0.2114	E: 0.0007	R: 0.0013	P: 0.4035
# [3/10][1275/2225][Time 5.83]
# Unified LR across all optimizers: 0.00013867877466266706
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0023	Gen: 0.2064	Rec: 0.2069	E: 0.0003	R: 0.0059	P: 0.3299
# [3/10][1325/2225][Time 5.88]
# Unified LR across all optimizers: 0.00013835982233177638
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0042	Gen: 0.2038	Rec: 0.2034	E: 0.0055	R: 0.0023	P: 0.2891
# [3/10][1375/2225][Time 5.75]
# Unified LR across all optimizers: 0.0001380416035708904
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0068	Gen: 0.2119	Rec: 0.2124	E: 0.0093	R: 0.0158	P: 0.3947
# [3/10][1425/2225][Time 5.75]
# Unified LR across all optimizers: 0.00013772411669284496
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0075	Gen: 0.2115	Rec: 0.2119	E: 0.0070	R: 0.0107	P: 0.3281
# [3/10][1475/2225][Time 5.61]
# Unified LR across all optimizers: 0.00013740736001435612
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0089	Gen: 0.2149	Rec: 0.2158	E: 0.0081	R: 0.0362	P: 0.3626
# [3/10][1525/2225][Time 5.57]
# Unified LR across all optimizers: 0.0001370913318560116
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0061	Gen: 0.2155	Rec: 0.2147	E: 0.0142	R: 0.0056	P: 1.0418
# [3/10][1575/2225][Time 5.97]
# Unified LR across all optimizers: 0.00013677603054226164
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0037	Gen: 0.2233	Rec: 0.2230	E: 0.0027	R: 0.0017	P: 0.3196
# [3/10][1625/2225][Time 5.59]
# Unified LR across all optimizers: 0.00013646145440140986
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0060	Gen: 0.2151	Rec: 0.2152	E: 0.0064	R: 0.0077	P: 0.2975
# [3/10][1675/2225][Time 5.58]
# Unified LR across all optimizers: 0.000136147601765605
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0038	Gen: 0.2236	Rec: 0.2240	E: 0.0023	R: 0.0069	P: 0.4509
# [3/10][1725/2225][Time 5.58]
# Unified LR across all optimizers: 0.00013583447097083163
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0045	Gen: 0.2179	Rec: 0.2187	E: 0.0053	R: 0.0202	P: 0.3921
# [3/10][1775/2225][Time 5.72]
# Unified LR across all optimizers: 0.00013552206035690145
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0024	Gen: 0.2105	Rec: 0.2105	E: 0.0012	R: 0.0020	P: 0.4316
# [3/10][1825/2225][Time 5.82]
# Unified LR across all optimizers: 0.00013521036826744445
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0033	Gen: 0.2089	Rec: 0.2087	E: 0.0027	R: 0.0018	P: 0.3151
# [3/10][1875/2225][Time 5.63]
# Unified LR across all optimizers: 0.00013489939304990025
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0049	Gen: 0.2094	Rec: 0.2088	E: 0.0095	R: 0.0048	P: 0.3251
# [3/10][1925/2225][Time 5.56]
# Unified LR across all optimizers: 0.00013458913305550914
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0072	Gen: 0.2117	Rec: 0.2124	E: 0.0088	R: 0.0125	P: 0.3412
# [3/10][1975/2225][Time 5.67]
# Unified LR across all optimizers: 0.00013427958663930363
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0088	Gen: 0.2126	Rec: 0.2144	E: 0.0029	R: 0.0197	P: 0.3446
# [3/10][2025/2225][Time 5.73]
# Unified LR across all optimizers: 0.00013397075216009928
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0062	Gen: 0.2246	Rec: 0.2228	E: 0.0332	R: 0.0053	P: 0.3834
# [3/10][2075/2225][Time 5.47]
# Unified LR across all optimizers: 0.00013366262798048648
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0055	Gen: 0.2081	Rec: 0.2089	E: 0.0032	R: 0.0120	P: 0.3261
# [3/10][2125/2225][Time 5.71]
# Unified LR across all optimizers: 0.00013335521246682152
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0022	Gen: 0.1947	Rec: 0.1942	E: 0.0053	R: 0.0012	P: 0.2248
# [3/10][2175/2225][Time 5.63]
# Unified LR across all optimizers: 0.00013304850398921782
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0172	Gen: 0.2294	Rec: 0.2319	E: 0.0197	R: 0.0597	P: 0.3983
# Iterations:   0%|          | 0/2225 [00:00<?, ?it/s]
# [4/10][0/2225][Time 5.62]
# Unified LR across all optimizers: 0.00013274250092153782
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0132	Gen: 0.2289	Rec: 0.2291	E: 0.0441	R: 0.0664	P: 0.3601
# [4/10][50/2225][Time 5.70]
# Unified LR across all optimizers: 0.00013243720164138364
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0021	Gen: 0.2208	Rec: 0.2213	E: 0.0006	R: 0.0048	P: 0.3695
# [4/10][100/2225][Time 5.55]
# Unified LR across all optimizers: 0.00013213260453008872
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0076	Gen: 0.2106	Rec: 0.2121	E: 0.0050	R: 0.0399	P: 0.3453
# [4/10][150/2225][Time 5.88]
# Unified LR across all optimizers: 0.00013182870797270977
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0043	Gen: 0.2131	Rec: 0.2141	E: 0.0028	R: 0.0105	P: 1.0540
# [4/10][200/2225][Time 5.82]
# Unified LR across all optimizers: 0.0001315255103580172
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0099	Gen: 0.2115	Rec: 0.2101	E: 0.0285	R: 0.0213	P: 0.2737
# [4/10][250/2225][Time 5.67]
# Unified LR across all optimizers: 0.00013122301007848758
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0077	Gen: 0.2183	Rec: 0.2191	E: 0.0038	R: 0.0256	P: 0.3842
# [4/10][300/2225][Time 5.57]
# Unified LR across all optimizers: 0.00013092120553029462
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0051	Gen: 0.2051	Rec: 0.2053	E: 0.0091	R: 0.0115	P: 0.2961
# [4/10][350/2225][Time 5.69]
# Unified LR across all optimizers: 0.00013062009511330047
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0055	Gen: 0.2083	Rec: 0.2094	E: 0.0036	R: 0.0204	P: 0.3201
# [4/10][400/2225][Time 5.76]
# Unified LR across all optimizers: 0.0001303196772310477
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0094	Gen: 0.2083	Rec: 0.2088	E: 0.0215	R: 0.0306	P: 0.2617
# [4/10][450/2225][Time 5.59]
# Unified LR across all optimizers: 0.00013001995029075084
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0076	Gen: 0.2409	Rec: 0.2410	E: 0.0119	R: 0.0201	P: 0.5757
# [4/10][500/2225][Time 5.70]
# Unified LR across all optimizers: 0.00012972091270328727
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0056	Gen: 0.2246	Rec: 0.2256	E: 0.0017	R: 0.0124	P: 0.4025
# [4/10][550/2225][Time 5.68]
# Unified LR across all optimizers: 0.00012942256288318946
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0025	Gen: 0.2063	Rec: 0.2055	E: 0.0082	R: 0.0011	P: 0.2565
# [4/10][600/2225][Time 5.76]
# Unified LR across all optimizers: 0.00012912489924863657
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0045	Gen: 0.2140	Rec: 0.2135	E: 0.0068	R: 0.0030	P: 0.2844
# [4/10][650/2225][Time 5.66]
# Unified LR across all optimizers: 0.00012882792022144538
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0061	Gen: 0.2181	Rec: 0.2166	E: 0.0121	R: 0.0013	P: 0.3644
# [4/10][700/2225][Time 5.74]
# Unified LR across all optimizers: 0.0001285316242270628
# ...
# [8/10][1250/2225][Time 6.12]
# Unified LR across all optimizers: 8.317829150871044e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0046	Gen: 0.1967	Rec: 0.1982	E: 0.0017	R: 0.0236	P: 0.3321
# [8/10][1300/2225][Time 6.03]
# Unified LR across all optimizers: 8.298698674689132e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0027	Gen: 0.1847	Rec: 0.1850	E: 0.0027	R: 0.0058	P: 0.1967
# [8/10][1350/2225][Time 5.96]
# Unified LR across all optimizers: 8.279612197381481e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0095	Gen: 0.1996	Rec: 0.1991	E: 0.0241	R: 0.0138	P: 0.3053
# [8/10][1400/2225][Time 6.05]
# Unified LR across all optimizers: 8.260569617753492e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0043	Gen: 0.1925	Rec: 0.1910	E: 0.0236	R: 0.0020	P: 0.2210
# [8/10][1450/2225][Time 6.25]
# Unified LR across all optimizers: 8.241570834843299e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0070	Gen: 0.1932	Rec: 0.1945	E: 0.0065	R: 0.0405	P: 0.2427
# [8/10][1500/2225][Time 6.02]
# Unified LR across all optimizers: 8.222615747921251e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0068	Gen: 0.2015	Rec: 0.2003	E: 0.0147	R: 0.0038	P: 0.2712
# [8/10][1550/2225][Time 5.98]
# Unified LR across all optimizers: 8.203704256489364e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0046	Gen: 0.2045	Rec: 0.2037	E: 0.0081	R: 0.0033	P: 0.2897
# [8/10][1600/2225][Time 6.10]
# Unified LR across all optimizers: 8.184836260280792e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0074	Gen: 0.2016	Rec: 0.2010	E: 0.0076	R: 0.0033	P: 0.2522
# [8/10][1650/2225][Time 5.99]
# Unified LR across all optimizers: 8.166011659259291e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0039	Gen: 0.1985	Rec: 0.1985	E: 0.0036	R: 0.0029	P: 0.2317
# [8/10][1700/2225][Time 6.15]
# Unified LR across all optimizers: 8.147230353618705e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0048	Gen: 0.2003	Rec: 0.2013	E: 0.0024	R: 0.0117	P: 0.3278
# [8/10][1750/2225][Time 6.14]
# Unified LR across all optimizers: 8.128492243782422e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0058	Gen: 0.1958	Rec: 0.1948	E: 0.0272	R: 0.0080	P: 0.2433
# [8/10][1800/2225][Time 5.97]
# Unified LR across all optimizers: 8.109797230402852e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0042	Gen: 0.2063	Rec: 0.2060	E: 0.0068	R: 0.0044	P: 0.3393
# [8/10][1850/2225][Time 6.03]
# Unified LR across all optimizers: 8.09114521436089e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0112	Gen: 0.2070	Rec: 0.2089	E: 0.0130	R: 0.0446	P: 0.2875
# [8/10][1900/2225][Time 5.93]
# Unified LR across all optimizers: 8.072536096765404e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0027	Gen: 0.1966	Rec: 0.1980	E: 0.0001	R: 0.0151	P: 0.3217
# [8/10][1950/2225][Time 6.23]
# Unified LR across all optimizers: 8.053969778952707e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0116	Gen: 0.2091	Rec: 0.2098	E: 0.0226	R: 0.0511	P: 0.3167
# [8/10][2000/2225][Time 6.28]
# Unified LR across all optimizers: 8.035446162486028e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0091	Gen: 0.2046	Rec: 0.2047	E: 0.0093	R: 0.0124	P: 0.2686
# [8/10][2050/2225][Time 6.05]
# Unified LR across all optimizers: 8.016965149154994e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0076	Gen: 0.2192	Rec: 0.2196	E: 0.0112	R: 0.0196	P: 0.4118
# [8/10][2100/2225][Time 6.06]
# Unified LR across all optimizers: 7.998526640975121e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0057	Gen: 0.2058	Rec: 0.2063	E: 0.0034	R: 0.0084	P: 0.4232
# [8/10][2150/2225][Time 6.16]
# Unified LR across all optimizers: 7.980130540187273e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0067	Gen: 0.2047	Rec: 0.2061	E: 0.0045	R: 0.0512	P: 0.3201
# [8/10][2200/2225][Time 6.18]
# Unified LR across all optimizers: 7.961776749257148e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0061	Gen: 0.1960	Rec: 0.1953	E: 0.0224	R: 0.0066	P: 0.2953
# Iterations:   0%|          | 0/2225 [00:00<?, ?it/s]
# [9/10][25/2225][Time 6.26]
# Unified LR across all optimizers: 7.943465170874777e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0057	Gen: 0.1949	Rec: 0.1947	E: 0.0078	R: 0.0064	P: 0.2327
# [9/10][75/2225][Time 6.14]
# Unified LR across all optimizers: 7.925195707953989e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0109	Gen: 0.1981	Rec: 0.2005	E: 0.0079	R: 0.0355	P: 0.2673
# [9/10][125/2225][Time 6.21]
# Unified LR across all optimizers: 7.90696826363192e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0067	Gen: 0.1920	Rec: 0.1924	E: 0.0091	R: 0.0197	P: 0.2686
# [9/10][175/2225][Time 6.35]
# Unified LR across all optimizers: 7.888782741268464e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0050	Gen: 0.1994	Rec: 0.1984	E: 0.0125	R: 0.0034	P: 0.4316
# [9/10][225/2225][Time 6.16]
# Unified LR across all optimizers: 7.870639044445802e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0082	Gen: 0.2064	Rec: 0.2071	E: 0.0069	R: 0.0114	P: 0.3702
# [9/10][275/2225][Time 6.02]
# Unified LR across all optimizers: 7.85253707696785e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0110	Gen: 0.1990	Rec: 0.2024	E: 0.0057	R: 0.0695	P: 0.2928
# [9/10][325/2225][Time 5.82]
# Unified LR across all optimizers: 7.834476742859793e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0092	Gen: 0.1936	Rec: 0.1957	E: 0.0044	R: 0.0334	P: 0.2330
# [9/10][375/2225][Time 5.82]
# Unified LR across all optimizers: 7.816457946367525e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0084	Gen: 0.2009	Rec: 0.2025	E: 0.0077	R: 0.0598	P: 0.3093
# [9/10][425/2225][Time 5.66]
# Unified LR across all optimizers: 7.79848059195718e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0066	Gen: 0.1925	Rec: 0.1930	E: 0.0088	R: 0.0142	P: 0.2764
# [9/10][475/2225][Time 5.70]
# Unified LR across all optimizers: 7.780544584314617e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0049	Gen: 0.1915	Rec: 0.1922	E: 0.0030	R: 0.0132	P: 0.2548
# [9/10][525/2225][Time 6.03]
# Unified LR across all optimizers: 7.762649828344911e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0084	Gen: 0.1954	Rec: 0.1955	E: 0.0100	R: 0.0143	P: 0.2915
# [9/10][575/2225][Time 5.89]
# Unified LR across all optimizers: 7.744796229171844e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0046	Gen: 0.1878	Rec: 0.1886	E: 0.0025	R: 0.0100	P: 0.2676
# [9/10][625/2225][Time 5.72]
# Unified LR across all optimizers: 7.726983692137414e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0077	Gen: 0.1998	Rec: 0.2013	E: 0.0125	R: 0.0375	P: 0.3737
# [9/10][675/2225][Time 5.68]
# Unified LR across all optimizers: 7.709212122801322e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0060	Gen: 0.1926	Rec: 0.1929	E: 0.0067	R: 0.0112	P: 0.2340
# [9/10][725/2225][Time 5.81]
# Unified LR across all optimizers: 7.691481426940477e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0092	Gen: 0.1908	Rec: 0.1930	E: 0.0050	R: 0.0623	P: 0.2473
# [9/10][775/2225][Time 5.72]
# Unified LR across all optimizers: 7.673791510548494e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0053	Gen: 0.1924	Rec: 0.1918	E: 0.0132	R: 0.0108	P: 0.2401
# [9/10][825/2225][Time 5.84]
# Unified LR across all optimizers: 7.656142279835203e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0032	Gen: 0.1968	Rec: 0.1966	E: 0.0055	R: 0.0037	P: 0.2955
# [9/10][875/2225][Time 5.63]
# Unified LR across all optimizers: 7.638533641226132e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0076	Gen: 0.1883	Rec: 0.1892	E: 0.0083	R: 0.0241	P: 0.2707
# [9/10][925/2225][Time 5.68]
# Unified LR across all optimizers: 7.620965501362034e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0034	Gen: 0.1852	Rec: 0.1863	E: 0.0008	R: 0.0105	P: 0.2105
# [9/10][975/2225][Time 5.80]
# Unified LR across all optimizers: 7.603437767098374e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0082	Gen: 0.1840	Rec: 0.1845	E: 0.0087	R: 0.0144	P: 0.2635
# [9/10][1025/2225][Time 5.58]
# Unified LR across all optimizers: 7.58595034550486e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0049	Gen: 0.1914	Rec: 0.1920	E: 0.0015	R: 0.0063	P: 0.2434
# [9/10][1075/2225][Time 5.90]
# Unified LR across all optimizers: 7.568503143864919e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0095	Gen: 0.1910	Rec: 0.1924	E: 0.0116	R: 0.0513	P: 0.2311
# [9/10][1125/2225][Time 5.81]
# Unified LR across all optimizers: 7.551096069675221e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0098	Gen: 0.1938	Rec: 0.1944	E: 0.0115	R: 0.0212	P: 0.2428
# [9/10][1175/2225][Time 5.84]
# Unified LR across all optimizers: 7.533729030645195e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0119	Gen: 0.1935	Rec: 0.1961	E: 0.0222	R: 0.0735	P: 0.2838
# [9/10][1225/2225][Time 5.61]
# Unified LR across all optimizers: 7.516401934696534e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0027	Gen: 0.1996	Rec: 0.1996	E: 0.0037	R: 0.0057	P: 0.3187
# [9/10][1275/2225][Time 5.60]
# Unified LR across all optimizers: 7.499114689962693e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0072	Gen: 0.2163	Rec: 0.2157	E: 0.0132	R: 0.0085	P: 1.1089
# [9/10][1325/2225][Time 5.71]
# Unified LR across all optimizers: 7.481867204788422e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0059	Gen: 0.1961	Rec: 0.1970	E: 0.0048	R: 0.0155	P: 0.2534
# [9/10][1375/2225][Time 5.97]
# Unified LR across all optimizers: 7.464659387729275e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0066	Gen: 0.1993	Rec: 0.1989	E: 0.0187	R: 0.0073	P: 0.3147
# [9/10][1425/2225][Time 5.73]
# Unified LR across all optimizers: 7.447491147551118e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0049	Gen: 0.1924	Rec: 0.1920	E: 0.0090	R: 0.0055	P: 0.2862
# [9/10][1475/2225][Time 5.75]
# Unified LR across all optimizers: 7.43036239322965e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0107	Gen: 0.2011	Rec: 0.2043	E: 0.0030	R: 0.0389	P: 0.4312
# [9/10][1525/2225][Time 5.82]
# Unified LR across all optimizers: 7.413273033949917e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0014	Gen: 0.1863	Rec: 0.1865	E: 0.0011	R: 0.0036	P: 0.3537
# [9/10][1575/2225][Time 5.77]
# Unified LR across all optimizers: 7.396222979105844e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0066	Gen: 0.1858	Rec: 0.1865	E: 0.0081	R: 0.0373	P: 0.1880
# [9/10][1625/2225][Time 5.91]
# Unified LR across all optimizers: 7.379212138299732e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0030	Gen: 0.1924	Rec: 0.1920	E: 0.0056	R: 0.0016	P: 0.2665
# [9/10][1675/2225][Time 5.88]
# Unified LR across all optimizers: 7.362240421341801e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0094	Gen: 0.1933	Rec: 0.1939	E: 0.0091	R: 0.0150	P: 0.2702
# [9/10][1725/2225][Time 5.82]
# Unified LR across all optimizers: 7.345307738249697e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0086	Gen: 0.1970	Rec: 0.1979	E: 0.0106	R: 0.0342	P: 0.3981
# [9/10][1775/2225][Time 5.84]
# Unified LR across all optimizers: 7.328413999248016e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0076	Gen: 0.1869	Rec: 0.1876	E: 0.0037	R: 0.0090	P: 0.2266
# [9/10][1825/2225][Time 5.75]
# Unified LR across all optimizers: 7.311559114767833e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0094	Gen: 0.1926	Rec: 0.1911	E: 0.0191	R: 0.0060	P: 0.2261
# [9/10][1875/2225][Time 5.75]
# Unified LR across all optimizers: 7.294742995446234e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0041	Gen: 0.1982	Rec: 0.1984	E: 0.0047	R: 0.0049	P: 0.3304
# [9/10][1925/2225][Time 5.90]
# Unified LR across all optimizers: 7.277965552125832e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0078	Gen: 0.1978	Rec: 0.1984	E: 0.0076	R: 0.0127	P: 0.2544
# [9/10][1975/2225][Time 5.84]
# Unified LR across all optimizers: 7.261226695854285e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0081	Gen: 0.1935	Rec: 0.1939	E: 0.0111	R: 0.0193	P: 0.2166
# [9/10][2025/2225][Time 5.74]
# Unified LR across all optimizers: 7.244526337883848e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0091	Gen: 0.2009	Rec: 0.2009	E: 0.0136	R: 0.0112	P: 0.2943
# [9/10][2075/2225][Time 5.70]
# Unified LR across all optimizers: 7.227864389670875e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0059	Gen: 0.1936	Rec: 0.1930	E: 0.0079	R: 0.0031	P: 0.2884
# [9/10][2125/2225][Time 5.66]
# Unified LR across all optimizers: 7.21124076287539e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0019	Gen: 0.1899	Rec: 0.1902	E: 0.0005	R: 0.0024	P: 0.2579
# [9/10][2175/2225][Time 6.04]
# Unified LR across all optimizers: 7.194655369360571e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0041	Gen: 0.1879	Rec: 0.1883	E: 0.0037	R: 0.0056	P: 0.2731

# %%
# DataLoader for processing training data in larger batches without shuffling
test_loader = torch.utils.data.DataLoader(dataset=testset, batch_size=256, shuffle=False, drop_last=False)

# CCNet setup for generating synthetic manipulated data
ccnet = causal_learning.ccnet
manipulated_data = None
random_labels = None
original_labels = None
probability_positive = 0.0017 # 0.17% of the data is positive

# Generate synthetic data to enhance the diversity of the training dataset
for data, labels in test_loader:
    data = data.to(device)
    labels = labels.to(device)
    
    # Create random labels with 0.17% positive (1) and 99.83% negative (0) labels
    random_label = (torch.rand(labels.size(0)).to(device) < probability_positive).float().unsqueeze(-1)

    # Use CCNet to explain the original data and generate synthetic counterparts
    explanations = ccnet.explain(data)
    synthetic_data = ccnet.produce(random_label, explanations)
    
    # Detach synthetic data and labels from GPU for further processing
    synthetic_data = synthetic_data.detach().cpu()
    random_label = random_label.detach().cpu()
    labels = labels.detach().cpu()

    # Accumulate the generated data for analysis and training
    if manipulated_data is None:
        manipulated_data = synthetic_data
        random_labels = random_label
        original_labels = labels
    else:
        manipulated_data = torch.cat([manipulated_data, synthetic_data], dim=0)
        random_labels = torch.cat([random_labels, random_label], dim=0)
        original_labels = torch.cat([original_labels, labels], dim=0)

# Output the shapes of the datasets for verification
print(f"Manipulated Data Shape: {manipulated_data.shape}")
print(f"Reversed Labels Shape: {random_labels.shape}")
print(f"Original Labels Shape: {original_labels.shape}")

# Create datasets for both synthetic and original label scenarios
random_label_testset = LabeledDataset(manipulated_data.numpy(), random_labels.numpy())
original_label_testset = LabeledDataset(manipulated_data.numpy(), original_labels.numpy())
# Out:
# Manipulated Data Shape: torch.Size([142404, 30])
# Reversed Labels Shape: torch.Size([142404, 1])
# Original Labels Shape: torch.Size([142404, 1])

# %% [markdown]
# #### Training Supervised Models
#
# This section outlines the process of training supervised learning models using both original and synthetic datasets. The `train_supervised_model` function is designed to iterate through the dataset, perform forward passes, compute loss, and update model weights using backpropagation.

# %%
def train_supervised_model(model, dataset, num_epoch=5):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu") 
    # Initialize the optimizer
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    # Ensure reproducibility by resetting the random seed
    # Create DataLoader for batch processing
    trainloader = torch.utils.data.DataLoader(dataset, batch_size=64, shuffle=True)
    # Training loop
    for epoch in range(num_epoch):  # Train for 2 epochs as an example
        for i, (data, label) in enumerate(trainloader):
            data = data.to(device).clone().detach()
            label = label.to(device).float()
            # Perform forward pass
            output = model(data)
            # Compute loss
            loss = torch.nn.functional.binary_cross_entropy(output, label)
            # Backward pass to compute gradients
            loss.backward()
            # Update weights
            optimizer.step()
            # Reset gradients
            optimizer.zero_grad()

# %%
class MLP(torch.nn.Module):
    def __init__(self, input_size, output_size, num_layers=4, hidden_size=256):
        super(MLP, self).__init__()
        self.input_size = input_size
        self.output_size = output_size
        self.hidden_size = hidden_size
        
        # Create a list to hold all layers
        layers = []
        
        # Input layer
        layers.append(torch.nn.Linear(input_size, hidden_size))
        layers.append(torch.nn.ReLU())
        
        # Hidden layers
        for _ in range(num_layers - 2):
            layers.append(torch.nn.Linear(hidden_size, hidden_size))
            layers.append(torch.nn.ReLU())
        
        # Output layer
        layers.append(torch.nn.Linear(hidden_size, output_size))
        
        # Register all layers
        self.layers = torch.nn.Sequential(*layers)

    def forward(self, x):
        x = self.layers(x)
        return torch.sigmoid(x)
    
# Initialize and train a model on the recreated dataset
decision_making_model = MLP(input_size=n_features, output_size=n_classes).to(device)
train_supervised_model(decision_making_model, trainset)

# %% [markdown]
# #### Evaluating Model Performance

# %%
from sklearn.metrics import f1_score

def get_f1_score(model, input_testset, device, batch_size=64):
    model.eval()  # Set the model to evaluation mode
    y_true = []
    y_pred = []
    # DataLoader for testing
    test_loader = torch.utils.data.DataLoader(input_testset, batch_size=batch_size, shuffle=False)

    # No gradient computation needed during inference
    with torch.no_grad():
        for data, label in test_loader:
            data = data.to(device)
            label = label.to(device)
            output = model(data)
            # Process output for binary classification
            predicted = (output.squeeze() > 0.5).long()
            y_true.extend(label.cpu().numpy())
            y_pred.extend(predicted.cpu().numpy())

    # Compute and return the F1 score
    score = f1_score(y_true, y_pred, average='binary')
    return score

# Calculate F1 scores for both models
fraud_detection_f1_score = get_f1_score(decision_making_model, testset, device)
random_testset_f1_score = get_f1_score(decision_making_model, random_label_testset, device)
manipulated_testset_f1_score = get_f1_score(decision_making_model, original_label_testset, device)

# Output the results
print("F1 score of the supervised learning model tested on the original data: ", fraud_detection_f1_score)
print("F1 score of the supervised learning model tested on the manipulated data with random label: ", random_testset_f1_score)
print("F1 score of the supervised learning model tested on the manipulated data with original label: ", manipulated_testset_f1_score)
# Out:
# F1 score of the supervised learning model tested on the original data:  0.826271186440678
# F1 score of the supervised learning model tested on the manipulated data with random label:  0.937381404174573
# F1 score of the supervised learning model tested on the manipulated data with original label:  0.09885931558935361
