# %% [markdown]
# Author:
#
#         PARK, JunHo, junho@ccnets.org
#
#
#         KIM, JeongYoong, jeongyoong@ccnets.org
#
#     COPYRIGHT (c) 2024. CCNets. All Rights reserved.

# %% [markdown]
# # Credit Card Fraud Detection: Handling Imbalanced Dataset with CCNet
#
# ## Introduction
#
# This tutorial explores the use of a Cooperative Network (CCNet) to address challenges associated with imbalanced datasets in the domain of credit card fraud detection. By leveraging the power of data generation, we aim to enhance the diversity and volume of training data, thereby improving the robustness and accuracy of models designed to identify fraudulent transactions.
#
# ## Tutorial Goals
#
# The objectives of this tutorial are designed to guide you through the process of enhancing data quality and model performance:
#
# ### Dataset Recreation with CCNet
# - **Understand Data Augmentation**: Learn how encoding techniques can be used to generate synthetic data instances that closely mimic the characteristics of real-world fraudulent and non-fraudulent transactions.
# - **Impact on Model Training**: Assess how augmenting the dataset influences the training process and subsequently, the model's ability to generalize from training to real-world scenarios.
#
# ### Model Training and Evaluation
# - **Dual Model Training**: Train two distinct models to directly compare performance metrics:
#   - A model trained on the **original dataset**.
#   - A model trained on the **CCNet-augmented dataset**.
# - **Performance Metrics**: Use the F1 score, a critical measure for models operating on imbalanced datasets, to evaluate and compare the effectiveness of these models.
#
# ### Testing and Validation
# - **Independent Model Testing**: Conduct a thorough evaluation of both models using a standalone test set that was not involved in the training phase.
# - **Objective Analysis**: Critically analyze the outcomes to validate whether data augmentation through CCNet offers a tangible benefit in detecting credit card fraud.
#
# ## Conclusion
#
# By the end of this tutorial, participants will not only grasp the theoretical underpinnings of using synthetic data to combat data imbalance but also gain hands-on experience in applying these concepts through CCNet to potentially enhance model performance in fraud detection tasks.

# %%
import sys
path_append = "../"
sys.path.append(path_append)  # Go up one directory from where you are.

# %%
# https://fraud-detection-handbook.github.io/fraud-detection-handbook/Chapter_7_DeepLearning/FeedForwardNeuralNetworks.html
import pandas as pd 

dataroot = path_append + "../data/credit_card_fraud_detection/creditcard.csv"
df = pd.read_csv(dataroot)
df
# Out:
# c:\Users\CCNets-team\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# c:\Users\CCNets-team\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
print('No Frauds', round(df['Class'].value_counts()[0] / len(df) *100,2), '%of the dataset')
print('Frauds', round(df['Class'].value_counts()[1] / len(df) *100,2), '%of the dataset')
# Out:
# No Frauds 99.83 %of the dataset
# Frauds 0.17 %of the dataset

# %%
import torch
from sklearn.preprocessing import StandardScaler
from torch.utils.data import Dataset

# Standardizing the features (excluding the class column)
# Standardizing the features (excluding the class column)
sc = StandardScaler()
df.iloc[:, :-1] = sc.fit_transform(df.iloc[:, :-1])

n_features = len(df.iloc[:, :-1].columns)
n_classes = len(df.iloc[:, -1:].columns)

print(n_features, n_classes)
# Out:
# 30 1

# %%
# Defining the labeled and unlabeled dataset classes
class LabeledDataset(Dataset):
    def __init__(self, x, y):
        self.x = x
        self.y = y
        
    def __len__(self):
        return len(self.x)

    def __getitem__(self, index):
        vals = torch.tensor(self.x[index], dtype=torch.float32)
        label = torch.tensor(self.y[index], dtype=torch.float32)
        return vals, label

# %% [markdown]
# #### Initial Setup and Model Configuration
#
# This section initializes the environment by setting a fixed random seed to ensure reproducibility of results. It imports necessary configurations and initializes model parameters with specific configurations. The model specified here is set to have no core model but uses a 'deepfm' encoder model for data processing, which is particularly tailored for structured or tabular data like credit card transactions.

# %%
from sklearn.model_selection import train_test_split

# Splitting the dataset into training and test sets for model evaluation
df_train, df_test = train_test_split(df, test_size=0.5, shuffle=False)
X_train, y_train = df_train.iloc[:, :-1].values, df_train.iloc[:, -1:].values
X_test, y_test = df_test.iloc[:, :-1].values, df_test.iloc[:, -1:].values

# Labeled datasets for supervised learning tasks
trainset = LabeledDataset(X_train, y_train)  # Corrected to include training data
testset = LabeledDataset(X_test, y_test)     # Test set with proper labels

# Printing the shapes of the datasets for verification
print(f"Labeled Trainset Shape: {len(trainset)}, {trainset.x.shape[1]}")
print(f"Labeled Testset Shape: {len(testset)}, {testset.x.shape[1]}")
# Out:
# Labeled Trainset Shape: 142403, 30
# Labeled Testset Shape: 142404, 30

# %%
# Set a fixed random seed for reproducibility of experiments
from nn.utils.init import set_random_seed
set_random_seed(0)

# Importing configuration setups for ML parameters and data
import torch
from tools.setting.ml_params import MLParameters
from tools.setting.data_config import DataConfig
from trainer_hub import TrainerHub

# Configuration for the data handling, defining dataset specifics and the task type
data_config = DataConfig(dataset_name='CreditCardFraudDetection', task_type='binary_classification', obs_shape=[n_features], label_size=n_classes)

# Initializing ML parameters without a core model and setting the encoder model to 'deepfm' with specific configurations
ml_params = MLParameters(core_model='mlp', encoder_model='none')

# Setting training parameters and device configuration
ml_params.training.num_epoch = 20
ml_params.model.core_config.num_layers = 5
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") 

# Create a TrainerHub instance to manage training and data processing
trainer_hub = TrainerHub(ml_params, data_config, device, use_print=True, use_wandb=False)
# Out:
# c:\Users\CCNets-team\anaconda3\lib\site-packages\transformers\utils\generic.py:311: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(

# %% [markdown]
# #### Dataset Splitting for Training and Testing
#
# The original dataset is split into training and testing parts to evaluate the model's performance accurately. This step is crucial for validating the effectiveness of the training on unseen data.

# %%
trainer_hub.train(trainset)
# Out:
# Epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# Iterations:   0%|          | 0/2225 [00:00<?, ?it/s]
# [0/10][50/2225][Time 1.13]
# Unified LR across all optimizers: 0.0001995308238189185
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0930	Gen: 0.6021	Rec: 0.6170	E: 0.0781	R: 0.1079	P: 1.1260
# [0/10][100/2225][Time 0.73]
# Unified LR across all optimizers: 0.00019907191565870155
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0003	Gen: 0.5154	Rec: 0.5154	E: 0.0004	R: 0.0003	P: 1.0305
# [0/10][150/2225][Time 0.71]
# Unified LR across all optimizers: 0.00019861406295796434
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0004	Gen: 0.4823	Rec: 0.4823	E: 0.0004	R: 0.0003	P: 0.9642
# [0/10][200/2225][Time 0.71]
# Unified LR across all optimizers: 0.00019815726328921765
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0005	Gen: 0.4419	Rec: 0.4417	E: 0.0007	R: 0.0003	P: 0.8831
# [0/10][250/2225][Time 0.70]
# Unified LR across all optimizers: 0.00019770151423055492
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0005	Gen: 0.4099	Rec: 0.4097	E: 0.0006	R: 0.0003	P: 0.8192
# [0/10][300/2225][Time 0.70]
# Unified LR across all optimizers: 0.00019724681336564005
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0007	Gen: 0.2462	Rec: 0.2465	E: 0.0004	R: 0.0011	P: 0.4920
# [0/10][2050/2225][Time 0.74]
# Unified LR across all optimizers: 0.00018197427410846564
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0024	Gen: 0.2517	Rec: 0.2524	E: 0.0017	R: 0.0031	P: 0.5017
# [0/10][2100/2225][Time 0.70]
# Unified LR across all optimizers: 0.00018155574489207887
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0030	Gen: 0.2475	Rec: 0.2481	E: 0.0024	R: 0.0035	P: 0.4926
# [0/10][2150/2225][Time 0.73]
# Unified LR across all optimizers: 0.00018113817826617823
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0012	Gen: 0.2465	Rec: 0.2469	E: 0.0008	R: 0.0017	P: 0.4922
# [0/10][2200/2225][Time 0.70]
# Unified LR across all optimizers: 0.00018072157201686696
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0026	Gen: 0.2401	Rec: 0.2413	E: 0.0013	R: 0.0038	P: 0.4789
# Iterations:   0%|          | 0/2225 [00:00<?, ?it/s]
# [1/10][25/2225][Time 0.75]
# Unified LR across all optimizers: 0.00018030592393534033
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0012	Gen: 0.2427	Rec: 0.2429	E: 0.0009	R: 0.0014	P: 0.4844
# [1/10][75/2225][Time 0.72]
# Unified LR across all optimizers: 0.0001798912318178735
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0027	Gen: 0.2406	Rec: 0.2419	E: 0.0014	R: 0.0039	P: 0.4798
# [1/10][125/2225][Time 0.70]
# Unified LR across all optimizers: 0.00017947749346581006
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0023	Gen: 0.2372	Rec: 0.2385	E: 0.0010	R: 0.0036	P: 0.4735
# [1/10][175/2225][Time 0.71]
# Unified LR across all optimizers: 0.0001790647066855505
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0030	Gen: 0.2420	Rec: 0.2433	E: 0.0017	R: 0.0044	P: 0.4822
# [1/10][225/2225][Time 0.71]
# Unified LR across all optimizers: 0.00017865286928854052
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0032	Gen: 0.2422	Rec: 0.2439	E: 0.0015	R: 0.0050	P: 0.4828
# [1/10][275/2225][Time 0.80]
# Unified LR across all optimizers: 0.00017824197909125899
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0024	Gen: 0.2324	Rec: 0.2333	E: 0.0015	R: 0.0033	P: 0.4632
# [1/10][325/2225][Time 0.77]
# Unified LR across all optimizers: 0.00017783203391520723
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0024	Gen: 0.2290	Rec: 0.2301	E: 0.0012	R: 0.0035	P: 0.4567
# [1/10][375/2225][Time 0.78]
# Unified LR across all optimizers: 0.00017742303158689668
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0025	Gen: 0.2329	Rec: 0.2337	E: 0.0017	R: 0.0033	P: 0.4641
# [1/10][425/2225][Time 0.76]
# Unified LR across all optimizers: 0.00017701496993783762
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0032	Gen: 0.2273	Rec: 0.2287	E: 0.0018	R: 0.0045	P: 0.4528
# [1/10][475/2225][Time 0.75]
# Unified LR across all optimizers: 0.00017660784680452796
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0000	Gen: 0.2292	Rec: 0.2292	E: 0.0000	R: 0.0000	P: 0.4584
# [1/10][525/2225][Time 0.79]
# Unified LR across all optimizers: 0.0001762016600284412
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0030	Gen: 0.2371	Rec: 0.2387	E: 0.0014	R: 0.0046	P: 0.4728
# [1/10][575/2225][Time 0.81]
# Unified LR across all optimizers: 0.00017579640745601563
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0018	Gen: 0.2307	Rec: 0.2316	E: 0.0009	R: 0.0028	P: 0.4604
# [1/10][625/2225][Time 0.83]
# Unified LR across all optimizers: 0.0001753920869386423
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0048	Gen: 0.2142	Rec: 0.2172	E: 0.0018	R: 0.0079	P: 0.4266
# [1/10][1525/2225][Time 0.70]
# Unified LR across all optimizers: 0.00016827127897182985
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0029	Gen: 0.2134	Rec: 0.2146	E: 0.0017	R: 0.0042	P: 0.4250
# [1/10][1575/2225][Time 0.69]
# Unified LR across all optimizers: 0.0001678842657696972
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0054	Gen: 0.2162	Rec: 0.2184	E: 0.0032	R: 0.0076	P: 0.4292
# [1/10][1625/2225][Time 0.68]
# Unified LR across all optimizers: 0.00016749814267322938
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0044	Gen: 0.2173	Rec: 0.2194	E: 0.0023	R: 0.0065	P: 0.4323
# [1/10][1675/2225][Time 0.70]
# Unified LR across all optimizers: 0.00016711290763524007
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0046	Gen: 0.2094	Rec: 0.2118	E: 0.0022	R: 0.0069	P: 0.4166
# [1/10][1725/2225][Time 0.71]
# Unified LR across all optimizers: 0.00016672855861325146
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0030	Gen: 0.2129	Rec: 0.2141	E: 0.0018	R: 0.0041	P: 0.4241
# [1/10][1775/2225][Time 0.73]
# Unified LR across all optimizers: 0.00016634509356948314
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0019	Gen: 0.2019	Rec: 0.2026	E: 0.0012	R: 0.0026	P: 0.4027
# [1/10][1825/2225][Time 0.80]
# Unified LR across all optimizers: 0.00016596251047084197
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0031	Gen: 0.2098	Rec: 0.2106	E: 0.0024	R: 0.0039	P: 0.4173
# [1/10][1875/2225][Time 0.73]
# Unified LR across all optimizers: 0.00016558080728890993
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0023	Gen: 0.2103	Rec: 0.2114	E: 0.0012	R: 0.0034	P: 0.4194
# [1/10][1925/2225][Time 0.81]
# Unified LR across all optimizers: 0.00016519998199993532
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0023	Gen: 0.2064	Rec: 0.2079	E: 0.0008	R: 0.0038	P: 0.4120
# [1/10][1975/2225][Time 0.79]
# Unified LR across all optimizers: 0.0001648200325848201
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0037	Gen: 0.2089	Rec: 0.2112	E: 0.0014	R: 0.0060	P: 0.4164
# [1/10][2025/2225][Time 0.81]
# Unified LR across all optimizers: 0.00016444095702911038
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0032	Gen: 0.2050	Rec: 0.2064	E: 0.0018	R: 0.0047	P: 0.4082
# [1/10][2075/2225][Time 0.74]
# Unified LR across all optimizers: 0.00016406275332298505
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0051	Gen: 0.2064	Rec: 0.2084	E: 0.0031	R: 0.0070	P: 0.4098
# [1/10][2125/2225][Time 0.78]
# Unified LR across all optimizers: 0.00016368541946124596
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0031	Gen: 0.2042	Rec: 0.2058	E: 0.0015	R: 0.0048	P: 0.4069
# [1/10][2175/2225][Time 0.78]
# Unified LR across all optimizers: 0.00016330895344330638
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0033	Gen: 0.2093	Rec: 0.2111	E: 0.0014	R: 0.0052	P: 0.4171
# Iterations:   0%|          | 0/2225 [00:00<?, ?it/s]
# [2/10][0/2225][Time 0.81]
# Unified LR across all optimizers: 0.00016293335327318117
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0058	Gen: 0.2098	Rec: 0.2132	E: 0.0023	R: 0.0092	P: 0.4173
# [2/10][50/2225][Time 0.79]
# Unified LR across all optimizers: 0.00016255861695947546
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0023	Gen: 0.1736	Rec: 0.1736	E: 0.0024	R: 0.0023	P: 0.3449
# [3/10][2125/2225][Time 0.78]
# Unified LR across all optimizers: 0.00013335521246682152
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0016	Gen: 0.1747	Rec: 0.1747	E: 0.0015	R: 0.0016	P: 0.3479
# [3/10][2175/2225][Time 0.80]
# Unified LR across all optimizers: 0.00013304850398921782
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0005	Gen: 0.1757	Rec: 0.1760	E: 0.0003	R: 0.0008	P: 0.3511
# Iterations:   0%|          | 0/2225 [00:00<?, ?it/s]
# [4/10][0/2225][Time 0.76]
# Unified LR across all optimizers: 0.00013274250092153782
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0015	Gen: 0.1817	Rec: 0.1818	E: 0.0015	R: 0.0015	P: 0.3620
# [4/10][50/2225][Time 0.81]
# Unified LR across all optimizers: 0.00013243720164138364
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0018	Gen: 0.1814	Rec: 0.1815	E: 0.0018	R: 0.0019	P: 0.3611
# [4/10][100/2225][Time 0.78]
# Unified LR across all optimizers: 0.00013213260453008872
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0025	Gen: 0.1782	Rec: 0.1786	E: 0.0021	R: 0.0028	P: 0.3544
# [4/10][150/2225][Time 0.80]
# Unified LR across all optimizers: 0.00013182870797270977
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0023	Gen: 0.1746	Rec: 0.1744	E: 0.0024	R: 0.0021	P: 0.3468
# [4/10][200/2225][Time 0.82]
# Unified LR across all optimizers: 0.0001315255103580172
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0024	Gen: 0.1792	Rec: 0.1793	E: 0.0023	R: 0.0025	P: 0.3561
# [4/10][250/2225][Time 0.87]
# Unified LR across all optimizers: 0.00013122301007848758
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0016	Gen: 0.1756	Rec: 0.1760	E: 0.0013	R: 0.0019	P: 0.3500
# [4/10][300/2225][Time 0.82]
# Unified LR across all optimizers: 0.00013092120553029462
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0032	Gen: 0.1810	Rec: 0.1808	E: 0.0034	R: 0.0030	P: 0.3587
# [4/10][350/2225][Time 0.80]
# Unified LR across all optimizers: 0.00013062009511330047
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0004	Gen: 0.1751	Rec: 0.1752	E: 0.0004	R: 0.0005	P: 0.3498
# [4/10][400/2225][Time 0.80]
# Unified LR across all optimizers: 0.0001303196772310477
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0017	Gen: 0.1725	Rec: 0.1726	E: 0.0016	R: 0.0017	P: 0.3435
# [4/10][450/2225][Time 0.77]
# Unified LR across all optimizers: 0.00013001995029075084
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0015	Gen: 0.1702	Rec: 0.1707	E: 0.0011	R: 0.0020	P: 0.3394
# [4/10][500/2225][Time 0.77]
# Unified LR across all optimizers: 0.00012972091270328727
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0009	Gen: 0.1752	Rec: 0.1752	E: 0.0009	R: 0.0010	P: 0.3494
# [4/10][550/2225][Time 0.77]
# Unified LR across all optimizers: 0.00012942256288318946
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0022	Gen: 0.1765	Rec: 0.1764	E: 0.0023	R: 0.0022	P: 0.3507
# [4/10][600/2225][Time 0.76]
# Unified LR across all optimizers: 0.00012912489924863657
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0011	Gen: 0.1753	Rec: 0.1751	E: 0.0014	R: 0.0009	P: 0.3492
# [4/10][650/2225][Time 0.77]
# Unified LR across all optimizers: 0.00012882792022144538
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0022	Gen: 0.1766	Rec: 0.1762	E: 0.0025	R: 0.0018	P: 0.3506
# [4/10][700/2225][Time 0.75]
# Unified LR across all optimizers: 0.0001285316242270628
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0021	Gen: 0.1725	Rec: 0.1725	E: 0.0020	R: 0.0021	P: 0.3429
# [4/10][750/2225][Time 0.79]
# Unified LR across all optimizers: 0.00012823600969455687
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0019	Gen: 0.1695	Rec: 0.1697	E: 0.0016	R: 0.0022	P: 0.3373
# [4/10][800/2225][Time 0.82]
# Unified LR across all optimizers: 0.00012794107505660892
# --------------------Training Metrics--------------------
# ...
# Unified LR across all optimizers: 8.337003727355101e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0004	Gen: 0.1602	Rec: 0.1600	E: 0.0006	R: 0.0002	P: 0.3198
# [8/10][1250/2225][Time 0.72]
# Unified LR across all optimizers: 8.317829150871044e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0005	Gen: 0.1571	Rec: 0.1570	E: 0.0006	R: 0.0004	P: 0.3137
# [8/10][1300/2225][Time 0.73]
# Unified LR across all optimizers: 8.298698674689132e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0007	Gen: 0.1544	Rec: 0.1543	E: 0.0007	R: 0.0007	P: 0.3080
# [8/10][1350/2225][Time 0.73]
# Unified LR across all optimizers: 8.279612197381481e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0013	Gen: 0.1596	Rec: 0.1594	E: 0.0015	R: 0.0010	P: 0.3177
# [8/10][1400/2225][Time 0.72]
# Unified LR across all optimizers: 8.260569617753492e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0007	Gen: 0.1535	Rec: 0.1533	E: 0.0009	R: 0.0005	P: 0.3061
# [8/10][1450/2225][Time 0.73]
# Unified LR across all optimizers: 8.241570834843299e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0019	Gen: 0.1580	Rec: 0.1575	E: 0.0025	R: 0.0014	P: 0.3136
# [8/10][1500/2225][Time 0.76]
# Unified LR across all optimizers: 8.222615747921251e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0009	Gen: 0.1608	Rec: 0.1607	E: 0.0010	R: 0.0007	P: 0.3206
# [8/10][1550/2225][Time 0.76]
# Unified LR across all optimizers: 8.203704256489364e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0015	Gen: 0.1596	Rec: 0.1595	E: 0.0016	R: 0.0015	P: 0.3176
# [8/10][1600/2225][Time 0.78]
# Unified LR across all optimizers: 8.184836260280792e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0020	Gen: 0.1546	Rec: 0.1538	E: 0.0027	R: 0.0012	P: 0.3064
# [8/10][1650/2225][Time 0.78]
# Unified LR across all optimizers: 8.166011659259291e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0021	Gen: 0.1518	Rec: 0.1519	E: 0.0020	R: 0.0022	P: 0.3016
# [8/10][1700/2225][Time 0.77]
# Unified LR across all optimizers: 8.147230353618705e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0008	Gen: 0.1544	Rec: 0.1544	E: 0.0008	R: 0.0008	P: 0.3080
# [8/10][1750/2225][Time 0.81]
# Unified LR across all optimizers: 8.128492243782422e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0005	Gen: 0.1569	Rec: 0.1570	E: 0.0004	R: 0.0006	P: 0.3134
# [8/10][1800/2225][Time 0.80]
# Unified LR across all optimizers: 8.109797230402852e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0011	Gen: 0.1537	Rec: 0.1535	E: 0.0013	R: 0.0009	P: 0.3062
# [8/10][1850/2225][Time 0.80]
# Unified LR across all optimizers: 8.09114521436089e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0008	Gen: 0.1557	Rec: 0.1556	E: 0.0009	R: 0.0007	P: 0.3105
# [8/10][1900/2225][Time 0.79]
# Unified LR across all optimizers: 8.072536096765404e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0020	Gen: 0.1568	Rec: 0.1571	E: 0.0017	R: 0.0022	P: 0.3119
# [8/10][1950/2225][Time 0.82]
# Unified LR across all optimizers: 8.053969778952707e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0002	Gen: 0.1589	Rec: 0.1588	E: 0.0003	R: 0.0001	P: 0.3175
# [8/10][2000/2225][Time 0.82]
# Unified LR across all optimizers: 8.035446162486028e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0018	Gen: 0.1537	Rec: 0.1540	E: 0.0016	R: 0.0021	P: 0.3058
# [8/10][2050/2225][Time 0.84]
# Unified LR across all optimizers: 8.016965149154994e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0004	Gen: 0.1585	Rec: 0.1585	E: 0.0004	R: 0.0004	P: 0.3165
# [8/10][2100/2225][Time 0.79]
# Unified LR across all optimizers: 7.998526640975121e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0011	Gen: 0.1552	Rec: 0.1550	E: 0.0013	R: 0.0009	P: 0.3092
# [8/10][2150/2225][Time 0.77]
# Unified LR across all optimizers: 7.980130540187273e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0017	Gen: 0.1568	Rec: 0.1563	E: 0.0022	R: 0.0012	P: 0.3114
# [8/10][2200/2225][Time 0.76]
# Unified LR across all optimizers: 7.961776749257148e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0013	Gen: 0.1616	Rec: 0.1617	E: 0.0012	R: 0.0014	P: 0.3220
# Iterations:   0%|          | 0/2225 [00:00<?, ?it/s]
# [9/10][25/2225][Time 0.80]
# Unified LR across all optimizers: 7.943465170874777e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0022	Gen: 0.1612	Rec: 0.1610	E: 0.0024	R: 0.0020	P: 0.3200
# [9/10][75/2225][Time 0.79]
# Unified LR across all optimizers: 7.925195707953989e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0021	Gen: 0.1551	Rec: 0.1555	E: 0.0017	R: 0.0024	P: 0.3086
# [9/10][125/2225][Time 0.81]
# Unified LR across all optimizers: 7.90696826363192e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0015	Gen: 0.1592	Rec: 0.1594	E: 0.0014	R: 0.0017	P: 0.3171
# [9/10][175/2225][Time 0.72]
# Unified LR across all optimizers: 7.888782741268464e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0016	Gen: 0.1591	Rec: 0.1591	E: 0.0016	R: 0.0017	P: 0.3166
# [9/10][225/2225][Time 0.76]
# Unified LR across all optimizers: 7.870639044445802e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0014	Gen: 0.1518	Rec: 0.1516	E: 0.0016	R: 0.0012	P: 0.3020
# [9/10][275/2225][Time 0.74]
# Unified LR across all optimizers: 7.85253707696785e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0008	Gen: 0.1567	Rec: 0.1567	E: 0.0008	R: 0.0008	P: 0.3126
# [9/10][325/2225][Time 0.72]
# Unified LR across all optimizers: 7.834476742859793e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0014	Gen: 0.1519	Rec: 0.1519	E: 0.0014	R: 0.0013	P: 0.3024
# [9/10][375/2225][Time 0.76]
# Unified LR across all optimizers: 7.816457946367525e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0010	Gen: 0.1496	Rec: 0.1497	E: 0.0009	R: 0.0010	P: 0.2984
# [9/10][425/2225][Time 0.74]
# Unified LR across all optimizers: 7.79848059195718e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0013	Gen: 0.1568	Rec: 0.1568	E: 0.0012	R: 0.0014	P: 0.3123
# [9/10][475/2225][Time 0.75]
# Unified LR across all optimizers: 7.780544584314617e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0021	Gen: 0.1526	Rec: 0.1531	E: 0.0016	R: 0.0026	P: 0.3036
# [9/10][525/2225][Time 0.72]
# Unified LR across all optimizers: 7.762649828344911e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0019	Gen: 0.1548	Rec: 0.1551	E: 0.0016	R: 0.0023	P: 0.3080
# [9/10][575/2225][Time 0.72]
# Unified LR across all optimizers: 7.744796229171844e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0008	Gen: 0.1557	Rec: 0.1555	E: 0.0010	R: 0.0007	P: 0.3104
# [9/10][625/2225][Time 0.78]
# Unified LR across all optimizers: 7.726983692137414e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0023	Gen: 0.1527	Rec: 0.1526	E: 0.0024	R: 0.0022	P: 0.3029
# [9/10][675/2225][Time 0.81]
# Unified LR across all optimizers: 7.709212122801322e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0016	Gen: 0.1586	Rec: 0.1587	E: 0.0014	R: 0.0017	P: 0.3157
# [9/10][725/2225][Time 0.83]
# Unified LR across all optimizers: 7.691481426940477e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0007	Gen: 0.1562	Rec: 0.1561	E: 0.0008	R: 0.0007	P: 0.3115
# [9/10][775/2225][Time 0.81]
# Unified LR across all optimizers: 7.673791510548494e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0008	Gen: 0.1546	Rec: 0.1545	E: 0.0009	R: 0.0007	P: 0.3084
# [9/10][825/2225][Time 0.81]
# Unified LR across all optimizers: 7.656142279835203e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0009	Gen: 0.1559	Rec: 0.1565	E: 0.0003	R: 0.0014	P: 0.3115
# [9/10][875/2225][Time 0.82]
# Unified LR across all optimizers: 7.638533641226132e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0013	Gen: 0.1572	Rec: 0.1574	E: 0.0010	R: 0.0015	P: 0.3133
# [9/10][925/2225][Time 0.82]
# Unified LR across all optimizers: 7.620965501362034e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0015	Gen: 0.1572	Rec: 0.1574	E: 0.0013	R: 0.0017	P: 0.3130
# [9/10][975/2225][Time 0.81]
# Unified LR across all optimizers: 7.603437767098374e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0016	Gen: 0.1514	Rec: 0.1512	E: 0.0018	R: 0.0015	P: 0.3009
# [9/10][1025/2225][Time 0.78]
# Unified LR across all optimizers: 7.58595034550486e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0011	Gen: 0.1553	Rec: 0.1558	E: 0.0006	R: 0.0016	P: 0.3100
# [9/10][1075/2225][Time 0.75]
# Unified LR across all optimizers: 7.568503143864919e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0008	Gen: 0.1554	Rec: 0.1550	E: 0.0012	R: 0.0004	P: 0.3096
# [9/10][1125/2225][Time 0.75]
# Unified LR across all optimizers: 7.551096069675221e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0010	Gen: 0.1552	Rec: 0.1549	E: 0.0013	R: 0.0007	P: 0.3091
# [9/10][1175/2225][Time 0.76]
# Unified LR across all optimizers: 7.533729030645195e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0005	Gen: 0.1583	Rec: 0.1583	E: 0.0005	R: 0.0005	P: 0.3160
# [9/10][1225/2225][Time 0.78]
# Unified LR across all optimizers: 7.516401934696534e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0027	Gen: 0.1527	Rec: 0.1523	E: 0.0030	R: 0.0023	P: 0.3023
# [9/10][1275/2225][Time 0.75]
# Unified LR across all optimizers: 7.499114689962693e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0002	Gen: 0.1481	Rec: 0.1480	E: 0.0002	R: 0.0001	P: 0.2960
# [9/10][1325/2225][Time 0.79]
# Unified LR across all optimizers: 7.481867204788422e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0009	Gen: 0.1531	Rec: 0.1533	E: 0.0007	R: 0.0011	P: 0.3055
# [9/10][1375/2225][Time 0.77]
# Unified LR across all optimizers: 7.464659387729275e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0020	Gen: 0.1543	Rec: 0.1545	E: 0.0017	R: 0.0022	P: 0.3068
# [9/10][1425/2225][Time 0.75]
# Unified LR across all optimizers: 7.447491147551118e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0006	Gen: 0.1539	Rec: 0.1537	E: 0.0008	R: 0.0004	P: 0.3069
# [9/10][1475/2225][Time 0.77]
# Unified LR across all optimizers: 7.43036239322965e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0006	Gen: 0.1495	Rec: 0.1495	E: 0.0006	R: 0.0006	P: 0.2984
# [9/10][1525/2225][Time 0.76]
# Unified LR across all optimizers: 7.413273033949917e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0011	Gen: 0.1544	Rec: 0.1546	E: 0.0009	R: 0.0013	P: 0.3079
# [9/10][1575/2225][Time 0.75]
# Unified LR across all optimizers: 7.396222979105844e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0017	Gen: 0.1539	Rec: 0.1541	E: 0.0016	R: 0.0019	P: 0.3063
# [9/10][1625/2225][Time 0.76]
# Unified LR across all optimizers: 7.379212138299732e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0018	Gen: 0.1522	Rec: 0.1525	E: 0.0014	R: 0.0021	P: 0.3029
# [9/10][1675/2225][Time 0.81]
# Unified LR across all optimizers: 7.362240421341801e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0015	Gen: 0.1556	Rec: 0.1552	E: 0.0018	R: 0.0011	P: 0.3093
# [9/10][1725/2225][Time 0.76]
# Unified LR across all optimizers: 7.345307738249697e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0024	Gen: 0.1509	Rec: 0.1511	E: 0.0022	R: 0.0027	P: 0.2996
# [9/10][1775/2225][Time 0.76]
# Unified LR across all optimizers: 7.328413999248016e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0005	Gen: 0.1516	Rec: 0.1516	E: 0.0005	R: 0.0006	P: 0.3026
# [9/10][1825/2225][Time 0.88]
# Unified LR across all optimizers: 7.311559114767833e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0017	Gen: 0.1517	Rec: 0.1518	E: 0.0016	R: 0.0018	P: 0.3018
# [9/10][1875/2225][Time 0.76]
# Unified LR across all optimizers: 7.294742995446234e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0010	Gen: 0.1522	Rec: 0.1520	E: 0.0011	R: 0.0009	P: 0.3032
# [9/10][1925/2225][Time 0.84]
# Unified LR across all optimizers: 7.277965552125832e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0025	Gen: 0.1587	Rec: 0.1592	E: 0.0020	R: 0.0030	P: 0.3154
# [9/10][1975/2225][Time 0.82]
# Unified LR across all optimizers: 7.261226695854285e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0005	Gen: 0.1504	Rec: 0.1504	E: 0.0005	R: 0.0004	P: 0.3004
# [9/10][2025/2225][Time 0.76]
# Unified LR across all optimizers: 7.244526337883848e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0015	Gen: 0.1520	Rec: 0.1520	E: 0.0015	R: 0.0015	P: 0.3025
# [9/10][2075/2225][Time 0.73]
# Unified LR across all optimizers: 7.227864389670875e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0003	Gen: 0.1463	Rec: 0.1462	E: 0.0004	R: 0.0002	P: 0.2923
# [9/10][2125/2225][Time 0.74]
# Unified LR across all optimizers: 7.21124076287539e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0024	Gen: 0.1567	Rec: 0.1568	E: 0.0023	R: 0.0025	P: 0.3111
# [9/10][2175/2225][Time 0.75]
# Unified LR across all optimizers: 7.194655369360571e-05
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Mlp
# Inf: 0.0012	Gen: 0.1575	Rec: 0.1577	E: 0.0010	R: 0.0014	P: 0.3139

# %% [markdown]
# #### Data Loading and Synthetic Data Generation
#
# This section deals with loading the unlabelled dataset, processing it through the trained model to create synthetic data. This data augmentation step is crucial for models that benefit from larger datasets, such as in fraud detection scenarios.

# %%
import torch
from tools.loader import collate_fn

batch_size = 64
len_trainset = len(trainset)
train_loader = torch.utils.data.DataLoader(dataset=trainset, batch_size=batch_size, collate_fn=collate_fn, shuffle=False)

# Initialize the recreated dataset container
recreated_training_data = None
recreated_labels = None

# Generate synthetic data through the model to augment the training dataset
with torch.no_grad():
    for data, _ in train_loader:
        data = data.to(device)
        # Generate a large amount of synthetic data
        explain = trainer_hub.core_ccnet.explain(data)
        
        generated_data, generated_condition = trainer_hub.core_ccnet.generate(explain)

        generated_data = generated_data.squeeze(1).clone().detach().cpu()
        generated_condition = generated_condition.clone().detach().cpu()

        # Concatenate the processed batch to the main dataset
        if recreated_training_data is None:
            recreated_training_data = generated_data
            recreated_labels = generated_condition
        else:
            recreated_training_data = torch.cat([recreated_training_data, generated_data], dim=0)
            recreated_labels = torch.cat([recreated_labels, generated_condition], dim=0)
        
        # Ensure we do not exceed the original trainset's size
        if len(recreated_training_data) >= len_trainset:
            recreated_training_data = recreated_training_data[:len_trainset]
            recreated_labels = recreated_labels[:len_trainset]
            break

print(f"Recreated Training Data Shape: {recreated_training_data.shape}")
print(f"Recreated Labels Shape: {recreated_labels.shape}")
# Out:
# Recreated Training Data Shape: torch.Size([142403, 30])
# Recreated Labels Shape: torch.Size([142403, 1])

# %% [markdown]
# #### Data Preparation for Model Training
#
# After synthetic data generation, this section separates the data and labels for training purposes, preparing them for use in machine learning models to ensure proper supervision and evaluation.

# %%
import torch

# Assuming recreated_dataset is a PyTorch tensor already available in your context
ccnet_recreated_dataset = LabeledDataset(recreated_training_data.numpy(), recreated_labels.numpy())

# Print the shapes of the datasets for verification
print(f"Labeled Original Trainset Shape: {len(trainset)}, {trainset.x.shape[1]}")
print(f"CCNet Recreated Dataset Shape: {len(ccnet_recreated_dataset)}, {ccnet_recreated_dataset.x.shape[1]}")

print(f"Labeled Original Testset Shape: {len(testset)}, {testset.x.shape[1]}")

# Retrieve number of features and classes from the recreated dataset
num_features = recreated_training_data.shape[1]
num_classes = recreated_labels.shape[1]

print(f"Number of Features: {num_features}")
print(f"Number of Classes: {num_classes}")
# Out:
# Labeled Original Trainset Shape: 142403, 30
# CCNet Recreated Dataset Shape: 142403, 30
# Labeled Original Testset Shape: 142404, 30
# Number of Features: 30
# Number of Classes: 1

# %%
recreated_labels
# Out:
# tensor([[0.0457],
#         [0.2234],
#         [0.6875],
#         ...,
#         [0.4374],
#         [0.4342],
#         [0.0497]])

# %%
recreated_training_data
# Out:
# tensor([[-1.3209, -0.4603,  0.2187,  ...,  0.3059, -0.0591,  0.0574],
#         [-0.8713,  0.4838,  0.1798,  ...,  0.0116,  0.1422, -0.2477],
#         [-0.6675, -0.8377, -0.7578,  ..., -0.1903, -0.1423,  1.7925],
#         ...,
#         [-0.2524, -0.5365,  0.2970,  ..., -0.7961, -0.1875,  0.0241],
#         [-0.2790, -1.7716,  1.9915,  ...,  1.6791,  1.0343, -0.1568],
#         [-0.4900, -0.3742,  0.4597,  ..., -0.6216, -0.6505, -0.0287]])

# %%
class DNN(torch.nn.Module):
    def __init__(self, input_size, output_size, num_layers=4, hidden_size=256):
        super(DNN, self).__init__()
        self.input_size = input_size
        self.output_size = output_size
        self.hidden_size = hidden_size
        
        # Create a list to hold all layers
        layers = []
        
        # Input layer
        layers.append(torch.nn.Linear(input_size, hidden_size))
        layers.append(torch.nn.ReLU())
        
        # Hidden layers
        for _ in range(num_layers - 2):
            layers.append(torch.nn.Linear(hidden_size, hidden_size))
            layers.append(torch.nn.ReLU())
        
        # Output layer
        layers.append(torch.nn.Linear(hidden_size, output_size))
        
        # Register all layers
        self.layers = torch.nn.Sequential(*layers)

    def forward(self, x):
        x = self.layers(x)
        return torch.sigmoid(x)

# %% [markdown]
# #### Training Supervised Models
#
# This section outlines the process of training supervised learning models using both original and synthetic datasets. The `train_supervised_model` function is designed to iterate through the dataset, perform forward passes, compute loss, and update model weights using backpropagation.

# %%
def train_supervised_model(model, dataset):
    # Initialize the optimizer
    optimizer = torch.optim.Adam(model.parameters(), lr=0.0002)
    # Ensure reproducibility by resetting the random seed
    set_random_seed(0)
    # Create DataLoader for batch processing
    trainloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)
    
    # Training loop
    for epoch in range(4):  # Train for 2 epochs as an example
        for i, (data, label) in enumerate(trainloader):
            data = data.to(device).clone().detach()
            label = label.to(device)
            # Perform forward pass
            output = model(data)
            # Compute loss
            loss = torch.nn.functional.binary_cross_entropy(output, label)
            # Backward pass to compute gradients
            loss.backward()
            # Update weights
            optimizer.step()
            # Reset gradients
            optimizer.zero_grad()

# %% [markdown]
# #### Model Training Using Recreated and Original Datasets
#
# Models are trained using both datasets generated through the Data Augmentation process and the original dataset. This comparison helps to determine the effectiveness of the synthetic data in improving model performance.

# %%
# Initialize and train a model on the recreated dataset
model_trained_on_recreated = DNN(input_size=num_features, output_size=num_classes).to(device)
train_supervised_model(model_trained_on_recreated, ccnet_recreated_dataset)

# Initialize and train a model on the original dataset
model_trained_on_original = DNN(input_size=num_features, output_size=num_classes).to(device)
train_supervised_model(model_trained_on_original, trainset)

# %% [markdown]
# #### Evaluating Model Performance
#
# After training, the models are evaluated using the F1 score, a harmonic mean of precision and recall, which is particularly useful in the context of imbalanced datasets like fraud detection. This step is critical for assessing the quality of the models trained on different types of data.

# %%
from sklearn.metrics import f1_score

def get_f1_score(model, testset, batch_size=batch_size):
    model.eval()  # Set the model to evaluation mode
    y_true = []
    y_pred = []
    # DataLoader for testing
    test_loader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False)

    # No gradient computation needed during inference
    with torch.no_grad():
        for data, label in test_loader:
            data = data.to(device)
            label = label.to(device)
            output = model(data)
            # Process output for binary classification
            predicted = (output.squeeze() > 0.5).long()
            y_true.extend(label.squeeze().long().cpu().numpy())
            y_pred.extend(predicted.cpu().numpy())

    # Compute and return the F1 score
    score = f1_score(y_true, y_pred, average='binary')
    return score

# Calculate F1 scores for both models
f1_score_original = get_f1_score(model_trained_on_original, testset)
f1_score_recreated = get_f1_score(model_trained_on_recreated, testset)

# Output the results
print("F1 score of the supervised learning model trained on the original data: ", f1_score_original)
print("F1 score of the supervised learning model trained on the recreated data: ", f1_score_recreated)
# Out:
# F1 score of the supervised learning model trained on the original data:  0.7272727272727273
# F1 score of the supervised learning model trained on the recreated data:  0.1297709923664122
