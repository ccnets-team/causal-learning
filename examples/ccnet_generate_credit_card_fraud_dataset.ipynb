# %% [markdown]
# Author:
#
#         PARK, JunHo, junho@ccnets.org
#
#
#         KIM, JeongYoong, jeongyoong@ccnets.org
#
#     COPYRIGHT (c) 2024. CCNets. All Rights reserved.

# %% [markdown]
# # Credit Card Fraud Detection: Handling Imbalanced Dataset with CCNet
#
# ## Introduction
#
# This tutorial explores the use of a Cooperative Network (CCNet) to address challenges associated with imbalanced datasets in the domain of credit card fraud detection. By leveraging the power of data generation, we aim to enhance the diversity and volume of training data, thereby improving the robustness and accuracy of models designed to identify fraudulent transactions.
#
# ## Tutorial Goals
#
# The objectives of this tutorial are designed to guide you through the process of enhancing data quality and model performance:
#
# ### Dataset Recreation with CCNet
# - **Understand Data Augmentation**: Learn how encoding techniques can be used to generate synthetic data instances that closely mimic the characteristics of real-world fraudulent and non-fraudulent transactions.
# - **Impact on Model Training**: Assess how augmenting the dataset influences the training process and subsequently, the model's ability to generalize from training to real-world scenarios.
#
# ### Model Training and Evaluation
# - **Dual Model Training**: Train two distinct models to directly compare performance metrics:
#   - A model trained on the **original dataset**.
#   - A model trained on the **CCNet-augmented dataset**.
# - **Performance Metrics**: Use the F1 score, a critical measure for models operating on imbalanced datasets, to evaluate and compare the effectiveness of these models.
#
# ### Testing and Validation
# - **Independent Model Testing**: Conduct a thorough evaluation of both models using a standalone test set that was not involved in the training phase.
# - **Objective Analysis**: Critically analyze the outcomes to validate whether data augmentation through CCNet offers a tangible benefit in detecting credit card fraud.
#
# ## Conclusion
#
# By the end of this tutorial, participants will not only grasp the theoretical underpinnings of using synthetic data to combat data imbalance but also gain hands-on experience in applying these concepts through CCNet to potentially enhance model performance in fraud detection tasks.

# %%
import sys
path_append = "../"
sys.path.append(path_append)  # Go up one directory from where you are.

# %%
# https://fraud-detection-handbook.github.io/fraud-detection-handbook/Chapter_7_DeepLearning/FeedForwardNeuralNetworks.html
import pandas as pd 

dataroot = path_append + "../data/credit_card_fraud_detection/creditcard.csv"
df = pd.read_csv(dataroot)
df
# Out:
#             Time         V1         V2        V3        V4        V5
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321  \
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838  \
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62  \
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
print('No Frauds', round(df['Class'].value_counts()[0] / len(df) *100,2), '%of the dataset')
print('Frauds', round(df['Class'].value_counts()[1] / len(df) *100,2), '%of the dataset')
# Out:
# No Frauds 99.83 %of the dataset
# Frauds 0.17 %of the dataset

# %%
import torch
from sklearn.preprocessing import StandardScaler
from torch.utils.data import Dataset

# Standardizing the features (excluding the class column)
# Standardizing the features (excluding the class column)
sc = StandardScaler()
df.iloc[:, :-1] = sc.fit_transform(df.iloc[:, :-1])

n_features = len(df.iloc[:, :-1].columns)
n_classes = len(df.iloc[:, -1:].columns)

print(n_features, n_classes)
# Out:
# 30 1

# %%
# Defining the labeled and unlabeled dataset classes
class LabeledDataset(Dataset):
    def __init__(self, x, y):
        self.x = x
        self.y = y
        
    def __len__(self):
        return len(self.x)

    def __getitem__(self, index):
        vals = torch.tensor(self.x[index], dtype=torch.float32)
        label = torch.tensor(self.y[index], dtype=torch.float32)
        return vals, label

# %% [markdown]
# #### Initial Setup and Model Configuration
#
# This section initializes the environment by setting a fixed random seed to ensure reproducibility of results. It imports necessary configurations and initializes model parameters with specific configurations. The model specified here is set to have no core model but uses a 'deepfm' encoder model for data processing, which is particularly tailored for structured or tabular data like credit card transactions.

# %%
from sklearn.model_selection import train_test_split

# Splitting the dataset into training and test sets for model evaluation
df_train, df_test = train_test_split(df, test_size=0.5, shuffle=False)
X_train, y_train = df_train.iloc[:, :-1].values, df_train.iloc[:, -1:].values
X_test, y_test = df_test.iloc[:, :-1].values, df_test.iloc[:, -1:].values

# Labeled datasets for supervised learning tasks
trainset = LabeledDataset(X_train, y_train)  # Corrected to include training data
testset = LabeledDataset(X_test, y_test)     # Test set with proper labels

# Printing the shapes of the datasets for verification
print(f"Labeled Trainset Shape: {len(trainset)}, {trainset.x.shape[1]}")
print(f"Labeled Testset Shape: {len(testset)}, {testset.x.shape[1]}")
# Out:
# Labeled Trainset Shape: 142403, 30
# Labeled Testset Shape: 142404, 30

# %%
# Set a fixed random seed for reproducibility of experiments
from nn.utils.init import set_random_seed
set_random_seed(0)

# Importing configuration setups for ML parameters and data
import torch
from tools.setting.ml_params import MLParameters
from tools.setting.data_config import DataConfig
from trainer_hub import TrainerHub

# Configuration for the data handling, defining dataset specifics and the task type
data_config = DataConfig(dataset_name='CreditCardFraudDetection', task_type='binary_classification', obs_shape=[n_features], label_size=n_classes)

# Initializing ML parameters without a core model and setting the encoder model to 'deepfm' with specific configurations
ml_params = MLParameters(core_model='gpt', encoder_model='none')
ml_params.model.core_config.num_layers = 5
ml_params.model.core_config.dropout = 0.0
ml_params.model.core_config.d_model = 128

# Setting training parameters and device configuration
ml_params.training.num_epoch = 4
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") 

# Create a TrainerHub instance to manage training and data processing
trainer_hub = TrainerHub(ml_params, data_config, device, use_print=True, use_wandb=False)

# %% [markdown]
# #### Dataset Splitting for Training and Testing
#
# The original dataset is split into training and testing parts to evaluate the model's performance accurately. This step is crucial for validating the effectiveness of the training on unseen data.

# %%
trainer_hub.train(trainset)
# Out:
# Epochs:   0%|          | 0/4 [00:00<?, ?it/s]
# Iterations:   0%|          | 0/2225 [00:00<?, ?it/s]
# [0/4][50/2225][Time 2.90]
# Unified LR across all optimizers: 0.0001995308238189185
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.2596	Gen: 0.5246	Rec: 0.5873	E: 0.1969	R: 0.3223	P: 0.8524
# [0/4][100/2225][Time 2.72]
# Unified LR across all optimizers: 0.00019907191565870155
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0099	Gen: 0.3328	Rec: 0.3328	E: 0.0099	R: 0.0100	P: 0.6557
# [0/4][150/2225][Time 2.84]
# Unified LR across all optimizers: 0.00019861406295796434
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0069	Gen: 0.2528	Rec: 0.2529	E: 0.0068	R: 0.0070	P: 0.4988
# [0/4][200/2225][Time 2.78]
# Unified LR across all optimizers: 0.00019815726328921765
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0074	Gen: 0.2202	Rec: 0.2202	E: 0.0074	R: 0.0073	P: 0.4331
# [0/4][250/2225][Time 2.84]
# Unified LR across all optimizers: 0.00019770151423055492
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0050	Gen: 0.1920	Rec: 0.1920	E: 0.0050	R: 0.0050	P: 0.3791
# [0/4][300/2225][Time 2.84]
# Unified LR across all optimizers: 0.00019724681336564005
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0052	Gen: 0.1668	Rec: 0.1666	E: 0.0054	R: 0.0050	P: 0.3282
# [0/4][350/2225][Time 2.78]
# Unified LR across all optimizers: 0.00019679315828369438
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0040	Gen: 0.1575	Rec: 0.1579	E: 0.0035	R: 0.0044	P: 0.3115
# [0/4][400/2225][Time 2.85]
# Unified LR across all optimizers: 0.00019634054657948372
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0022	Gen: 0.1461	Rec: 0.1462	E: 0.0021	R: 0.0022	P: 0.2901
# [0/4][450/2225][Time 2.76]
# Unified LR across all optimizers: 0.00019588897585330582
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0026	Gen: 0.1390	Rec: 0.1392	E: 0.0024	R: 0.0028	P: 0.2756
# [0/4][500/2225][Time 2.86]
# Unified LR across all optimizers: 0.00019543844371097777
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0030	Gen: 0.1250	Rec: 0.1255	E: 0.0025	R: 0.0035	P: 0.2475
# [0/4][550/2225][Time 2.78]
# Unified LR across all optimizers: 0.00019498894776382288
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0025	Gen: 0.1189	Rec: 0.1190	E: 0.0024	R: 0.0026	P: 0.2354
# [0/4][600/2225][Time 2.80]
# Unified LR across all optimizers: 0.00019454048562865856
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0019	Gen: 0.1130	Rec: 0.1128	E: 0.0021	R: 0.0017	P: 0.2239
# [0/4][650/2225][Time 2.84]
# Unified LR across all optimizers: 0.00019409305492778308
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0025	Gen: 0.1137	Rec: 0.1139	E: 0.0023	R: 0.0027	P: 0.2250
# [0/4][700/2225][Time 2.76]
# Unified LR across all optimizers: 0.00019364665328896346
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0031	Gen: 0.1037	Rec: 0.1034	E: 0.0035	R: 0.0028	P: 0.2040
# [0/4][750/2225][Time 2.91]
# Unified LR across all optimizers: 0.00019320127834542263
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0025	Gen: 0.1012	Rec: 0.1017	E: 0.0020	R: 0.0030	P: 0.2005
# [0/4][800/2225][Time 2.90]
# Unified LR across all optimizers: 0.00019275692773582703
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0015	Gen: 0.0932	Rec: 0.0927	E: 0.0020	R: 0.0010	P: 0.1844
# [0/4][850/2225][Time 2.79]
# Unified LR across all optimizers: 0.0001923135991042739
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0025	Gen: 0.0902	Rec: 0.0909	E: 0.0018	R: 0.0032	P: 0.1786
# [0/4][900/2225][Time 2.94]
# Unified LR across all optimizers: 0.0001918712901002789
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0030	Gen: 0.0929	Rec: 0.0933	E: 0.0025	R: 0.0034	P: 0.1832
# [0/4][950/2225][Time 2.88]
# Unified LR across all optimizers: 0.00019142999837876384
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0028	Gen: 0.0936	Rec: 0.0938	E: 0.0026	R: 0.0030	P: 0.1847
# [0/4][1000/2225][Time 2.85]
# Unified LR across all optimizers: 0.00019098972160004388
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0019	Gen: 0.0860	Rec: 0.0863	E: 0.0017	R: 0.0021	P: 0.1704
# [0/4][1050/2225][Time 2.81]
# Unified LR across all optimizers: 0.00019055045742981543
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0016	Gen: 0.0835	Rec: 0.0835	E: 0.0016	R: 0.0016	P: 0.1655
# [0/4][1100/2225][Time 2.85]
# Unified LR across all optimizers: 0.00019011220353914353
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0016	Gen: 0.0885	Rec: 0.0880	E: 0.0021	R: 0.0012	P: 0.1748
# [0/4][1150/2225][Time 2.83]
# Unified LR across all optimizers: 0.00018967495760444968
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0012	Gen: 0.0802	Rec: 0.0803	E: 0.0011	R: 0.0013	P: 0.1594
# [0/4][1200/2225][Time 2.86]
# Unified LR across all optimizers: 0.00018923871730749947
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0033	Gen: 0.0829	Rec: 0.0833	E: 0.0028	R: 0.0038	P: 0.1629
# [0/4][1250/2225][Time 2.83]
# Unified LR across all optimizers: 0.00018880348033539028
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0026	Gen: 0.0792	Rec: 0.0799	E: 0.0018	R: 0.0033	P: 0.1565
# [0/4][1300/2225][Time 2.84]
# Unified LR across all optimizers: 0.00018836924438053897
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0022	Gen: 0.0755	Rec: 0.0763	E: 0.0015	R: 0.0029	P: 0.1496
# [0/4][1350/2225][Time 2.90]
# Unified LR across all optimizers: 0.0001879360071406698
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0025	Gen: 0.0813	Rec: 0.0818	E: 0.0020	R: 0.0030	P: 0.1606
# [0/4][1400/2225][Time 2.84]
# Unified LR across all optimizers: 0.000187503766318802
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0021	Gen: 0.0705	Rec: 0.0710	E: 0.0016	R: 0.0026	P: 0.1394
# [0/4][1450/2225][Time 2.78]
# Unified LR across all optimizers: 0.00018707251962323787
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0022	Gen: 0.0727	Rec: 0.0730	E: 0.0019	R: 0.0026	P: 0.1434
# [0/4][1500/2225][Time 2.92]
# Unified LR across all optimizers: 0.0001866422647675502
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0030	Gen: 0.0735	Rec: 0.0735	E: 0.0031	R: 0.0029	P: 0.1440
# [0/4][1550/2225][Time 2.81]
# Unified LR across all optimizers: 0.00018621299947057073
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0007	Gen: 0.0716	Rec: 0.0718	E: 0.0006	R: 0.0009	P: 0.1427
# [0/4][1600/2225][Time 2.84]
# Unified LR across all optimizers: 0.00018578472145637737
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0014	Gen: 0.0651	Rec: 0.0651	E: 0.0014	R: 0.0014	P: 0.1288
# [0/4][1650/2225][Time 2.85]
# Unified LR across all optimizers: 0.00018535742845428288
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0030	Gen: 0.0762	Rec: 0.0771	E: 0.0021	R: 0.0038	P: 0.1504
# [0/4][1700/2225][Time 2.83]
# Unified LR across all optimizers: 0.00018493111819882223
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0020	Gen: 0.0733	Rec: 0.0737	E: 0.0016	R: 0.0024	P: 0.1451
# [0/4][1750/2225][Time 2.82]
# Unified LR across all optimizers: 0.00018450578842974107
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0025	Gen: 0.0664	Rec: 0.0671	E: 0.0018	R: 0.0032	P: 0.1310
# [0/4][1800/2225][Time 2.84]
# Unified LR across all optimizers: 0.00018408143689198318
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0021	Gen: 0.0658	Rec: 0.0659	E: 0.0021	R: 0.0022	P: 0.1295
# [0/4][1850/2225][Time 2.88]
# Unified LR across all optimizers: 0.0001836580613356789
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0023	Gen: 0.0606	Rec: 0.0608	E: 0.0021	R: 0.0025	P: 0.1191
# [0/4][1900/2225][Time 2.86]
# Unified LR across all optimizers: 0.0001832356595161332
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0033	Gen: 0.0642	Rec: 0.0637	E: 0.0038	R: 0.0028	P: 0.1247
# [0/4][1950/2225][Time 3.08]
# Unified LR across all optimizers: 0.00018281422919381367
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0027	Gen: 0.0609	Rec: 0.0600	E: 0.0036	R: 0.0017	P: 0.1182
# [0/4][2000/2225][Time 2.99]
# Unified LR across all optimizers: 0.00018239376813433867
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0009	Gen: 0.0647	Rec: 0.0648	E: 0.0008	R: 0.0011	P: 0.1286
# [0/4][2050/2225][Time 2.81]
# Unified LR across all optimizers: 0.00018197427410846564
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0019	Gen: 0.0572	Rec: 0.0570	E: 0.0022	R: 0.0017	P: 0.1122
# [0/4][2100/2225][Time 2.90]
# Unified LR across all optimizers: 0.00018155574489207887
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0024	Gen: 0.0611	Rec: 0.0614	E: 0.0021	R: 0.0026	P: 0.1201
# [0/4][2150/2225][Time 2.88]
# Unified LR across all optimizers: 0.00018113817826617823
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0033	Gen: 0.0642	Rec: 0.0648	E: 0.0027	R: 0.0039	P: 0.1256
# [0/4][2200/2225][Time 2.87]
# Unified LR across all optimizers: 0.00018072157201686696
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0013	Gen: 0.0615	Rec: 0.0617	E: 0.0011	R: 0.0014	P: 0.1219
# Iterations:   0%|          | 0/2225 [00:00<?, ?it/s]
# [1/4][25/2225][Time 2.91]
# Unified LR across all optimizers: 0.00018030592393534033
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0012	Gen: 0.0572	Rec: 0.0575	E: 0.0009	R: 0.0015	P: 0.1135
# [1/4][75/2225][Time 2.87]
# Unified LR across all optimizers: 0.0001798912318178735
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0018	Gen: 0.0571	Rec: 0.0572	E: 0.0018	R: 0.0018	P: 0.1125
# [1/4][125/2225][Time 2.86]
# Unified LR across all optimizers: 0.00017947749346581006
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0016	Gen: 0.0561	Rec: 0.0563	E: 0.0014	R: 0.0018	P: 0.1108
# [1/4][175/2225][Time 2.87]
# Unified LR across all optimizers: 0.0001790647066855505
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0016	Gen: 0.0598	Rec: 0.0600	E: 0.0014	R: 0.0018	P: 0.1182
# [1/4][225/2225][Time 2.82]
# Unified LR across all optimizers: 0.00017865286928854052
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0018	Gen: 0.0598	Rec: 0.0599	E: 0.0017	R: 0.0019	P: 0.1180
# [1/4][275/2225][Time 2.81]
# Unified LR across all optimizers: 0.00017824197909125899
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0012	Gen: 0.0560	Rec: 0.0558	E: 0.0014	R: 0.0010	P: 0.1106
# [1/4][325/2225][Time 2.82]
# Unified LR across all optimizers: 0.00017783203391520723
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0015	Gen: 0.0496	Rec: 0.0498	E: 0.0013	R: 0.0017	P: 0.0979
# [1/4][375/2225][Time 2.89]
# Unified LR across all optimizers: 0.00017742303158689668
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0016	Gen: 0.0541	Rec: 0.0539	E: 0.0017	R: 0.0014	P: 0.1064
# [1/4][425/2225][Time 2.77]
# Unified LR across all optimizers: 0.00017701496993783762
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0016	Gen: 0.0499	Rec: 0.0496	E: 0.0018	R: 0.0013	P: 0.0980
# [1/4][475/2225][Time 2.85]
# Unified LR across all optimizers: 0.00017660784680452796
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0001	Gen: 0.0496	Rec: 0.0496	E: 0.0001	R: 0.0001	P: 0.0992
# [1/4][525/2225][Time 2.87]
# Unified LR across all optimizers: 0.0001762016600284412
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0012	Gen: 0.0568	Rec: 0.0568	E: 0.0012	R: 0.0012	P: 0.1124
# [1/4][575/2225][Time 2.82]
# Unified LR across all optimizers: 0.00017579640745601563
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0010	Gen: 0.0525	Rec: 0.0526	E: 0.0008	R: 0.0011	P: 0.1041
# [1/4][625/2225][Time 2.83]
# Unified LR across all optimizers: 0.0001753920869386423
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0024	Gen: 0.0546	Rec: 0.0543	E: 0.0027	R: 0.0020	P: 0.1065
# [1/4][675/2225][Time 2.78]
# Unified LR across all optimizers: 0.0001749886963326542
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0019	Gen: 0.0545	Rec: 0.0540	E: 0.0025	R: 0.0014	P: 0.1065
# [1/4][725/2225][Time 2.84]
# Unified LR across all optimizers: 0.0001745862334993144
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0013	Gen: 0.0507	Rec: 0.0506	E: 0.0014	R: 0.0011	P: 0.1000
# [1/4][775/2225][Time 2.75]
# Unified LR across all optimizers: 0.00017418469630480507
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0013	Gen: 0.0536	Rec: 0.0537	E: 0.0013	R: 0.0014	P: 0.1060
# [1/4][825/2225][Time 3.01]
# Unified LR across all optimizers: 0.00017378408262021616
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0025	Gen: 0.0536	Rec: 0.0529	E: 0.0032	R: 0.0018	P: 0.1039
# [1/4][875/2225][Time 2.83]
# Unified LR across all optimizers: 0.00017338439032153356
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0012	Gen: 0.0521	Rec: 0.0516	E: 0.0017	R: 0.0006	P: 0.1025
# [1/4][925/2225][Time 2.81]
# Unified LR across all optimizers: 0.00017298561728962847
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0029	Gen: 0.0485	Rec: 0.0483	E: 0.0030	R: 0.0028	P: 0.0939
# [1/4][975/2225][Time 2.86]
# Unified LR across all optimizers: 0.00017258776141024598
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0008	Gen: 0.0473	Rec: 0.0468	E: 0.0013	R: 0.0003	P: 0.0933
# [1/4][1025/2225][Time 2.81]
# Unified LR across all optimizers: 0.00017219082057399394
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0015	Gen: 0.0502	Rec: 0.0497	E: 0.0021	R: 0.0010	P: 0.0983
# [1/4][1075/2225][Time 2.87]
# Unified LR across all optimizers: 0.00017179479267633146
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0004	Gen: 0.0511	Rec: 0.0512	E: 0.0003	R: 0.0004	P: 0.1019
# [1/4][1125/2225][Time 2.90]
# Unified LR across all optimizers: 0.00017139967561755819
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0022	Gen: 0.0507	Rec: 0.0500	E: 0.0029	R: 0.0015	P: 0.0985
# [1/4][1175/2225][Time 2.81]
# Unified LR across all optimizers: 0.00017100546730280274
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0006	Gen: 0.0462	Rec: 0.0460	E: 0.0008	R: 0.0004	P: 0.0916
# [1/4][1225/2225][Time 2.79]
# Unified LR across all optimizers: 0.00017061216564201177
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0019	Gen: 0.0525	Rec: 0.0515	E: 0.0029	R: 0.0009	P: 0.1021
# [1/4][1275/2225][Time 2.87]
# Unified LR across all optimizers: 0.0001702197685499392
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0005	Gen: 0.0429	Rec: 0.0426	E: 0.0008	R: 0.0002	P: 0.0850
# [1/4][1325/2225][Time 2.83]
# Unified LR across all optimizers: 0.0001698282739461345
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0013	Gen: 0.0434	Rec: 0.0429	E: 0.0019	R: 0.0008	P: 0.0850
# [1/4][1375/2225][Time 2.84]
# Unified LR across all optimizers: 0.00016943767975493242
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0012	Gen: 0.0436	Rec: 0.0432	E: 0.0017	R: 0.0008	P: 0.0856
# [1/4][1425/2225][Time 2.84]
# Unified LR across all optimizers: 0.0001690479839054414
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0006	Gen: 0.0432	Rec: 0.0432	E: 0.0006	R: 0.0006	P: 0.0858
# [1/4][1475/2225][Time 2.77]
# Unified LR across all optimizers: 0.00016865918433153277
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0012	Gen: 0.0465	Rec: 0.0464	E: 0.0013	R: 0.0010	P: 0.0918
# [1/4][1525/2225][Time 2.86]
# Unified LR across all optimizers: 0.00016827127897182985
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0010	Gen: 0.0470	Rec: 0.0467	E: 0.0013	R: 0.0008	P: 0.0927
# [1/4][1575/2225][Time 2.77]
# Unified LR across all optimizers: 0.0001678842657696972
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0012	Gen: 0.0476	Rec: 0.0475	E: 0.0014	R: 0.0011	P: 0.0938
# [1/4][1625/2225][Time 2.85]
# Unified LR across all optimizers: 0.00016749814267322938
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0019	Gen: 0.0496	Rec: 0.0485	E: 0.0030	R: 0.0009	P: 0.0962
# [1/4][1675/2225][Time 2.81]
# Unified LR across all optimizers: 0.00016711290763524007
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0013	Gen: 0.0409	Rec: 0.0405	E: 0.0017	R: 0.0008	P: 0.0801
# [1/4][1725/2225][Time 2.79]
# Unified LR across all optimizers: 0.00016672855861325146
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0008	Gen: 0.0465	Rec: 0.0462	E: 0.0011	R: 0.0005	P: 0.0919
# [1/4][1775/2225][Time 2.78]
# Unified LR across all optimizers: 0.00016634509356948314
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0010	Gen: 0.0387	Rec: 0.0381	E: 0.0017	R: 0.0004	P: 0.0758
# [1/4][1825/2225][Time 2.84]
# Unified LR across all optimizers: 0.00016596251047084197
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0017	Gen: 0.0420	Rec: 0.0411	E: 0.0025	R: 0.0009	P: 0.0814
# [1/4][1875/2225][Time 2.77]
# Unified LR across all optimizers: 0.00016558080728890993
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0018	Gen: 0.0438	Rec: 0.0433	E: 0.0023	R: 0.0013	P: 0.0854
# [1/4][1925/2225][Time 2.85]
# Unified LR across all optimizers: 0.00016519998199993532
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0006	Gen: 0.0446	Rec: 0.0444	E: 0.0009	R: 0.0004	P: 0.0884
# [1/4][1975/2225][Time 2.76]
# Unified LR across all optimizers: 0.0001648200325848201
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0012	Gen: 0.0456	Rec: 0.0454	E: 0.0014	R: 0.0010	P: 0.0899
# [1/4][2025/2225][Time 2.82]
# Unified LR across all optimizers: 0.00016444095702911038
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0015	Gen: 0.0389	Rec: 0.0386	E: 0.0018	R: 0.0012	P: 0.0760
# [1/4][2075/2225][Time 2.90]
# Unified LR across all optimizers: 0.00016406275332298505
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0019	Gen: 0.0417	Rec: 0.0409	E: 0.0027	R: 0.0010	P: 0.0808
# [1/4][2125/2225][Time 2.83]
# Unified LR across all optimizers: 0.00016368541946124596
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0013	Gen: 0.0419	Rec: 0.0414	E: 0.0018	R: 0.0008	P: 0.0820
# [1/4][2175/2225][Time 2.84]
# Unified LR across all optimizers: 0.00016330895344330638
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0006	Gen: 0.0442	Rec: 0.0439	E: 0.0009	R: 0.0004	P: 0.0875
# Iterations:   0%|          | 0/2225 [00:00<?, ?it/s]
# [2/4][0/2225][Time 2.88]
# Unified LR across all optimizers: 0.00016293335327318117
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0009	Gen: 0.0428	Rec: 0.0428	E: 0.0009	R: 0.0009	P: 0.0847
# [2/4][50/2225][Time 2.87]
# Unified LR across all optimizers: 0.00016255861695947546
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0020	Gen: 0.0408	Rec: 0.0397	E: 0.0032	R: 0.0009	P: 0.0785
# [2/4][100/2225][Time 2.97]
# Unified LR across all optimizers: 0.00016218474251537463
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0009	Gen: 0.0427	Rec: 0.0423	E: 0.0013	R: 0.0006	P: 0.0841
# [2/4][150/2225][Time 3.15]
# Unified LR across all optimizers: 0.00016181172795863357
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0009	Gen: 0.0405	Rec: 0.0399	E: 0.0015	R: 0.0003	P: 0.0795
# [2/4][200/2225][Time 2.86]
# Unified LR across all optimizers: 0.0001614395713115662
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0005	Gen: 0.0371	Rec: 0.0370	E: 0.0006	R: 0.0003	P: 0.0736
# [2/4][250/2225][Time 2.82]
# Unified LR across all optimizers: 0.00016106827060103523
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0008	Gen: 0.0387	Rec: 0.0387	E: 0.0008	R: 0.0008	P: 0.0766
# [2/4][300/2225][Time 2.78]
# Unified LR across all optimizers: 0.00016069782385844109
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0016	Gen: 0.0408	Rec: 0.0409	E: 0.0015	R: 0.0017	P: 0.0801
# [2/4][350/2225][Time 2.84]
# Unified LR across all optimizers: 0.00016032822911971208
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0011	Gen: 0.0390	Rec: 0.0385	E: 0.0016	R: 0.0005	P: 0.0764
# [2/4][400/2225][Time 2.82]
# Unified LR across all optimizers: 0.0001599594844252937
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0023	Gen: 0.0436	Rec: 0.0434	E: 0.0025	R: 0.0022	P: 0.0847
# [2/4][450/2225][Time 2.98]
# Unified LR across all optimizers: 0.00015959158782013816
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0008	Gen: 0.0403	Rec: 0.0405	E: 0.0006	R: 0.0010	P: 0.0799
# [2/4][500/2225][Time 2.76]
# Unified LR across all optimizers: 0.00015922453735369438
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0010	Gen: 0.0393	Rec: 0.0390	E: 0.0013	R: 0.0007	P: 0.0772
# [2/4][550/2225][Time 2.83]
# Unified LR across all optimizers: 0.00015885833107989733
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0020	Gen: 0.0392	Rec: 0.0391	E: 0.0021	R: 0.0019	P: 0.0764
# [2/4][600/2225][Time 2.84]
# Unified LR across all optimizers: 0.00015849296705715778
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0006	Gen: 0.0388	Rec: 0.0388	E: 0.0006	R: 0.0006	P: 0.0770
# [2/4][650/2225][Time 2.93]
# Unified LR across all optimizers: 0.0001581284433483521
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0011	Gen: 0.0397	Rec: 0.0395	E: 0.0012	R: 0.0009	P: 0.0781
# [2/4][700/2225][Time 2.78]
# Unified LR across all optimizers: 0.00015776475802081183
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0006	Gen: 0.0339	Rec: 0.0338	E: 0.0006	R: 0.0005	P: 0.0671
# [2/4][750/2225][Time 2.90]
# Unified LR across all optimizers: 0.00015740190914631356
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0009	Gen: 0.0427	Rec: 0.0423	E: 0.0013	R: 0.0005	P: 0.0840
# [2/4][800/2225][Time 2.73]
# Unified LR across all optimizers: 0.0001570398948010687
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0015	Gen: 0.0394	Rec: 0.0390	E: 0.0020	R: 0.0010	P: 0.0769
# [2/4][850/2225][Time 2.81]
# Unified LR across all optimizers: 0.00015667871306571324
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0016	Gen: 0.0439	Rec: 0.0436	E: 0.0020	R: 0.0012	P: 0.0859
# [2/4][900/2225][Time 2.86]
# Unified LR across all optimizers: 0.00015631836202529756
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0010	Gen: 0.0352	Rec: 0.0344	E: 0.0018	R: 0.0002	P: 0.0685
# [2/4][950/2225][Time 2.82]
# Unified LR across all optimizers: 0.00015595883976927632
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0015	Gen: 0.0361	Rec: 0.0353	E: 0.0023	R: 0.0006	P: 0.0699
# [2/4][1000/2225][Time 2.83]
# Unified LR across all optimizers: 0.0001556001443914984
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0006	Gen: 0.0372	Rec: 0.0368	E: 0.0011	R: 0.0002	P: 0.0734
# [2/4][1050/2225][Time 2.83]
# Unified LR across all optimizers: 0.0001552422739901963
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0003	Gen: 0.0323	Rec: 0.0322	E: 0.0004	R: 0.0003	P: 0.0642
# [2/4][1100/2225][Time 2.87]
# Unified LR across all optimizers: 0.00015488522666797712
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0019	Gen: 0.0377	Rec: 0.0372	E: 0.0024	R: 0.0014	P: 0.0730
# [2/4][1150/2225][Time 2.92]
# Unified LR across all optimizers: 0.00015452900053181137
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0010	Gen: 0.0355	Rec: 0.0349	E: 0.0016	R: 0.0004	P: 0.0693
# [2/4][1200/2225][Time 3.02]
# Unified LR across all optimizers: 0.00015417359369302347
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0011	Gen: 0.0365	Rec: 0.0357	E: 0.0018	R: 0.0004	P: 0.0711
# [2/4][1250/2225][Time 2.87]
# Unified LR across all optimizers: 0.00015381900426728195
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0017	Gen: 0.0331	Rec: 0.0324	E: 0.0024	R: 0.0010	P: 0.0639
# [2/4][1300/2225][Time 2.92]
# Unified LR across all optimizers: 0.00015346523037458877
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0015	Gen: 0.0320	Rec: 0.0316	E: 0.0019	R: 0.0010	P: 0.0622
# [2/4][1350/2225][Time 2.85]
# Unified LR across all optimizers: 0.00015311227013926996
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0013	Gen: 0.0368	Rec: 0.0368	E: 0.0013	R: 0.0013	P: 0.0723
# [2/4][1400/2225][Time 2.92]
# Unified LR across all optimizers: 0.00015276012168996563
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0009	Gen: 0.0367	Rec: 0.0368	E: 0.0008	R: 0.0009	P: 0.0726
# [2/4][1450/2225][Time 2.89]
# Unified LR across all optimizers: 0.00015240878315961963
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0007	Gen: 0.0317	Rec: 0.0314	E: 0.0011	R: 0.0004	P: 0.0624
# [2/4][1500/2225][Time 2.85]
# Unified LR across all optimizers: 0.00015205825268547007
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0016	Gen: 0.0415	Rec: 0.0410	E: 0.0021	R: 0.0012	P: 0.0809
# [2/4][1550/2225][Time 2.88]
# Unified LR across all optimizers: 0.0001517085284090394
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0014	Gen: 0.0394	Rec: 0.0389	E: 0.0019	R: 0.0010	P: 0.0769
# [2/4][1600/2225][Time 2.91]
# Unified LR across all optimizers: 0.00015135960847612417
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0008	Gen: 0.0361	Rec: 0.0358	E: 0.0011	R: 0.0005	P: 0.0711
# [2/4][1650/2225][Time 2.96]
# Unified LR across all optimizers: 0.0001510114910367858
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0013	Gen: 0.0393	Rec: 0.0385	E: 0.0021	R: 0.0005	P: 0.0765
# [2/4][1700/2225][Time 2.85]
# Unified LR across all optimizers: 0.00015066417424534014
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0012	Gen: 0.0366	Rec: 0.0363	E: 0.0016	R: 0.0009	P: 0.0716
# [2/4][1750/2225][Time 2.86]
# Unified LR across all optimizers: 0.00015031765626034814
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0011	Gen: 0.0346	Rec: 0.0347	E: 0.0011	R: 0.0011	P: 0.0682
# [2/4][1800/2225][Time 2.84]
# Unified LR across all optimizers: 0.00014997193524460595
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0009	Gen: 0.0395	Rec: 0.0393	E: 0.0011	R: 0.0006	P: 0.0779
# [2/4][1850/2225][Time 2.87]
# Unified LR across all optimizers: 0.00014962700936513516
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0008	Gen: 0.0301	Rec: 0.0297	E: 0.0012	R: 0.0005	P: 0.0590
# [2/4][1900/2225][Time 2.87]
# Unified LR across all optimizers: 0.00014928287679317315
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0023	Gen: 0.0371	Rec: 0.0364	E: 0.0031	R: 0.0016	P: 0.0711
# [2/4][1950/2225][Time 2.87]
# Unified LR across all optimizers: 0.0001489395357041632
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0015	Gen: 0.0359	Rec: 0.0351	E: 0.0023	R: 0.0008	P: 0.0695
# [2/4][2000/2225][Time 2.87]
# Unified LR across all optimizers: 0.000148596984277745
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0013	Gen: 0.0353	Rec: 0.0346	E: 0.0020	R: 0.0006	P: 0.0687
# [2/4][2050/2225][Time 2.87]
# Unified LR across all optimizers: 0.0001482552206977451
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0003	Gen: 0.0310	Rec: 0.0311	E: 0.0003	R: 0.0004	P: 0.0617
# [2/4][2100/2225][Time 2.86]
# Unified LR across all optimizers: 0.00014791424315216693
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0007	Gen: 0.0334	Rec: 0.0331	E: 0.0010	R: 0.0005	P: 0.0657
# [2/4][2150/2225][Time 2.86]
# Unified LR across all optimizers: 0.00014757404983318153
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0013	Gen: 0.0322	Rec: 0.0319	E: 0.0016	R: 0.0010	P: 0.0629
# [2/4][2200/2225][Time 2.84]
# Unified LR across all optimizers: 0.00014723463893711783
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0020	Gen: 0.0350	Rec: 0.0342	E: 0.0027	R: 0.0012	P: 0.0672
# Iterations:   0%|          | 0/2225 [00:00<?, ?it/s]
# [3/4][25/2225][Time 2.97]
# Unified LR across all optimizers: 0.00014689600866445298
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0005	Gen: 0.0351	Rec: 0.0349	E: 0.0007	R: 0.0003	P: 0.0696
# [3/4][75/2225][Time 2.90]
# Unified LR across all optimizers: 0.00014655815721980301
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0004	Gen: 0.0347	Rec: 0.0345	E: 0.0006	R: 0.0002	P: 0.0688
# [3/4][125/2225][Time 2.87]
# Unified LR across all optimizers: 0.00014622108281191326
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0014	Gen: 0.0341	Rec: 0.0333	E: 0.0022	R: 0.0006	P: 0.0659
# [3/4][175/2225][Time 2.86]
# Unified LR across all optimizers: 0.00014588478365364866
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0014	Gen: 0.0373	Rec: 0.0366	E: 0.0021	R: 0.0007	P: 0.0725
# [3/4][225/2225][Time 2.90]
# Unified LR across all optimizers: 0.0001455492579619846
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0020	Gen: 0.0307	Rec: 0.0299	E: 0.0027	R: 0.0012	P: 0.0587
# [3/4][275/2225][Time 2.87]
# Unified LR across all optimizers: 0.00014521450395799725
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0012	Gen: 0.0347	Rec: 0.0346	E: 0.0013	R: 0.0011	P: 0.0680
# [3/4][325/2225][Time 2.88]
# Unified LR across all optimizers: 0.00014488051986685427
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0006	Gen: 0.0322	Rec: 0.0322	E: 0.0006	R: 0.0006	P: 0.0639
# [3/4][375/2225][Time 2.90]
# Unified LR across all optimizers: 0.00014454730391780514
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0018	Gen: 0.0342	Rec: 0.0339	E: 0.0020	R: 0.0015	P: 0.0663
# [3/4][425/2225][Time 2.92]
# Unified LR across all optimizers: 0.0001442148543441721
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0007	Gen: 0.0343	Rec: 0.0341	E: 0.0009	R: 0.0005	P: 0.0677
# [3/4][475/2225][Time 2.88]
# Unified LR across all optimizers: 0.00014388316938334075
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0006	Gen: 0.0311	Rec: 0.0306	E: 0.0011	R: 0.0002	P: 0.0611
# [3/4][525/2225][Time 2.86]
# Unified LR across all optimizers: 0.0001435522472767503
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0014	Gen: 0.0353	Rec: 0.0354	E: 0.0013	R: 0.0015	P: 0.0693
# [3/4][575/2225][Time 2.89]
# Unified LR across all optimizers: 0.00014322208626988471
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0017	Gen: 0.0352	Rec: 0.0343	E: 0.0026	R: 0.0008	P: 0.0678
# [3/4][625/2225][Time 2.89]
# Unified LR across all optimizers: 0.00014289268461226322
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0016	Gen: 0.0328	Rec: 0.0326	E: 0.0018	R: 0.0014	P: 0.0638
# [3/4][675/2225][Time 2.90]
# Unified LR across all optimizers: 0.00014256404055743098
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0006	Gen: 0.0308	Rec: 0.0305	E: 0.0009	R: 0.0004	P: 0.0607
# [3/4][725/2225][Time 2.88]
# Unified LR across all optimizers: 0.00014223615236295
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0014	Gen: 0.0279	Rec: 0.0272	E: 0.0021	R: 0.0007	P: 0.0536
# [3/4][775/2225][Time 3.21]
# Unified LR across all optimizers: 0.0001419090182903897
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0009	Gen: 0.0309	Rec: 0.0307	E: 0.0011	R: 0.0007	P: 0.0607
# [3/4][825/2225][Time 3.10]
# Unified LR across all optimizers: 0.00014158263660531755
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0018	Gen: 0.0329	Rec: 0.0324	E: 0.0024	R: 0.0013	P: 0.0635
# [3/4][875/2225][Time 3.19]
# Unified LR across all optimizers: 0.00014125700557729063
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0013	Gen: 0.0324	Rec: 0.0322	E: 0.0015	R: 0.0011	P: 0.0633
# [3/4][925/2225][Time 2.77]
# Unified LR across all optimizers: 0.00014093212347984557
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0015	Gen: 0.0285	Rec: 0.0281	E: 0.0019	R: 0.0011	P: 0.0551
# [3/4][975/2225][Time 2.86]
# Unified LR across all optimizers: 0.00014060798859048983
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0007	Gen: 0.0277	Rec: 0.0277	E: 0.0006	R: 0.0007	P: 0.0547
# [3/4][1025/2225][Time 2.87]
# Unified LR across all optimizers: 0.00014028459919069257
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0007	Gen: 0.0275	Rec: 0.0272	E: 0.0009	R: 0.0005	P: 0.0540
# [3/4][1075/2225][Time 2.90]
# Unified LR across all optimizers: 0.00013996195356587524
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0005	Gen: 0.0337	Rec: 0.0336	E: 0.0006	R: 0.0003	P: 0.0668
# [3/4][1125/2225][Time 2.91]
# Unified LR across all optimizers: 0.0001396400500054029
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0018	Gen: 0.0309	Rec: 0.0305	E: 0.0023	R: 0.0014	P: 0.0596
# [3/4][1175/2225][Time 2.93]
# Unified LR across all optimizers: 0.00013931888680257493
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0006	Gen: 0.0329	Rec: 0.0329	E: 0.0007	R: 0.0006	P: 0.0651
# [3/4][1225/2225][Time 2.88]
# Unified LR across all optimizers: 0.000138998462254616
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.0297	Rec: 0.0297	E: 0.0000	R: 0.0000	P: 0.0593
# [3/4][1275/2225][Time 2.87]
# Unified LR across all optimizers: 0.00013867877466266706
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0004	Gen: 0.0271	Rec: 0.0270	E: 0.0005	R: 0.0003	P: 0.0537
# [3/4][1325/2225][Time 2.86]
# Unified LR across all optimizers: 0.00013835982233177638
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0026	Gen: 0.0297	Rec: 0.0293	E: 0.0029	R: 0.0022	P: 0.0564
# [3/4][1375/2225][Time 2.87]
# Unified LR across all optimizers: 0.0001380416035708904
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0005	Gen: 0.0337	Rec: 0.0338	E: 0.0005	R: 0.0005	P: 0.0670
# [3/4][1425/2225][Time 2.89]
# Unified LR across all optimizers: 0.00013772411669284496
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0014	Gen: 0.0317	Rec: 0.0311	E: 0.0020	R: 0.0007	P: 0.0615
# [3/4][1475/2225][Time 2.90]
# Unified LR across all optimizers: 0.00013740736001435612
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0014	Gen: 0.0304	Rec: 0.0298	E: 0.0019	R: 0.0009	P: 0.0588
# [3/4][1525/2225][Time 2.90]
# Unified LR across all optimizers: 0.0001370913318560116
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0016	Gen: 0.0316	Rec: 0.0309	E: 0.0022	R: 0.0009	P: 0.0609
# [3/4][1575/2225][Time 2.95]
# Unified LR across all optimizers: 0.00013677603054226164
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0012	Gen: 0.0341	Rec: 0.0337	E: 0.0016	R: 0.0008	P: 0.0666
# [3/4][1625/2225][Time 2.93]
# Unified LR across all optimizers: 0.00013646145440140986
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0019	Gen: 0.0276	Rec: 0.0267	E: 0.0029	R: 0.0010	P: 0.0524
# [3/4][1675/2225][Time 2.92]
# Unified LR across all optimizers: 0.000136147601765605
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0006	Gen: 0.0298	Rec: 0.0296	E: 0.0008	R: 0.0004	P: 0.0588
# [3/4][1725/2225][Time 2.89]
# Unified LR across all optimizers: 0.00013583447097083163
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0013	Gen: 0.0295	Rec: 0.0291	E: 0.0017	R: 0.0009	P: 0.0574
# [3/4][1775/2225][Time 2.91]
# Unified LR across all optimizers: 0.00013552206035690145
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0006	Gen: 0.0272	Rec: 0.0270	E: 0.0008	R: 0.0004	P: 0.0536
# [3/4][1825/2225][Time 2.91]
# Unified LR across all optimizers: 0.00013521036826744445
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0011	Gen: 0.0283	Rec: 0.0278	E: 0.0016	R: 0.0006	P: 0.0550
# [3/4][1875/2225][Time 2.92]
# Unified LR across all optimizers: 0.00013489939304990025
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0002	Gen: 0.0275	Rec: 0.0274	E: 0.0003	R: 0.0001	P: 0.0547
# [3/4][1925/2225][Time 2.90]
# Unified LR across all optimizers: 0.00013458913305550914
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0011	Gen: 0.0263	Rec: 0.0257	E: 0.0017	R: 0.0005	P: 0.0508
# [3/4][1975/2225][Time 2.88]
# Unified LR across all optimizers: 0.00013427958663930363
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0006	Gen: 0.0269	Rec: 0.0271	E: 0.0005	R: 0.0007	P: 0.0534
# [3/4][2025/2225][Time 2.90]
# Unified LR across all optimizers: 0.00013397075216009928
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0020	Gen: 0.0336	Rec: 0.0327	E: 0.0029	R: 0.0011	P: 0.0644
# [3/4][2075/2225][Time 2.93]
# Unified LR across all optimizers: 0.00013366262798048648
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0018	Gen: 0.0276	Rec: 0.0274	E: 0.0020	R: 0.0017	P: 0.0532
# [3/4][2125/2225][Time 2.92]
# Unified LR across all optimizers: 0.00013335521246682152
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0008	Gen: 0.0284	Rec: 0.0282	E: 0.0010	R: 0.0005	P: 0.0558
# [3/4][2175/2225][Time 2.84]
# Unified LR across all optimizers: 0.00013304850398921782
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0001	Gen: 0.0279	Rec: 0.0279	E: 0.0001	R: 0.0002	P: 0.0556

# %% [markdown]
# #### Data Loading and Synthetic Data Generation
#
# This section deals with loading the unlabelled dataset, processing it through the trained model to create synthetic data. This data augmentation step is crucial for models that benefit from larger datasets, such as in fraud detection scenarios.

# %%
import torch
from tools.loader import collate_fn

batch_size = 64
len_trainset = len(trainset)
train_loader = torch.utils.data.DataLoader(dataset=trainset, batch_size=batch_size, collate_fn=collate_fn, shuffle=False)

# Initialize the recreated dataset container
recreated_training_data = None
recreated_labels = None

# Generate synthetic data through the model to augment the training dataset
with torch.no_grad():
    for data, _ in train_loader:
        data = data.to(device)
        # Generate a large amount of synthetic data
        explain = trainer_hub.core_ccnet.explain(data)
        
        generated_data, generated_condition = trainer_hub.core_ccnet.generate(explain)

        generated_data = generated_data.squeeze(1).clone().detach().cpu()
        generated_condition = generated_condition.squeeze(1).clone().detach().cpu()

        # Concatenate the processed batch to the main dataset
        if recreated_training_data is None:
            recreated_training_data = generated_data
            recreated_labels = generated_condition
        else:
            recreated_training_data = torch.cat([recreated_training_data, generated_data], dim=0)
            recreated_labels = torch.cat([recreated_labels, generated_condition], dim=0)
        
        # Ensure we do not exceed the original trainset's size
        if len(recreated_training_data) >= len_trainset:
            recreated_training_data = recreated_training_data[:len_trainset]
            recreated_labels = recreated_labels[:len_trainset]
            break

print(f"Recreated Training Data Shape: {recreated_training_data.shape}")
print(f"Recreated Labels Shape: {recreated_labels.shape}")
# Out:
# Recreated Training Data Shape: torch.Size([142403, 30])
# Recreated Labels Shape: torch.Size([142403, 1])

# %% [markdown]
# #### Data Preparation for Model Training
#
# After synthetic data generation, this section separates the data and labels for training purposes, preparing them for use in machine learning models to ensure proper supervision and evaluation.

# %%
import torch

# Assuming recreated_dataset is a PyTorch tensor already available in your context
ccnet_recreated_dataset = LabeledDataset(recreated_training_data.numpy(), recreated_labels.numpy())

# Print the shapes of the datasets for verification
print(f"Labeled Original Trainset Shape: {len(trainset)}, {trainset.x.shape[1]}")
print(f"CCNet Recreated Dataset Shape: {len(ccnet_recreated_dataset)}, {ccnet_recreated_dataset.x.shape[1]}")

print(f"Labeled Original Testset Shape: {len(testset)}, {testset.x.shape[1]}")

# Retrieve number of features and classes from the recreated dataset
num_features = recreated_training_data.shape[1]
num_classes = recreated_labels.shape[1]

print(f"Number of Features: {num_features}")
print(f"Number of Classes: {num_classes}")
# Out:
# Labeled Original Trainset Shape: 142403, 30
# CCNet Recreated Dataset Shape: 142403, 30
# Labeled Original Testset Shape: 142404, 30
# Number of Features: 30
# Number of Classes: 1

# %%
class DNN(torch.nn.Module):
    def __init__(self, input_size, output_size, num_layers=4, hidden_size=256):
        super(DNN, self).__init__()
        self.input_size = input_size
        self.output_size = output_size
        self.hidden_size = hidden_size
        
        # Create a list to hold all layers
        layers = []
        
        # Input layer
        layers.append(torch.nn.Linear(input_size, hidden_size))
        layers.append(torch.nn.ReLU())
        
        # Hidden layers
        for _ in range(num_layers - 2):
            layers.append(torch.nn.Linear(hidden_size, hidden_size))
            layers.append(torch.nn.ReLU())
        
        # Output layer
        layers.append(torch.nn.Linear(hidden_size, output_size))
        
        # Register all layers
        self.layers = torch.nn.Sequential(*layers)

    def forward(self, x):
        x = self.layers(x)
        return torch.sigmoid(x)

# %% [markdown]
# #### Training Supervised Models
#
# This section outlines the process of training supervised learning models using both original and synthetic datasets. The `train_supervised_model` function is designed to iterate through the dataset, perform forward passes, compute loss, and update model weights using backpropagation.

# %%
def train_supervised_model(model, dataset):
    # Initialize the optimizer
    optimizer = torch.optim.Adam(model.parameters(), lr=0.0002)
    # Ensure reproducibility by resetting the random seed
    set_random_seed(0)
    # Create DataLoader for batch processing
    trainloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)
    
    # Training loop
    for epoch in range(4):  # Train for 2 epochs as an example
        for i, (data, label) in enumerate(trainloader):
            data = data.to(device).clone().detach()
            label = label.to(device)
            # Perform forward pass
            output = model(data)
            # Compute loss
            loss = torch.nn.functional.binary_cross_entropy(output, label)
            # Backward pass to compute gradients
            loss.backward()
            # Update weights
            optimizer.step()
            # Reset gradients
            optimizer.zero_grad()

# %% [markdown]
# #### Model Training Using Recreated and Original Datasets
#
# Models are trained using both datasets generated through the Data Augmentation process and the original dataset. This comparison helps to determine the effectiveness of the synthetic data in improving model performance.

# %%
# Initialize and train a model on the recreated dataset
model_trained_on_recreated = DNN(input_size=num_features, output_size=num_classes).to(device)
train_supervised_model(model_trained_on_recreated, ccnet_recreated_dataset)

# Initialize and train a model on the original dataset
model_trained_on_original = DNN(input_size=num_features, output_size=num_classes).to(device)
train_supervised_model(model_trained_on_original, trainset)

# %% [markdown]
# #### Evaluating Model Performance
#
# After training, the models are evaluated using the F1 score, a harmonic mean of precision and recall, which is particularly useful in the context of imbalanced datasets like fraud detection. This step is critical for assessing the quality of the models trained on different types of data.

# %%
from sklearn.metrics import f1_score

def get_f1_score(model, testset, batch_size=batch_size):
    model.eval()  # Set the model to evaluation mode
    y_true = []
    y_pred = []
    # DataLoader for testing
    test_loader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False)

    # No gradient computation needed during inference
    with torch.no_grad():
        for data, label in test_loader:
            data = data.to(device)
            label = label.to(device)
            output = model(data)
            # Process output for binary classification
            predicted = (output.squeeze() > 0.5).long()
            y_true.extend(label.squeeze().long().cpu().numpy())
            y_pred.extend(predicted.cpu().numpy())

    # Compute and return the F1 score
    score = f1_score(y_true, y_pred, average='binary')
    return score

# Calculate F1 scores for both models
f1_score_original = get_f1_score(model_trained_on_original, testset)
f1_score_recreated = get_f1_score(model_trained_on_recreated, testset)

# Output the results
print("F1 score of the supervised learning model trained on the original data: ", f1_score_original)
print("F1 score of the supervised learning model trained on the recreated data: ", f1_score_recreated)
# Out:
# F1 score of the supervised learning model trained on the original data:  0.7272727272727273
# F1 score of the supervised learning model trained on the recreated data:  0.018405797101449274
