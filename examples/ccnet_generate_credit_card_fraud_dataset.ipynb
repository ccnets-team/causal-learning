# %% [markdown]
# Author:
#
#         PARK, JunHo, junho@ccnets.org
#
#
#         KIM, JeongYoong, jeongyoong@ccnets.org
#
#     COPYRIGHT (c) 2024. CCNets. All Rights reserved.

# %% [markdown]
# # Credit Card Fraud Detection: Handling Imbalanced Dataset with CCNet
#
# ## Introduction
#
# This tutorial explores the use of a Cooperative Network (CCNet) to address challenges associated with imbalanced datasets in the domain of credit card fraud detection. By leveraging the power of data generation, we aim to enhance the diversity and volume of training data, thereby improving the robustness and accuracy of models designed to identify fraudulent transactions.
#
# ## Tutorial Goals
#
# The objectives of this tutorial are designed to guide you through the process of enhancing data quality and model performance:
#
# ### Dataset Recreation with CCNet
# - **Understand Data Augmentation**: Learn how encoding techniques can be used to generate synthetic data instances that closely mimic the characteristics of real-world fraudulent and non-fraudulent transactions.
# - **Impact on Model Training**: Assess how augmenting the dataset influences the training process and subsequently, the model's ability to generalize from training to real-world scenarios.
#
# ### Model Training and Evaluation
# - **Dual Model Training**: Train two distinct models to directly compare performance metrics:
#   - A model trained on the **original dataset**.
#   - A model trained on the **CCNet-augmented dataset**.
# - **Performance Metrics**: Use the F1 score, a critical measure for models operating on imbalanced datasets, to evaluate and compare the effectiveness of these models.
#
# ### Testing and Validation
# - **Independent Model Testing**: Conduct a thorough evaluation of both models using a standalone test set that was not involved in the training phase.
# - **Objective Analysis**: Critically analyze the outcomes to validate whether data augmentation through CCNet offers a tangible benefit in detecting credit card fraud.
#
# ## Conclusion
#
# By the end of this tutorial, participants will not only grasp the theoretical underpinnings of using synthetic data to combat data imbalance but also gain hands-on experience in applying these concepts through CCNet to potentially enhance model performance in fraud detection tasks.

# %%
import sys
path_append = "../"
sys.path.append(path_append)  # Go up one directory from where you are.

# %%
# https://fraud-detection-handbook.github.io/fraud-detection-handbook/Chapter_7_DeepLearning/FeedForwardNeuralNetworks.html
import pandas as pd 

dataroot = path_append + "../data/credit_card_fraud_detection/creditcard.csv"
df = pd.read_csv(dataroot)
df
# Out:
# c:\Users\CCNets-team\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# c:\Users\CCNets-team\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
print('No Frauds', round(df['Class'].value_counts()[0] / len(df) *100,2), '%of the dataset')
print('Frauds', round(df['Class'].value_counts()[1] / len(df) *100,2), '%of the dataset')
# Out:
# No Frauds 99.83 %of the dataset
# Frauds 0.17 %of the dataset

# %%
import torch
from sklearn.preprocessing import StandardScaler, RobustScaler
from torch.utils.data import Dataset

# Initialize scalers
standard_sc = StandardScaler()
robust_sc = RobustScaler()
# Scale 'Amount' and 'Time' columns separately
df['scaled_amount'] = robust_sc.fit_transform(df['Amount'].values.reshape(-1, 1))
df['scaled_time'] = robust_sc.fit_transform(df['Time'].values.reshape(-1, 1))

# Drop original 'Time' and 'Amount' columns
df.drop(['Time', 'Amount'], axis=1, inplace=True)

# Move the 'Class' column to the end
class_column = df.pop('Class')
df = pd.concat([df, class_column], axis=1)

# Scale the rest of the features (excluding the class column)
df.iloc[:, :-1] = standard_sc.fit_transform(df.iloc[:, :-1])

# Calculate the number of features and classes
n_features = len(df.iloc[:, :-1].columns)
n_classes = len(df.iloc[:, -1:].columns)

print(n_features, n_classes)
# Out:
# 30 1

# %%
df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -0.694242 -0.044075  1.672773  0.973366 -0.245117  0.347068  0.193679
# 1  0.608496  0.161176  0.109797  0.316523  0.043483 -0.061820 -0.063700
# 2 -0.693500 -0.811578  1.169468  0.268231 -0.364572  1.351454  0.639776
# 3 -0.493325 -0.112169  1.182516 -0.609727 -0.007469  0.936150  0.192071
# 4 -0.591330  0.531541  1.021412  0.284655 -0.295015  0.071999  0.479302
#
#          V8        V9       V10  ...       V22       V23       V24       V25  \
# 0  0.082637  0.331128  0.083386  ...  0.382854 -0.176911  0.110507  0.246585
# 1  0.071253 -0.232494 -0.153350  ... -0.880077  0.162201 -0.561131  0.320694
# 2  0.207373 -1.378675  0.190700  ...  1.063358  1.456320 -1.138092 -0.628537
# 3  0.316018 -1.262503 -0.050468  ...  0.007267 -0.304777 -1.941027  1.241904
# 4 -0.226510  0.744326  0.691625  ...  1.100011 -0.220123  0.233250 -0.395202
#
#         V26       V27       V28  scaled_amount  scaled_time  Class
# 0 -0.392170  0.330892 -0.063781       0.244964    -1.996583      0
# 1  0.261069 -0.022256  0.044608      -0.342475    -1.996583      0
# 2 -0.288447 -0.137137 -0.181021       1.160686    -1.996562      0
# 3 -0.460217  0.155396  0.186189       0.140534    -1.996562      0
# 4  1.041611  0.543620  0.651816      -0.073403    -1.996541      0
#
# [5 rows x 31 columns]

# %%
# Defining the labeled and unlabeled dataset classes
class LabeledDataset(Dataset):
    def __init__(self, x, y):
        self.x = x
        self.y = y
        
    def __len__(self):
        return len(self.x)

    def __getitem__(self, index):
        vals = torch.tensor(self.x[index], dtype=torch.float32)
        label = torch.tensor(self.y[index], dtype=torch.float32)
        return vals, label

# %% [markdown]
# #### Initial Setup and Model Configuration
#
# This section initializes the environment by setting a fixed random seed to ensure reproducibility of results. It imports necessary configurations and initializes model parameters with specific configurations. The model specified here is set to have no core model but uses a 'tabnet' encoder model for data processing, which is particularly tailored for structured or tabular data like credit card transactions.

# %%
from sklearn.model_selection import train_test_split

# Splitting the dataset into training and test sets for model evaluation
df_train, df_test = train_test_split(df, test_size=0.5, shuffle=False)
X_train, y_train = df_train.iloc[:, :-1].values, df_train.iloc[:, -1:].values
X_test, y_test = df_test.iloc[:, :-1].values, df_test.iloc[:, -1:].values

# Labeled datasets for supervised learning tasks
trainset = LabeledDataset(X_train, y_train)  # Corrected to include training data
testset = LabeledDataset(X_test, y_test)     # Test set with proper labels

# Printing the shapes of the datasets for verification
print(f"Labeled Trainset Shape: {len(trainset)}, {trainset.x.shape[1]}")
print(f"Labeled Testset Shape: {len(testset)}, {testset.x.shape[1]}")
# Out:
# Labeled Trainset Shape: 142403, 30
# Labeled Testset Shape: 142404, 30

# %%
# Set a fixed random seed for reproducibility of experiments
from nn.utils.init import set_random_seed
set_random_seed(0)

# Importing configuration setups for ML parameters and data
import torch
from tools.setting.ml_params import MLParameters
from tools.setting.data_config import DataConfig
from trainer_hub import TrainerHub

# Configuration for the data handling, defining dataset specifics and the task type
data_config = DataConfig(dataset_name='CreditCardFraudDetection', task_type='binary_classification', obs_shape=[n_features], label_size=n_classes, explain_size=n_features - n_classes)

# Initializing ML parameters without a core model and setting the encoder model to 'tabnet' with specific configurations
ml_params = MLParameters(core_model='tabnet', encoder_model='none')

# Setting training parameters and device configuration
ml_params.training.num_epoch = 4
ml_params.model.core_config.num_layers = 4
ml_params.algorithm.error_function = 'mse'

device = torch.device("cuda" if torch.cuda.is_available() else "cpu") 

# Create a TrainerHub instance to manage training and data processing
trainer_hub = TrainerHub(ml_params, data_config, device, use_print=True, use_wandb=False)
# Out:
# c:\Users\CCNets-team\anaconda3\lib\site-packages\transformers\utils\generic.py:311: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(

# %% [markdown]
# #### Dataset Splitting for Training and Testing
#
# The original dataset is split into training and testing parts to evaluate the model's performance accurately. This step is crucial for validating the effectiveness of the training on unseen data.

# %%
trainer_hub.train(trainset)
# Out:
# Epochs:   0%|          | 0/4 [00:00<?, ?it/s]
# Iterations:   0%|          | 0/2225 [00:00<?, ?it/s]
# [0/4][50/2225][Time 6.51]
# Unified LR across all optimizers: 0.0001995308238189185
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.2261	Gen: 0.6369	Rec: 0.6479	E: 0.1258	R: 0.1979	P: 1.5804
# [0/4][100/2225][Time 6.06]
# Unified LR across all optimizers: 0.00019907191565870155
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0053	Gen: 0.2179	Rec: 0.2178	E: 0.0017	R: 0.0024	P: 0.3366
# [0/4][1850/2225][Time 5.69]
# Unified LR across all optimizers: 0.0001836580613356789
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0044	Gen: 0.2192	Rec: 0.2193	E: 0.0030	R: 0.0021	P: 0.3403
# [0/4][1900/2225][Time 6.09]
# Unified LR across all optimizers: 0.0001832356595161332
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0027	Gen: 0.2189	Rec: 0.2189	E: 0.0013	R: 0.0030	P: 0.4471
# [0/4][1950/2225][Time 5.91]
# Unified LR across all optimizers: 0.00018281422919381367
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0032	Gen: 0.2068	Rec: 0.2066	E: 0.0017	R: 0.0007	P: 0.2892
# [0/4][2000/2225][Time 6.18]
# Unified LR across all optimizers: 0.00018239376813433867
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0043	Gen: 0.2140	Rec: 0.2140	E: 0.0008	R: 0.0013	P: 0.2935
# [0/4][2050/2225][Time 6.28]
# Unified LR across all optimizers: 0.00018197427410846564
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0030	Gen: 0.2136	Rec: 0.2130	E: 0.0050	R: 0.0005	P: 0.3701
# [0/4][2100/2225][Time 6.09]
# Unified LR across all optimizers: 0.00018155574489207887
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0021	Gen: 0.2129	Rec: 0.2129	E: 0.0005	R: 0.0003	P: 0.3601
# [0/4][2150/2225][Time 6.03]
# Unified LR across all optimizers: 0.00018113817826617823
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0061	Gen: 0.2087	Rec: 0.2078	E: 0.0043	R: 0.0020	P: 0.2802
# [0/4][2200/2225][Time 5.93]
# Unified LR across all optimizers: 0.00018072157201686696
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0056	Gen: 0.2225	Rec: 0.2212	E: 0.0129	R: 0.0012	P: 0.3131
# Iterations:   0%|          | 0/2225 [00:00<?, ?it/s]
# [1/4][25/2225][Time 6.05]
# Unified LR across all optimizers: 0.00018030592393534033
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0075	Gen: 0.2373	Rec: 0.2371	E: 0.0028	R: 0.0020	P: 0.3762
# [1/4][75/2225][Time 6.28]
# Unified LR across all optimizers: 0.0001798912318178735
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0091	Gen: 0.2325	Rec: 0.2320	E: 0.0043	R: 0.0026	P: 0.3323
# [1/4][125/2225][Time 6.20]
# Unified LR across all optimizers: 0.00017947749346581006
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0063	Gen: 0.2182	Rec: 0.2185	E: 0.0015	R: 0.0029	P: 0.3660
# [1/4][175/2225][Time 6.01]
# Unified LR across all optimizers: 0.0001790647066855505
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0072	Gen: 0.2145	Rec: 0.2152	E: 0.0029	R: 0.0090	P: 0.3466
# [1/4][225/2225][Time 6.20]
# Unified LR across all optimizers: 0.00017865286928854052
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0067	Gen: 0.2069	Rec: 0.2078	E: 0.0010	R: 0.0057	P: 0.3826
# [1/4][275/2225][Time 6.09]
# Unified LR across all optimizers: 0.00017824197909125899
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0047	Gen: 0.2019	Rec: 0.2016	E: 0.0013	R: 0.0008	P: 0.3084
# [1/4][325/2225][Time 6.63]
# Unified LR across all optimizers: 0.00017783203391520723
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0039	Gen: 0.1953	Rec: 0.1952	E: 0.0004	R: 0.0007	P: 0.2312
# [1/4][375/2225][Time 5.94]
# Unified LR across all optimizers: 0.00017742303158689668
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0056	Gen: 0.1963	Rec: 0.1959	E: 0.0022	R: 0.0009	P: 0.2690
# [1/4][425/2225][Time 6.53]
# Unified LR across all optimizers: 0.00017701496993783762
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0027	Gen: 0.1841	Rec: 0.1833	E: 0.0056	R: 0.0001	P: 0.2044
# [1/4][1325/2225][Time 5.71]
# Unified LR across all optimizers: 0.0001698282739461345
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0043	Gen: 0.1827	Rec: 0.1827	E: 0.0012	R: 0.0013	P: 0.2169
# [1/4][1375/2225][Time 5.98]
# Unified LR across all optimizers: 0.00016943767975493242
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0043	Gen: 0.1844	Rec: 0.1845	E: 0.0013	R: 0.0022	P: 0.2315
# [1/4][1425/2225][Time 6.11]
# Unified LR across all optimizers: 0.0001690479839054414
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0031	Gen: 0.1801	Rec: 0.1808	E: 0.0002	R: 0.0033	P: 0.2391
# [1/4][1475/2225][Time 5.80]
# Unified LR across all optimizers: 0.00016865918433153277
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0047	Gen: 0.1781	Rec: 0.1782	E: 0.0007	R: 0.0030	P: 0.2759
# [1/4][1525/2225][Time 5.81]
# Unified LR across all optimizers: 0.00016827127897182985
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0036	Gen: 0.1777	Rec: 0.1780	E: 0.0006	R: 0.0024	P: 0.2334
# [1/4][1575/2225][Time 5.62]
# Unified LR across all optimizers: 0.0001678842657696972
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0047	Gen: 0.1765	Rec: 0.1762	E: 0.0019	R: 0.0017	P: 0.2495
# [1/4][1625/2225][Time 5.64]
# Unified LR across all optimizers: 0.00016749814267322938
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0062	Gen: 0.1888	Rec: 0.1874	E: 0.0076	R: 0.0012	P: 0.3399
# [1/4][1675/2225][Time 6.07]
# Unified LR across all optimizers: 0.00016711290763524007
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0047	Gen: 0.1867	Rec: 0.1873	E: 0.0013	R: 0.0081	P: 0.2540
# [1/4][1725/2225][Time 5.70]
# Unified LR across all optimizers: 0.00016672855861325146
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0037	Gen: 0.1904	Rec: 0.1906	E: 0.0028	R: 0.0039	P: 0.3063
# [1/4][1775/2225][Time 5.65]
# Unified LR across all optimizers: 0.00016634509356948314
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0034	Gen: 0.1805	Rec: 0.1805	E: 0.0020	R: 0.0030	P: 0.2029
# [1/4][1825/2225][Time 5.79]
# Unified LR across all optimizers: 0.00016596251047084197
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0054	Gen: 0.1856	Rec: 0.1847	E: 0.0040	R: 0.0014	P: 0.2273
# [1/4][1875/2225][Time 5.98]
# Unified LR across all optimizers: 0.00016558080728890993
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0034	Gen: 0.1859	Rec: 0.1853	E: 0.0011	R: 0.0002	P: 0.2643
# [1/4][1925/2225][Time 5.94]
# Unified LR across all optimizers: 0.00016519998199993532
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0032	Gen: 0.1763	Rec: 0.1769	E: 0.0005	R: 0.0051	P: 0.2901
# [1/4][1975/2225][Time 5.88]
# Unified LR across all optimizers: 0.0001648200325848201
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0048	Gen: 0.1793	Rec: 0.1803	E: 0.0009	R: 0.0079	P: 0.2648
# [1/4][2025/2225][Time 5.67]
# Unified LR across all optimizers: 0.00016444095702911038
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0042	Gen: 0.1747	Rec: 0.1750	E: 0.0011	R: 0.0039	P: 0.2109
# [1/4][2075/2225][Time 6.68]
# Unified LR across all optimizers: 0.00016406275332298505
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0078	Gen: 0.1969	Rec: 0.1967	E: 0.0077	R: 0.0170	P: 0.2957
# [1/4][2125/2225][Time 6.18]
# Unified LR across all optimizers: 0.00016368541946124596
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0059	Gen: 0.1959	Rec: 0.1972	E: 0.0031	R: 0.0253	P: 0.3157
# [1/4][2175/2225][Time 6.10]
# Unified LR across all optimizers: 0.00016330895344330638
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0045	Gen: 0.1954	Rec: 0.1971	E: 0.0007	R: 0.0258	P: 0.2915
# Iterations:   0%|          | 0/2225 [00:00<?, ?it/s]
# [2/4][0/2225][Time 6.56]
# Unified LR across all optimizers: 0.00016293335327318117
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0051	Gen: 0.1943	Rec: 0.1946	E: 0.0028	R: 0.0037	P: 0.2856
# [2/4][50/2225][Time 6.11]
# Unified LR across all optimizers: 0.00016255861695947546
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0070	Gen: 0.1854	Rec: 0.1852	E: 0.0038	R: 0.0090	P: 0.2331
# [2/4][100/2225][Time 5.96]
# Unified LR across all optimizers: 0.00016218474251537463
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0025	Gen: 0.1903	Rec: 0.1899	E: 0.0011	R: 0.0003	P: 0.3145
# [2/4][150/2225][Time 5.65]
# Unified LR across all optimizers: 0.00016181172795863357
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0044	Gen: 0.1931	Rec: 0.1919	E: 0.0142	R: 0.0015	P: 0.2424
# [2/4][200/2225][Time 5.62]
# Unified LR across all optimizers: 0.0001614395713115662
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0049	Gen: 0.1970	Rec: 0.1970	E: 0.0182	R: 0.0118	P: 0.2606
# [2/4][250/2225][Time 6.17]
# Unified LR across all optimizers: 0.00016106827060103523
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0047	Gen: 0.2106	Rec: 0.2121	E: 0.0009	R: 0.0237	P: 0.2901
# [2/4][300/2225][Time 5.96]
# Unified LR across all optimizers: 0.00016069782385844109
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0089	Gen: 0.1970	Rec: 0.1991	E: 0.0064	R: 0.0486	P: 0.2703
# [2/4][350/2225][Time 5.69]
# Unified LR across all optimizers: 0.00016032822911971208
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0060	Gen: 0.1976	Rec: 0.1975	E: 0.0052	R: 0.0124	P: 0.2620
# [2/4][400/2225][Time 5.80]
# Unified LR across all optimizers: 0.0001599594844252937
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0070	Gen: 0.2087	Rec: 0.2078	E: 0.0045	R: 0.0016	P: 0.3703
# [2/4][450/2225][Time 6.56]
# Unified LR across all optimizers: 0.00015959158782013816
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0106	Gen: 0.1983	Rec: 0.2014	E: 0.0074	R: 0.0633	P: 0.2655
# [2/4][500/2225][Time 6.25]
# Unified LR across all optimizers: 0.00015922453735369438
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0090	Gen: 0.1976	Rec: 0.2001	E: 0.0054	R: 0.0403	P: 0.2674
# [2/4][550/2225][Time 6.22]
# Unified LR across all optimizers: 0.00015885833107989733
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0062	Gen: 0.1901	Rec: 0.1914	E: 0.0017	R: 0.0092	P: 0.2676
# [2/4][600/2225][Time 6.14]
# Unified LR across all optimizers: 0.00015849296705715778
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0023	Gen: 0.1855	Rec: 0.1861	E: 0.0007	R: 0.0031	P: 0.2913
# [2/4][650/2225][Time 6.38]
# Unified LR across all optimizers: 0.0001581284433483521
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0044	Gen: 0.1904	Rec: 0.1912	E: 0.0017	R: 0.0069	P: 0.2576
# [2/4][700/2225][Time 5.93]
# Unified LR across all optimizers: 0.00015776475802081183
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0063	Gen: 0.1898	Rec: 0.1913	E: 0.0072	R: 0.0216	P: 0.2578
# [2/4][750/2225][Time 5.89]
# Unified LR across all optimizers: 0.00015740190914631356
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0043	Gen: 0.2016	Rec: 0.2019	E: 0.0040	R: 0.0106	P: 0.5218
# [2/4][800/2225][Time 6.04]
# Unified LR across all optimizers: 0.0001570398948010687
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0079	Gen: 0.1946	Rec: 0.1970	E: 0.0040	R: 0.0328	P: 0.2555
# [2/4][850/2225][Time 6.00]
# Unified LR across all optimizers: 0.00015667871306571324
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0026	Gen: 0.2045	Rec: 0.2035	E: 0.0119	R: 0.0003	P: 0.4114
# [2/4][900/2225][Time 5.83]
# Unified LR across all optimizers: 0.00015631836202529756
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0043	Gen: 0.2026	Rec: 0.2011	E: 0.0088	R: 0.0002	P: 0.2830
# [2/4][950/2225][Time 5.82]
# Unified LR across all optimizers: 0.00015595883976927632
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0035	Gen: 0.1929	Rec: 0.1926	E: 0.0020	R: 0.0007	P: 0.2647
# [2/4][1000/2225][Time 5.70]
# Unified LR across all optimizers: 0.0001556001443914984
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0034	Gen: 0.1900	Rec: 0.1897	E: 0.0014	R: 0.0008	P: 0.2929
# [2/4][1050/2225][Time 6.30]
# Unified LR across all optimizers: 0.0001552422739901963
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0016	Gen: 0.1783	Rec: 0.1786	E: 0.0005	R: 0.0019	P: 0.2021
# [2/4][1100/2225][Time 5.98]
# Unified LR across all optimizers: 0.00015488522666797712
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0059	Gen: 0.1844	Rec: 0.1841	E: 0.0025	R: 0.0025	P: 0.2723
# [2/4][1150/2225][Time 5.62]
# Unified LR across all optimizers: 0.00015452900053181137
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0033	Gen: 0.1779	Rec: 0.1776	E: 0.0009	R: 0.0007	P: 0.2413
# [2/4][1200/2225][Time 5.80]
# Unified LR across all optimizers: 0.00015417359369302347
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0034	Gen: 0.1793	Rec: 0.1790	E: 0.0011	R: 0.0009	P: 0.2675
# [2/4][1250/2225][Time 5.78]
# Unified LR across all optimizers: 0.00015381900426728195
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0039	Gen: 0.1774	Rec: 0.1765	E: 0.0047	R: 0.0006	P: 0.2083
# [2/4][1300/2225][Time 5.91]
# Unified LR across all optimizers: 0.00015346523037458877
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0034	Gen: 0.1758	Rec: 0.1757	E: 0.0007	R: 0.0009	P: 0.1973
# [2/4][1350/2225][Time 5.85]
# Unified LR across all optimizers: 0.00015311227013926996
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0032	Gen: 0.1812	Rec: 0.1815	E: 0.0004	R: 0.0016	P: 0.2945
# [2/4][1400/2225][Time 5.64]
# Unified LR across all optimizers: 0.00015276012168996563
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0030	Gen: 0.1804	Rec: 0.1809	E: 0.0002	R: 0.0025	P: 0.2686
# [2/4][1450/2225][Time 5.84]
# Unified LR across all optimizers: 0.00015240878315961963
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0023	Gen: 0.1661	Rec: 0.1657	E: 0.0012	R: 0.0004	P: 0.1812
# [2/4][1500/2225][Time 5.76]
# Unified LR across all optimizers: 0.00015205825268547007
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0048	Gen: 0.1809	Rec: 0.1812	E: 0.0013	R: 0.0033	P: 0.2718
# [2/4][1550/2225][Time 5.68]
# Unified LR across all optimizers: 0.0001517085284090394
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0034	Gen: 0.1755	Rec: 0.1755	E: 0.0008	R: 0.0012	P: 0.2714
# [2/4][1600/2225][Time 5.80]
# Unified LR across all optimizers: 0.00015135960847612417
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0039	Gen: 0.1737	Rec: 0.1733	E: 0.0026	R: 0.0016	P: 0.2388
# [2/4][1650/2225][Time 5.81]
# Unified LR across all optimizers: 0.0001510114910367858
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0026	Gen: 0.1798	Rec: 0.1797	E: 0.0022	R: 0.0030	P: 0.2963
# [2/4][1700/2225][Time 5.77]
# Unified LR across all optimizers: 0.00015066417424534014
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0034	Gen: 0.1740	Rec: 0.1739	E: 0.0013	R: 0.0015	P: 0.2231
# [2/4][1750/2225][Time 5.81]
# Unified LR across all optimizers: 0.00015031765626034814
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0037	Gen: 0.1789	Rec: 0.1789	E: 0.0019	R: 0.0027	P: 0.2288
# [2/4][1800/2225][Time 5.64]
# Unified LR across all optimizers: 0.00014997193524460595
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0032	Gen: 0.1807	Rec: 0.1809	E: 0.0010	R: 0.0028	P: 0.3812
# [2/4][1850/2225][Time 5.75]
# Unified LR across all optimizers: 0.00014962700936513516
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0035	Gen: 0.1719	Rec: 0.1716	E: 0.0021	R: 0.0013	P: 0.2001
# [2/4][1900/2225][Time 6.03]
# Unified LR across all optimizers: 0.00014928287679317315
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0078	Gen: 0.1867	Rec: 0.1867	E: 0.0055	R: 0.0076	P: 0.3051
# [2/4][1950/2225][Time 5.76]
# Unified LR across all optimizers: 0.0001489395357041632
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0076	Gen: 0.1932	Rec: 0.1930	E: 0.0151	R: 0.0147	P: 0.3215
# [2/4][2000/2225][Time 5.89]
# Unified LR across all optimizers: 0.000148596984277745
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0059	Gen: 0.2008	Rec: 0.2011	E: 0.0082	R: 0.0136	P: 0.2965
# [2/4][2050/2225][Time 5.86]
# Unified LR across all optimizers: 0.0001482552206977451
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0026	Gen: 0.1883	Rec: 0.1892	E: 0.0002	R: 0.0056	P: 0.2914
# [2/4][2100/2225][Time 5.83]
# Unified LR across all optimizers: 0.00014791424315216693
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0054	Gen: 0.1855	Rec: 0.1867	E: 0.0060	R: 0.0168	P: 0.2379
# [2/4][2150/2225][Time 5.94]
# Unified LR across all optimizers: 0.00014757404983318153
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0041	Gen: 0.1979	Rec: 0.1968	E: 0.0059	R: 0.0009	P: 0.2831
# [2/4][2200/2225][Time 5.90]
# Unified LR across all optimizers: 0.00014723463893711783
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0075	Gen: 0.2015	Rec: 0.1997	E: 0.0356	R: 0.0039	P: 0.2882
# Iterations:   0%|          | 0/2225 [00:00<?, ?it/s]
# [3/4][25/2225][Time 5.81]
# Unified LR across all optimizers: 0.00014689600866445298
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0039	Gen: 0.2033	Rec: 0.2044	E: 0.0012	R: 0.0157	P: 0.3011
# [3/4][75/2225][Time 5.92]
# Unified LR across all optimizers: 0.00014655815721980301
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0036	Gen: 0.1933	Rec: 0.1943	E: 0.0016	R: 0.0226	P: 0.3067
# [3/4][125/2225][Time 5.77]
# Unified LR across all optimizers: 0.00014622108281191326
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0058	Gen: 0.1922	Rec: 0.1924	E: 0.0028	R: 0.0093	P: 0.2768
# [3/4][175/2225][Time 5.73]
# Unified LR across all optimizers: 0.00014588478365364866
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0055	Gen: 0.1956	Rec: 0.1950	E: 0.0078	R: 0.0036	P: 0.4234
# [3/4][225/2225][Time 6.04]
# Unified LR across all optimizers: 0.0001455492579619846
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0049	Gen: 0.2018	Rec: 0.2011	E: 0.0032	R: 0.0008	P: 0.2524
# [3/4][275/2225][Time 5.90]
# Unified LR across all optimizers: 0.00014521450395799725
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0085	Gen: 0.1966	Rec: 0.1969	E: 0.0288	R: 0.0218	P: 0.2606
# [3/4][325/2225][Time 5.84]
# Unified LR across all optimizers: 0.00014488051986685427
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0025	Gen: 0.1961	Rec: 0.1961	E: 0.0024	R: 0.0022	P: 0.2590
# [3/4][375/2225][Time 5.73]
# Unified LR across all optimizers: 0.00014454730391780514
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0077	Gen: 0.2014	Rec: 0.2003	E: 0.0235	R: 0.0039	P: 0.2914
# [3/4][425/2225][Time 5.65]
# Unified LR across all optimizers: 0.0001442148543441721
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0029	Gen: 0.2003	Rec: 0.2004	E: 0.0008	R: 0.0021	P: 0.3251
# [3/4][475/2225][Time 6.23]
# Unified LR across all optimizers: 0.00014388316938334075
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0037	Gen: 0.2033	Rec: 0.2020	E: 0.0169	R: 0.0011	P: 0.2731
# [3/4][525/2225][Time 6.53]
# Unified LR across all optimizers: 0.0001435522472767503
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0057	Gen: 0.2013	Rec: 0.2013	E: 0.0066	R: 0.0128	P: 0.3536
# [3/4][575/2225][Time 6.33]
# Unified LR across all optimizers: 0.00014322208626988471
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0072	Gen: 0.2045	Rec: 0.2034	E: 0.0173	R: 0.0036	P: 0.3371
# [3/4][625/2225][Time 6.15]
# Unified LR across all optimizers: 0.00014289268461226322
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0062	Gen: 0.2065	Rec: 0.2065	E: 0.0027	R: 0.0045	P: 0.3100
# [3/4][675/2225][Time 6.21]
# Unified LR across all optimizers: 0.00014256404055743098
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0043	Gen: 0.1903	Rec: 0.1910	E: 0.0033	R: 0.0139	P: 0.2365
# [3/4][725/2225][Time 6.30]
# Unified LR across all optimizers: 0.00014223615236295
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0049	Gen: 0.1858	Rec: 0.1860	E: 0.0035	R: 0.0065	P: 0.2074
# [3/4][775/2225][Time 6.21]
# Unified LR across all optimizers: 0.0001419090182903897
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0055	Gen: 0.1859	Rec: 0.1874	E: 0.0020	R: 0.0170	P: 0.2227
# [3/4][825/2225][Time 6.08]
# Unified LR across all optimizers: 0.00014158263660531755
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0129	Gen: 0.2000	Rec: 0.1997	E: 0.0358	R: 0.0271	P: 0.2811
# [3/4][875/2225][Time 6.33]
# Unified LR across all optimizers: 0.00014125700557729063
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0070	Gen: 0.2111	Rec: 0.2119	E: 0.0032	R: 0.0103	P: 0.3664
# [3/4][925/2225][Time 6.00]
# Unified LR across all optimizers: 0.00014093212347984557
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0070	Gen: 0.1937	Rec: 0.1945	E: 0.0069	R: 0.0105	P: 0.2438
# [3/4][975/2225][Time 5.98]
# Unified LR across all optimizers: 0.00014060798859048983
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0045	Gen: 0.1974	Rec: 0.1972	E: 0.0089	R: 0.0054	P: 0.2939
# [3/4][1025/2225][Time 6.01]
# Unified LR across all optimizers: 0.00014028459919069257
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0050	Gen: 0.1944	Rec: 0.1946	E: 0.0049	R: 0.0064	P: 0.2736
# [3/4][1075/2225][Time 5.87]
# Unified LR across all optimizers: 0.00013996195356587524
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0065	Gen: 0.1927	Rec: 0.1950	E: 0.0063	R: 0.0484	P: 0.4365
# [3/4][1125/2225][Time 5.94]
# Unified LR across all optimizers: 0.0001396400500054029
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0117	Gen: 0.2166	Rec: 0.2172	E: 0.0303	R: 0.0287	P: 0.3089
# [3/4][1175/2225][Time 5.80]
# Unified LR across all optimizers: 0.00013931888680257493
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0044	Gen: 0.2185	Rec: 0.2183	E: 0.0227	R: 0.0119	P: 0.3572
# [3/4][1225/2225][Time 5.99]
# Unified LR across all optimizers: 0.000138998462254616
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0000	Gen: 0.2007	Rec: 0.2007	E: 0.0000	R: 0.0000	P: 0.3584
# [3/4][1275/2225][Time 6.24]
# Unified LR across all optimizers: 0.00013867877466266706
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0033	Gen: 0.1968	Rec: 0.1967	E: 0.0139	R: 0.0089	P: 0.2713
# [3/4][1325/2225][Time 5.87]
# Unified LR across all optimizers: 0.00013835982233177638
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0117	Gen: 0.2088	Rec: 0.2102	E: 0.0162	R: 0.0354	P: 0.2837
# [3/4][1375/2225][Time 5.60]
# Unified LR across all optimizers: 0.0001380416035708904
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0039	Gen: 0.2197	Rec: 0.2210	E: 0.0027	R: 0.0186	P: 0.4225
# [3/4][1425/2225][Time 5.80]
# Unified LR across all optimizers: 0.00013772411669284496
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0091	Gen: 0.2097	Rec: 0.2109	E: 0.0158	R: 0.0534	P: 0.3249
# [3/4][1475/2225][Time 5.87]
# Unified LR across all optimizers: 0.00013740736001435612
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0033	Gen: 0.2098	Rec: 0.2089	E: 0.0031	R: 0.0003	P: 0.3688
# [3/4][1525/2225][Time 6.43]
# Unified LR across all optimizers: 0.0001370913318560116
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0043	Gen: 0.2009	Rec: 0.2005	E: 0.0014	R: 0.0011	P: 0.3566
# [3/4][1575/2225][Time 6.67]
# Unified LR across all optimizers: 0.00013677603054226164
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0092	Gen: 0.2106	Rec: 0.2123	E: 0.0141	R: 0.0363	P: 0.3721
# [3/4][1625/2225][Time 5.87]
# Unified LR across all optimizers: 0.00013646145440140986
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0121	Gen: 0.2216	Rec: 0.2194	E: 0.0519	R: 0.0200	P: 0.3258
# [3/4][1675/2225][Time 5.89]
# Unified LR across all optimizers: 0.000136147601765605
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0048	Gen: 0.2116	Rec: 0.2134	E: 0.0039	R: 0.0415	P: 0.3324
# [3/4][1725/2225][Time 5.71]
# Unified LR across all optimizers: 0.00013583447097083163
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0076	Gen: 0.2075	Rec: 0.2090	E: 0.0086	R: 0.0337	P: 0.3634
# [3/4][1775/2225][Time 5.92]
# Unified LR across all optimizers: 0.00013552206035690145
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0052	Gen: 0.2014	Rec: 0.2020	E: 0.0073	R: 0.0136	P: 0.3211
# [3/4][1825/2225][Time 6.05]
# Unified LR across all optimizers: 0.00013521036826744445
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0064	Gen: 0.2064	Rec: 0.2069	E: 0.0120	R: 0.0155	P: 0.3586
# [3/4][1875/2225][Time 5.84]
# Unified LR across all optimizers: 0.00013489939304990025
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0026	Gen: 0.2012	Rec: 0.2026	E: 0.0004	R: 0.0198	P: 0.3302
# [3/4][1925/2225][Time 5.70]
# Unified LR across all optimizers: 0.00013458913305550914
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0051	Gen: 0.1963	Rec: 0.1964	E: 0.0070	R: 0.0090	P: 0.2346
# [3/4][1975/2225][Time 5.68]
# Unified LR across all optimizers: 0.00013427958663930363
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0014	Gen: 0.1935	Rec: 0.1939	E: 0.0002	R: 0.0022	P: 0.3353
# [3/4][2025/2225][Time 5.84]
# Unified LR across all optimizers: 0.00013397075216009928
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0105	Gen: 0.2030	Rec: 0.2039	E: 0.0148	R: 0.0316	P: 0.3335
# [3/4][2075/2225][Time 6.15]
# Unified LR across all optimizers: 0.00013366262798048648
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0081	Gen: 0.1997	Rec: 0.2009	E: 0.0046	R: 0.0238	P: 0.3006
# [3/4][2125/2225][Time 5.76]
# Unified LR across all optimizers: 0.00013335521246682152
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0040	Gen: 0.1981	Rec: 0.1987	E: 0.0077	R: 0.0163	P: 0.3074
# [3/4][2175/2225][Time 5.70]
# Unified LR across all optimizers: 0.00013304850398921782
# --------------------Training Metrics--------------------
# Cooperative Network(core):  Three Tabnet
# Inf: 0.0015	Gen: 0.1921	Rec: 0.1930	E: 0.0002	R: 0.0120	P: 0.2751

# %% [markdown]
# #### Data Loading and Synthetic Data Generation
#
# This section deals with loading the unlabelled dataset, processing it through the trained model to create synthetic data. This data augmentation step is crucial for models that benefit from larger datasets, such as in fraud detection scenarios.

# %%
import torch
from tools.loader import collate_fn

len_trainset = len(trainset)
train_loader = torch.utils.data.DataLoader(dataset=trainset, batch_size=256, collate_fn=collate_fn, shuffle=False)

# Initialize the recreated dataset container
recreated_training_data = None
recreated_labels = None

# Generate synthetic data through the model to augment the training dataset
with torch.no_grad():
    for data, _ in train_loader:
        data = data.to(device)
        # Generate a large amount of synthetic data
        explain = trainer_hub.core_ccnet.explain(data)
        
        generated_data, generated_label = trainer_hub.core_ccnet.generate(explain)

        generated_data = generated_data.squeeze(1).detach().cpu()
        generated_label = generated_label.detach().cpu().argmax(dim=-1).unsqueeze(-1)

        # Concatenate the processed batch to the main dataset
        if recreated_training_data is None:
            recreated_training_data = generated_data
            recreated_labels = generated_label
        else:
            recreated_training_data = torch.cat([recreated_training_data, generated_data], dim=0)
            recreated_labels = torch.cat([recreated_labels, generated_label], dim=0)
        
        # Ensure we do not exceed the original trainset's size
        if len(recreated_training_data) >= len_trainset:
            recreated_training_data = recreated_training_data[:len_trainset]
            recreated_labels = recreated_labels[:len_trainset]
            break

print(f"Recreated Training Data Shape: {recreated_training_data.shape}")
print(f"Recreated Labels Shape: {recreated_labels.shape}")
# Out:
# Recreated Training Data Shape: torch.Size([142403, 30])
# Recreated Labels Shape: torch.Size([142403, 1])

# %% [markdown]
# #### Data Preparation for Model Training
#
# After synthetic data generation, this section separates the data and labels for training purposes, preparing them for use in machine learning models to ensure proper supervision and evaluation.

# %%
import torch

# Assuming recreated_dataset is a PyTorch tensor already available in your context
ccnet_recreated_dataset = LabeledDataset(recreated_training_data.numpy(), recreated_labels.numpy())

# Print the shapes of the datasets for verification
print(f"Labeled Original Trainset Shape: {len(trainset)}, {trainset.x.shape[1]}")
print(f"CCNet Recreated Dataset Shape: {len(ccnet_recreated_dataset)}, {ccnet_recreated_dataset.x.shape[1]}")

print(f"Labeled Original Testset Shape: {len(testset)}, {testset.x.shape[1]}")

# Retrieve number of features and classes from the recreated dataset
num_features = recreated_training_data.shape[1]
num_classes = recreated_labels.shape[1]

print(f"Number of Features: {num_features}")
print(f"Number of Classes: {num_classes}")
# Out:
# Labeled Original Trainset Shape: 142403, 30
# CCNet Recreated Dataset Shape: 142403, 30
# Labeled Original Testset Shape: 142404, 30
# Number of Features: 30
# Number of Classes: 1

# %%
class DNN(torch.nn.Module):
    def __init__(self, input_size, output_size, num_layers=4, hidden_size=256):
        super(DNN, self).__init__()
        self.input_size = input_size
        self.output_size = output_size
        self.hidden_size = hidden_size
        
        # Create a list to hold all layers
        layers = []
        
        # Input layer
        layers.append(torch.nn.Linear(input_size, hidden_size))
        layers.append(torch.nn.ReLU())
        
        # Hidden layers
        for _ in range(num_layers - 2):
            layers.append(torch.nn.Linear(hidden_size, hidden_size))
            layers.append(torch.nn.ReLU())
        
        # Output layer
        layers.append(torch.nn.Linear(hidden_size, output_size))
        
        # Register all layers
        self.layers = torch.nn.Sequential(*layers)

    def forward(self, x):
        x = self.layers(x)
        return torch.sigmoid(x)

# %% [markdown]
# #### Training Supervised Models
#
# This section outlines the process of training supervised learning models using both original and synthetic datasets. The `train_supervised_model` function is designed to iterate through the dataset, perform forward passes, compute loss, and update model weights using backpropagation.

# %%
def train_supervised_model(model, dataset, num_epoch=5):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu") 
    # Initialize the optimizer
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    # Ensure reproducibility by resetting the random seed
    # Create DataLoader for batch processing
    trainloader = torch.utils.data.DataLoader(dataset, batch_size=64, shuffle=True)
    # Training loop
    for epoch in range(num_epoch):  # Train for 2 epochs as an example
        for i, (data, label) in enumerate(trainloader):
            data = data.to(device).clone().detach()
            label = label.to(device).float()
            # Perform forward pass
            output = model(data)
            # Compute loss
            loss = torch.nn.functional.binary_cross_entropy(output, label)
            # Backward pass to compute gradients
            loss.backward()
            # Update weights
            optimizer.step()
            # Reset gradients
            optimizer.zero_grad()

# %% [markdown]
# #### Model Training Using Recreated and Original Datasets
#
# Models are trained using both datasets generated through the Data Augmentation process and the original dataset. This comparison helps to determine the effectiveness of the synthetic data in improving model performance.

# %%
# Initialize and train a model on the recreated dataset
model_trained_on_recreated = DNN(input_size=num_features, output_size=num_classes).to(device)
train_supervised_model(model_trained_on_recreated, ccnet_recreated_dataset)

# Initialize and train a model on the original dataset
model_trained_on_original = DNN(input_size=num_features, output_size=num_classes).to(device)
train_supervised_model(model_trained_on_original, trainset)

# %% [markdown]
# #### Evaluating Model Performance
#
# After training, the models are evaluated using the F1 score, a harmonic mean of precision and recall, which is particularly useful in the context of imbalanced datasets like fraud detection. This step is critical for assessing the quality of the models trained on different types of data.

# %%
from sklearn.metrics import f1_score

def get_f1_score(model, testset, batch_size=256):
    model.eval()  # Set the model to evaluation mode
    y_true = []
    y_pred = []
    # DataLoader for testing
    test_loader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False)

    # No gradient computation needed during inference
    with torch.no_grad():
        for data, label in test_loader:
            data = data.to(device)
            label = label.to(device)
            output = model(data)
            # Process output for binary classification
            predicted = (output.squeeze() > 0.5).long()
            y_true.extend(label.squeeze().long().cpu().numpy())
            y_pred.extend(predicted.cpu().numpy())

    # Compute and return the F1 score
    score = f1_score(y_true, y_pred, average='binary')
    return score

# Calculate F1 scores for both models
f1_score_original = get_f1_score(model_trained_on_original, testset)
f1_score_recreated = get_f1_score(model_trained_on_recreated, testset)

# Output the results
print("F1 score of the supervised learning model trained on the original data: ", f1_score_original)
print("F1 score of the supervised learning model trained on the recreated data: ", f1_score_recreated)
# Out:
# F1 score of the supervised learning model trained on the original data:  0.6382978723404256
# F1 score of the supervised learning model trained on the recreated data:  0.7573696145124716
