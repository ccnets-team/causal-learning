# %% [markdown]
# Author:
#
#         KIM, JeongYoong, jeongyoong@ccnets.org
#
#     COPYRIGHT (c) 2024. CCNets. All Rights reserved.

# %% [markdown]
# # Airline Passenger Satisfaction Classification
#
# https://www.kaggle.com/datasets/teejmahal20/airline-passenger-satisfaction/data
#
#
# <p>
#     <img src="https://www.travelandleisure.com/thmb/h97kSvljd2QYH2nUy3Y9ZNgO_pw=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/plane-data-BUSYROUTES1217-f4f84b08d47f4951b11c148cee2c3dea.jpg" width=600>
# </p>

# %% [markdown]
# ## 1. Load Libraries

# %%
import os
import sys
import warnings
warnings.filterwarnings("ignore")

path_append = "../"
sys.path.append(path_append)  # Go up one directory from where you are.

# %%
import torch
import pandas as pd

# %% [markdown]
# ## 2. Load  Dataset

# %%
df = pd.read_csv(path_append + '../data/Airline Customer Satisfaction/Airline_customer_satisfaction.csv')
df.head()
# Out:
#   satisfaction   Customer Type  Age   Type of Travel     Class  \
# 0    satisfied  Loyal Customer   65  Personal Travel       Eco
# 1    satisfied  Loyal Customer   47  Personal Travel  Business
# 2    satisfied  Loyal Customer   15  Personal Travel       Eco
# 3    satisfied  Loyal Customer   60  Personal Travel       Eco
# 4    satisfied  Loyal Customer   70  Personal Travel       Eco
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0              265             0                                  0
# 1             2464             0                                  0
# 2             2138             0                                  0
# 3              623             0                                  0
# 4              354             0                                  0
#
#    Food and drink  Gate location  ...  Online support  Ease of Online booking  \
# 0               0              2  ...               2                       3
# 1               0              3  ...               2                       3
# 2               0              3  ...               2                       2
# 3               0              3  ...               3                       1
# 4               0              3  ...               4                       2
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 3                 0                 3                5
# 1                 4                 4                 4                2
# 2                 3                 3                 4                4
# 3                 1                 0                 1                4
# 4                 2                 0                 2                4
#
#    Cleanliness  Online boarding  Departure Delay in Minutes  \
# 0            3                2                           0
# 1            3                2                         310
# 2            4                2                           0
# 3            1                3                           0
# 4            2                5                           0
#
#    Arrival Delay in Minutes
# 0                       0.0
# 1                     305.0
# 2                       0.0
# 3                       0.0
# 4                       0.0
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   satisfaction                       129880 non-null  object
#  1   Customer Type                      129880 non-null  object
#  2   Age                                129880 non-null  int64
#  3   Type of Travel                     129880 non-null  object
#  4   Class                              129880 non-null  object
#  5   Flight Distance                    129880 non-null  int64
#  6   Seat comfort                       129880 non-null  int64
#  7   Departure/Arrival time convenient  129880 non-null  int64
#  8   Food and drink                     129880 non-null  int64
#  9   Gate location                      129880 non-null  int64
#  10  Inflight wifi service              129880 non-null  int64
#  11  Inflight entertainment             129880 non-null  int64
#  12  Online support                     129880 non-null  int64
#  13  Ease of Online booking             129880 non-null  int64
#  14  On-board service                   129880 non-null  int64
#  15  Leg room service                   129880 non-null  int64
#  16  Baggage handling                   129880 non-null  int64
#  17  Checkin service                    129880 non-null  int64
#  18  Cleanliness                        129880 non-null  int64
#  19  Online boarding                    129880 non-null  int64
#  20  Departure Delay in Minutes         129880 non-null  int64
#  21  Arrival Delay in Minutes           129487 non-null  float64
# dtypes: float64(1), int64(17), object(4)
# memory usage: 21.8+ MB

# %%
# Check labels count
df[['satisfaction']].value_counts()
# Out:
# satisfaction
# satisfied       71087
# dissatisfied    58793
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Preprocessing

# %%
# Check for missing values amd drop 
df_subset = df.dropna(axis=0).reset_index(drop = True)

# %%
# Label encoding
df_subset['Class'] = df_subset['Class'].map({"Business": 3, "Eco Plus": 2, "Eco": 1}) 
df_subset['satisfaction'] = df_subset['satisfaction'].map({"satisfied": 1,  "dissatisfied": 0})

# One hot encoding
df_subset = pd.get_dummies(df_subset, drop_first = True)

# %%
from sklearn.preprocessing import StandardScaler

# Standardize the features
sc = StandardScaler()
df_subset.iloc[:, 1:] = sc.fit_transform(df_subset.iloc[:, :-1])

n_features = len(df_subset.iloc[:, :-1].columns)
n_classes = len(df_subset.iloc[:, -1:].columns)

print(n_features, n_classes)
# Out:
# 21 1

# %%
df_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129487 entries, 0 to 129486
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   satisfaction                       129487 non-null  int64
#  1   Age                                129487 non-null  float64
#  2   Class                              129487 non-null  float64
#  3   Flight Distance                    129487 non-null  float64
#  4   Seat comfort                       129487 non-null  float64
#  5   Departure/Arrival time convenient  129487 non-null  float64
#  6   Food and drink                     129487 non-null  float64
#  7   Gate location                      129487 non-null  float64
#  8   Inflight wifi service              129487 non-null  float64
#  9   Inflight entertainment             129487 non-null  float64
#  10  Online support                     129487 non-null  float64
#  11  Ease of Online booking             129487 non-null  float64
#  12  On-board service                   129487 non-null  float64
#  13  Leg room service                   129487 non-null  float64
#  14  Baggage handling                   129487 non-null  float64
#  15  Checkin service                    129487 non-null  float64
#  16  Cleanliness                        129487 non-null  float64
#  17  Online boarding                    129487 non-null  float64
#  18  Departure Delay in Minutes         129487 non-null  float64
#  19  Arrival Delay in Minutes           129487 non-null  float64
#  20  Customer Type_disloyal Customer    129487 non-null  float64
#  21  Type of Travel_Personal Travel     129487 non-null  float64
# dtypes: float64(21), int64(1)
# memory usage: 21.7 MB

# %%
# Custom Dataset Class
class AirlineDataset(torch.utils.data.Dataset):
    def __init__(self, x, y):
        self.x = x
        self.y = y
        
    def __len__(self):
        return len(self.x)

    def __getitem__(self, index):
        vals = torch.tensor(self.x[index], dtype = torch.float32)
        label = torch.tensor(self.y[index], dtype= torch.float32)
        return vals, label

# %%
from sklearn.model_selection import train_test_split

# Split the data into train, validation and test sets
df_train, df_test = train_test_split(df_subset, test_size=0.2, shuffle=True, random_state=33)

df_train, df_val = train_test_split(df_train, test_size=0.25, shuffle=True, random_state=33)  # 0.25 * 0.8 = 0.2

X_train, y_train = df_train.iloc[:, 1:].values, df_train.iloc[:, :1].values
X_val, y_val = df_val.iloc[:, 1:].values, df_val.iloc[:, :1].values
X_test, y_test = df_test.iloc[:, 1:].values, df_test.iloc[:, :1].values

trainset = AirlineDataset(X_train, y_train)
valset = AirlineDataset(X_val, y_val)
testset = AirlineDataset(X_test, y_test)

print(f"Labeled Trainset Shape: {len(trainset)}, {trainset.x.shape[1]}")
print(f"Labeled Valset Shape: {len(valset)}, {valset.x.shape[1]}")
print(f"Labeled Testset Shape: {len(testset)}, {testset.x.shape[1]}")
# Out:
# Labeled Trainset Shape: 77691, 21
# Labeled Valset Shape: 25898, 21
# Labeled Testset Shape: 25898, 21

# %%
# Check the shape of the first element in the trainset
trainset[0][0].shape, trainset[0][1].shape # ( = obs_shape, label_shape)
# Out:
# (torch.Size([21]), torch.Size([1]))

# %% [markdown]
# # Training

# %%
from tools.setting.data_config import DataConfig
from tools.setting.ml_params import MLParameters
from trainer_hub import TrainerHub

# Set the data configuration
data_config = DataConfig(dataset_name = 'airline_satisfaction', task_type='binary_classification', obs_shape=[21], label_size=1)

#  Set the ML parameters
ml_params = MLParameters(core_model = 'gpt', encoder_model = 'none')

ml_params.num_epoch = 1
ml_params.optimization.decay_rate_100k = 0.01

# Set the device to GPU if available, else CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") 

# Initialize the TrainerHub class with the training configuration, data configuration, device, and use_print and use_wandb flags
trainer_hub = TrainerHub(ml_params, data_config, device, use_print=True, use_wandb=False, print_interval=30)

# %%
trainer_hub.train(trainset, valset)
# Out:
# Epochs:   0%|          | 0/1 [00:00<?, ?it/s]
# Iterations:   0%|          | 0/1213 [00:00<?, ?it/s]
# [0/1][5/1213][Time 0.90]
# Unified LR across all optimizers: 0.00019994474559179828
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.3877	Gen: 0.9916	Rec: 1.0403	E: 0.3390	R: 0.4364	P: 1.6442
# --------------------Test Metrics------------------------
# accuracy: 0.8945
# precision: 0.8640
# recall: 0.9153
# f1_score: 0.8889
#
# [0/1][10/1213][Time 0.59]
# Unified LR across all optimizers: 0.0001998987119127626
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.1997	Gen: 0.5263	Rec: 0.5377	E: 0.1883	R: 0.2111	P: 0.8643
# --------------------Test Metrics------------------------
# accuracy: 0.8359
# precision: 0.7550
# recall: 0.9580
# f1_score: 0.8444
#
# [0/1][15/1213][Time 0.58]
# Unified LR across all optimizers: 0.00019985268883215303
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0900	Gen: 0.4383	Rec: 0.4440	E: 0.0843	R: 0.0957	P: 0.7922
# --------------------Test Metrics------------------------
# accuracy: 0.8125
# precision: 0.7152
# recall: 0.9916
# f1_score: 0.8310
#
# [0/1][20/1213][Time 0.53]
# Unified LR across all optimizers: 0.0001998066763475294
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0399	Gen: 0.4109	Rec: 0.4145	E: 0.0363	R: 0.0435	P: 0.7855
# --------------------Test Metrics------------------------
# accuracy: 0.9492
# precision: 0.9071
# recall: 1.0000
# f1_score: 0.9513
#
# [0/1][25/1213][Time 0.53]
# Unified LR across all optimizers: 0.00019976067445645222
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0123	Gen: 0.3757	Rec: 0.3763	E: 0.0117	R: 0.0130	P: 0.7397
# --------------------Test Metrics------------------------
# accuracy: 0.9531
# precision: 0.9024
# recall: 1.0000
# f1_score: 0.9487
#
# [0/1][30/1213][Time 0.58]
# Unified LR across all optimizers: 0.0001997146831564825
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0146	Gen: 0.3474	Rec: 0.3479	E: 0.0141	R: 0.0151	P: 0.6807
# --------------------Test Metrics------------------------
# accuracy: 0.9727
# precision: 0.9352
# recall: 1.0000
# f1_score: 0.9665
#
# [0/1][35/1213][Time 0.61]
# Unified LR across all optimizers: 0.00019966870244518181
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0037	Gen: 0.3141	Rec: 0.3141	E: 0.0036	R: 0.0037	P: 0.6245
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][40/1213][Time 0.55]
# Unified LR across all optimizers: 0.00019962273232011234
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0023	Gen: 0.3108	Rec: 0.3108	E: 0.0023	R: 0.0023	P: 0.6193
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9915
# recall: 1.0000
# f1_score: 0.9957
#
# [0/1][45/1213][Time 0.60]
# Unified LR across all optimizers: 0.00019957677277883683
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0021	Gen: 0.2998	Rec: 0.3001	E: 0.0018	R: 0.0025	P: 0.5978
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][50/1213][Time 0.51]
# Unified LR across all optimizers: 0.0001995308238189185
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0021	Gen: 0.2786	Rec: 0.2787	E: 0.0021	R: 0.0022	P: 0.5551
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9913
# recall: 1.0000
# f1_score: 0.9956
#
# [0/1][55/1213][Time 0.55]
# Unified LR across all optimizers: 0.00019948488543792121
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0034	Gen: 0.2580	Rec: 0.2583	E: 0.0031	R: 0.0037	P: 0.5129
# --------------------Test Metrics------------------------
# accuracy: 0.9805
# precision: 0.9576
# recall: 1.0000
# f1_score: 0.9784
#
# [0/1][60/1213][Time 0.52]
# Unified LR across all optimizers: 0.0001994389576334093
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0042	Gen: 0.2603	Rec: 0.2606	E: 0.0040	R: 0.0045	P: 0.5166
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9912
# recall: 1.0000
# f1_score: 0.9956
#
# [0/1][65/1213][Time 0.53]
# Unified LR across all optimizers: 0.0001993930404029478
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0003	Gen: 0.2544	Rec: 0.2544	E: 0.0003	R: 0.0003	P: 0.5086
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][70/1213][Time 0.53]
# Unified LR across all optimizers: 0.0001993471337441022
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0023	Gen: 0.2423	Rec: 0.2422	E: 0.0025	R: 0.0021	P: 0.4822
# --------------------Test Metrics------------------------
# accuracy: 0.9922
# precision: 0.9831
# recall: 1.0000
# f1_score: 0.9915
#
# [0/1][75/1213][Time 0.53]
# Unified LR across all optimizers: 0.0001993012376544385
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0037	Gen: 0.2360	Rec: 0.2364	E: 0.0033	R: 0.0041	P: 0.4688
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][80/1213][Time 0.53]
# Unified LR across all optimizers: 0.00019925535213152345
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0018	Gen: 0.2346	Rec: 0.2346	E: 0.0018	R: 0.0018	P: 0.4674
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][85/1213][Time 0.54]
# Unified LR across all optimizers: 0.00019920947717292416
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0038	Gen: 0.2246	Rec: 0.2251	E: 0.0033	R: 0.0043	P: 0.4459
# --------------------Test Metrics------------------------
# accuracy: 0.9844
# precision: 0.9672
# recall: 1.0000
# f1_score: 0.9833
#
# [0/1][90/1213][Time 0.57]
# Unified LR across all optimizers: 0.00019916361277620847
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0048	Gen: 0.2184	Rec: 0.2201	E: 0.0031	R: 0.0065	P: 0.4337
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9907
# recall: 1.0000
# f1_score: 0.9953
#
# [0/1][95/1213][Time 0.53]
# Unified LR across all optimizers: 0.00019911775893894463
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0049	Gen: 0.2187	Rec: 0.2203	E: 0.0034	R: 0.0064	P: 0.4341
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][100/1213][Time 0.57]
# Unified LR across all optimizers: 0.00019907191565870155
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0041	Gen: 0.2073	Rec: 0.2080	E: 0.0034	R: 0.0047	P: 0.4112
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9922
# recall: 1.0000
# f1_score: 0.9961
#
# [0/1][105/1213][Time 0.50]
# Unified LR across all optimizers: 0.0001990260829330486
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0005	Gen: 0.2080	Rec: 0.2080	E: 0.0005	R: 0.0006	P: 0.4155
# --------------------Test Metrics------------------------
# accuracy: 0.9883
# precision: 0.9835
# recall: 0.9917
# f1_score: 0.9876
#
# [0/1][110/1213][Time 0.53]
# Unified LR across all optimizers: 0.00019898026075955587
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0001	Gen: 0.2028	Rec: 0.2028	E: 0.0001	R: 0.0002	P: 0.4055
# --------------------Test Metrics------------------------
# accuracy: 0.9844
# precision: 0.9636
# recall: 1.0000
# f1_score: 0.9815
#
# [0/1][115/1213][Time 0.57]
# Unified LR across all optimizers: 0.00019893444913579385
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0012	Gen: 0.2011	Rec: 0.2017	E: 0.0005	R: 0.0018	P: 0.4016
# --------------------Test Metrics------------------------
# accuracy: 0.9922
# precision: 0.9823
# recall: 1.0000
# f1_score: 0.9911
#
# [0/1][120/1213][Time 0.53]
# Unified LR across all optimizers: 0.00019888864805933367
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0011	Gen: 0.2078	Rec: 0.2082	E: 0.0008	R: 0.0015	P: 0.4149
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][125/1213][Time 0.48]
# Unified LR across all optimizers: 0.00019884285752774702
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0055	Gen: 0.2005	Rec: 0.2009	E: 0.0050	R: 0.0059	P: 0.3959
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 1.0000
# recall: 0.9915
# f1_score: 0.9957
#
# [0/1][130/1213][Time 0.52]
# Unified LR across all optimizers: 0.00019879707753860614
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0010	Gen: 0.1910	Rec: 0.1915	E: 0.0005	R: 0.0015	P: 0.3815
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][135/1213][Time 0.52]
# Unified LR across all optimizers: 0.0001987513080894838
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0018	Gen: 0.1950	Rec: 0.1959	E: 0.0010	R: 0.0027	P: 0.3890
# --------------------Test Metrics------------------------
# accuracy: 0.9922
# precision: 0.9915
# recall: 0.9915
# f1_score: 0.9915
#
# [0/1][140/1213][Time 0.58]
# Unified LR across all optimizers: 0.00019870554917795336
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0014	Gen: 0.1916	Rec: 0.1924	E: 0.0006	R: 0.0022	P: 0.3826
# --------------------Test Metrics------------------------
# accuracy: 0.9922
# precision: 0.9919
# recall: 0.9919
# f1_score: 0.9919
#
# [0/1][145/1213][Time 0.51]
# Unified LR across all optimizers: 0.0001986598008015887
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0032	Gen: 0.1889	Rec: 0.1902	E: 0.0020	R: 0.0045	P: 0.3759
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9914
# recall: 1.0000
# f1_score: 0.9957
#
# [0/1][150/1213][Time 0.57]
# Unified LR across all optimizers: 0.00019861406295796434
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0012	Gen: 0.2028	Rec: 0.2034	E: 0.0006	R: 0.0017	P: 0.4051
# --------------------Test Metrics------------------------
# accuracy: 0.9883
# precision: 0.9835
# recall: 0.9917
# f1_score: 0.9876
#
# [0/1][155/1213][Time 0.58]
# Unified LR across all optimizers: 0.00019856833564465526
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0036	Gen: 0.1904	Rec: 0.1913	E: 0.0027	R: 0.0045	P: 0.3781
# --------------------Test Metrics------------------------
# accuracy: 0.9844
# precision: 0.9677
# recall: 1.0000
# f1_score: 0.9836
#
# [0/1][160/1213][Time 0.60]
# Unified LR across all optimizers: 0.0001985226188592371
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0059	Gen: 0.1996	Rec: 0.2011	E: 0.0043	R: 0.0074	P: 0.3949
# --------------------Test Metrics------------------------
# accuracy: 0.9453
# precision: 0.9037
# recall: 0.9919
# f1_score: 0.9457
#
# [0/1][165/1213][Time 0.55]
# Unified LR across all optimizers: 0.00019847691259928596
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0105	Gen: 0.1924	Rec: 0.1966	E: 0.0063	R: 0.0146	P: 0.3785
# --------------------Test Metrics------------------------
# accuracy: 0.9805
# precision: 0.9597
# recall: 1.0000
# f1_score: 0.9794
#
# [0/1][170/1213][Time 0.57]
# Unified LR across all optimizers: 0.00019843121686237853
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0081	Gen: 0.1907	Rec: 0.1918	E: 0.0070	R: 0.0091	P: 0.3745
# --------------------Test Metrics------------------------
# accuracy: 0.9922
# precision: 0.9833
# recall: 1.0000
# f1_score: 0.9916
#
# [0/1][175/1213][Time 0.54]
# Unified LR across all optimizers: 0.00019838553164609206
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0030	Gen: 0.1857	Rec: 0.1864	E: 0.0023	R: 0.0037	P: 0.3691
# --------------------Test Metrics------------------------
# accuracy: 0.9805
# precision: 0.9688
# recall: 0.9920
# f1_score: 0.9802
#
# [0/1][180/1213][Time 0.55]
# Unified LR across all optimizers: 0.0001983398569480044
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0050	Gen: 0.1804	Rec: 0.1816	E: 0.0038	R: 0.0062	P: 0.3570
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9922
# recall: 1.0000
# f1_score: 0.9961
#
# [0/1][185/1213][Time 0.54]
# Unified LR across all optimizers: 0.00019829419276569393
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0055	Gen: 0.1789	Rec: 0.1811	E: 0.0033	R: 0.0076	P: 0.3545
# --------------------Test Metrics------------------------
# accuracy: 0.9883
# precision: 0.9758
# recall: 1.0000
# f1_score: 0.9878
#
# [0/1][190/1213][Time 0.52]
# Unified LR across all optimizers: 0.00019824853909673957
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0026	Gen: 0.1822	Rec: 0.1827	E: 0.0022	R: 0.0030	P: 0.3623
# --------------------Test Metrics------------------------
# accuracy: 0.9883
# precision: 0.9764
# recall: 1.0000
# f1_score: 0.9880
#
# [0/1][195/1213][Time 0.57]
# Unified LR across all optimizers: 0.00019820289593872078
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0042	Gen: 0.1808	Rec: 0.1820	E: 0.0030	R: 0.0054	P: 0.3586
# --------------------Test Metrics------------------------
# accuracy: 0.9883
# precision: 0.9741
# recall: 1.0000
# f1_score: 0.9869
#
# [0/1][200/1213][Time 0.58]
# Unified LR across all optimizers: 0.00019815726328921765
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0031	Gen: 0.1805	Rec: 0.1810	E: 0.0026	R: 0.0037	P: 0.3583
# --------------------Test Metrics------------------------
# accuracy: 0.9844
# precision: 0.9835
# recall: 0.9835
# f1_score: 0.9835
#
# [0/1][205/1213][Time 0.59]
# Unified LR across all optimizers: 0.00019811164114581076
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0049	Gen: 0.1745	Rec: 0.1761	E: 0.0033	R: 0.0065	P: 0.3457
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 1.0000
# recall: 0.9901
# f1_score: 0.9950
#
# [0/1][210/1213][Time 0.49]
# Unified LR across all optimizers: 0.00019806602950608128
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0043	Gen: 0.1638	Rec: 0.1661	E: 0.0020	R: 0.0066	P: 0.3256
# --------------------Test Metrics------------------------
# accuracy: 0.9844
# precision: 0.9854
# recall: 0.9854
# f1_score: 0.9854
#
# [0/1][215/1213][Time 0.57]
# Unified LR across all optimizers: 0.00019802042836761092
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0042	Gen: 0.1656	Rec: 0.1677	E: 0.0022	R: 0.0062	P: 0.3291
# --------------------Test Metrics------------------------
# accuracy: 0.9922
# precision: 0.9800
# recall: 1.0000
# f1_score: 0.9899
#
# [0/1][220/1213][Time 0.62]
# Unified LR across all optimizers: 0.00019797483772798194
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0047	Gen: 0.1731	Rec: 0.1743	E: 0.0035	R: 0.0059	P: 0.3426
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 1.0000
# recall: 0.9912
# f1_score: 0.9956
#
# [0/1][225/1213][Time 0.55]
# Unified LR across all optimizers: 0.0001979292575847772
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0047	Gen: 0.1735	Rec: 0.1747	E: 0.0034	R: 0.0059	P: 0.3435
# --------------------Test Metrics------------------------
# accuracy: 0.9883
# precision: 0.9915
# recall: 0.9832
# f1_score: 0.9873
#
# [0/1][230/1213][Time 0.51]
# Unified LR across all optimizers: 0.00019788368793558007
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0026	Gen: 0.1712	Rec: 0.1718	E: 0.0019	R: 0.0032	P: 0.3405
# --------------------Test Metrics------------------------
# accuracy: 0.9844
# precision: 0.9748
# recall: 0.9915
# f1_score: 0.9831
#
# [0/1][235/1213][Time 0.54]
# Unified LR across all optimizers: 0.0001978381287779745
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0020	Gen: 0.1661	Rec: 0.1668	E: 0.0013	R: 0.0027	P: 0.3309
# --------------------Test Metrics------------------------
# accuracy: 0.9844
# precision: 0.9661
# recall: 1.0000
# f1_score: 0.9828
#
# [0/1][240/1213][Time 0.57]
# Unified LR across all optimizers: 0.000197792580109545
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0006	Gen: 0.1657	Rec: 0.1654	E: 0.0009	R: 0.0004	P: 0.3305
# --------------------Test Metrics------------------------
# accuracy: 0.9883
# precision: 1.0000
# recall: 0.9754
# f1_score: 0.9876
#
# [0/1][245/1213][Time 0.50]
# Unified LR across all optimizers: 0.00019774704192787658
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0036	Gen: 0.1704	Rec: 0.1722	E: 0.0018	R: 0.0055	P: 0.3390
# --------------------Test Metrics------------------------
# accuracy: 0.9844
# precision: 0.9915
# recall: 0.9748
# f1_score: 0.9831
#
# [0/1][250/1213][Time 0.50]
# Unified LR across all optimizers: 0.00019770151423055492
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0035	Gen: 0.1624	Rec: 0.1645	E: 0.0014	R: 0.0056	P: 0.3235
# --------------------Test Metrics------------------------
# accuracy: 0.9688
# precision: 0.9907
# recall: 0.9386
# f1_score: 0.9640
#
# [0/1][255/1213][Time 0.54]
# Unified LR across all optimizers: 0.00019765599701516612
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0080	Gen: 0.1625	Rec: 0.1662	E: 0.0043	R: 0.0116	P: 0.3207
# --------------------Test Metrics------------------------
# accuracy: 0.9727
# precision: 0.9913
# recall: 0.9500
# f1_score: 0.9702
#
# [0/1][260/1213][Time 0.56]
# Unified LR across all optimizers: 0.00019761049027929698
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0047	Gen: 0.1654	Rec: 0.1675	E: 0.0025	R: 0.0069	P: 0.3282
# --------------------Test Metrics------------------------
# accuracy: 0.9766
# precision: 0.9915
# recall: 0.9587
# f1_score: 0.9748
#
# [0/1][265/1213][Time 0.56]
# Unified LR across all optimizers: 0.0001975649940205347
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0030	Gen: 0.1574	Rec: 0.1592	E: 0.0012	R: 0.0048	P: 0.3136
# --------------------Test Metrics------------------------
# accuracy: 0.9766
# precision: 1.0000
# recall: 0.9504
# f1_score: 0.9746
#
# [0/1][270/1213][Time 1.30]
# Unified LR across all optimizers: 0.00019751950823646716
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0014	Gen: 0.1642	Rec: 0.1651	E: 0.0004	R: 0.0023	P: 0.3280
# --------------------Test Metrics------------------------
# accuracy: 0.9922
# precision: 1.0000
# recall: 0.9832
# f1_score: 0.9915
#
# [0/1][275/1213][Time 1.28]
# Unified LR across all optimizers: 0.00019747403292468276
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0034	Gen: 0.1659	Rec: 0.1675	E: 0.0018	R: 0.0049	P: 0.3300
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9919
# recall: 1.0000
# f1_score: 0.9959
#
# [0/1][280/1213][Time 1.28]
# Unified LR across all optimizers: 0.00019742856808277042
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0017	Gen: 0.1612	Rec: 0.1614	E: 0.0015	R: 0.0018	P: 0.3209
# --------------------Test Metrics------------------------
# accuracy: 0.9922
# precision: 0.9832
# recall: 1.0000
# f1_score: 0.9915
#
# [0/1][285/1213][Time 1.27]
# Unified LR across all optimizers: 0.00019738311370831965
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0001	Gen: 0.1577	Rec: 0.1577	E: 0.0001	R: 0.0001	P: 0.3153
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9917
# recall: 1.0000
# f1_score: 0.9959
#
# [0/1][290/1213][Time 1.44]
# Unified LR across all optimizers: 0.0001973376697989205
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0032	Gen: 0.1615	Rec: 0.1635	E: 0.0012	R: 0.0052	P: 0.3217
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9916
# recall: 1.0000
# f1_score: 0.9958
#
# [0/1][295/1213][Time 1.27]
# Unified LR across all optimizers: 0.00019729223635216357
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0012	Gen: 0.1581	Rec: 0.1587	E: 0.0006	R: 0.0018	P: 0.3156
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9913
# recall: 1.0000
# f1_score: 0.9956
#
# [0/1][300/1213][Time 1.28]
# Unified LR across all optimizers: 0.00019724681336564005
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0027	Gen: 0.1553	Rec: 0.1568	E: 0.0011	R: 0.0042	P: 0.3094
# --------------------Test Metrics------------------------
# accuracy: 0.9922
# precision: 0.9910
# recall: 0.9910
# f1_score: 0.9910
#
# [0/1][305/1213][Time 1.24]
# Unified LR across all optimizers: 0.00019720140083694164
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0013	Gen: 0.1525	Rec: 0.1533	E: 0.0005	R: 0.0020	P: 0.3045
# --------------------Test Metrics------------------------
# accuracy: 0.9883
# precision: 0.9758
# recall: 1.0000
# f1_score: 0.9878
#
# [0/1][310/1213][Time 1.26]
# Unified LR across all optimizers: 0.0001971559987636606
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0025	Gen: 0.1544	Rec: 0.1557	E: 0.0012	R: 0.0038	P: 0.3076
# --------------------Test Metrics------------------------
# accuracy: 0.9922
# precision: 0.9912
# recall: 0.9912
# f1_score: 0.9912
#
# [0/1][315/1213][Time 1.40]
# Unified LR across all optimizers: 0.0001971106071433898
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0014	Gen: 0.1562	Rec: 0.1570	E: 0.0006	R: 0.0022	P: 0.3118
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 1.0000
# recall: 0.9920
# f1_score: 0.9960
#
# [0/1][320/1213][Time 1.29]
# Unified LR across all optimizers: 0.00019706522597372263
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0012	Gen: 0.1624	Rec: 0.1626	E: 0.0010	R: 0.0013	P: 0.3238
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][325/1213][Time 1.27]
# Unified LR across all optimizers: 0.000197019855252253
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0004	Gen: 0.1491	Rec: 0.1492	E: 0.0002	R: 0.0005	P: 0.2980
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][330/1213][Time 1.29]
# Unified LR across all optimizers: 0.00019697449497657537
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0016	Gen: 0.1595	Rec: 0.1595	E: 0.0016	R: 0.0016	P: 0.3174
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][335/1213][Time 1.26]
# Unified LR across all optimizers: 0.0001969291451442848
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0011	Gen: 0.1579	Rec: 0.1579	E: 0.0012	R: 0.0011	P: 0.3146
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][340/1213][Time 1.32]
# Unified LR across all optimizers: 0.00019688380575297695
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0006	Gen: 0.1572	Rec: 0.1575	E: 0.0003	R: 0.0009	P: 0.3140
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9922
# recall: 1.0000
# f1_score: 0.9961
#
# [0/1][345/1213][Time 1.41]
# Unified LR across all optimizers: 0.0001968384768002479
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0009	Gen: 0.1466	Rec: 0.1466	E: 0.0009	R: 0.0009	P: 0.2923
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][350/1213][Time 1.31]
# Unified LR across all optimizers: 0.00019679315828369438
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0008	Gen: 0.1498	Rec: 0.1502	E: 0.0004	R: 0.0013	P: 0.2992
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9916
# recall: 1.0000
# f1_score: 0.9958
#
# [0/1][355/1213][Time 1.36]
# Unified LR across all optimizers: 0.00019674785020091362
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0035	Gen: 0.1590	Rec: 0.1592	E: 0.0033	R: 0.0038	P: 0.3147
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9912
# recall: 1.0000
# f1_score: 0.9956
#
# [0/1][360/1213][Time 1.31]
# Unified LR across all optimizers: 0.0001967025525495035
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0015	Gen: 0.1538	Rec: 0.1544	E: 0.0009	R: 0.0021	P: 0.3067
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9916
# recall: 1.0000
# f1_score: 0.9958
#
# [0/1][365/1213][Time 1.27]
# Unified LR across all optimizers: 0.00019665726532706233
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0022	Gen: 0.1595	Rec: 0.1604	E: 0.0013	R: 0.0031	P: 0.3177
# --------------------Test Metrics------------------------
# accuracy: 0.9883
# precision: 0.9758
# recall: 1.0000
# f1_score: 0.9878
#
# [0/1][370/1213][Time 1.26]
# Unified LR across all optimizers: 0.00019661198853118903
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0013	Gen: 0.1548	Rec: 0.1551	E: 0.0010	R: 0.0016	P: 0.3085
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9904
# recall: 1.0000
# f1_score: 0.9952
#
# [0/1][375/1213][Time 1.29]
# Unified LR across all optimizers: 0.00019656672215948305
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0005	Gen: 0.1554	Rec: 0.1556	E: 0.0003	R: 0.0007	P: 0.3104
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9913
# recall: 1.0000
# f1_score: 0.9956
#
# [0/1][380/1213][Time 1.29]
# Unified LR across all optimizers: 0.00019652146620954448
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0008	Gen: 0.1466	Rec: 0.1471	E: 0.0002	R: 0.0013	P: 0.2929
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 1.0000
# recall: 0.9916
# f1_score: 0.9958
#
# [0/1][385/1213][Time 1.31]
# Unified LR across all optimizers: 0.00019647622067897388
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0007	Gen: 0.1464	Rec: 0.1466	E: 0.0005	R: 0.0010	P: 0.2922
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][390/1213][Time 1.29]
# Unified LR across all optimizers: 0.00019643098556537233
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0030	Gen: 0.1459	Rec: 0.1476	E: 0.0013	R: 0.0047	P: 0.2905
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][395/1213][Time 1.35]
# Unified LR across all optimizers: 0.00019638576086634154
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0017	Gen: 0.1532	Rec: 0.1538	E: 0.0010	R: 0.0024	P: 0.3053
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9900
# recall: 1.0000
# f1_score: 0.9950
#
# [0/1][400/1213][Time 1.39]
# Unified LR across all optimizers: 0.00019634054657948372
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1535	Rec: 0.1535	E: 0.0000	R: 0.0000	P: 0.3070
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][405/1213][Time 1.28]
# Unified LR across all optimizers: 0.0001962953427024017
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0016	Gen: 0.1424	Rec: 0.1429	E: 0.0012	R: 0.0021	P: 0.2837
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][410/1213][Time 1.30]
# Unified LR across all optimizers: 0.0001962501492326988
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0012	Gen: 0.1458	Rec: 0.1462	E: 0.0008	R: 0.0016	P: 0.2908
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][415/1213][Time 1.44]
# Unified LR across all optimizers: 0.00019620496616797885
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1460	Rec: 0.1460	E: 0.0000	R: 0.0000	P: 0.2920
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][420/1213][Time 1.24]
# Unified LR across all optimizers: 0.00019615979350584637
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0015	Gen: 0.1468	Rec: 0.1476	E: 0.0006	R: 0.0023	P: 0.2929
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9912
# recall: 1.0000
# f1_score: 0.9956
#
# [0/1][425/1213][Time 1.40]
# Unified LR across all optimizers: 0.00019611463124390632
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0019	Gen: 0.1406	Rec: 0.1418	E: 0.0007	R: 0.0031	P: 0.2805
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][430/1213][Time 1.24]
# Unified LR across all optimizers: 0.00019606947937976423
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1449	Rec: 0.1449	E: 0.0000	R: 0.0000	P: 0.2899
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9908
# recall: 1.0000
# f1_score: 0.9954
#
# [0/1][435/1213][Time 1.43]
# Unified LR across all optimizers: 0.00019602433791102622
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0008	Gen: 0.1435	Rec: 0.1438	E: 0.0005	R: 0.0011	P: 0.2865
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][440/1213][Time 0.62]
# Unified LR across all optimizers: 0.00019597920683529893
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0024	Gen: 0.1474	Rec: 0.1485	E: 0.0013	R: 0.0035	P: 0.2935
# --------------------Test Metrics------------------------
# accuracy: 0.9883
# precision: 0.9754
# recall: 1.0000
# f1_score: 0.9876
#
# [0/1][445/1213][Time 0.62]
# Unified LR across all optimizers: 0.00019593408615018956
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0012	Gen: 0.1436	Rec: 0.1441	E: 0.0007	R: 0.0017	P: 0.2866
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][450/1213][Time 0.58]
# Unified LR across all optimizers: 0.00019588897585330582
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0005	Gen: 0.1456	Rec: 0.1459	E: 0.0002	R: 0.0008	P: 0.2910
# --------------------Test Metrics------------------------
# accuracy: 0.9883
# precision: 0.9762
# recall: 1.0000
# f1_score: 0.9880
#
# [0/1][455/1213][Time 0.60]
# Unified LR across all optimizers: 0.00019584387594225605
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0013	Gen: 0.1415	Rec: 0.1423	E: 0.0005	R: 0.0021	P: 0.2825
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][460/1213][Time 0.59]
# Unified LR across all optimizers: 0.00019579878641464912
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0011	Gen: 0.1400	Rec: 0.1404	E: 0.0007	R: 0.0015	P: 0.2793
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][465/1213][Time 0.57]
# Unified LR across all optimizers: 0.00019575370726809439
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1419	Rec: 0.1419	E: 0.0000	R: 0.0000	P: 0.2838
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][470/1213][Time 0.60]
# Unified LR across all optimizers: 0.00019570863850020174
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0011	Gen: 0.1436	Rec: 0.1444	E: 0.0003	R: 0.0020	P: 0.2869
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 1.0000
# recall: 0.9912
# f1_score: 0.9956
#
# [0/1][475/1213][Time 0.63]
# Unified LR across all optimizers: 0.0001956635801085818
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1498	Rec: 0.1498	E: 0.0000	R: 0.0000	P: 0.2995
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][480/1213][Time 0.60]
# Unified LR across all optimizers: 0.00019561853209084553
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1420	Rec: 0.1420	E: 0.0000	R: 0.0000	P: 0.2839
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 1.0000
# recall: 0.9912
# f1_score: 0.9956
#
# [0/1][485/1213][Time 0.62]
# Unified LR across all optimizers: 0.00019557349444460458
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1388	Rec: 0.1388	E: 0.0000	R: 0.0000	P: 0.2775
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][490/1213][Time 0.64]
# Unified LR across all optimizers: 0.00019552846716747106
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0020	Gen: 0.1430	Rec: 0.1431	E: 0.0019	R: 0.0021	P: 0.2841
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][495/1213][Time 0.60]
# Unified LR across all optimizers: 0.00019548345025705772
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0022	Gen: 0.1409	Rec: 0.1419	E: 0.0012	R: 0.0032	P: 0.2806
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 1.0000
# recall: 0.9913
# f1_score: 0.9956
#
# [0/1][500/1213][Time 0.56]
# Unified LR across all optimizers: 0.00019543844371097777
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1400	Rec: 0.1400	E: 0.0000	R: 0.0000	P: 0.2801
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 1.0000
# recall: 0.9915
# f1_score: 0.9957
#
# [0/1][505/1213][Time 0.56]
# Unified LR across all optimizers: 0.00019539344752684504
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0006	Gen: 0.1409	Rec: 0.1412	E: 0.0003	R: 0.0009	P: 0.2815
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][510/1213][Time 0.58]
# Unified LR across all optimizers: 0.00019534846170227383
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0007	Gen: 0.1436	Rec: 0.1438	E: 0.0004	R: 0.0009	P: 0.2868
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][515/1213][Time 0.63]
# Unified LR across all optimizers: 0.00019530348623487907
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0015	Gen: 0.1402	Rec: 0.1408	E: 0.0009	R: 0.0021	P: 0.2795
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 1.0000
# recall: 0.9913
# f1_score: 0.9956
#
# [0/1][520/1213][Time 0.61]
# Unified LR across all optimizers: 0.00019525852112227618
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1358	Rec: 0.1358	E: 0.0000	R: 0.0000	P: 0.2715
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 1.0000
# recall: 0.9910
# f1_score: 0.9955
#
# [0/1][525/1213][Time 0.52]
# Unified LR across all optimizers: 0.00019521356636208122
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0020	Gen: 0.1338	Rec: 0.1346	E: 0.0012	R: 0.0027	P: 0.2664
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 1.0000
# recall: 0.9914
# f1_score: 0.9957
#
# [0/1][530/1213][Time 0.54]
# Unified LR across all optimizers: 0.00019516862195191064
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1413	Rec: 0.1413	E: 0.0000	R: 0.0000	P: 0.2826
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][535/1213][Time 0.60]
# Unified LR across all optimizers: 0.00019512368788938161
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1443	Rec: 0.1443	E: 0.0000	R: 0.0000	P: 0.2886
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][540/1213][Time 0.58]
# Unified LR across all optimizers: 0.00019507876417211177
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0010	Gen: 0.1422	Rec: 0.1428	E: 0.0004	R: 0.0017	P: 0.2839
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9917
# recall: 1.0000
# f1_score: 0.9958
#
# [0/1][545/1213][Time 0.54]
# Unified LR across all optimizers: 0.0001950338507977193
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0009	Gen: 0.1448	Rec: 0.1448	E: 0.0009	R: 0.0009	P: 0.2888
# --------------------Test Metrics------------------------
# accuracy: 0.9922
# precision: 0.9901
# recall: 0.9901
# f1_score: 0.9901
#
# [0/1][550/1213][Time 0.62]
# Unified LR across all optimizers: 0.00019498894776382288
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0005	Gen: 0.1432	Rec: 0.1434	E: 0.0003	R: 0.0008	P: 0.2860
# --------------------Test Metrics------------------------
# accuracy: 0.9922
# precision: 0.9820
# recall: 1.0000
# f1_score: 0.9909
#
# [0/1][555/1213][Time 0.55]
# Unified LR across all optimizers: 0.00019494405506804188
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1375	Rec: 0.1375	E: 0.0000	R: 0.0000	P: 0.2750
# --------------------Test Metrics------------------------
# accuracy: 0.9883
# precision: 0.9760
# recall: 1.0000
# f1_score: 0.9879
#
# [0/1][560/1213][Time 0.53]
# Unified LR across all optimizers: 0.0001948991727079961
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1363	Rec: 0.1363	E: 0.0000	R: 0.0000	P: 0.2725
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9921
# recall: 1.0000
# f1_score: 0.9960
#
# [0/1][565/1213][Time 0.61]
# Unified LR across all optimizers: 0.0001948543006813059
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1373	Rec: 0.1373	E: 0.0000	R: 0.0000	P: 0.2745
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][570/1213][Time 0.55]
# Unified LR across all optimizers: 0.00019480943898559223
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0017	Gen: 0.1361	Rec: 0.1364	E: 0.0014	R: 0.0020	P: 0.2707
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9915
# recall: 1.0000
# f1_score: 0.9957
#
# [0/1][575/1213][Time 0.58]
# Unified LR across all optimizers: 0.00019476458761847658
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1308	Rec: 0.1308	E: 0.0000	R: 0.0000	P: 0.2617
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][580/1213][Time 0.53]
# Unified LR across all optimizers: 0.00019471974657758097
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0015	Gen: 0.1380	Rec: 0.1383	E: 0.0013	R: 0.0018	P: 0.2747
# --------------------Test Metrics------------------------
# accuracy: 0.9922
# precision: 0.9817
# recall: 1.0000
# f1_score: 0.9907
#
# [0/1][585/1213][Time 0.62]
# Unified LR across all optimizers: 0.00019467491586052795
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0011	Gen: 0.1358	Rec: 0.1363	E: 0.0007	R: 0.0016	P: 0.2710
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9917
# recall: 1.0000
# f1_score: 0.9959
#
# [0/1][590/1213][Time 0.55]
# Unified LR across all optimizers: 0.0001946300954649407
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1390	Rec: 0.1390	E: 0.0000	R: 0.0000	P: 0.2780
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][595/1213][Time 0.58]
# Unified LR across all optimizers: 0.00019458528538844283
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1346	Rec: 0.1346	E: 0.0000	R: 0.0000	P: 0.2691
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][600/1213][Time 0.60]
# Unified LR across all optimizers: 0.00019454048562865856
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1363	Rec: 0.1363	E: 0.0000	R: 0.0000	P: 0.2726
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9922
# recall: 1.0000
# f1_score: 0.9961
#
# [0/1][605/1213][Time 0.65]
# Unified LR across all optimizers: 0.00019449569618321268
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0011	Gen: 0.1371	Rec: 0.1374	E: 0.0007	R: 0.0014	P: 0.2734
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9917
# recall: 1.0000
# f1_score: 0.9959
#
# [0/1][610/1213][Time 0.59]
# Unified LR across all optimizers: 0.0001944509170497305
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0006	Gen: 0.1342	Rec: 0.1345	E: 0.0003	R: 0.0010	P: 0.2681
# --------------------Test Metrics------------------------
# accuracy: 0.9883
# precision: 0.9730
# recall: 1.0000
# f1_score: 0.9863
#
# [0/1][615/1213][Time 0.64]
# Unified LR across all optimizers: 0.00019440614822583782
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1325	Rec: 0.1325	E: 0.0000	R: 0.0000	P: 0.2649
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9921
# recall: 1.0000
# f1_score: 0.9960
#
# [0/1][620/1213][Time 0.60]
# Unified LR across all optimizers: 0.00019436138970916112
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1315	Rec: 0.1315	E: 0.0000	R: 0.0000	P: 0.2630
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9915
# recall: 1.0000
# f1_score: 0.9957
#
# [0/1][625/1213][Time 0.63]
# Unified LR across all optimizers: 0.0001943166414973273
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0011	Gen: 0.1317	Rec: 0.1319	E: 0.0009	R: 0.0014	P: 0.2625
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9917
# recall: 1.0000
# f1_score: 0.9958
#
# [0/1][630/1213][Time 0.54]
# Unified LR across all optimizers: 0.00019427190358796388
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1297	Rec: 0.1297	E: 0.0000	R: 0.0000	P: 0.2593
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9912
# recall: 1.0000
# f1_score: 0.9956
#
# [0/1][635/1213][Time 0.59]
# Unified LR across all optimizers: 0.00019422717597869887
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0023	Gen: 0.1368	Rec: 0.1374	E: 0.0017	R: 0.0029	P: 0.2718
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][640/1213][Time 0.61]
# Unified LR across all optimizers: 0.0001941824586671609
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0017	Gen: 0.1336	Rec: 0.1343	E: 0.0010	R: 0.0025	P: 0.2662
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][645/1213][Time 0.53]
# Unified LR across all optimizers: 0.0001941377516509791
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1364	Rec: 0.1364	E: 0.0000	R: 0.0000	P: 0.2728
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][650/1213][Time 0.64]
# Unified LR across all optimizers: 0.00019409305492778308
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0008	Gen: 0.1358	Rec: 0.1358	E: 0.0008	R: 0.0007	P: 0.2708
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][655/1213][Time 0.60]
# Unified LR across all optimizers: 0.00019404836849520315
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1354	Rec: 0.1354	E: 0.0000	R: 0.0000	P: 0.2708
# --------------------Test Metrics------------------------
# accuracy: 0.9844
# precision: 1.0000
# recall: 0.9643
# f1_score: 0.9818
#
# [0/1][660/1213][Time 0.56]
# Unified LR across all optimizers: 0.00019400369235087007
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0012	Gen: 0.1346	Rec: 0.1355	E: 0.0003	R: 0.0021	P: 0.2688
# --------------------Test Metrics------------------------
# accuracy: 0.9922
# precision: 0.9916
# recall: 0.9916
# f1_score: 0.9916
#
# [0/1][665/1213][Time 0.56]
# Unified LR across all optimizers: 0.0001939590264924151
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1355	Rec: 0.1355	E: 0.0000	R: 0.0000	P: 0.2710
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][670/1213][Time 0.56]
# Unified LR across all optimizers: 0.00019391437091747016
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0009	Gen: 0.1429	Rec: 0.1432	E: 0.0007	R: 0.0012	P: 0.2852
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][675/1213][Time 0.53]
# Unified LR across all optimizers: 0.0001938697256236676
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0010	Gen: 0.1277	Rec: 0.1280	E: 0.0007	R: 0.0014	P: 0.2547
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9921
# recall: 1.0000
# f1_score: 0.9960
#
# [0/1][680/1213][Time 0.60]
# Unified LR across all optimizers: 0.0001938250906086404
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0011	Gen: 0.1334	Rec: 0.1340	E: 0.0005	R: 0.0017	P: 0.2663
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 1.0000
# recall: 0.9918
# f1_score: 0.9959
#
# [0/1][685/1213][Time 0.62]
# Unified LR across all optimizers: 0.0001937804658700221
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0010	Gen: 0.1328	Rec: 0.1328	E: 0.0010	R: 0.0011	P: 0.2645
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][690/1213][Time 0.51]
# Unified LR across all optimizers: 0.00019373585140544666
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0013	Gen: 0.1368	Rec: 0.1368	E: 0.0012	R: 0.0014	P: 0.2723
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 1.0000
# recall: 0.9918
# f1_score: 0.9959
#
# [0/1][695/1213][Time 0.55]
# Unified LR across all optimizers: 0.00019369124721254873
# --------------------Training Metrics--------------------
# Trainer:  gpt
# ...
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][985/1213][Time 0.59]
# Unified LR across all optimizers: 0.00019112169820366138
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1221	Rec: 0.1221	E: 0.0000	R: 0.0000	P: 0.2442
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][990/1213][Time 0.57]
# Unified LR across all optimizers: 0.00019107769587248824
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0008	Gen: 0.1211	Rec: 0.1217	E: 0.0003	R: 0.0014	P: 0.2419
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9924
# recall: 1.0000
# f1_score: 0.9962
#
# [0/1][995/1213][Time 0.60]
# Unified LR across all optimizers: 0.00019103370367205987
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0008	Gen: 0.1253	Rec: 0.1260	E: 0.0002	R: 0.0015	P: 0.2505
# --------------------Test Metrics------------------------
# accuracy: 0.9922
# precision: 0.9912
# recall: 0.9912
# f1_score: 0.9912
#
# [0/1][1000/1213][Time 0.57]
# Unified LR across all optimizers: 0.00019098972160004388
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0012	Gen: 0.1261	Rec: 0.1268	E: 0.0005	R: 0.0018	P: 0.2517
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 1.0000
# recall: 0.9916
# f1_score: 0.9958
#
# [0/1][1005/1213][Time 0.56]
# Unified LR across all optimizers: 0.00019094574965410838
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1261	Rec: 0.1261	E: 0.0000	R: 0.0000	P: 0.2521
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9914
# recall: 1.0000
# f1_score: 0.9957
#
# [0/1][1010/1213][Time 0.54]
# Unified LR across all optimizers: 0.000190901787831922
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0009	Gen: 0.1285	Rec: 0.1285	E: 0.0009	R: 0.0009	P: 0.2562
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][1015/1213][Time 0.53]
# Unified LR across all optimizers: 0.00019085783613115396
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1250	Rec: 0.1250	E: 0.0000	R: 0.0000	P: 0.2499
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][1020/1213][Time 0.60]
# Unified LR across all optimizers: 0.00019081389454947398
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1259	Rec: 0.1259	E: 0.0000	R: 0.0000	P: 0.2518
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][1025/1213][Time 0.53]
# Unified LR across all optimizers: 0.00019076996308455232
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1251	Rec: 0.1251	E: 0.0000	R: 0.0000	P: 0.2502
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9921
# recall: 1.0000
# f1_score: 0.9960
#
# [0/1][1030/1213][Time 0.61]
# Unified LR across all optimizers: 0.00019072604173405976
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1223	Rec: 0.1223	E: 0.0000	R: 0.0000	P: 0.2446
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][1035/1213][Time 0.54]
# Unified LR across all optimizers: 0.00019068213049566767
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1180	Rec: 0.1180	E: 0.0000	R: 0.0000	P: 0.2361
# --------------------Test Metrics------------------------
# accuracy: 0.9922
# precision: 1.0000
# recall: 0.9800
# f1_score: 0.9899
#
# [0/1][1040/1213][Time 0.62]
# Unified LR across all optimizers: 0.00019063822936704787
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1218	Rec: 0.1218	E: 0.0000	R: 0.0000	P: 0.2436
# --------------------Test Metrics------------------------
# accuracy: 0.9922
# precision: 0.9912
# recall: 0.9912
# f1_score: 0.9912
#
# [0/1][1045/1213][Time 0.55]
# Unified LR across all optimizers: 0.00019059433834587282
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0008	Gen: 0.1215	Rec: 0.1219	E: 0.0004	R: 0.0012	P: 0.2427
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9916
# recall: 1.0000
# f1_score: 0.9958
#
# [0/1][1050/1213][Time 0.61]
# Unified LR across all optimizers: 0.00019055045742981543
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0009	Gen: 0.1199	Rec: 0.1204	E: 0.0004	R: 0.0014	P: 0.2395
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][1055/1213][Time 0.64]
# Unified LR across all optimizers: 0.00019050658661654918
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0007	Gen: 0.1247	Rec: 0.1253	E: 0.0002	R: 0.0013	P: 0.2492
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][1060/1213][Time 0.58]
# Unified LR across all optimizers: 0.00019046272590374807
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0014	Gen: 0.1208	Rec: 0.1213	E: 0.0009	R: 0.0019	P: 0.2407
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][1065/1213][Time 0.51]
# Unified LR across all optimizers: 0.0001904188752890867
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1176	Rec: 0.1176	E: 0.0000	R: 0.0000	P: 0.2351
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9917
# recall: 1.0000
# f1_score: 0.9958
#
# [0/1][1070/1213][Time 0.64]
# Unified LR across all optimizers: 0.00019037503477024013
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0016	Gen: 0.1183	Rec: 0.1192	E: 0.0007	R: 0.0026	P: 0.2358
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][1075/1213][Time 0.55]
# Unified LR across all optimizers: 0.00019033120434488394
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1160	Rec: 0.1160	E: 0.0000	R: 0.0000	P: 0.2320
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 1.0000
# recall: 0.9916
# f1_score: 0.9958
#
# [0/1][1080/1213][Time 0.54]
# Unified LR across all optimizers: 0.00019028738401069434
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1211	Rec: 0.1211	E: 0.0000	R: 0.0000	P: 0.2423
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][1085/1213][Time 0.58]
# Unified LR across all optimizers: 0.000190243573765348
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1202	Rec: 0.1202	E: 0.0000	R: 0.0000	P: 0.2404
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][1090/1213][Time 0.67]
# Unified LR across all optimizers: 0.00019019977360652216
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1210	Rec: 0.1210	E: 0.0000	R: 0.0000	P: 0.2420
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][1095/1213][Time 0.60]
# Unified LR across all optimizers: 0.00019015598353189458
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0013	Gen: 0.1235	Rec: 0.1242	E: 0.0006	R: 0.0020	P: 0.2464
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][1100/1213][Time 0.56]
# Unified LR across all optimizers: 0.00019011220353914353
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0001	Gen: 0.1209	Rec: 0.1209	E: 0.0001	R: 0.0001	P: 0.2418
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][1105/1213][Time 0.54]
# Unified LR across all optimizers: 0.00019006843362594786
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1138	Rec: 0.1138	E: 0.0000	R: 0.0000	P: 0.2277
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][1110/1213][Time 0.61]
# Unified LR across all optimizers: 0.0001900246737899869
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0020	Gen: 0.1217	Rec: 0.1227	E: 0.0009	R: 0.0031	P: 0.2424
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][1115/1213][Time 0.59]
# Unified LR across all optimizers: 0.00018998092402894057
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0016	Gen: 0.1197	Rec: 0.1206	E: 0.0007	R: 0.0025	P: 0.2386
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 1.0000
# recall: 0.9915
# f1_score: 0.9957
#
# [0/1][1120/1213][Time 0.64]
# Unified LR across all optimizers: 0.00018993718434048932
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0009	Gen: 0.1205	Rec: 0.1209	E: 0.0005	R: 0.0013	P: 0.2404
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][1125/1213][Time 0.56]
# Unified LR across all optimizers: 0.00018989345472231412
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0011	Gen: 0.1213	Rec: 0.1219	E: 0.0004	R: 0.0017	P: 0.2421
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][1130/1213][Time 0.57]
# Unified LR across all optimizers: 0.00018984973517209642
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0018	Gen: 0.1220	Rec: 0.1217	E: 0.0021	R: 0.0015	P: 0.2418
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][1135/1213][Time 0.61]
# Unified LR across all optimizers: 0.0001898060256875183
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0010	Gen: 0.1178	Rec: 0.1184	E: 0.0004	R: 0.0016	P: 0.2352
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][1140/1213][Time 1.24]
# Unified LR across all optimizers: 0.0001897623262662623
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1210	Rec: 0.1210	E: 0.0000	R: 0.0000	P: 0.2419
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][1145/1213][Time 1.41]
# Unified LR across all optimizers: 0.00018971863690601156
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1243	Rec: 0.1243	E: 0.0000	R: 0.0000	P: 0.2486
# --------------------Test Metrics------------------------
# accuracy: 0.9922
# precision: 0.9907
# recall: 0.9907
# f1_score: 0.9907
#
# [0/1][1150/1213][Time 1.46]
# Unified LR across all optimizers: 0.00018967495760444968
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0016	Gen: 0.1204	Rec: 0.1213	E: 0.0008	R: 0.0025	P: 0.2401
# --------------------Test Metrics------------------------
# accuracy: 0.9922
# precision: 1.0000
# recall: 0.9826
# f1_score: 0.9912
#
# [0/1][1155/1213][Time 1.27]
# Unified LR across all optimizers: 0.00018963128835926084
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0008	Gen: 0.1204	Rec: 0.1206	E: 0.0005	R: 0.0010	P: 0.2402
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 1.0000
# recall: 0.9902
# f1_score: 0.9951
#
# [0/1][1160/1213][Time 1.36]
# Unified LR across all optimizers: 0.00018958762916812974
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1161	Rec: 0.1161	E: 0.0000	R: 0.0000	P: 0.2322
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 1.0000
# recall: 0.9912
# f1_score: 0.9956
#
# [0/1][1165/1213][Time 0.79]
# Unified LR across all optimizers: 0.00018954398002874162
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0026	Gen: 0.1235	Rec: 0.1253	E: 0.0008	R: 0.0044	P: 0.2463
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][1170/1213][Time 0.56]
# Unified LR across all optimizers: 0.00018950034093878222
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0015	Gen: 0.1192	Rec: 0.1199	E: 0.0008	R: 0.0022	P: 0.2376
# --------------------Test Metrics------------------------
# accuracy: 0.9922
# precision: 0.9918
# recall: 0.9918
# f1_score: 0.9918
#
# [0/1][1175/1213][Time 0.58]
# Unified LR across all optimizers: 0.00018945671189593785
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0000	Gen: 0.1218	Rec: 0.1218	E: 0.0000	R: 0.0000	P: 0.2436
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 1.0000
# recall: 0.9915
# f1_score: 0.9957
#
# [0/1][1180/1213][Time 0.64]
# Unified LR across all optimizers: 0.00018941309289789536
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0013	Gen: 0.1181	Rec: 0.1189	E: 0.0006	R: 0.0021	P: 0.2357
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 1.0000
# recall: 0.9916
# f1_score: 0.9958
#
# [0/1][1185/1213][Time 0.57]
# Unified LR across all optimizers: 0.0001893694839423421
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0007	Gen: 0.1174	Rec: 0.1178	E: 0.0003	R: 0.0011	P: 0.2346
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000
#
# [0/1][1190/1213][Time 0.63]
# Unified LR across all optimizers: 0.000189325885026966
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0015	Gen: 0.1190	Rec: 0.1196	E: 0.0010	R: 0.0021	P: 0.2371
# --------------------Test Metrics------------------------
# accuracy: 0.9922
# precision: 0.9918
# recall: 0.9918
# f1_score: 0.9918
#
# [0/1][1195/1213][Time 0.52]
# Unified LR across all optimizers: 0.00018928229614945547
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0014	Gen: 0.1205	Rec: 0.1212	E: 0.0006	R: 0.0021	P: 0.2403
# --------------------Test Metrics------------------------
# accuracy: 0.9922
# precision: 1.0000
# recall: 0.9843
# f1_score: 0.9921
#
# [0/1][1200/1213][Time 0.59]
# Unified LR across all optimizers: 0.00018923871730749947
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0033	Gen: 0.1191	Rec: 0.1203	E: 0.0021	R: 0.0045	P: 0.2361
# --------------------Test Metrics------------------------
# accuracy: 0.9922
# precision: 0.9846
# recall: 1.0000
# f1_score: 0.9922
#
# [0/1][1205/1213][Time 0.59]
# Unified LR across all optimizers: 0.00018919514849878745
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0006	Gen: 0.1255	Rec: 0.1257	E: 0.0005	R: 0.0007	P: 0.2506
# --------------------Test Metrics------------------------
# accuracy: 0.9961
# precision: 0.9922
# recall: 1.0000
# f1_score: 0.9961
#
# [0/1][1210/1213][Time 0.60]
# Unified LR across all optimizers: 0.0001891515897210095
# --------------------Training Metrics--------------------
# Trainer:  gpt
# Inf: 0.0021	Gen: 0.1208	Rec: 0.1219	E: 0.0010	R: 0.0032	P: 0.2407
# --------------------Test Metrics------------------------
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1_score: 1.0000

# %%
trainer_hub.test(testset)
# Out:
# {'accuracy': 0.9969109296798706,
#  'precision': 0.9948239287229529,
#  'recall': 0.998382014817338,
#  'f1_score': 0.9965997959877593}
