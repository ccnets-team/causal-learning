# %% [markdown]
# Author:
#
#         PARK, JunHo, junho@ccnets.org
#
#
#         KIM, JeongYoong, jeongyoong@ccnets.org
#
#     COPYRIGHT (c) 2024. CCNets. All Rights reserved.

# %% [markdown]
# # Credit Card Fraud Detection: Handling Imbalanced Dataset with CCNet
#
# ## Introduction
#
# This tutorial explores the use of a Cooperative Encoding Network (CCNet) to address challenges associated with imbalanced datasets in the domain of credit card fraud detection. By leveraging the power of synthetic data generation, we aim to enhance the diversity and volume of training data, thereby improving the robustness and accuracy of models designed to identify fraudulent transactions.
#
# ## Tutorial Goals
#
# The objectives of this tutorial are designed to guide you through the process of enhancing data quality and model performance:
#
# ### Dataset Recreation with CCNet
# - **Understand Data Augmentation**: Learn how encoding techniques can be used to generate synthetic data instances that closely mimic the characteristics of real-world fraudulent and non-fraudulent transactions.
# - **Impact on Model Training**: Assess how augmenting the dataset influences the training process and subsequently, the model's ability to generalize from training to real-world scenarios.
#
# ### Model Training and Evaluation
# - **Dual Model Training**: Train two distinct models to directly compare performance metrics:
#   - A model trained on the **original dataset**.
#   - A model trained on the **CCNet-augmented dataset**.
# - **Performance Metrics**: Use the F1 score, a critical measure for models operating on imbalanced datasets, to evaluate and compare the effectiveness of these models.
#
# ### Testing and Validation
# - **Independent Model Testing**: Conduct a thorough evaluation of both models using a standalone test set that was not involved in the training phase.
# - **Objective Analysis**: Critically analyze the outcomes to validate whether data augmentation through CCNet offers a tangible benefit in detecting credit card fraud.
#
# ## Conclusion
#
# By the end of this tutorial, participants will not only grasp the theoretical underpinnings of using synthetic data to combat data imbalance but also gain hands-on experience in applying these concepts through CCNet to potentially enhance model performance in fraud detection tasks.

# %%
import sys
path_append = "../"
sys.path.append(path_append)  # Go up one directory from where you are.

# %%
# https://fraud-detection-handbook.github.io/fraud-detection-handbook/Chapter_7_DeepLearning/FeedForwardNeuralNetworks.html
import pandas as pd 

dataroot = path_append + "../data/credit_card_fraud_detection/creditcard.csv"
df = pd.read_csv(dataroot)
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
print('No Frauds', round(df['Class'].value_counts()[0] / len(df) *100,2), '%of the dataset')
print('Frauds', round(df['Class'].value_counts()[1] / len(df) *100,2), '%of the dataset')
# Out:
# No Frauds 99.83 %of the dataset
# Frauds 0.17 %of the dataset

# %%
import torch
from sklearn.preprocessing import StandardScaler
from torch.utils.data import Dataset

# Standardizing the features (excluding the class column)
sc = StandardScaler()
df.iloc[:, :-1] = sc.fit_transform(df.iloc[:, :-1])

# Total elements including features and class
n_elements = df.shape[1]
print(f"Number of features and classes (total columns): {n_elements}")
# Out:
# Number of features and classes (total columns): 31

# %%
# Defining the labeled and unlabeled dataset classes
class LabeledDataset(Dataset):
    def __init__(self, x, y):
        self.x = x
        self.y = y
        
    def __len__(self):
        return len(self.x)

    def __getitem__(self, index):
        vals = torch.tensor(self.x[index], dtype=torch.float32)
        label = torch.tensor(self.y[index], dtype=torch.float32)
        return vals, label

class UnlabelledDataset(Dataset):
    def __init__(self, x):
        self.x = x
        
    def __len__(self):
        return len(self.x)

    def __getitem__(self, index):
        vals = torch.tensor(self.x[index], dtype=torch.float32)
        return vals, None

# %% [markdown]
# #### Initial Setup and Model Configuration
#
# This section initializes the environment by setting a fixed random seed to ensure reproducibility of results. It imports necessary configurations and initializes model parameters with specific configurations. The model specified here is set to have no core model but uses a 'deepfm' encoder model for data processing, which is particularly tailored for structured or tabular data like credit card transactions.

# %%
from sklearn.model_selection import train_test_split

# Splitting the dataset into training and test sets for model evaluation
df_train, df_test = train_test_split(df, test_size=0.5, shuffle=False)
X_train, y_train = df_train.iloc[:, :-1].values, df_train.iloc[:, -1:].values
X_test, y_test = df_test.iloc[:, :-1].values, df_test.iloc[:, -1:].values

# Preparing the datasets for use in training and testing
df_train_values = df_train.iloc[:, :].values  # Full training data for unsupervised tasks
unlabelled_dataset = UnlabelledDataset(df_train_values)  # Renamed to reflect it includes the full train data

# Labeled datasets for supervised learning tasks
supervised_trainset = LabeledDataset(X_train, y_train)  # Corrected to include training data
supervised_testset = LabeledDataset(X_test, y_test)     # Test set with proper labels

# Printing the shapes of the datasets for verification
print(f"Unlabelled Dataset Shape: {len(unlabelled_dataset)}, {unlabelled_dataset.x.shape[1]}")
print(f"Labeled Trainset Shape: {len(supervised_trainset)}, {supervised_trainset.x.shape[1]}")
print(f"Labeled Testset Shape: {len(supervised_testset)}, {supervised_testset.x.shape[1]}")
# Out:
# Unlabelled Dataset Shape: 142403, 31
# Labeled Trainset Shape: 142403, 30
# Labeled Testset Shape: 142404, 30

# %%
# Set a fixed random seed for reproducibility of experiments
from nn.utils.init import set_random_seed
set_random_seed(0)

# Importing configuration setups for ML parameters and data
import torch
from tools.setting.ml_params import MLParameters
from tools.setting.data_config import DataConfig
from trainer_hub import TrainerHub

# Configuration for the data handling, defining dataset specifics and the task type
data_config = DataConfig(dataset_name='CreditCardFraudDetection', task_type='augmentation', obs_shape=[n_elements], label_size=None)

# Initializing ML parameters without a core model and setting the encoder model to 'deepfm' with specific configurations
ml_params = MLParameters(core_model='none', encoder_model='deepfm')
ml_params.model.encoder_config.num_layers = 4
ml_params.model.encoder_config.dropout = 0.0

# Setting training parameters and device configuration
ml_params.training.num_epoch = 4
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") 

# Create a TrainerHub instance to manage training and data processing
trainer_hub = TrainerHub(ml_params, data_config, device, use_print=True, use_wandb=False, use_full_eval=False)
# Out:
# c:\Users\CCNets-team\anaconda3\lib\site-packages\transformers\utils\generic.py:311: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(

# %% [markdown]
# #### Dataset Splitting for Training and Testing
#
# The original dataset is split into training and testing parts to evaluate the model's performance accurately. This step is crucial for validating the effectiveness of the training on unseen data.

# %%
trainer_hub.train(unlabelled_dataset)
# Out:
# Epochs:   0%|          | 0/4 [00:00<?, ?it/s]
# Iterations:   0%|          | 0/2225 [00:00<?, ?it/s]
# [0/4][50/2225][Time 1.60]
# Unified LR across all optimizers: 0.0001995308238189185
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.5556	Gen: 0.5464	Rec: 0.5939	E: 0.5082	R: 0.6031	P: 0.5847
# [0/4][100/2225][Time 1.39]
# Unified LR across all optimizers: 0.00019907191565870155
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.5096	Gen: 0.4889	Rec: 0.5416	E: 0.4570	R: 0.5623	P: 0.5208
# [0/4][150/2225][Time 1.41]
# Unified LR across all optimizers: 0.00019861406295796434
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.4606	Gen: 0.4456	Rec: 0.4907	E: 0.4155	R: 0.5058	P: 0.4756
# [0/4][200/2225][Time 1.40]
# Unified LR across all optimizers: 0.00019815726328921765
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.4107	Gen: 0.4094	Rec: 0.4379	E: 0.3822	R: 0.4391	P: 0.4367
# [0/4][250/2225][Time 1.39]
# Unified LR across all optimizers: 0.00019770151423055492
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.3619	Gen: 0.3701	Rec: 0.3844	E: 0.3477	R: 0.3762	P: 0.3925
# [0/4][300/2225][Time 1.36]
# Unified LR across all optimizers: 0.00019724681336564005
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.3299	Gen: 0.3459	Rec: 0.3485	E: 0.3273	R: 0.3324	P: 0.3646
# [0/4][350/2225][Time 1.37]
# Unified LR across all optimizers: 0.00019679315828369438
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.3043	Gen: 0.3255	Rec: 0.3228	E: 0.3069	R: 0.3016	P: 0.3440
# [0/4][400/2225][Time 1.36]
# Unified LR across all optimizers: 0.00019634054657948372
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.2920	Gen: 0.3144	Rec: 0.3112	E: 0.2952	R: 0.2889	P: 0.3336
# [0/4][450/2225][Time 1.39]
# Unified LR across all optimizers: 0.00019588897585330582
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.2669	Gen: 0.2907	Rec: 0.2823	E: 0.2754	R: 0.2585	P: 0.3060
# [0/4][500/2225][Time 1.39]
# Unified LR across all optimizers: 0.00019543844371097777
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.2608	Gen: 0.2846	Rec: 0.2764	E: 0.2690	R: 0.2526	P: 0.3003
# [0/4][550/2225][Time 1.41]
# Unified LR across all optimizers: 0.00019498894776382288
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.2423	Gen: 0.2652	Rec: 0.2585	E: 0.2491	R: 0.2355	P: 0.2814
# [0/4][600/2225][Time 1.41]
# Unified LR across all optimizers: 0.00019454048562865856
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.2399	Gen: 0.2622	Rec: 0.2546	E: 0.2475	R: 0.2323	P: 0.2769
# [0/4][650/2225][Time 1.39]
# Unified LR across all optimizers: 0.00019409305492778308
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.2264	Gen: 0.2497	Rec: 0.2403	E: 0.2357	R: 0.2171	P: 0.2636
# [0/4][700/2225][Time 1.42]
# Unified LR across all optimizers: 0.00019364665328896346
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.2150	Gen: 0.2364	Rec: 0.2291	E: 0.2223	R: 0.2076	P: 0.2506
# [0/4][750/2225][Time 1.38]
# Unified LR across all optimizers: 0.00019320127834542263
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.2142	Gen: 0.2338	Rec: 0.2280	E: 0.2200	R: 0.2084	P: 0.2475
# [0/4][800/2225][Time 1.38]
# Unified LR across all optimizers: 0.00019275692773582703
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1958	Gen: 0.2171	Rec: 0.2092	E: 0.2037	R: 0.1879	P: 0.2304
# [0/4][850/2225][Time 1.40]
# Unified LR across all optimizers: 0.0001923135991042739
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1939	Gen: 0.2135	Rec: 0.2073	E: 0.2001	R: 0.1877	P: 0.2270
# [0/4][900/2225][Time 1.38]
# Unified LR across all optimizers: 0.0001918712901002789
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1923	Gen: 0.2095	Rec: 0.2064	E: 0.1954	R: 0.1892	P: 0.2235
# [0/4][950/2225][Time 1.35]
# Unified LR across all optimizers: 0.00019142999837876384
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1779	Gen: 0.1954	Rec: 0.1916	E: 0.1817	R: 0.1741	P: 0.2091
# [0/4][1000/2225][Time 1.35]
# Unified LR across all optimizers: 0.00019098972160004388
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1866	Gen: 0.2015	Rec: 0.2001	E: 0.1880	R: 0.1853	P: 0.2150
# [0/4][1050/2225][Time 1.40]
# Unified LR across all optimizers: 0.00019055045742981543
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1767	Gen: 0.1910	Rec: 0.1900	E: 0.1777	R: 0.1757	P: 0.2043
# [0/4][1100/2225][Time 1.38]
# Unified LR across all optimizers: 0.00019011220353914353
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1631	Gen: 0.1779	Rec: 0.1760	E: 0.1650	R: 0.1612	P: 0.1909
# [0/4][1150/2225][Time 1.35]
# Unified LR across all optimizers: 0.00018967495760444968
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1617	Gen: 0.1751	Rec: 0.1754	E: 0.1614	R: 0.1620	P: 0.1889
# [0/4][1200/2225][Time 1.38]
# Unified LR across all optimizers: 0.00018923871730749947
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1658	Gen: 0.1767	Rec: 0.1785	E: 0.1641	R: 0.1676	P: 0.1894
# [0/4][1250/2225][Time 1.37]
# Unified LR across all optimizers: 0.00018880348033539028
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1754	Gen: 0.1844	Rec: 0.1883	E: 0.1715	R: 0.1793	P: 0.1973
# [0/4][1300/2225][Time 1.37]
# Unified LR across all optimizers: 0.00018836924438053897
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1448	Gen: 0.1564	Rec: 0.1566	E: 0.1446	R: 0.1450	P: 0.1682
# [0/4][1350/2225][Time 1.36]
# Unified LR across all optimizers: 0.0001879360071406698
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1608	Gen: 0.1701	Rec: 0.1726	E: 0.1583	R: 0.1633	P: 0.1819
# [0/4][1400/2225][Time 1.38]
# Unified LR across all optimizers: 0.000187503766318802
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1523	Gen: 0.1612	Rec: 0.1644	E: 0.1491	R: 0.1556	P: 0.1733
# [0/4][1450/2225][Time 1.36]
# Unified LR across all optimizers: 0.00018707251962323787
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1420	Gen: 0.1530	Rec: 0.1538	E: 0.1412	R: 0.1429	P: 0.1647
# [0/4][1500/2225][Time 1.37]
# Unified LR across all optimizers: 0.0001866422647675502
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1421	Gen: 0.1512	Rec: 0.1536	E: 0.1397	R: 0.1445	P: 0.1627
# [0/4][1550/2225][Time 1.38]
# Unified LR across all optimizers: 0.00018621299947057073
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1460	Gen: 0.1539	Rec: 0.1568	E: 0.1431	R: 0.1488	P: 0.1648
# [0/4][1600/2225][Time 1.37]
# Unified LR across all optimizers: 0.00018578472145637737
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1487	Gen: 0.1566	Rec: 0.1598	E: 0.1455	R: 0.1519	P: 0.1678
# [0/4][1650/2225][Time 1.36]
# Unified LR across all optimizers: 0.00018535742845428288
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1369	Gen: 0.1458	Rec: 0.1472	E: 0.1355	R: 0.1383	P: 0.1560
# [0/4][1700/2225][Time 1.40]
# Unified LR across all optimizers: 0.00018493111819882223
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1292	Gen: 0.1392	Rec: 0.1396	E: 0.1288	R: 0.1295	P: 0.1496
# [0/4][1750/2225][Time 1.34]
# Unified LR across all optimizers: 0.00018450578842974107
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1294	Gen: 0.1382	Rec: 0.1397	E: 0.1279	R: 0.1309	P: 0.1486
# [0/4][1800/2225][Time 1.39]
# Unified LR across all optimizers: 0.00018408143689198318
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1272	Gen: 0.1360	Rec: 0.1369	E: 0.1263	R: 0.1281	P: 0.1457
# [0/4][1850/2225][Time 1.35]
# Unified LR across all optimizers: 0.0001836580613356789
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1286	Gen: 0.1375	Rec: 0.1386	E: 0.1276	R: 0.1296	P: 0.1475
# [0/4][1900/2225][Time 1.39]
# Unified LR across all optimizers: 0.0001832356595161332
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1309	Gen: 0.1386	Rec: 0.1408	E: 0.1287	R: 0.1331	P: 0.1485
# [0/4][1950/2225][Time 1.36]
# Unified LR across all optimizers: 0.00018281422919381367
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1254	Gen: 0.1332	Rec: 0.1348	E: 0.1238	R: 0.1270	P: 0.1427
# [0/4][2000/2225][Time 1.38]
# Unified LR across all optimizers: 0.00018239376813433867
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1185	Gen: 0.1271	Rec: 0.1274	E: 0.1182	R: 0.1187	P: 0.1360
# [0/4][2050/2225][Time 1.36]
# Unified LR across all optimizers: 0.00018197427410846564
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1232	Gen: 0.1315	Rec: 0.1327	E: 0.1220	R: 0.1243	P: 0.1411
# [0/4][2100/2225][Time 1.35]
# Unified LR across all optimizers: 0.00018155574489207887
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1271	Gen: 0.1346	Rec: 0.1359	E: 0.1257	R: 0.1284	P: 0.1434
# [0/4][2150/2225][Time 1.34]
# Unified LR across all optimizers: 0.00018113817826617823
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1235	Gen: 0.1306	Rec: 0.1328	E: 0.1212	R: 0.1257	P: 0.1399
# [0/4][2200/2225][Time 1.36]
# Unified LR across all optimizers: 0.00018072157201686696
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1189	Gen: 0.1271	Rec: 0.1277	E: 0.1183	R: 0.1195	P: 0.1359
# Iterations:   0%|          | 0/2225 [00:00<?, ?it/s]
# [1/4][25/2225][Time 1.36]
# Unified LR across all optimizers: 0.00018030592393534033
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1187	Gen: 0.1265	Rec: 0.1273	E: 0.1180	R: 0.1195	P: 0.1351
# [1/4][75/2225][Time 1.34]
# Unified LR across all optimizers: 0.0001798912318178735
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1177	Gen: 0.1253	Rec: 0.1261	E: 0.1169	R: 0.1185	P: 0.1337
# [1/4][125/2225][Time 1.41]
# Unified LR across all optimizers: 0.00017947749346581006
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1152	Gen: 0.1231	Rec: 0.1238	E: 0.1145	R: 0.1158	P: 0.1317
# [1/4][175/2225][Time 1.38]
# Unified LR across all optimizers: 0.0001790647066855505
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1200	Gen: 0.1275	Rec: 0.1287	E: 0.1187	R: 0.1212	P: 0.1362
# [1/4][225/2225][Time 1.42]
# Unified LR across all optimizers: 0.00017865286928854052
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1194	Gen: 0.1264	Rec: 0.1275	E: 0.1183	R: 0.1205	P: 0.1345
# [1/4][275/2225][Time 1.39]
# Unified LR across all optimizers: 0.00017824197909125899
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1094	Gen: 0.1175	Rec: 0.1172	E: 0.1097	R: 0.1092	P: 0.1253
# [1/4][325/2225][Time 1.39]
# Unified LR across all optimizers: 0.00017783203391520723
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1072	Gen: 0.1148	Rec: 0.1150	E: 0.1071	R: 0.1074	P: 0.1226
# [1/4][375/2225][Time 1.38]
# Unified LR across all optimizers: 0.00017742303158689668
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1112	Gen: 0.1187	Rec: 0.1187	E: 0.1112	R: 0.1112	P: 0.1262
# [1/4][425/2225][Time 1.40]
# Unified LR across all optimizers: 0.00017701496993783762
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1048	Gen: 0.1119	Rec: 0.1124	E: 0.1042	R: 0.1054	P: 0.1195
# [1/4][475/2225][Time 1.33]
# Unified LR across all optimizers: 0.00017660784680452796
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1063	Gen: 0.1144	Rec: 0.1139	E: 0.1068	R: 0.1059	P: 0.1219
# [1/4][525/2225][Time 1.37]
# Unified LR across all optimizers: 0.0001762016600284412
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1150	Gen: 0.1215	Rec: 0.1226	E: 0.1139	R: 0.1161	P: 0.1291
# [1/4][575/2225][Time 1.40]
# Unified LR across all optimizers: 0.00017579640745601563
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1096	Gen: 0.1160	Rec: 0.1174	E: 0.1081	R: 0.1110	P: 0.1238
# [1/4][625/2225][Time 1.36]
# Unified LR across all optimizers: 0.0001753920869386423
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1105	Gen: 0.1164	Rec: 0.1185	E: 0.1085	R: 0.1125	P: 0.1244
# [1/4][675/2225][Time 1.39]
# Unified LR across all optimizers: 0.0001749886963326542
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1093	Gen: 0.1163	Rec: 0.1166	E: 0.1090	R: 0.1096	P: 0.1236
# [1/4][725/2225][Time 1.40]
# Unified LR across all optimizers: 0.0001745862334993144
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1044	Gen: 0.1115	Rec: 0.1117	E: 0.1042	R: 0.1047	P: 0.1188
# [1/4][775/2225][Time 1.35]
# Unified LR across all optimizers: 0.00017418469630480507
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1101	Gen: 0.1164	Rec: 0.1178	E: 0.1088	R: 0.1115	P: 0.1241
# [1/4][825/2225][Time 1.37]
# Unified LR across all optimizers: 0.00017378408262021616
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1096	Gen: 0.1158	Rec: 0.1167	E: 0.1087	R: 0.1104	P: 0.1229
# [1/4][875/2225][Time 1.39]
# Unified LR across all optimizers: 0.00017338439032153356
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1080	Gen: 0.1143	Rec: 0.1150	E: 0.1073	R: 0.1087	P: 0.1213
# [1/4][925/2225][Time 1.33]
# Unified LR across all optimizers: 0.00017298561728962847
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1029	Gen: 0.1092	Rec: 0.1101	E: 0.1019	R: 0.1039	P: 0.1164
# [1/4][975/2225][Time 1.41]
# Unified LR across all optimizers: 0.00017258776141024598
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0951	Gen: 0.1034	Rec: 0.1016	E: 0.0969	R: 0.0932	P: 0.1099
# [1/4][1025/2225][Time 1.36]
# Unified LR across all optimizers: 0.00017219082057399394
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1002	Gen: 0.1085	Rec: 0.1069	E: 0.1018	R: 0.0987	P: 0.1152
# [1/4][1075/2225][Time 1.37]
# Unified LR across all optimizers: 0.00017179479267633146
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1035	Gen: 0.1110	Rec: 0.1108	E: 0.1037	R: 0.1033	P: 0.1183
# [1/4][1125/2225][Time 1.40]
# Unified LR across all optimizers: 0.00017139967561755819
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1036	Gen: 0.1100	Rec: 0.1104	E: 0.1032	R: 0.1040	P: 0.1169
# [1/4][1175/2225][Time 1.34]
# Unified LR across all optimizers: 0.00017100546730280274
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0988	Gen: 0.1066	Rec: 0.1062	E: 0.0992	R: 0.0984	P: 0.1139
# [1/4][1225/2225][Time 1.35]
# Unified LR across all optimizers: 0.00017061216564201177
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1042	Gen: 0.1111	Rec: 0.1117	E: 0.1036	R: 0.1047	P: 0.1186
# [1/4][1275/2225][Time 1.18]
# Unified LR across all optimizers: 0.0001702197685499392
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0948	Gen: 0.1023	Rec: 0.1015	E: 0.0956	R: 0.0939	P: 0.1090
# [1/4][1325/2225][Time 1.23]
# Unified LR across all optimizers: 0.0001698282739461345
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0943	Gen: 0.1016	Rec: 0.1013	E: 0.0947	R: 0.0940	P: 0.1086
# [1/4][1375/2225][Time 1.21]
# Unified LR across all optimizers: 0.00016943767975493242
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0976	Gen: 0.1053	Rec: 0.1051	E: 0.0978	R: 0.0974	P: 0.1128
# [1/4][1425/2225][Time 1.45]
# Unified LR across all optimizers: 0.0001690479839054414
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0984	Gen: 0.1050	Rec: 0.1056	E: 0.0978	R: 0.0990	P: 0.1122
# [1/4][1475/2225][Time 1.22]
# Unified LR across all optimizers: 0.00016865918433153277
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0964	Gen: 0.1038	Rec: 0.1036	E: 0.0965	R: 0.0963	P: 0.1110
# [1/4][1525/2225][Time 1.20]
# Unified LR across all optimizers: 0.00016827127897182985
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0984	Gen: 0.1056	Rec: 0.1058	E: 0.0982	R: 0.0985	P: 0.1130
# [1/4][1575/2225][Time 1.25]
# Unified LR across all optimizers: 0.0001678842657696972
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0976	Gen: 0.1046	Rec: 0.1047	E: 0.0975	R: 0.0978	P: 0.1117
# [1/4][1625/2225][Time 1.23]
# Unified LR across all optimizers: 0.00016749814267322938
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.1005	Gen: 0.1075	Rec: 0.1078	E: 0.1002	R: 0.1008	P: 0.1148
# [1/4][1675/2225][Time 1.21]
# Unified LR across all optimizers: 0.00016711290763524007
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0934	Gen: 0.1001	Rec: 0.1008	E: 0.0927	R: 0.0940	P: 0.1076
# [1/4][1725/2225][Time 1.26]
# Unified LR across all optimizers: 0.00016672855861325146
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0966	Gen: 0.1039	Rec: 0.1036	E: 0.0968	R: 0.0963	P: 0.1109
# [1/4][1775/2225][Time 1.19]
# Unified LR across all optimizers: 0.00016634509356948314
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0842	Gen: 0.0929	Rec: 0.0916	E: 0.0855	R: 0.0830	P: 0.1003
# [1/4][1825/2225][Time 1.30]
# Unified LR across all optimizers: 0.00016596251047084197
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0923	Gen: 0.0995	Rec: 0.0996	E: 0.0922	R: 0.0924	P: 0.1067
# [1/4][1875/2225][Time 1.30]
# Unified LR across all optimizers: 0.00016558080728890993
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0931	Gen: 0.1001	Rec: 0.0999	E: 0.0933	R: 0.0929	P: 0.1070
# [1/4][1925/2225][Time 1.36]
# Unified LR across all optimizers: 0.00016519998199993532
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0926	Gen: 0.1000	Rec: 0.0997	E: 0.0929	R: 0.0924	P: 0.1070
# [1/4][1975/2225][Time 1.31]
# Unified LR across all optimizers: 0.0001648200325848201
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0948	Gen: 0.1027	Rec: 0.1019	E: 0.0956	R: 0.0941	P: 0.1098
# [1/4][2025/2225][Time 1.32]
# Unified LR across all optimizers: 0.00016444095702911038
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0904	Gen: 0.0980	Rec: 0.0973	E: 0.0911	R: 0.0898	P: 0.1048
# [1/4][2075/2225][Time 1.34]
# Unified LR across all optimizers: 0.00016406275332298505
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0915	Gen: 0.0987	Rec: 0.0986	E: 0.0916	R: 0.0915	P: 0.1058
# [1/4][2125/2225][Time 1.34]
# Unified LR across all optimizers: 0.00016368541946124596
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0884	Gen: 0.0960	Rec: 0.0953	E: 0.0892	R: 0.0877	P: 0.1029
# [1/4][2175/2225][Time 1.29]
# Unified LR across all optimizers: 0.00016330895344330638
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0969	Gen: 0.1029	Rec: 0.1036	E: 0.0962	R: 0.0976	P: 0.1097
# Iterations:   0%|          | 0/2225 [00:00<?, ?it/s]
# [2/4][0/2225][Time 1.36]
# Unified LR across all optimizers: 0.00016293335327318117
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0946	Gen: 0.1014	Rec: 0.1010	E: 0.0951	R: 0.0942	P: 0.1077
# [2/4][50/2225][Time 1.22]
# Unified LR across all optimizers: 0.00016255861695947546
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0891	Gen: 0.0965	Rec: 0.0959	E: 0.0898	R: 0.0884	P: 0.1033
# [2/4][100/2225][Time 1.16]
# Unified LR across all optimizers: 0.00016218474251537463
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0910	Gen: 0.0981	Rec: 0.0976	E: 0.0915	R: 0.0906	P: 0.1047
# [2/4][150/2225][Time 1.15]
# Unified LR across all optimizers: 0.00016181172795863357
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0874	Gen: 0.0952	Rec: 0.0938	E: 0.0889	R: 0.0860	P: 0.1016
# [2/4][200/2225][Time 1.19]
# Unified LR across all optimizers: 0.0001614395713115662
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0863	Gen: 0.0940	Rec: 0.0932	E: 0.0871	R: 0.0856	P: 0.1009
# [2/4][250/2225][Time 1.23]
# Unified LR across all optimizers: 0.00016106827060103523
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0878	Gen: 0.0958	Rec: 0.0942	E: 0.0894	R: 0.0862	P: 0.1022
# [2/4][300/2225][Time 1.28]
# Unified LR across all optimizers: 0.00016069782385844109
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0886	Gen: 0.0961	Rec: 0.0952	E: 0.0895	R: 0.0876	P: 0.1028
# [2/4][350/2225][Time 1.28]
# Unified LR across all optimizers: 0.00016032822911971208
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0827	Gen: 0.0908	Rec: 0.0887	E: 0.0848	R: 0.0805	P: 0.0969
# [2/4][400/2225][Time 1.30]
# Unified LR across all optimizers: 0.0001599594844252937
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0895	Gen: 0.0965	Rec: 0.0959	E: 0.0902	R: 0.0888	P: 0.1029
# [2/4][450/2225][Time 1.25]
# Unified LR across all optimizers: 0.00015959158782013816
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0889	Gen: 0.0953	Rec: 0.0954	E: 0.0888	R: 0.0890	P: 0.1018
# [2/4][500/2225][Time 1.23]
# Unified LR across all optimizers: 0.00015922453735369438
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0877	Gen: 0.0943	Rec: 0.0941	E: 0.0879	R: 0.0875	P: 0.1006
# [2/4][550/2225][Time 1.26]
# Unified LR across all optimizers: 0.00015885833107989733
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0828	Gen: 0.0903	Rec: 0.0891	E: 0.0839	R: 0.0817	P: 0.0966
# [2/4][600/2225][Time 1.23]
# Unified LR across all optimizers: 0.00015849296705715778
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0833	Gen: 0.0906	Rec: 0.0893	E: 0.0846	R: 0.0820	P: 0.0965
# [2/4][650/2225][Time 1.22]
# Unified LR across all optimizers: 0.0001581284433483521
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0837	Gen: 0.0908	Rec: 0.0898	E: 0.0847	R: 0.0828	P: 0.0969
# [2/4][700/2225][Time 1.21]
# Unified LR across all optimizers: 0.00015776475802081183
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0782	Gen: 0.0850	Rec: 0.0845	E: 0.0786	R: 0.0777	P: 0.0914
# [2/4][750/2225][Time 1.20]
# Unified LR across all optimizers: 0.00015740190914631356
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0843	Gen: 0.0913	Rec: 0.0905	E: 0.0851	R: 0.0836	P: 0.0974
# [2/4][800/2225][Time 1.24]
# Unified LR across all optimizers: 0.0001570398948010687
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0827	Gen: 0.0897	Rec: 0.0884	E: 0.0840	R: 0.0814	P: 0.0954
# [2/4][850/2225][Time 1.28]
# Unified LR across all optimizers: 0.00015667871306571324
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0878	Gen: 0.0942	Rec: 0.0939	E: 0.0881	R: 0.0875	P: 0.1004
# [2/4][900/2225][Time 1.30]
# Unified LR across all optimizers: 0.00015631836202529756
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0755	Gen: 0.0831	Rec: 0.0812	E: 0.0774	R: 0.0737	P: 0.0888
# [2/4][950/2225][Time 1.26]
# Unified LR across all optimizers: 0.00015595883976927632
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0767	Gen: 0.0837	Rec: 0.0827	E: 0.0776	R: 0.0757	P: 0.0897
# [2/4][1000/2225][Time 1.26]
# Unified LR across all optimizers: 0.0001556001443914984
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0789	Gen: 0.0857	Rec: 0.0850	E: 0.0796	R: 0.0782	P: 0.0919
# [2/4][1050/2225][Time 1.29]
# Unified LR across all optimizers: 0.0001552422739901963
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0723	Gen: 0.0793	Rec: 0.0782	E: 0.0735	R: 0.0711	P: 0.0852
# [2/4][1100/2225][Time 1.27]
# Unified LR across all optimizers: 0.00015488522666797712
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0792	Gen: 0.0853	Rec: 0.0853	E: 0.0793	R: 0.0792	P: 0.0914
# [2/4][1150/2225][Time 1.24]
# Unified LR across all optimizers: 0.00015452900053181137
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0754	Gen: 0.0821	Rec: 0.0813	E: 0.0762	R: 0.0747	P: 0.0880
# [2/4][1200/2225][Time 1.25]
# Unified LR across all optimizers: 0.00015417359369302347
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0759	Gen: 0.0827	Rec: 0.0819	E: 0.0767	R: 0.0752	P: 0.0887
# [2/4][1250/2225][Time 1.23]
# Unified LR across all optimizers: 0.00015381900426728195
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0717	Gen: 0.0784	Rec: 0.0775	E: 0.0726	R: 0.0708	P: 0.0842
# [2/4][1300/2225][Time 1.27]
# Unified LR across all optimizers: 0.00015346523037458877
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0711	Gen: 0.0775	Rec: 0.0772	E: 0.0715	R: 0.0708	P: 0.0835
# [2/4][1350/2225][Time 1.25]
# Unified LR across all optimizers: 0.00015311227013926996
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0776	Gen: 0.0834	Rec: 0.0832	E: 0.0778	R: 0.0774	P: 0.0891
# [2/4][1400/2225][Time 1.22]
# Unified LR across all optimizers: 0.00015276012168996563
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0769	Gen: 0.0825	Rec: 0.0828	E: 0.0767	R: 0.0772	P: 0.0884
# [2/4][1450/2225][Time 1.21]
# Unified LR across all optimizers: 0.00015240878315961963
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0687	Gen: 0.0756	Rec: 0.0741	E: 0.0701	R: 0.0672	P: 0.0810
# [2/4][1500/2225][Time 1.21]
# Unified LR across all optimizers: 0.00015205825268547007
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0794	Gen: 0.0852	Rec: 0.0850	E: 0.0797	R: 0.0792	P: 0.0908
# [2/4][1550/2225][Time 1.15]
# Unified LR across all optimizers: 0.0001517085284090394
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0778	Gen: 0.0835	Rec: 0.0832	E: 0.0782	R: 0.0775	P: 0.0889
# [2/4][1600/2225][Time 1.18]
# Unified LR across all optimizers: 0.00015135960847612417
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0726	Gen: 0.0790	Rec: 0.0782	E: 0.0734	R: 0.0718	P: 0.0845
# [2/4][1650/2225][Time 1.17]
# Unified LR across all optimizers: 0.0001510114910367858
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0758	Gen: 0.0824	Rec: 0.0812	E: 0.0770	R: 0.0747	P: 0.0878
# [2/4][1700/2225][Time 1.19]
# Unified LR across all optimizers: 0.00015066417424534014
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0765	Gen: 0.0824	Rec: 0.0817	E: 0.0772	R: 0.0758	P: 0.0875
# [2/4][1750/2225][Time 1.20]
# Unified LR across all optimizers: 0.00015031765626034814
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0701	Gen: 0.0761	Rec: 0.0757	E: 0.0705	R: 0.0697	P: 0.0817
# [2/4][1800/2225][Time 1.22]
# Unified LR across all optimizers: 0.00014997193524460595
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0773	Gen: 0.0832	Rec: 0.0826	E: 0.0780	R: 0.0767	P: 0.0884
# [2/4][1850/2225][Time 1.21]
# Unified LR across all optimizers: 0.00014962700936513516
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0636	Gen: 0.0701	Rec: 0.0693	E: 0.0643	R: 0.0629	P: 0.0758
# [2/4][1900/2225][Time 1.23]
# Unified LR across all optimizers: 0.00014928287679317315
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0763	Gen: 0.0812	Rec: 0.0815	E: 0.0760	R: 0.0766	P: 0.0864
# [2/4][1950/2225][Time 1.25]
# Unified LR across all optimizers: 0.0001489395357041632
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0714	Gen: 0.0773	Rec: 0.0764	E: 0.0722	R: 0.0705	P: 0.0823
# [2/4][2000/2225][Time 1.24]
# Unified LR across all optimizers: 0.000148596984277745
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0704	Gen: 0.0764	Rec: 0.0752	E: 0.0715	R: 0.0692	P: 0.0812
# [2/4][2050/2225][Time 1.24]
# Unified LR across all optimizers: 0.0001482552206977451
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0641	Gen: 0.0706	Rec: 0.0695	E: 0.0652	R: 0.0631	P: 0.0760
# [2/4][2100/2225][Time 1.24]
# Unified LR across all optimizers: 0.00014791424315216693
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0667	Gen: 0.0728	Rec: 0.0717	E: 0.0678	R: 0.0657	P: 0.0778
# [2/4][2150/2225][Time 1.28]
# Unified LR across all optimizers: 0.00014757404983318153
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0653	Gen: 0.0710	Rec: 0.0704	E: 0.0659	R: 0.0647	P: 0.0761
# [2/4][2200/2225][Time 1.29]
# Unified LR across all optimizers: 0.00014723463893711783
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0680	Gen: 0.0732	Rec: 0.0733	E: 0.0679	R: 0.0681	P: 0.0784
# Iterations:   0%|          | 0/2225 [00:00<?, ?it/s]
# [3/4][25/2225][Time 1.33]
# Unified LR across all optimizers: 0.00014689600866445298
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0672	Gen: 0.0734	Rec: 0.0723	E: 0.0683	R: 0.0662	P: 0.0785
# [3/4][75/2225][Time 1.24]
# Unified LR across all optimizers: 0.00014655815721980301
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0652	Gen: 0.0714	Rec: 0.0702	E: 0.0665	R: 0.0640	P: 0.0763
# [3/4][125/2225][Time 1.24]
# Unified LR across all optimizers: 0.00014622108281191326
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0681	Gen: 0.0742	Rec: 0.0733	E: 0.0689	R: 0.0672	P: 0.0794
# [3/4][175/2225][Time 1.28]
# Unified LR across all optimizers: 0.00014588478365364866
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0707	Gen: 0.0761	Rec: 0.0757	E: 0.0710	R: 0.0703	P: 0.0811
# [3/4][225/2225][Time 1.22]
# Unified LR across all optimizers: 0.0001455492579619846
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0614	Gen: 0.0670	Rec: 0.0664	E: 0.0619	R: 0.0608	P: 0.0720
# [3/4][275/2225][Time 1.17]
# Unified LR across all optimizers: 0.00014521450395799725
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0663	Gen: 0.0716	Rec: 0.0709	E: 0.0670	R: 0.0657	P: 0.0761
# [3/4][325/2225][Time 1.23]
# Unified LR across all optimizers: 0.00014488051986685427
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0651	Gen: 0.0712	Rec: 0.0700	E: 0.0663	R: 0.0639	P: 0.0761
# [3/4][375/2225][Time 1.18]
# Unified LR across all optimizers: 0.00014454730391780514
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0673	Gen: 0.0716	Rec: 0.0725	E: 0.0664	R: 0.0682	P: 0.0768
# [3/4][425/2225][Time 1.21]
# Unified LR across all optimizers: 0.0001442148543441721
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0663	Gen: 0.0716	Rec: 0.0711	E: 0.0668	R: 0.0658	P: 0.0764
# [3/4][475/2225][Time 1.24]
# Unified LR across all optimizers: 0.00014388316938334075
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0620	Gen: 0.0679	Rec: 0.0668	E: 0.0632	R: 0.0609	P: 0.0727
# [3/4][525/2225][Time 1.26]
# Unified LR across all optimizers: 0.0001435522472767503
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0668	Gen: 0.0718	Rec: 0.0713	E: 0.0673	R: 0.0663	P: 0.0763
# [3/4][575/2225][Time 1.25]
# Unified LR across all optimizers: 0.00014322208626988471
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0668	Gen: 0.0719	Rec: 0.0714	E: 0.0673	R: 0.0664	P: 0.0765
# [3/4][625/2225][Time 1.26]
# Unified LR across all optimizers: 0.00014289268461226322
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0655	Gen: 0.0700	Rec: 0.0706	E: 0.0649	R: 0.0661	P: 0.0751
# [3/4][675/2225][Time 1.28]
# Unified LR across all optimizers: 0.00014256404055743098
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0604	Gen: 0.0663	Rec: 0.0649	E: 0.0617	R: 0.0590	P: 0.0709
# [3/4][725/2225][Time 1.28]
# Unified LR across all optimizers: 0.00014223615236295
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0568	Gen: 0.0626	Rec: 0.0614	E: 0.0581	R: 0.0555	P: 0.0672
# [3/4][775/2225][Time 1.29]
# Unified LR across all optimizers: 0.0001419090182903897
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0608	Gen: 0.0660	Rec: 0.0656	E: 0.0612	R: 0.0604	P: 0.0708
# [3/4][825/2225][Time 1.26]
# Unified LR across all optimizers: 0.00014158263660531755
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0673	Gen: 0.0707	Rec: 0.0721	E: 0.0659	R: 0.0687	P: 0.0754
# [3/4][875/2225][Time 1.29]
# Unified LR across all optimizers: 0.00014125700557729063
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0637	Gen: 0.0687	Rec: 0.0686	E: 0.0638	R: 0.0636	P: 0.0736
# [3/4][925/2225][Time 1.29]
# Unified LR across all optimizers: 0.00014093212347984557
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0586	Gen: 0.0641	Rec: 0.0632	E: 0.0595	R: 0.0576	P: 0.0688
# [3/4][975/2225][Time 1.24]
# Unified LR across all optimizers: 0.00014060798859048983
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0577	Gen: 0.0633	Rec: 0.0623	E: 0.0587	R: 0.0567	P: 0.0679
# [3/4][1025/2225][Time 1.24]
# Unified LR across all optimizers: 0.00014028459919069257
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0567	Gen: 0.0623	Rec: 0.0613	E: 0.0577	R: 0.0557	P: 0.0669
# [3/4][1075/2225][Time 1.27]
# Unified LR across all optimizers: 0.00013996195356587524
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0636	Gen: 0.0696	Rec: 0.0679	E: 0.0653	R: 0.0620	P: 0.0738
# [3/4][1125/2225][Time 1.25]
# Unified LR across all optimizers: 0.0001396400500054029
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0609	Gen: 0.0658	Rec: 0.0659	E: 0.0608	R: 0.0611	P: 0.0707
# [3/4][1175/2225][Time 1.31]
# Unified LR across all optimizers: 0.00013931888680257493
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0620	Gen: 0.0675	Rec: 0.0666	E: 0.0629	R: 0.0611	P: 0.0720
# [3/4][1225/2225][Time 1.21]
# Unified LR across all optimizers: 0.000138998462254616
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0591	Gen: 0.0653	Rec: 0.0634	E: 0.0610	R: 0.0572	P: 0.0696
# [3/4][1275/2225][Time 1.24]
# Unified LR across all optimizers: 0.00013867877466266706
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0568	Gen: 0.0624	Rec: 0.0612	E: 0.0581	R: 0.0556	P: 0.0668
# [3/4][1325/2225][Time 1.24]
# Unified LR across all optimizers: 0.00013835982233177638
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0591	Gen: 0.0639	Rec: 0.0636	E: 0.0594	R: 0.0588	P: 0.0684
# [3/4][1375/2225][Time 1.23]
# Unified LR across all optimizers: 0.0001380416035708904
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0622	Gen: 0.0678	Rec: 0.0661	E: 0.0639	R: 0.0604	P: 0.0718
# [3/4][1425/2225][Time 1.22]
# Unified LR across all optimizers: 0.00013772411669284496
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0592	Gen: 0.0635	Rec: 0.0636	E: 0.0591	R: 0.0592	P: 0.0679
# [3/4][1475/2225][Time 1.27]
# Unified LR across all optimizers: 0.00013740736001435612
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0585	Gen: 0.0637	Rec: 0.0631	E: 0.0591	R: 0.0579	P: 0.0682
# [3/4][1525/2225][Time 1.36]
# Unified LR across all optimizers: 0.0001370913318560116
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0600	Gen: 0.0651	Rec: 0.0643	E: 0.0608	R: 0.0592	P: 0.0694
# [3/4][1575/2225][Time 1.38]
# Unified LR across all optimizers: 0.00013677603054226164
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0652	Gen: 0.0697	Rec: 0.0684	E: 0.0665	R: 0.0639	P: 0.0730
# [3/4][1625/2225][Time 1.38]
# Unified LR across all optimizers: 0.00013646145440140986
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0554	Gen: 0.0602	Rec: 0.0599	E: 0.0557	R: 0.0551	P: 0.0646
# [3/4][1675/2225][Time 1.31]
# Unified LR across all optimizers: 0.000136147601765605
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0567	Gen: 0.0624	Rec: 0.0608	E: 0.0583	R: 0.0551	P: 0.0665
# [3/4][1725/2225][Time 1.37]
# Unified LR across all optimizers: 0.00013583447097083163
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0576	Gen: 0.0619	Rec: 0.0618	E: 0.0577	R: 0.0575	P: 0.0661
# [3/4][1775/2225][Time 1.33]
# Unified LR across all optimizers: 0.00013552206035690145
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0564	Gen: 0.0610	Rec: 0.0607	E: 0.0567	R: 0.0561	P: 0.0653
# [3/4][1825/2225][Time 1.33]
# Unified LR across all optimizers: 0.00013521036826744445
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0563	Gen: 0.0611	Rec: 0.0607	E: 0.0567	R: 0.0560	P: 0.0655
# [3/4][1875/2225][Time 1.36]
# Unified LR across all optimizers: 0.00013489939304990025
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0550	Gen: 0.0602	Rec: 0.0593	E: 0.0558	R: 0.0542	P: 0.0645
# [3/4][1925/2225][Time 1.37]
# Unified LR across all optimizers: 0.00013458913305550914
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0538	Gen: 0.0591	Rec: 0.0578	E: 0.0551	R: 0.0526	P: 0.0631
# [3/4][1975/2225][Time 1.37]
# Unified LR across all optimizers: 0.00013427958663930363
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0550	Gen: 0.0605	Rec: 0.0597	E: 0.0558	R: 0.0543	P: 0.0652
# [3/4][2025/2225][Time 1.39]
# Unified LR across all optimizers: 0.00013397075216009928
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0606	Gen: 0.0659	Rec: 0.0642	E: 0.0623	R: 0.0589	P: 0.0695
# [3/4][2075/2225][Time 1.37]
# Unified LR across all optimizers: 0.00013366262798048648
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0542	Gen: 0.0589	Rec: 0.0584	E: 0.0547	R: 0.0537	P: 0.0631
# [3/4][2125/2225][Time 1.34]
# Unified LR across all optimizers: 0.00013335521246682152
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0542	Gen: 0.0596	Rec: 0.0580	E: 0.0558	R: 0.0526	P: 0.0634
# [3/4][2175/2225][Time 1.39]
# Unified LR across all optimizers: 0.00013304850398921782
# --------------------Training Metrics--------------------
# Trainer:  deepfm
# Inf: 0.0529	Gen: 0.0584	Rec: 0.0569	E: 0.0544	R: 0.0515	P: 0.0624

# %% [markdown]
# #### Data Loading and Synthetic Data Generation
#
# This section deals with loading the unlabelled dataset, processing it through the trained model to create synthetic data. This data augmentation step is crucial for models that benefit from larger datasets, such as in fraud detection scenarios.

# %%
import torch
from tools.loader import collate_fn

batch_size = 64
len_unlabelled_trainset = len(unlabelled_dataset)
unlabelled_train_loader = torch.utils.data.DataLoader(dataset=unlabelled_dataset, batch_size=batch_size, collate_fn=collate_fn, shuffle=False)

# Initialize the recreated dataset container
recreated_dataset = None

# Generate synthetic data through the model to augment the training dataset
with torch.no_grad():
    for data, _ in unlabelled_train_loader:
        data = data.to(device)
        # Generate a large amount of synthetic data
        batch_recreated_data = trainer_hub.encoder_ccnet.synthesize(data)

        # Filter out entries where the last feature is not in the range (0, 1)
        valid_entries = (batch_recreated_data[:, -1] >= 0) & (batch_recreated_data[:, -1] <= 1)
        batch_recreated_data = batch_recreated_data[valid_entries]

        # Check if any valid data remains after filtering; if none, skip this batch
        if batch_recreated_data.shape[0] == 0:
            continue
        
        # Sort the filtered data by the last feature (class label)
        sorted_batch = batch_recreated_data[torch.argsort(batch_recreated_data[:, -1])]

        # Select front half and rear half from the sorted batch
        # Since you want exactly batch_size items, take the first and last quarter
        select_size = batch_size // 2  # Selecting half of the batch size for each tail
        balanced_batch = torch.cat([sorted_batch[:select_size], sorted_batch[-select_size:]], dim=0)

        # Shuffle the selected batch
        indices = torch.randperm(len(balanced_batch))
        balanced_batch = balanced_batch[indices]

        # Concatenate the processed batch to the main dataset
        if recreated_dataset is None:
            recreated_dataset = balanced_batch
        else:
            recreated_dataset = torch.cat([recreated_dataset, balanced_batch], dim=0)
        
        # Ensure we do not exceed the original unlabelled dataset's size
        if len(recreated_dataset) >= len_unlabelled_trainset:
            recreated_dataset = recreated_dataset[:len_unlabelled_trainset]
            break

print(f"Recreated Dataset Shape: {recreated_dataset.shape}")
# Out:
# Recreated Dataset Shape: torch.Size([142403, 31])

# %% [markdown]
# #### Data Preparation for Model Training
#
# After synthetic data generation, this section separates the data and labels for training purposes, preparing them for use in machine learning models to ensure proper supervision and evaluation.

# %%
import torch

# Assuming recreated_dataset is a PyTorch tensor already available in your context

# Separate the recreated data into features and labels for training
recreated_training_data = recreated_dataset[:, :-1].clone().detach().cpu().numpy()  # Features from recreated data
recreated_labels = recreated_dataset[:, -1:].clone().detach().cpu().numpy()  # Labels from recreated data
ccnet_recreated_dataset = LabeledDataset(recreated_training_data, recreated_labels)

# Print the shapes of the datasets for verification
print(f"Labeled Original Trainset Shape: {len(supervised_trainset)}, {supervised_trainset.x.shape[1]}")
print(f"CCNet Recreated Dataset Shape: {len(ccnet_recreated_dataset)}, {ccnet_recreated_dataset.x.shape[1]}")

print(f"Labeled Original Testset Shape: {len(supervised_testset)}, {supervised_testset.x.shape[1]}")

# Retrieve number of features and classes from the recreated dataset
num_features = recreated_training_data.shape[1]
num_classes = recreated_labels.shape[1]

print(f"Number of Features: {num_features}")
print(f"Number of Classes: {num_classes}")
# Out:
# Labeled Original Trainset Shape: 142403, 30
# CCNet Recreated Dataset Shape: 142403, 30
# Labeled Original Testset Shape: 142404, 30
# Number of Features: 30
# Number of Classes: 1

# %%
class DNN(torch.nn.Module):
    def __init__(self, input_size, output_size, num_layers=4, hidden_size=256):
        super(DNN, self).__init__()
        self.input_size = input_size
        self.output_size = output_size
        self.hidden_size = hidden_size
        
        # Create a list to hold all layers
        layers = []
        
        # Input layer
        layers.append(torch.nn.Linear(input_size, hidden_size))
        layers.append(torch.nn.ReLU())
        
        # Hidden layers
        for _ in range(num_layers - 2):
            layers.append(torch.nn.Linear(hidden_size, hidden_size))
            layers.append(torch.nn.ReLU())
        
        # Output layer
        layers.append(torch.nn.Linear(hidden_size, output_size))
        
        # Register all layers
        self.layers = torch.nn.Sequential(*layers)

    def forward(self, x):
        x = self.layers(x)
        return torch.sigmoid(x)

# %% [markdown]
# #### Training Supervised Models
#
# This section outlines the process of training supervised learning models using both original and synthetic datasets. The `train_supervised_model` function is designed to iterate through the dataset, perform forward passes, compute loss, and update model weights using backpropagation.

# %%
def train_supervised_model(model, dataset):
    # Initialize the optimizer
    optimizer = torch.optim.Adam(model.parameters(), lr=0.0002)
    # Ensure reproducibility by resetting the random seed
    set_random_seed(0)
    # Create DataLoader for batch processing
    trainloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)
    
    # Training loop
    for epoch in range(4):  # Train for 2 epochs as an example
        for i, (data, label) in enumerate(trainloader):
            data = data.to(device)
            label = label.to(device)
            # Perform forward pass
            output = model(data)
            # Compute loss
            loss = torch.nn.functional.binary_cross_entropy(output, label)
            # Backward pass to compute gradients
            loss.backward()
            # Update weights
            optimizer.step()
            # Reset gradients
            optimizer.zero_grad()

# %% [markdown]
# #### Model Training Using Recreated and Original Datasets
#
# Models are trained using both datasets generated through the Data Augmentation process and the original dataset. This comparison helps to determine the effectiveness of the synthetic data in improving model performance.

# %%
# Initialize and train a model on the recreated dataset
model_trained_on_recreated = DNN(input_size=num_features, output_size=num_classes).to(device)
train_supervised_model(model_trained_on_recreated, ccnet_recreated_dataset)

# Initialize and train a model on the original dataset
model_trained_on_original = DNN(input_size=num_features, output_size=num_classes).to(device)
train_supervised_model(model_trained_on_original, supervised_trainset)

# %% [markdown]
# #### Evaluating Model Performance
#
# After training, the models are evaluated using the F1 score, a harmonic mean of precision and recall, which is particularly useful in the context of imbalanced datasets like fraud detection. This step is critical for assessing the quality of the models trained on different types of data.

# %%
from sklearn.metrics import f1_score

def get_f1_score(model, testset, batch_size=batch_size):
    model.eval()  # Set the model to evaluation mode
    y_true = []
    y_pred = []
    # DataLoader for testing
    test_loader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False)

    # No gradient computation needed during inference
    with torch.no_grad():
        for data, label in test_loader:
            data = data.to(device)
            label = label.to(device)
            output = model(data)
            # Process output for binary classification
            predicted = (output.squeeze() > 0.5).long()
            y_true.extend(label.squeeze().long().cpu().numpy())
            y_pred.extend(predicted.cpu().numpy())

    # Compute and return the F1 score
    score = f1_score(y_true, y_pred, average='binary')
    return score

# Calculate F1 scores for both models
f1_score_original = get_f1_score(model_trained_on_original, supervised_testset)
f1_score_recreated = get_f1_score(model_trained_on_recreated, supervised_testset)

# Output the results
print("F1 score of the supervised learning model trained on the original data: ", f1_score_original)
print("F1 score of the supervised learning model trained on the recreated data: ", f1_score_recreated)
# Out:
# F1 score of the supervised learning model trained on the original data:  0.7272727272727273
# F1 score of the supervised learning model trained on the recreated data:  0.8321513002364066
